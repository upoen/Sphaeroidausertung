# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)
    
# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X vorher: {X.shape}')
print(f'Form von Y vorher: {Y.shape}')

# Modell erstellen
model = Sequential([
    Conv2D(64, 3, activation='relu', padding='same', input_shape=(192, 256, 1)),
    Dropout(0.1),  # Dropout-Schicht hinzugefügt
    Conv2D(64, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(128, 3, activation='relu', padding='same'),
    Dropout(0.2),  # Dropout-Schicht hinzugefügt
    Conv2D(128, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(512, 3, activation='relu', padding='same'),
    Dropout(0.3),  # Dropout-Schicht hinzugefügt
    Conv2D(256, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(128, 3, activation='relu', padding='same'),
    Dropout(0.2),  # Dropout-Schicht hinzugefügt
    Conv2D(128, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(64, 3, activation='relu', padding='same'),
    Dropout(0.1),  # Dropout-Schicht hinzugefügt
    Conv2D(64, 3, activation='relu', padding='same'),
    Conv2D(1, (3, 3), activation='sigmoid', padding='same')
])

# Modellzusammenfassung anzeigen
model.summary()

# Adam-Optimizer mit spezifischer Lernrate erstellen
optimizer = Adam(learning_rate=0.001)

# Modell kompilieren mit dem Adam-Optimizer
model.compile(optimizer=optimizer, loss='binary_crossentropy')

# EarlyStopping-Callback hinzufügen
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Trainieren des Modells
history = model.fit(X, Y, batch_size= 8, epochs=1000, validation_split=0.01, callbacks=[early_stopping])

# Pfad zum Speichern des Modells im HDF5-Format
model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-01-.h5') 

# Überprüfen der Formen (optional)
print(f'Form von X nachher: {X.shape}')
print(f'Form von Y nachher: {Y.shape}')

def plot_training_history(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_training_history(history)
# Out:
# Form von X vorher: (600, 192, 256, 1)
# Form von Y vorher: (600, 192, 256, 1)
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_105 (Conv2D)             │ (None, 192, 256, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_50 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_106 (Conv2D)             │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_21 (MaxPooling2D) │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_107 (Conv2D)             │ (None, 96, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_51 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_108 (Conv2D)             │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_22 (MaxPooling2D) │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_109 (Conv2D)             │ (None, 48, 64, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_52 (Dropout)            │ (None, 48, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_110 (Conv2D)             │ (None, 48, 64, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_20 (UpSampling2D) │ (None, 96, 128, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_111 (Conv2D)             │ (None, 96, 128, 128)   │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_53 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_112 (Conv2D)             │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_21 (UpSampling2D) │ (None, 192, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_113 (Conv2D)             │ (None, 192, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_54 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_114 (Conv2D)             │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_115 (Conv2D)             │ (None, 192, 256, 1)    │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,583,169 (9.85 MB)
#  Trainable params: 2,583,169 (9.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 285s 4s/step - loss: 0.4470 - val_loss: 0.4398
# Epoch 2/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 273s 4s/step - loss: 0.3380 - val_loss: 0.2818
# Epoch 3/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 269s 4s/step - loss: 0.2643 - val_loss: 0.2738
# Epoch 4/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.2649 - val_loss: 0.2666
# Epoch 5/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 266s 4s/step - loss: 0.2371 - val_loss: 0.5229
# Epoch 6/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.2925 - val_loss: 0.3068
# Epoch 7/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 269s 4s/step - loss: 0.2440 - val_loss: 0.3963
# Epoch 8/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.1962 - val_loss: 0.4001
# Epoch 9/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 264s 4s/step - loss: 0.1445 - val_loss: 0.3540
# Epoch 10/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 264s 4s/step - loss: 0.1294 - val_loss: 0.4565
# Epoch 11/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 265s 4s/step - loss: 0.1033 - val_loss: 0.4137
# Epoch 12/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 282s 4s/step - loss: 0.1072 - val_loss: 0.4345
# Epoch 13/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 293s 4s/step - loss: 0.1214 - val_loss: 0.4382
# Epoch 14/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 264s 4s/step - loss: 0.1042 - val_loss: 0.4164
# Epoch 15/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 266s 4s/step - loss: 0.0914 - val_loss: 0.4753
# Epoch 16/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 250s 3s/step - loss: 0.0870 - val_loss: 0.4772
# Epoch 17/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 246s 3s/step - loss: 0.0873 - val_loss: 0.5392
# Epoch 18/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 263s 4s/step - loss: 0.0835 - val_loss: 0.6410
# Epoch 19/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 263s 4s/step - loss: 0.0879 - val_loss: 0.3953
# Epoch 20/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 263s 3s/step - loss: 0.0735 - val_loss: 0.4762
# Epoch 21/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 265s 4s/step - loss: 0.0603 - val_loss: 0.4446
# Epoch 22/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 266s 4s/step - loss: 0.0718 - val_loss: 0.2597
# Epoch 23/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 265s 4s/step - loss: 0.0831 - val_loss: 0.4912
# Epoch 24/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 265s 4s/step - loss: 0.0626 - val_loss: 0.5040
# Epoch 25/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 265s 4s/step - loss: 0.0520 - val_loss: 0.4037
# Epoch 26/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 264s 4s/step - loss: 0.0653 - val_loss: 0.4142
# Epoch 27/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 264s 4s/step - loss: 0.0772 - val_loss: 0.4251
# Epoch 28/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 265s 4s/step - loss: 0.0590 - val_loss: 0.4339
# Epoch 29/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 265s 4s/step - loss: 0.0578 - val_loss: 0.3182
# Epoch 30/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 264s 4s/step - loss: 0.0596 - val_loss: 0.3396
# Epoch 31/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 262s 3s/step - loss: 0.0484 - val_loss: 0.4036
# Epoch 32/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 265s 4s/step - loss: 0.0515 - val_loss: 0.4447
# Epoch 33/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 263s 4s/step - loss: 0.0448 - val_loss: 0.6866
# Epoch 34/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 264s 4s/step - loss: 0.0463 - val_loss: 0.3792
# Epoch 35/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 263s 4s/step - loss: 0.0386 - val_loss: 0.3967
# Epoch 36/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 265s 4s/step - loss: 0.0410 - val_loss: 0.4402
# Epoch 37/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 266s 4s/step - loss: 0.0416 - val_loss: 0.3601
# Epoch 38/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 266s 4s/step - loss: 0.0492 - val_loss: 0.5725
# Epoch 39/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0555 - val_loss: 0.4821
# Epoch 40/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0421 - val_loss: 0.4287
# Epoch 41/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0429 - val_loss: 0.3597
# Epoch 42/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0402 - val_loss: 0.5826
# Epoch 43/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0387 - val_loss: 0.5369
# Epoch 44/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0400 - val_loss: 0.5202
# Epoch 45/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0291 - val_loss: 0.4588
# Epoch 46/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 266s 4s/step - loss: 0.0367 - val_loss: 0.4404
# Epoch 47/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 269s 4s/step - loss: 0.0313 - val_loss: 0.4104
# Epoch 48/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0344 - val_loss: 0.5236
# Epoch 49/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0310 - val_loss: 0.6231
# Epoch 50/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 274s 4s/step - loss: 0.0332 - val_loss: 0.4053
# Epoch 51/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0433 - val_loss: 0.3532
# Epoch 52/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0336 - val_loss: 0.4597
# Epoch 53/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0272 - val_loss: 0.6397
# Epoch 54/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 269s 4s/step - loss: 0.0293 - val_loss: 0.3821
# Epoch 55/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0278 - val_loss: 0.4498
# Epoch 56/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0289 - val_loss: 0.5257
# Epoch 57/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0243 - val_loss: 0.5937
# Epoch 58/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 269s 4s/step - loss: 0.0437 - val_loss: 0.4406
# Epoch 59/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0299 - val_loss: 0.4480
# Epoch 60/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 269s 4s/step - loss: 0.0310 - val_loss: 0.4417
# Epoch 61/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 269s 4s/step - loss: 0.0259 - val_loss: 0.6287
# Epoch 62/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0280 - val_loss: 0.5435
# Epoch 63/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0231 - val_loss: 0.5561
# Epoch 64/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0268 - val_loss: 0.6266
# Epoch 65/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 266s 4s/step - loss: 0.0246 - val_loss: 0.6790
# Epoch 66/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 269s 4s/step - loss: 0.0249 - val_loss: 0.6573
# Epoch 67/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 267s 4s/step - loss: 0.0313 - val_loss: 0.5865
# Epoch 68/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0266 - val_loss: 0.4748
# Epoch 69/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0241 - val_loss: 0.5852
# Epoch 70/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 269s 4s/step - loss: 0.0201 - val_loss: 0.6588
# Epoch 71/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0191 - val_loss: 0.5492
# Epoch 72/1000
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 268s 4s/step - loss: 0.0219 - val_loss: 0.6466
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Form von X nachher: (600, 192, 256, 1)
# Form von Y nachher: (600, 192, 256, 1)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)
    
# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X vorher: {X.shape}')
print(f'Form von Y vorher: {Y.shape}')

# Modell erstellen
model = Sequential([
    Conv2D(64, 3, activation='relu', padding='same', input_shape=(192, 256, 1)),
    BatchNormalization(),
    Dropout(0.2),
    Conv2D(64, 3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2), padding='same'),
    
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.3),
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2), padding='same'),
    
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.4),
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2), padding='same'),
    
    Conv2D(512, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.5),
    Conv2D(512, 3, activation='relu', padding='same'),
    BatchNormalization(),
    
    UpSampling2D((2, 2)),
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.4),
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    
    UpSampling2D((2, 2)),
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.3),
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    
    UpSampling2D((2, 2)),
    Conv2D(64, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.2),
    Conv2D(64, 3, activation='relu', padding='same'),
    BatchNormalization(),
    
    Conv2D(1, (3, 3), activation='sigmoid', padding='same')
])

# Modellzusammenfassung anzeigen
model.summary()

# Adam-Optimizer mit spezifischer Lernrate erstellen
optimizer = Adam(learning_rate=0.001)

# Modell kompilieren mit dem Adam-Optimizer
model.compile(optimizer=optimizer, loss='binary_crossentropy')

# EarlyStopping-Callback hinzufügen
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Trainieren des Modells
history = model.fit(X, Y, batch_size=16, epochs=1000, validation_split=0.1, callbacks=[early_stopping])

# Pfad zum Speichern des Modells im HDF5-Format
model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-0-.h5') 

# Überprüfen der Formen (optional)
print(f'Form von X nachher: {X.shape}')
print(f'Form von Y nachher: {Y.shape}')

def plot_training_history(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_training_history(history)
# Out:
# Form von X vorher: (600, 192, 256, 1)
# Form von Y vorher: (600, 192, 256, 1)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_70 (Conv2D)              │ (None, 192, 256, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_19          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_32 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_71 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_72 (Conv2D)              │ (None, 96, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_33 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_73 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_14 (MaxPooling2D) │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_74 (Conv2D)              │ (None, 48, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_34 (Dropout)            │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_75 (Conv2D)              │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_24          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_15 (MaxPooling2D) │ (None, 24, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_76 (Conv2D)              │ (None, 24, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_25          │ (None, 24, 32, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_35 (Dropout)            │ (None, 24, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_77 (Conv2D)              │ (None, 24, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_26          │ (None, 24, 32, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_13 (UpSampling2D) │ (None, 48, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_78 (Conv2D)              │ (None, 48, 64, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_27          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_36 (Dropout)            │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_79 (Conv2D)              │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_28          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_14 (UpSampling2D) │ (None, 96, 128, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_80 (Conv2D)              │ (None, 96, 128, 128)   │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_29          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_37 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_81 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_30          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_15 (UpSampling2D) │ (None, 192, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_82 (Conv2D)              │ (None, 192, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_31          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_38 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_83 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_32          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_84 (Conv2D)              │ (None, 192, 256, 1)    │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,019,393 (26.78 MB)
#  Trainable params: 7,013,761 (26.76 MB)
#  Non-trainable params: 5,632 (22.00 KB)
# Epoch 1/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 421s 12s/step - loss: 0.5208 - val_loss: 85.4840
# Epoch 2/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 407s 12s/step - loss: 0.1826 - val_loss: 9.0028
# Epoch 3/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 433s 13s/step - loss: 0.1339 - val_loss: 11.3691
# Epoch 4/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 407s 12s/step - loss: 0.1021 - val_loss: 0.6320
# Epoch 5/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 405s 12s/step - loss: 0.0923 - val_loss: 0.8380
# Epoch 6/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 407s 12s/step - loss: 0.0632 - val_loss: 0.9401
# Epoch 7/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 409s 12s/step - loss: 0.0666 - val_loss: 9.0964
# Epoch 8/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 428s 13s/step - loss: 0.0659 - val_loss: 1.0760
# Epoch 9/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 421s 12s/step - loss: 0.0883 - val_loss: 0.4813
# Epoch 10/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 408s 12s/step - loss: 0.0789 - val_loss: 0.7548
# Epoch 11/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 411s 12s/step - loss: 0.0507 - val_loss: 0.8479
# Epoch 12/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0522 - val_loss: 0.6942
# Epoch 13/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0345 - val_loss: 0.9065
# Epoch 14/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 409s 12s/step - loss: 0.0594 - val_loss: 1.4350
# Epoch 15/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 409s 12s/step - loss: 0.0511 - val_loss: 2.4801
# Epoch 16/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 413s 12s/step - loss: 0.0427 - val_loss: 0.9835
# Epoch 17/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 411s 12s/step - loss: 0.0309 - val_loss: 1.1672
# Epoch 18/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 419s 12s/step - loss: 0.0321 - val_loss: 1.0474
# Epoch 19/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 412s 12s/step - loss: 0.0271 - val_loss: 1.2190
# Epoch 20/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 412s 12s/step - loss: 0.0271 - val_loss: 1.9525
# Epoch 21/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0232 - val_loss: 1.7425
# Epoch 22/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 413s 12s/step - loss: 0.0212 - val_loss: 1.3319
# Epoch 23/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 411s 12s/step - loss: 0.0215 - val_loss: 1.3001
# Epoch 24/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 408s 12s/step - loss: 0.0227 - val_loss: 1.5852
# Epoch 25/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 411s 12s/step - loss: 0.0196 - val_loss: 1.1359
# Epoch 26/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0218 - val_loss: 1.5637
# Epoch 27/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0188 - val_loss: 2.1946
# Epoch 28/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 409s 12s/step - loss: 0.0191 - val_loss: 1.6162
# Epoch 29/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 409s 12s/step - loss: 0.0220 - val_loss: 2.2764
# Epoch 30/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0208 - val_loss: 3.3046
# Epoch 31/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 412s 12s/step - loss: 0.0242 - val_loss: 1.4173
# Epoch 32/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 409s 12s/step - loss: 0.0199 - val_loss: 1.3346
# Epoch 33/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0186 - val_loss: 1.7440
# Epoch 34/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0181 - val_loss: 1.0961
# Epoch 35/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0180 - val_loss: 1.9892
# Epoch 36/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 412s 12s/step - loss: 0.0152 - val_loss: 1.8135
# Epoch 37/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0144 - val_loss: 1.0242
# Epoch 38/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0144 - val_loss: 1.4560
# Epoch 39/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 411s 12s/step - loss: 0.0139 - val_loss: 1.5266
# Epoch 40/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0135 - val_loss: 1.0082
# Epoch 41/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0134 - val_loss: 1.0728
# Epoch 42/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 410s 12s/step - loss: 0.0129 - val_loss: 1.0377
# Epoch 43/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 386s 11s/step - loss: 0.0135 - val_loss: 0.8117
# Epoch 44/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 380s 11s/step - loss: 0.0136 - val_loss: 1.0672
# Epoch 45/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 383s 11s/step - loss: 0.0139 - val_loss: 1.3204
# Epoch 46/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 383s 11s/step - loss: 0.0141 - val_loss: 1.2270
# Epoch 47/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 382s 11s/step - loss: 0.0166 - val_loss: 0.7593
# Epoch 48/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 379s 11s/step - loss: 0.0183 - val_loss: 10.9813
# Epoch 49/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 382s 11s/step - loss: 0.0235 - val_loss: 3.3109
# Epoch 50/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 383s 11s/step - loss: 0.0197 - val_loss: 7.8513
# Epoch 51/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 381s 11s/step - loss: 0.0237 - val_loss: 4.3674
# Epoch 52/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 384s 11s/step - loss: 0.0228 - val_loss: 2.4011
# Epoch 53/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 381s 11s/step - loss: 0.0161 - val_loss: 2.2157
# Epoch 54/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 382s 11s/step - loss: 0.0137 - val_loss: 1.8790
# Epoch 55/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 383s 11s/step - loss: 0.0136 - val_loss: 1.4606
# Epoch 56/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 383s 11s/step - loss: 0.0138 - val_loss: 1.8774
# Epoch 57/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 383s 11s/step - loss: 0.0133 - val_loss: 1.3876
# Epoch 58/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 381s 11s/step - loss: 0.0116 - val_loss: 1.0522
# Epoch 59/1000
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 383s 11s/step - loss: 0.0128 - val_loss: 1.0829
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Form von X nachher: (600, 192, 256, 1)
# Form von Y nachher: (600, 192, 256, 1)

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)
    
# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X vorher: {X.shape}')
print(f'Form von Y vorher: {Y.shape}')

# Modell erstellen
model = Sequential([
    Conv2D(64, 3, activation='relu', padding='same', input_shape=(192, 256, 1)),
    BatchNormalization(),
    Dropout(0.2),
    Conv2D(64, 3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2), padding='same'),
    
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.3),
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2), padding='same'),
    
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.4),
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2), padding='same'),
    
    Conv2D(512, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.5),
    Conv2D(512, 3, activation='relu', padding='same'),
    BatchNormalization(),
    
    UpSampling2D((2, 2)),
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.4),
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    
    UpSampling2D((2, 2)),
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.3),
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    
    UpSampling2D((2, 2)),
    Conv2D(64, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.2),
    Conv2D(64, 3, activation='relu', padding='same'),
    BatchNormalization(),
    
    Conv2D(1, (3, 3), activation='sigmoid', padding='same')
])

# Modellzusammenfassung anzeigen
model.summary()

# Adam-Optimizer mit spezifischer Lernrate erstellen
optimizer = Adam(learning_rate=0.001)

# Modell kompilieren mit dem Adam-Optimizer
model.compile(optimizer=optimizer, loss='binary_crossentropy')

# EarlyStopping- und ReduceLROnPlateau-Callbacks hinzufügen
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=1e-6)

# Trainieren des Modells
history = model.fit(X, Y, batch_size=16, epochs=1000, validation_split=0.01, callbacks=[early_stopping, reduce_lr])

# Pfad zum Speichern des Modells im HDF5-Format
model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-03-.h5') 

# Überprüfen der Formen (optional)
print(f'Form von X nachher: {X.shape}')
print(f'Form von Y nachher: {Y.shape}')

def plot_training_history(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_training_history(history)
# Out:
# Form von X vorher: (600, 192, 256, 1)
# Form von Y vorher: (600, 192, 256, 1)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_85 (Conv2D)              │ (None, 192, 256, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_33          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_39 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_86 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_34          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_87 (Conv2D)              │ (None, 96, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_35          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_40 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_88 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_36          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_89 (Conv2D)              │ (None, 48, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_37          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_41 (Dropout)            │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_90 (Conv2D)              │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_38          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 24, 32, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_91 (Conv2D)              │ (None, 24, 32, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_39          │ (None, 24, 32, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_42 (Dropout)            │ (None, 24, 32, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_92 (Conv2D)              │ (None, 24, 32, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_40          │ (None, 24, 32, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_16 (UpSampling2D) │ (None, 48, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_93 (Conv2D)              │ (None, 48, 64, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_41          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_43 (Dropout)            │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_94 (Conv2D)              │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_42          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_17 (UpSampling2D) │ (None, 96, 128, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_95 (Conv2D)              │ (None, 96, 128, 128)   │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_43          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_44 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_96 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_44          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_18 (UpSampling2D) │ (None, 192, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_97 (Conv2D)              │ (None, 192, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_45 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_98 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_99 (Conv2D)              │ (None, 192, 256, 1)    │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,019,393 (26.78 MB)
#  Trainable params: 7,013,761 (26.76 MB)
#  Non-trainable params: 5,632 (22.00 KB)
# Epoch 1/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 430s 11s/step - loss: 0.6040 - val_loss: 1204.8850 - learning_rate: 0.0010
# Epoch 2/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.2715 - val_loss: 25.9384 - learning_rate: 0.0010
# Epoch 3/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 414s 11s/step - loss: 0.1701 - val_loss: 4.0510 - learning_rate: 0.0010
# Epoch 4/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.1241 - val_loss: 1.4940 - learning_rate: 0.0010
# Epoch 5/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.1388 - val_loss: 1.3275 - learning_rate: 0.0010
# Epoch 6/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 415s 11s/step - loss: 0.0981 - val_loss: 1.3956 - learning_rate: 0.0010
# Epoch 7/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 414s 11s/step - loss: 0.1134 - val_loss: 0.6119 - learning_rate: 0.0010
# Epoch 8/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 414s 11s/step - loss: 0.1324 - val_loss: 1.4782 - learning_rate: 0.0010
# Epoch 9/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0942 - val_loss: 1.3335 - learning_rate: 0.0010
# Epoch 10/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 412s 11s/step - loss: 0.0896 - val_loss: 1.0884 - learning_rate: 0.0010
# Epoch 11/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0631 - val_loss: 0.8784 - learning_rate: 0.0010
# Epoch 12/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 412s 11s/step - loss: 0.0677 - val_loss: 1.1838 - learning_rate: 0.0010
# Epoch 13/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 412s 11s/step - loss: 0.0889 - val_loss: 1.0574 - learning_rate: 0.0010
# Epoch 14/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0767 - val_loss: 0.8253 - learning_rate: 0.0010
# Epoch 15/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 412s 11s/step - loss: 0.0539 - val_loss: 0.5981 - learning_rate: 0.0010
# Epoch 16/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0593 - val_loss: 0.8924 - learning_rate: 0.0010
# Epoch 17/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 411s 11s/step - loss: 0.0500 - val_loss: 0.3823 - learning_rate: 0.0010
# Epoch 18/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0441 - val_loss: 0.3460 - learning_rate: 0.0010
# Epoch 19/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0445 - val_loss: 0.2882 - learning_rate: 0.0010
# Epoch 20/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0364 - val_loss: 0.3679 - learning_rate: 0.0010
# Epoch 21/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 412s 11s/step - loss: 0.0388 - val_loss: 0.2671 - learning_rate: 0.0010
# Epoch 22/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0513 - val_loss: 0.4807 - learning_rate: 0.0010
# Epoch 23/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0424 - val_loss: 0.4298 - learning_rate: 0.0010
# Epoch 24/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0419 - val_loss: 0.3045 - learning_rate: 0.0010
# Epoch 25/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 415s 11s/step - loss: 0.0284 - val_loss: 0.4840 - learning_rate: 0.0010
# Epoch 26/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0284 - val_loss: 0.2586 - learning_rate: 0.0010
# Epoch 27/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 413s 11s/step - loss: 0.0280 - val_loss: 0.3278 - learning_rate: 0.0010
# Epoch 28/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 412s 11s/step - loss: 0.0240 - val_loss: 0.2811 - learning_rate: 0.0010
# Epoch 29/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 414s 11s/step - loss: 0.0298 - val_loss: 0.3256 - learning_rate: 0.0010
# Epoch 30/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 412s 11s/step - loss: 0.0237 - val_loss: 0.3078 - learning_rate: 0.0010
# Epoch 31/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 414s 11s/step - loss: 0.0282 - val_loss: 0.3688 - learning_rate: 0.0010
# Epoch 32/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 437s 11s/step - loss: 0.0248 - val_loss: 0.4798 - learning_rate: 0.0010
# Epoch 33/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0234 - val_loss: 0.3645 - learning_rate: 0.0010
# Epoch 34/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 464s 12s/step - loss: 0.0263 - val_loss: 0.8139 - learning_rate: 0.0010
# Epoch 35/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 479s 13s/step - loss: 0.0196 - val_loss: 0.3563 - learning_rate: 0.0010
# Epoch 36/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 469s 12s/step - loss: 0.0195 - val_loss: 0.4021 - learning_rate: 0.0010
# Epoch 37/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 466s 12s/step - loss: 0.0319 - val_loss: 0.3638 - learning_rate: 5.0000e-04
# Epoch 38/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 464s 12s/step - loss: 0.0181 - val_loss: 0.4731 - learning_rate: 5.0000e-04
# Epoch 39/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 448s 12s/step - loss: 0.0181 - val_loss: 0.2934 - learning_rate: 5.0000e-04
# Epoch 40/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 452s 12s/step - loss: 0.0166 - val_loss: 0.2932 - learning_rate: 5.0000e-04
# Epoch 41/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 459s 12s/step - loss: 0.0171 - val_loss: 0.2921 - learning_rate: 5.0000e-04
# Epoch 42/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0181 - val_loss: 0.3965 - learning_rate: 5.0000e-04
# Epoch 43/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 455s 12s/step - loss: 0.0246 - val_loss: 0.5244 - learning_rate: 5.0000e-04
# Epoch 44/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0179 - val_loss: 0.3458 - learning_rate: 5.0000e-04
# Epoch 45/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 456s 12s/step - loss: 0.0168 - val_loss: 0.3815 - learning_rate: 5.0000e-04
# Epoch 46/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 456s 12s/step - loss: 0.0146 - val_loss: 0.3487 - learning_rate: 5.0000e-04
# Epoch 47/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 456s 12s/step - loss: 0.0135 - val_loss: 0.3162 - learning_rate: 2.5000e-04
# Epoch 48/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 458s 12s/step - loss: 0.0128 - val_loss: 0.3089 - learning_rate: 2.5000e-04
# Epoch 49/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0149 - val_loss: 0.3386 - learning_rate: 2.5000e-04
# Epoch 50/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0148 - val_loss: 0.3210 - learning_rate: 2.5000e-04
# Epoch 51/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 456s 12s/step - loss: 0.0142 - val_loss: 0.3085 - learning_rate: 2.5000e-04
# Epoch 52/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0137 - val_loss: 0.3109 - learning_rate: 2.5000e-04
# Epoch 53/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0134 - val_loss: 0.3052 - learning_rate: 2.5000e-04
# Epoch 54/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 459s 12s/step - loss: 0.0146 - val_loss: 0.3227 - learning_rate: 2.5000e-04
# Epoch 55/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 456s 12s/step - loss: 0.0136 - val_loss: 0.3280 - learning_rate: 2.5000e-04
# Epoch 56/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 456s 12s/step - loss: 0.0133 - val_loss: 0.3243 - learning_rate: 2.5000e-04
# Epoch 57/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 456s 12s/step - loss: 0.0147 - val_loss: 0.3275 - learning_rate: 1.2500e-04
# Epoch 58/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 458s 12s/step - loss: 0.0135 - val_loss: 0.3177 - learning_rate: 1.2500e-04
# Epoch 59/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0133 - val_loss: 0.3097 - learning_rate: 1.2500e-04
# Epoch 60/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0129 - val_loss: 0.3193 - learning_rate: 1.2500e-04
# Epoch 61/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 455s 12s/step - loss: 0.0134 - val_loss: 0.3378 - learning_rate: 1.2500e-04
# Epoch 62/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0130 - val_loss: 0.3423 - learning_rate: 1.2500e-04
# Epoch 63/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 456s 12s/step - loss: 0.0136 - val_loss: 0.3500 - learning_rate: 1.2500e-04
# Epoch 64/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 458s 12s/step - loss: 0.0128 - val_loss: 0.3179 - learning_rate: 1.2500e-04
# Epoch 65/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 458s 12s/step - loss: 0.0124 - val_loss: 0.3332 - learning_rate: 1.2500e-04
# Epoch 66/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0138 - val_loss: 0.3714 - learning_rate: 1.2500e-04
# Epoch 67/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 456s 12s/step - loss: 0.0145 - val_loss: 0.4022 - learning_rate: 6.2500e-05
# Epoch 68/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 458s 12s/step - loss: 0.0148 - val_loss: 0.3832 - learning_rate: 6.2500e-05
# Epoch 69/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0127 - val_loss: 0.3866 - learning_rate: 6.2500e-05
# Epoch 70/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 457s 12s/step - loss: 0.0165 - val_loss: 0.4315 - learning_rate: 6.2500e-05
# Epoch 71/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 455s 12s/step - loss: 0.0146 - val_loss: 0.4295 - learning_rate: 6.2500e-05
# Epoch 72/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 450s 12s/step - loss: 0.0128 - val_loss: 0.4159 - learning_rate: 6.2500e-05
# Epoch 73/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 449s 12s/step - loss: 0.0128 - val_loss: 0.4068 - learning_rate: 6.2500e-05
# Epoch 74/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 449s 12s/step - loss: 0.0124 - val_loss: 0.4001 - learning_rate: 6.2500e-05
# Epoch 75/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 448s 12s/step - loss: 0.0123 - val_loss: 0.4021 - learning_rate: 6.2500e-05
# Epoch 76/1000
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 450s 12s/step - loss: 0.0127 - val_loss: 0.3918 - learning_rate: 6.2500e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Form von X nachher: (600, 192, 256, 1)
# Form von Y nachher: (600, 192, 256, 1)

# %%
# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder angepasst/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken angepasst/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))  # Größe anpassen
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))  # Größe anpassen
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)
    
# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X vorher: {X.shape}')
print(f'Form von Y vorher: {Y.shape}')

# Definiere das Model für Keras Tuner
def build_model(hp):
    model = Sequential()
    
    # Erster Convolutional Block
    model.add(Conv2D(64, 3, activation='relu', padding='same', input_shape=(192, 256, 1)))
    model.add(BatchNormalization())
    model.add(Dropout(hp.Float('dropout_1', min_value=0.1, max_value=0.5, step=0.1)))
    
    # Dynamische Anzahl von Convolution-Blöcken mit Pooling
    num_blocks = hp.Int('conv_blocks', 2, 4)  # Verhindere zu tiefe Blöcke, die zu viel Pooling bewirken
    for i in range(num_blocks):
        model.add(Conv2D(64 * (2 ** i), 3, activation='relu', padding='same'))
        model.add(BatchNormalization())
        if i < num_blocks - 1:  # MaxPooling nur bis zur vorletzten Schicht
            model.add(MaxPooling2D((2, 2), padding='same'))  # Reduziert die Größe um die Hälfte
        model.add(Dropout(hp.Float(f'dropout_{i+2}', min_value=0.1, max_value=0.5, step=0.1)))
    
    # Upsampling-Schichten, um die Größe wiederherzustellen
    for i in range(num_blocks - 2, -1, -1):
        model.add(UpSampling2D((2, 2)))  # Verdoppelt die Größe, um die ursprüngliche Dimension wiederherzustellen
        model.add(Conv2D(64 * (2 ** i), 3, activation='relu', padding='same'))
        model.add(BatchNormalization())
        model.add(Dropout(hp.Float(f'dropout_{i+5}', min_value=0.1, max_value=0.5, step=0.1)))
    
    # Output-Schicht (keine zusätzliche UpSampling-Schicht am Ende)
    model.add(Conv2D(1, (3, 3), activation='sigmoid', padding='same'))  # Ausgabe hat die gleiche Größe wie Input
    
    # Modell kompilieren
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy')
    
    return model


# Definiere die Hyperparameter für die Batchgröße innerhalb des Tuners
def build_tuner(hp):
    return build_model(hp)

tuner = kt.Hyperband(
    build_tuner,
    objective='val_loss',
    max_epochs=50,
    factor=3,
    hyperband_iterations=2,
    directory='my_dir',
    project_name='spheroid_tuning'
)

# EarlyStopping- und ReduceLROnPlateau-Callbacks hinzufügen
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Führe die Hyperparameter-Suche durch (batch_size wird jetzt über Hyperparameter geregelt)
tuner.search(X, Y, validation_split=0.15, callbacks=[early_stopping, reduce_lr], batch_size=16)

# Beste Hyperparameter und Modell anzeigen
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Beste Anzahl Convolution-Blöcke: {best_hps.get('conv_blocks')}")
print(f"Beste Dropout-Werte: {[best_hps.get(f'dropout_{i+1}') for i in range(best_hps.get('conv_blocks'))]}")
print(f"Beste Batch-Größe: {best_hps.get('batch_size')}")

# Bestes Modell trainieren
model = tuner.hypermodel.build(best_hps)
history = model.fit(X, Y, batch_size=best_hps.get('batch_size'), epochs=500, validation_split=0.15, callbacks=[early_stopping, reduce_lr])

# Modell speichern
model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-04-.h5')

# Plot der Training History
def plot_training_history(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_training_history(history)
# Out:
# Trial 56 Complete [00h 51m 47s]
# val_loss: 0.352993369102478
#
# Best val_loss So Far: 0.2850687801837921
# Total elapsed time: 18h 14m 57s
#
# Search: Running Trial #57
#
# Value             |Best Value So Far |Hyperparameter
# 0.1               |0.2               |dropout_1
# 4                 |5                 |conv_blocks
# 0.3               |0.5               |dropout_2
# 0.5               |0.2               |dropout_3
# 0.3               |0.2               |dropout_6
# 0.5               |0.1               |dropout_4
# 0.3               |0.4               |dropout_5
# 0.2               |0.3               |dropout_8
# 0.1               |0.3               |dropout_7
# 0.3               |0.3               |dropout_9
# 17                |6                 |tuner/epochs
# 0                 |0                 |tuner/initial_epoch
# 1                 |2                 |tuner/bracket
# 0                 |0                 |tuner/round
#
# Epoch 1/17
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 263s 8s/step - loss: 0.5464 - val_loss: 8.3184 - learning_rate: 0.0010
# Epoch 2/17
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 259s 8s/step - loss: 0.2072 - val_loss: 18.2551 - learning_rate: 0.0010
# Epoch 3/17
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 252s 7s/step - loss: 0.1556 - val_loss: 7.9924 - learning_rate: 0.0010
# Epoch 4/17
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 252s 7s/step - loss: 0.1160 - val_loss: 1.1945 - learning_rate: 0.0010
# Epoch 5/17
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 254s 7s/step - loss: 0.1040 - val_loss: 0.7437 - learning_rate: 0.0010
# Epoch 6/17
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 255s 7s/step - loss: 0.0801 - val_loss: 0.9127 - learning_rate: 0.0010
# Epoch 7/17
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 252s 7s/step - loss: 0.0770 - val_loss: 0.9535 - learning_rate: 0.0010
# Epoch 8/17
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 253s 7s/step - loss: 0.0727 - val_loss: 0.6866 - learning_rate: 0.0010
# Epoch 9/17
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 254s 7s/step - loss: 0.0854 - val_loss: 0.7089 - learning_rate: 0.0010
# Epoch 10/17
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 253s 7s/step - loss: 0.0643 - val_loss: 0.6255 - learning_rate: 0.0010
# Epoch 11/17
# 23/34 ━━━━━━━━━━━━━━━━━━━━ 1:21 7s/step - loss: 0.0602
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 98
#      95 reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
#      97 # Führe die Hyperparameter-Suche durch (batch_size wird jetzt über Hyperparameter geregelt)
# ---> 98 tuner.search(X, Y, validation_split=0.1, callbacks=[early_stopping, reduce_lr], batch_size=16)
#     100 # Beste Hyperparameter und Modell anzeigen
#     101 best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras_tuner\src\tuners\hyperband.py:427, in Hyperband.run_trial(self, trial, *fit_args, **fit_kwargs)
#     425     fit_kwargs["epochs"] = hp.values["tuner/epochs"]
#     426     fit_kwargs["initial_epoch"] = hp.values["tuner/initial_epoch"]
# --> 427 return super().run_trial(trial, *fit_args, **fit_kwargs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras_tuner\src\engine\tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras_tuner\src\engine\tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras_tuner\src\engine\hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder angepasst/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken angepasst/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)
    
# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X vorher: {X.shape}')
print(f'Form von Y vorher: {Y.shape}')

# Modell erstellen
model = Sequential([
    Conv2D(64, 3, activation='relu', padding='same', input_shape=(192, 256, 1)),
    Dropout(0.1),  # Dropout-Schicht hinzugefügt
    Conv2D(64, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(128, 3, activation='relu', padding='same'),
    Dropout(0.2),  # Dropout-Schicht hinzugefügt
    Conv2D(128, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(512, 3, activation='relu', padding='same'),
    Dropout(0.3),  # Dropout-Schicht hinzugefügt
    Conv2D(256, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(128, 3, activation='relu', padding='same'),
    Dropout(0.2),  # Dropout-Schicht hinzugefügt
    Conv2D(128, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(64, 3, activation='relu', padding='same'),
    Dropout(0.1),  # Dropout-Schicht hinzugefügt
    Conv2D(64, 3, activation='relu', padding='same'),
    Conv2D(1, (3, 3), activation='sigmoid', padding='same')
])

# Modellzusammenfassung anzeigen
model.summary()

# Adam-Optimizer mit spezifischer Lernrate erstellen
optimizer = Adam(learning_rate=0.0001)

# Modell kompilieren mit dem Adam-Optimizer
model.compile(optimizer=optimizer, loss='binary_crossentropy')

# EarlyStopping-Callback hinzufügen
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Trainieren des Modells
history = model.fit(X, Y, batch_size= 8, epochs=1000, validation_split=0.15, callbacks=[early_stopping])

# Pfad zum Speichern des Modells im HDF5-Format
model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-.h5') 

# Überprüfen der Formen (optional)
print(f'Form von X nachher: {X.shape}')
print(f'Form von Y nachher: {Y.shape}')

def plot_training_history(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_training_history(history)
# Out:
# Form von X vorher: (553, 192, 256, 1)
# Form von Y vorher: (553, 192, 256, 1)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_33 (Conv2D)              │ (None, 192, 256, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_34 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 96, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_16 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 48, 64, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_17 (Dropout)            │ (None, 48, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 48, 64, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_6 (UpSampling2D)  │ (None, 96, 128, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_39 (Conv2D)              │ (None, 96, 128, 128)   │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_18 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_40 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_7 (UpSampling2D)  │ (None, 192, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_41 (Conv2D)              │ (None, 192, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_19 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_42 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_43 (Conv2D)              │ (None, 192, 256, 1)    │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,583,169 (9.85 MB)
#  Trainable params: 2,583,169 (9.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 225s 4s/step - loss: 0.5439 - val_loss: 0.3691
# Epoch 2/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 217s 4s/step - loss: 0.3962 - val_loss: 0.3141
# Epoch 3/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 227s 4s/step - loss: 0.3598 - val_loss: 0.3062
# Epoch 4/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 223s 4s/step - loss: 0.2539 - val_loss: 0.5207
# Epoch 5/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 224s 4s/step - loss: 0.1882 - val_loss: 0.4258
# Epoch 6/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 239s 4s/step - loss: 0.1283 - val_loss: 0.4635
# Epoch 7/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 271s 5s/step - loss: 0.1190 - val_loss: 0.4265
# Epoch 8/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 231s 4s/step - loss: 0.1098 - val_loss: 0.4247
# Epoch 9/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 224s 4s/step - loss: 0.1295 - val_loss: 0.4696
# Epoch 10/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 236s 4s/step - loss: 0.0959 - val_loss: 0.5746
# Epoch 11/1000
#  5/59 ━━━━━━━━━━━━━━━━━━━━ 3:23 4s/step - loss: 0.0906
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 92
#      89 early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
#      91 # Trainieren des Modells
# ---> 92 history = model.fit(X, Y, batch_size= 8, epochs=1000, validation_split=0.15, callbacks=[early_stopping])
#      94 # Pfad zum Speichern des Modells im HDF5-Format
#      95 model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-.h5')
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder angepasst/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken angepasst/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))  # Größe anpassen
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))  # Größe anpassen
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)

# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X vorher: {X.shape}')
print(f'Form von Y vorher: {Y.shape}')

# Dice Loss Funktion
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice

# Combo Loss Funktion (Binary Crossentropy + Dice Loss)
def combo_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    return bce + dice

# Dice Loss als Metrik
def dice_metric(y_true, y_pred):
    return dice_loss(y_true, y_pred)

# Modell erstellen
model = Sequential([
    Conv2D(64, 3, activation='relu', padding='same', input_shape=(192, 256, 1)),
    BatchNormalization(),
    Dropout(0.3),
    MaxPooling2D((2, 2), padding='same'),
    
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.4),
    MaxPooling2D((2, 2), padding='same'),

    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.5),
    UpSampling2D((2, 2)),

    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.4),
    UpSampling2D((2, 2)),

    Conv2D(64, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.3),
    
    Conv2D(1, (3, 3), activation='sigmoid', padding='same')
])


reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-6)

# Modellzusammenfassung anzeigen
model.summary()

# Adam-Optimizer erstellen
optimizer = Adam(learning_rate=0.00001)

# Modell kompilieren mit Combo Loss und Dice Loss als Metrik
model.compile(optimizer=optimizer, loss=combo_loss, metrics=[dice_metric])

# EarlyStopping-Callback hinzufügen
early_stopping = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

# Trainieren des Modells
history = model.fit(X, Y, batch_size=16, epochs=1000, validation_split=0.15, callbacks=[early_stopping, reduce_lr])

# Modell speichern
model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-combo_loss.h5')

# Plot der Training History
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Verlust
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Dice Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_metric'], label='Training Dice Loss')
    plt.plot(history.history['val_dice_metric'], label='Validation Dice Loss')
    plt.title('Training and Validation Dice Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Loss')
    plt.legend()

    plt.show()

plot_training_history(history)
# Out:
# Form von X vorher: (552, 192, 256, 1)
# Form von Y vorher: (552, 192, 256, 1)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_73 (Conv2D)              │ (None, 192, 256, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_47          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_26 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_74 (Conv2D)              │ (None, 96, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_48          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_27 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_75 (Conv2D)              │ (None, 48, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_49          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_28 (Dropout)            │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_11 (UpSampling2D) │ (None, 96, 128, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_76 (Conv2D)              │ (None, 96, 128, 128)   │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_50          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_29 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_12 (UpSampling2D) │ (None, 192, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_77 (Conv2D)              │ (None, 192, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_51          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_30 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_78 (Conv2D)              │ (None, 192, 256, 1)    │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 741,633 (2.83 MB)
#  Trainable params: 740,353 (2.82 MB)
#  Non-trainable params: 1,280 (5.00 KB)
# Epoch 1/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 155s 5s/step - dice_metric: 0.6811 - loss: 1.5240 - val_dice_metric: 0.7839 - val_loss: 1.3689 - learning_rate: 1.0000e-05
# Epoch 2/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.5543 - loss: 1.1849 - val_dice_metric: 0.8181 - val_loss: 1.2798 - learning_rate: 1.0000e-05
# Epoch 3/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.5090 - loss: 1.0642 - val_dice_metric: 0.8412 - val_loss: 1.2758 - learning_rate: 1.0000e-05
# Epoch 4/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 153s 5s/step - dice_metric: 0.4810 - loss: 0.9942 - val_dice_metric: 0.8568 - val_loss: 1.2851 - learning_rate: 1.0000e-05
# Epoch 5/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.4559 - loss: 0.9099 - val_dice_metric: 0.8654 - val_loss: 1.2942 - learning_rate: 1.0000e-05
# Epoch 6/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 155s 5s/step - dice_metric: 0.4404 - loss: 0.8681 - val_dice_metric: 0.8723 - val_loss: 1.2996 - learning_rate: 1.0000e-05
# Epoch 7/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 154s 5s/step - dice_metric: 0.4234 - loss: 0.8347 - val_dice_metric: 0.8788 - val_loss: 1.3088 - learning_rate: 1.0000e-05
# Epoch 8/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 156s 5s/step - dice_metric: 0.4151 - loss: 0.8030 - val_dice_metric: 0.8844 - val_loss: 1.3196 - learning_rate: 1.0000e-05
# Epoch 9/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3945 - loss: 0.7728 - val_dice_metric: 0.8874 - val_loss: 1.3272 - learning_rate: 1.0000e-05
# Epoch 10/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 151s 5s/step - dice_metric: 0.3709 - loss: 0.7250 - val_dice_metric: 0.9006 - val_loss: 1.3538 - learning_rate: 1.0000e-05
# Epoch 11/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 151s 5s/step - dice_metric: 0.3845 - loss: 0.7590 - val_dice_metric: 0.9038 - val_loss: 1.3621 - learning_rate: 1.0000e-05
# Epoch 12/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3680 - loss: 0.7208 - val_dice_metric: 0.9161 - val_loss: 1.3960 - learning_rate: 1.0000e-05
# Epoch 13/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3520 - loss: 0.7049 - val_dice_metric: 0.9178 - val_loss: 1.4119 - learning_rate: 1.0000e-05
# Epoch 14/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3419 - loss: 0.6634 - val_dice_metric: 0.9190 - val_loss: 1.4257 - learning_rate: 1.0000e-06
# Epoch 15/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3377 - loss: 0.6510 - val_dice_metric: 0.9177 - val_loss: 1.4355 - learning_rate: 1.0000e-06
# Epoch 16/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 151s 5s/step - dice_metric: 0.3376 - loss: 0.6466 - val_dice_metric: 0.9146 - val_loss: 1.4427 - learning_rate: 1.0000e-06
# Epoch 17/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 151s 5s/step - dice_metric: 0.3447 - loss: 0.6964 - val_dice_metric: 0.9089 - val_loss: 1.4443 - learning_rate: 1.0000e-06
# Epoch 18/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3361 - loss: 0.6499 - val_dice_metric: 0.9008 - val_loss: 1.4391 - learning_rate: 1.0000e-06
# Epoch 19/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3183 - loss: 0.6113 - val_dice_metric: 0.8885 - val_loss: 1.4213 - learning_rate: 1.0000e-06
# Epoch 20/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 153s 5s/step - dice_metric: 0.3335 - loss: 0.6463 - val_dice_metric: 0.8733 - val_loss: 1.3976 - learning_rate: 1.0000e-06
# Epoch 21/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 153s 5s/step - dice_metric: 0.3389 - loss: 0.6675 - val_dice_metric: 0.8537 - val_loss: 1.3717 - learning_rate: 1.0000e-06
# Epoch 22/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 151s 5s/step - dice_metric: 0.3134 - loss: 0.5997 - val_dice_metric: 0.8257 - val_loss: 1.3461 - learning_rate: 1.0000e-06
# Epoch 23/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3256 - loss: 0.6285 - val_dice_metric: 0.7943 - val_loss: 1.3278 - learning_rate: 1.0000e-06
# Epoch 24/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 153s 5s/step - dice_metric: 0.3348 - loss: 0.6517 - val_dice_metric: 0.7638 - val_loss: 1.3139 - learning_rate: 1.0000e-06
# Epoch 25/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3426 - loss: 0.6817 - val_dice_metric: 0.7347 - val_loss: 1.3041 - learning_rate: 1.0000e-06
# Epoch 26/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3254 - loss: 0.6255 - val_dice_metric: 0.7056 - val_loss: 1.3023 - learning_rate: 1.0000e-06
# Epoch 27/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 150s 5s/step - dice_metric: 0.3264 - loss: 0.6298 - val_dice_metric: 0.6833 - val_loss: 1.3035 - learning_rate: 1.0000e-06
# Epoch 28/1000
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 152s 5s/step - dice_metric: 0.3208 - loss: 0.6104 - val_dice_metric: 0.6683 - val_loss: 1.3065 - learning_rate: 1.0000e-06
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder angepasst/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken angepasst/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))  # Größe anpassen
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))  # Größe anpassen
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)

# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X: {X.shape}')
print(f'Form von Y: {Y.shape}')

# Dice Loss Funktion
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice

# Focal Loss Funktion
def focal_loss(gamma=2., alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        alpha_tensor = tf.constant(alpha, dtype=tf.float32)  # Use a different variable name for alpha
        gamma_tensor = tf.constant(gamma, dtype=tf.float32)
        y_true = tf.cast(y_true, tf.float32)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha_tensor * tf.math.pow(1 - y_pred, gamma_tensor) * cross_entropy
        return tf.reduce_sum(loss, axis=-1)
    return focal_loss_fixed

# Combo Loss Funktion (Focal Loss + Binary Crossentropy + Dice Loss)
def combo_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    focal = focal_loss(gamma=2., alpha=0.25)(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    return 0.5*bce + 0.25*focal + 0.5* dice

# Dice Loss als Metrik
def dice_metric(y_true, y_pred):
    return dice_loss(y_true, y_pred)

def weighted_binary_crossentropy(y_true, y_pred, weight):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    weight_tensor = tf.where(tf.equal(y_true, 1), weight, 1.0)
    return tf.reduce_mean(bce * weight_tensor)

# Modell erstellen
model = Sequential([
    Conv2D(32, 3, activation='relu', padding='same', input_shape=(192, 256, 1)),
    BatchNormalization(),
    Dropout(0.2),
    Conv2D(32, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(64, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    
    Conv2D(64, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.3),
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(128, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.4),
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(128, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    
    Conv2D(128, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.3),
    Conv2D(256, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(64, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    
    Conv2D(64, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Dropout(0.2),
    Conv2D(32, 3, activation='relu', padding='same'),
    BatchNormalization(),
    Conv2D(32, 3, activation='relu', padding='same'),
    
    Conv2D(1, (3, 3), activation='sigmoid', padding='same')
])

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Modellzusammenfassung anzeigen
model.summary()

# Adam-Optimizer erstellen
optimizer = Adam(learning_rate=0.0001)

# Modell kompilieren mit Combo Loss und Dice Loss als Metrik
model.compile(optimizer=optimizer, loss=combo_loss, metrics=[dice_metric])

# Trainieren des Modells
history = model.fit(X, Y, batch_size=8, epochs=1000, validation_split=0.15, callbacks=[early_stopping, reduce_lr])

# Modell speichern
model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-combo_loss3.h5')  #combo loss ist gespeichert, graphen sahen aus wie bei zelle darüber

# Plot der Training History
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Verlust
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Dice Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_metric'], label='Training Dice Metric')
    plt.plot(history.history['val_dice_metric'], label='Validation Dice Metric')
    plt.title('Training and Validation Dice Metric')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Metric')
    plt.legend()

    plt.show()

plot_training_history(history)
# Out:
# Form von X: (552, 192, 256, 1)
# Form von Y: (552, 192, 256, 1)
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_282 (Conv2D)             │ (None, 192, 256, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_201         │ (None, 192, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_104 (Dropout)           │ (None, 192, 256, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_283 (Conv2D)             │ (None, 192, 256, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_202         │ (None, 192, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_284 (Conv2D)             │ (None, 192, 256, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_48 (MaxPooling2D) │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_285 (Conv2D)             │ (None, 96, 128, 64)    │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_203         │ (None, 96, 128, 64)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_105 (Dropout)           │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_286 (Conv2D)             │ (None, 96, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_204         │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_287 (Conv2D)             │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_49 (MaxPooling2D) │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_288 (Conv2D)             │ (None, 48, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_205         │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_106 (Dropout)           │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_289 (Conv2D)             │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_206         │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_290 (Conv2D)             │ (None, 48, 64, 128)    │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_34 (UpSampling2D) │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_291 (Conv2D)             │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_207         │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_107 (Dropout)           │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_292 (Conv2D)             │ (None, 96, 128, 256)   │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_208         │ (None, 96, 128, 256)   │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_293 (Conv2D)             │ (None, 96, 128, 64)    │       147,520 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_35 (UpSampling2D) │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_294 (Conv2D)             │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_209         │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_108 (Dropout)           │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_295 (Conv2D)             │ (None, 192, 256, 32)   │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_210         │ (None, 192, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_296 (Conv2D)             │ (None, 192, 256, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_297 (Conv2D)             │ (None, 192, 256, 1)    │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,126,913 (8.11 MB)
#  Trainable params: 2,124,417 (8.10 MB)
#  Non-trainable params: 2,496 (9.75 KB)
# Epoch 1/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 270s 4s/step - dice_metric: 0.5177 - loss: 0.2839 - val_dice_metric: 0.8998 - val_loss: 0.3457 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 259s 4s/step - dice_metric: 0.1963 - loss: 0.0825 - val_dice_metric: 0.9791 - val_loss: 0.4648 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 255s 4s/step - dice_metric: 0.1159 - loss: 0.0519 - val_dice_metric: 0.9913 - val_loss: 0.5226 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 240s 4s/step - dice_metric: 0.0887 - loss: 0.0424 - val_dice_metric: 0.9912 - val_loss: 0.5219 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 241s 4s/step - dice_metric: 0.0700 - loss: 0.0324 - val_dice_metric: 0.9935 - val_loss: 0.5415 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 239s 4s/step - dice_metric: 0.0588 - loss: 0.0282 - val_dice_metric: 0.9631 - val_loss: 0.5451 - learning_rate: 1.0000e-04
# Epoch 7/1000
#  6/59 ━━━━━━━━━━━━━━━━━━━━ 3:39 4s/step - dice_metric: 0.0620 - loss: 0.0262
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 151
#     148 model.compile(optimizer=optimizer, loss=combo_loss, metrics=[dice_metric])
#     150 # Trainieren des Modells
# --> 151 history = model.fit(X, Y, batch_size=8, epochs=1000, validation_split=0.15, callbacks=[early_stopping, reduce_lr])
#     153 # Modell speichern
#     154 model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-combo_loss3.h5')  #combo loss ist gespeichert, graphen sahen aus wie bei zelle darüber
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#mit cross validation

import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import KFold

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder angepasst/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken angepasst/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))  # Größe anpassen
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))  # Größe anpassen
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)

# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X: {X.shape}')
print(f'Form von Y: {Y.shape}')

# Dice Loss Funktion
def dice_loss(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice = (2. * intersection + smooth) / (union + smooth)
    return 1 - dice

# Focal Loss Funktion
def focal_loss(gamma=2., alpha=0.25):
    def focal_loss_fixed(y_true, y_pred):
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        alpha_tensor = tf.constant(alpha, dtype=tf.float32)
        gamma_tensor = tf.constant(gamma, dtype=tf.float32)
        y_true = tf.cast(y_true, tf.float32)
        cross_entropy = -y_true * tf.math.log(y_pred)
        loss = alpha_tensor * tf.math.pow(1 - y_pred, gamma_tensor) * cross_entropy
        return tf.reduce_sum(loss, axis=-1)
    return focal_loss_fixed

# Combo Loss Funktion (Focal Loss + Binary Crossentropy + Dice Loss)
def combo_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    focal = focal_loss(gamma=2., alpha=0.25)(y_true, y_pred)
    dice = dice_loss(y_true, y_pred)
    return 0.5 * bce + 0.1 * focal + 0.4 * dice

# Dice Loss als Metrik
def dice_metric(y_true, y_pred):
    return dice_loss(y_true, y_pred)

def create_model():
    model = Sequential([
        Conv2D(32, 3, activation='relu', padding='same', input_shape=(192, 256, 1)),
        BatchNormalization(),
        Dropout(0.2),
        Conv2D(32, 3, activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(64, 3, activation='relu', padding='same'),
        MaxPooling2D((2, 2), padding='same'),

        Conv2D(64, 3, activation='relu', padding='same'),
        BatchNormalization(),
        Dropout(0.3),
        Conv2D(128, 3, activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(128, 3, activation='relu', padding='same'),
        MaxPooling2D((2, 2), padding='same'),

        Conv2D(256, 3, activation='relu', padding='same'),
        BatchNormalization(),
        Dropout(0.4),
        Conv2D(256, 3, activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(128, 3, activation='relu', padding='same'),
        UpSampling2D((2, 2)),

        Conv2D(128, 3, activation='relu', padding='same'),
        BatchNormalization(),
        Dropout(0.3),
        Conv2D(256, 3, activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(64, 3, activation='relu', padding='same'),
        UpSampling2D((2, 2)),

        Conv2D(64, 3, activation='relu', padding='same'),
        BatchNormalization(),
        Dropout(0.2),
        Conv2D(32, 3, activation='relu', padding='same'),
        BatchNormalization(),
        Conv2D(32, 3, activation='relu', padding='same'),

        Conv2D(1, (3, 3), activation='sigmoid', padding='same')
    ])
    return model

# Cross-Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold_no = 1
best_params = {'learning_rate': 0.0001, 'batch_size': 8}

for train_index, val_index in kf.split(X):
    print(f"Training Fold {fold_no} / {kf.get_n_splits()}")
    X_train, X_val = X[train_index], X[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]

    # Modell erstellen
    model = create_model()

    # Callbacks
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, min_lr=1e-6)
    early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

    # Modell kompilieren
    model.compile(optimizer=Adam(learning_rate=best_params['learning_rate']), loss=combo_loss, metrics=[dice_metric])

    # Modell trainieren
    history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), batch_size=best_params['batch_size'], epochs=1000, callbacks=[early_stopping, reduce_lr])

    # Evaluierung auf Validierungsdaten
    val_loss, val_dice = model.evaluate(X_val, Y_val, verbose=0)
    print(f"Fold {fold_no} - Validation Loss: {val_loss:.4f}, Validation Dice Metric: {val_dice:.4f}")

    fold_no += 1

# Trainiere das finale Modell auf allen Daten mit den besten Parametern
final_model = create_model()
final_model.compile(optimizer=Adam(learning_rate=best_params['learning_rate']), loss=combo_loss, metrics=[dice_metric])

final_history = final_model.fit(X, Y, batch_size=best_params['batch_size'], epochs=1000, callbacks=[early_stopping, reduce_lr])

# Modell speichern
final_model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/final_spheroid_segmentation.h5')

# Plot der Training History
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Verlust
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Dice Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_metric'], label='Training Dice Metric')
    plt.plot(history.history['val_dice_metric'], label='Validation Dice Metric')
    plt.title('Training and Validation Dice Metric')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Metric')
    plt.legend()

    plt.show()

plot_training_history(final_history)
# Out:
# Form von X: (552, 192, 256, 1)
# Form von Y: (552, 192, 256, 1)
# Training Fold 1 / 5
# Epoch 1/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 254s 4s/step - dice_metric: 0.5041 - loss: 0.4060 - val_dice_metric: 0.9302 - val_loss: 0.6824 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 229s 4s/step - dice_metric: 0.1889 - loss: 0.1604 - val_dice_metric: 0.9913 - val_loss: 0.9062 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 231s 4s/step - dice_metric: 0.1463 - loss: 0.1287 - val_dice_metric: 0.9962 - val_loss: 0.9865 - learning_rate: 1.0000e-04
# Epoch 4/1000
#  4/56 ━━━━━━━━━━━━━━━━━━━━ 3:45 4s/step - dice_metric: 0.0996 - loss: 0.0855
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 157
#     154 model.compile(optimizer=Adam(learning_rate=best_params['learning_rate']), loss=combo_loss, metrics=[dice_metric])
#     156 # Modell trainieren
# --> 157 history = model.fit(X_train, Y_train, validation_data=(X_val, Y_val), batch_size=best_params['batch_size'], epochs=1000, callbacks=[early_stopping, reduce_lr])
#     159 # Evaluierung auf Validierungsdaten
#     160 val_loss, val_dice = model.evaluate(X_val, Y_val, verbose=0)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Unet modell mit reduziertem Datensatz, Cross validation 

import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import KFold

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder angepasst/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken angepasst/'

# Bild- und Maskenpfade laden
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Funktionen zum Laden und Vorverarbeiten
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))
    img = np.array(img)
    img = img / 255.0
    img = np.expand_dims(img, axis=-1)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))
    mask = np.array(mask)
    mask = np.where(mask > 128, 1, 0)
    mask = np.expand_dims(mask, axis=-1)
    return mask

# Daten laden
X = [load_and_preprocess_image_pillow(path) for path in image_paths]
Y = [load_and_preprocess_mask_pillow(path) for path in mask_paths]

X = np.array(X)
Y = np.array(Y)

print(f'Form von X: {X.shape}')
print(f'Form von Y: {Y.shape}')

# Dice Metric
def dice_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice

# Benutzerdefinierte Verlustfunktion
def combined_loss(y_true, y_pred, smooth=1e-6, binary_weight=0.5, dice_weight=0.5):
    # Binary Crossentropy
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    
    # Dice Loss
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice_loss = 1 - (2. * intersection + smooth) / (union + smooth)
    
    return binary_weight * bce + dice_weight * dice_loss

# U-Net Modell
def unet_model(input_size=(192, 256, 1)):
    inputs = Input(input_size)

    # Encoder (Downsampling Path)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(0.3)(pool1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(0.4)(pool2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)

    # Bottleneck
    bottleneck = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    bottleneck = BatchNormalization()(bottleneck)

    # Decoder (Upsampling Path)
    up6 = UpSampling2D(size=(2, 2))(bottleneck)
    up6 = Conv2D(256, 2, activation='relu', padding='same')(up6)
    up6 = BatchNormalization()(up6)
    merge6 = concatenate([conv3, up6], axis=3)

    conv6 = Conv2D(256, 3, activation='relu', padding='same')(merge6)
    conv6 = BatchNormalization()(conv6)

    up7 = UpSampling2D(size=(2, 2))(conv6)
    up7 = Conv2D(128, 2, activation='relu', padding='same')(up7)
    up7 = BatchNormalization()(up7)
    merge7 = concatenate([conv2, up7], axis=3)

    conv7 = Conv2D(128, 3, activation='relu', padding='same')(merge7)
    conv7 = BatchNormalization()(conv7)

    up8 = UpSampling2D(size=(2, 2))(conv7)
    up8 = Conv2D(64, 2, activation='relu', padding='same')(up8)
    up8 = BatchNormalization()(up8)
    merge8 = concatenate([conv1, up8], axis=3)

    conv8 = Conv2D(64, 3, activation='relu', padding='same')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(64, 3, activation='relu', padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)

    conv8 = Conv2D(1, 1, activation='sigmoid')(conv8)

    model = Model(inputs=inputs, outputs=conv8)
    return model

# Cross-Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold_no = 1
best_model = None
best_val_dice = -np.inf
best_fold = 0

for train_index, val_index in kf.split(X):
    print(f"Training Fold {fold_no} / {kf.get_n_splits()}")
    X_train, X_val = X[train_index], X[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]

    # Modell erstellen
    model = unet_model()

    # Callbacks
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Modell kompilieren
    optimizer = Adam(learning_rate=1e-4)
    model.compile(optimizer=optimizer, loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5), metrics=[dice_metric])

    # Modellzusammenfassung
    model.summary()

    # Training
    history = model.fit(X_train, Y_train, batch_size=8, epochs=1000, validation_data=(X_val, Y_val), callbacks=[early_stopping, reduce_lr])

    # Evaluation
    val_loss, val_dice = model.evaluate(X_val, Y_val, verbose=0)
    print(f"Fold {fold_no} - Validation Loss: {val_loss:.4f}, Validation Dice Metric: {val_dice:.4f}")

    # Check if this fold is the best one
    if val_dice > best_val_dice:
        best_val_dice = val_dice
        best_model = model
        best_fold = fold_no
        best_model.save(f'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_best_fold.h5')

    fold_no += 1

# Training History plotten für das beste Fold
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Verlust
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Dice Metric
    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_metric'], label='Training Dice Metric')
    plt.plot(history.history['val_dice_metric'], label='Validation Dice Metric')
    plt.title('Training and Validation Dice Metric')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Metric')
    plt.legend()

    plt.show()

# Plotting History for the best fold
plot_training_history(history)
# Out:
# Form von X: (552, 192, 256, 1)
# Form von Y: (552, 192, 256, 1)
# Training Fold 1 / 5
# Model: "functional_19"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_30      │ (None, 192, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_390 (Conv2D) │ (None, 192, 256,  │        640 │ input_layer_30[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_390[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_391 (Conv2D) │ (None, 192, 256,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_391[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_72    │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_143         │ (None, 96, 128,   │          0 │ max_pooling2d_72… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_392 (Conv2D) │ (None, 96, 128,   │     73,856 │ dropout_143[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_392[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_393 (Conv2D) │ (None, 96, 128,   │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_393[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_73    │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_144         │ (None, 48, 64,    │          0 │ max_pooling2d_73… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_394 (Conv2D) │ (None, 48, 64,    │    295,168 │ dropout_144[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_394[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_395 (Conv2D) │ (None, 48, 64,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_395[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_74    │ (None, 24, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_145         │ (None, 24, 32,    │          0 │ max_pooling2d_74… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_396 (Conv2D) │ (None, 24, 32,    │  1,180,160 │ dropout_145[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32,    │      2,048 │ conv2d_396[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_46    │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_397 (Conv2D) │ (None, 48, 64,    │    524,544 │ up_sampling2d_46… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_397[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_398 (Conv2D) │ (None, 48, 64,    │  1,179,904 │ concatenate_11[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_398[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_47    │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_399 (Conv2D) │ (None, 96, 128,   │    131,200 │ up_sampling2d_47… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_399[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_400 (Conv2D) │ (None, 96, 128,   │    295,040 │ concatenate_12[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_400[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_48    │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_401 (Conv2D) │ (None, 192, 256,  │     32,832 │ up_sampling2d_48… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_401[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_402 (Conv2D) │ (None, 192, 256,  │     73,792 │ concatenate_13[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_402[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_403 (Conv2D) │ (None, 192, 256,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_403[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_404 (Conv2D) │ (None, 192, 256,  │         65 │ batch_normalizat… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,608,193 (17.58 MB)
#  Trainable params: 4,603,457 (17.56 MB)
#  Non-trainable params: 4,736 (18.50 KB)
# Epoch 1/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 381s 7s/step - dice_metric: 0.5632 - loss: 0.4490 - val_dice_metric: 0.2064 - val_loss: 0.6418 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 379s 7s/step - dice_metric: 0.7856 - loss: 0.2181 - val_dice_metric: 0.1339 - val_loss: 0.6776 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 427s 8s/step - dice_metric: 0.8218 - loss: 0.1710 - val_dice_metric: 0.0714 - val_loss: 0.7593 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 447s 8s/step - dice_metric: 0.8582 - loss: 0.1462 - val_dice_metric: 0.0455 - val_loss: 0.8133 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 438s 8s/step - dice_metric: 0.8792 - loss: 0.1353 - val_dice_metric: 0.0303 - val_loss: 0.8577 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 459s 8s/step - dice_metric: 0.8877 - loss: 0.1133 - val_dice_metric: 0.0254 - val_loss: 0.8761 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 477s 9s/step - dice_metric: 0.9242 - loss: 0.0791 - val_dice_metric: 0.0850 - val_loss: 0.7802 - learning_rate: 5.0000e-05
# Epoch 8/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 457s 8s/step - dice_metric: 0.9153 - loss: 0.0791 - val_dice_metric: 0.0872 - val_loss: 0.8235 - learning_rate: 5.0000e-05
# Epoch 9/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 422s 8s/step - dice_metric: 0.9202 - loss: 0.0753 - val_dice_metric: 0.2156 - val_loss: 0.7058 - learning_rate: 5.0000e-05
# Epoch 10/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 429s 8s/step - dice_metric: 0.9343 - loss: 0.0651 - val_dice_metric: 0.6899 - val_loss: 0.2923 - learning_rate: 5.0000e-05
# Epoch 11/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 445s 8s/step - dice_metric: 0.9362 - loss: 0.0584 - val_dice_metric: 0.6904 - val_loss: 0.2841 - learning_rate: 5.0000e-05
# Epoch 12/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 446s 8s/step - dice_metric: 0.9465 - loss: 0.0475 - val_dice_metric: 0.8748 - val_loss: 0.1131 - learning_rate: 5.0000e-05
# Epoch 13/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 449s 8s/step - dice_metric: 0.9464 - loss: 0.0494 - val_dice_metric: 0.8600 - val_loss: 0.1229 - learning_rate: 5.0000e-05
# Epoch 14/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 447s 8s/step - dice_metric: 0.9300 - loss: 0.0651 - val_dice_metric: 0.9171 - val_loss: 0.0832 - learning_rate: 5.0000e-05
# Epoch 15/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 372s 7s/step - dice_metric: 0.9462 - loss: 0.0534 - val_dice_metric: 0.9378 - val_loss: 0.0543 - learning_rate: 5.0000e-05
# Epoch 16/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 370s 7s/step - dice_metric: 0.9473 - loss: 0.0477 - val_dice_metric: 0.9403 - val_loss: 0.0539 - learning_rate: 5.0000e-05
# Epoch 17/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 359s 6s/step - dice_metric: 0.9530 - loss: 0.0422 - val_dice_metric: 0.9308 - val_loss: 0.0636 - learning_rate: 5.0000e-05
# Epoch 18/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 368s 7s/step - dice_metric: 0.9561 - loss: 0.0402 - val_dice_metric: 0.9280 - val_loss: 0.0694 - learning_rate: 5.0000e-05
# Epoch 19/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 360s 6s/step - dice_metric: 0.9515 - loss: 0.0455 - val_dice_metric: 0.9397 - val_loss: 0.0635 - learning_rate: 5.0000e-05
# Epoch 20/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 377s 7s/step - dice_metric: 0.9363 - loss: 0.0614 - val_dice_metric: 0.9380 - val_loss: 0.0612 - learning_rate: 5.0000e-05
# Epoch 21/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 394s 7s/step - dice_metric: 0.9633 - loss: 0.0330 - val_dice_metric: 0.9481 - val_loss: 0.0447 - learning_rate: 5.0000e-05
# Epoch 22/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 388s 7s/step - dice_metric: 0.9560 - loss: 0.0401 - val_dice_metric: 0.9356 - val_loss: 0.0691 - learning_rate: 5.0000e-05
# Epoch 23/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 383s 7s/step - dice_metric: 0.9590 - loss: 0.0386 - val_dice_metric: 0.9449 - val_loss: 0.0510 - learning_rate: 5.0000e-05
# Epoch 24/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 375s 7s/step - dice_metric: 0.9669 - loss: 0.0296 - val_dice_metric: 0.9474 - val_loss: 0.0527 - learning_rate: 5.0000e-05
# Epoch 25/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 367s 7s/step - dice_metric: 0.9623 - loss: 0.0352 - val_dice_metric: 0.9497 - val_loss: 0.0460 - learning_rate: 5.0000e-05
# Epoch 26/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 384s 7s/step - dice_metric: 0.9649 - loss: 0.0318 - val_dice_metric: 0.9425 - val_loss: 0.0662 - learning_rate: 5.0000e-05
# Epoch 27/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 373s 7s/step - dice_metric: 0.9659 - loss: 0.0309 - val_dice_metric: 0.9482 - val_loss: 0.0486 - learning_rate: 2.5000e-05
# Epoch 28/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 369s 7s/step - dice_metric: 0.9636 - loss: 0.0332 - val_dice_metric: 0.9580 - val_loss: 0.0379 - learning_rate: 2.5000e-05
# Epoch 29/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 375s 7s/step - dice_metric: 0.9681 - loss: 0.0284 - val_dice_metric: 0.9570 - val_loss: 0.0393 - learning_rate: 2.5000e-05
# Epoch 30/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 372s 7s/step - dice_metric: 0.9675 - loss: 0.0293 - val_dice_metric: 0.9581 - val_loss: 0.0376 - learning_rate: 2.5000e-05
# Epoch 31/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 381s 7s/step - dice_metric: 0.9717 - loss: 0.0256 - val_dice_metric: 0.9496 - val_loss: 0.0485 - learning_rate: 2.5000e-05
# Epoch 32/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 371s 7s/step - dice_metric: 0.9687 - loss: 0.0284 - val_dice_metric: 0.9470 - val_loss: 0.0527 - learning_rate: 2.5000e-05
# Epoch 33/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 386s 7s/step - dice_metric: 0.9684 - loss: 0.0311 - val_dice_metric: 0.9537 - val_loss: 0.0450 - learning_rate: 2.5000e-05
# Epoch 34/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 373s 7s/step - dice_metric: 0.9732 - loss: 0.0231 - val_dice_metric: 0.9520 - val_loss: 0.0443 - learning_rate: 2.5000e-05
# Epoch 35/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 370s 7s/step - dice_metric: 0.9716 - loss: 0.0250 - val_dice_metric: 0.9481 - val_loss: 0.0522 - learning_rate: 2.5000e-05
# Epoch 36/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 365s 7s/step - dice_metric: 0.9737 - loss: 0.0233 - val_dice_metric: 0.9540 - val_loss: 0.0434 - learning_rate: 1.2500e-05
# Epoch 37/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 364s 6s/step - dice_metric: 0.9730 - loss: 0.0237 - val_dice_metric: 0.9524 - val_loss: 0.0461 - learning_rate: 1.2500e-05
# Epoch 38/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 363s 6s/step - dice_metric: 0.9752 - loss: 0.0225 - val_dice_metric: 0.9569 - val_loss: 0.0403 - learning_rate: 1.2500e-05
# Epoch 39/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 364s 7s/step - dice_metric: 0.9752 - loss: 0.0219 - val_dice_metric: 0.9563 - val_loss: 0.0412 - learning_rate: 1.2500e-05
# Epoch 40/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 371s 7s/step - dice_metric: 0.9715 - loss: 0.0245 - val_dice_metric: 0.9573 - val_loss: 0.0410 - learning_rate: 1.2500e-05
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 1 - Validation Loss: 0.0348, Validation Dice Metric: 0.9560
# Training Fold 2 / 5
# Model: "functional_21"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_31      │ (None, 192, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_405 (Conv2D) │ (None, 192, 256,  │        640 │ input_layer_31[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_405[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_406 (Conv2D) │ (None, 192, 256,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_406[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_75    │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_146         │ (None, 96, 128,   │          0 │ max_pooling2d_75… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_407 (Conv2D) │ (None, 96, 128,   │     73,856 │ dropout_146[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_407[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_408 (Conv2D) │ (None, 96, 128,   │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_408[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_76    │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_147         │ (None, 48, 64,    │          0 │ max_pooling2d_76… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_409 (Conv2D) │ (None, 48, 64,    │    295,168 │ dropout_147[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_409[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_410 (Conv2D) │ (None, 48, 64,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_410[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_77    │ (None, 24, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_148         │ (None, 24, 32,    │          0 │ max_pooling2d_77… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_411 (Conv2D) │ (None, 24, 32,    │  1,180,160 │ dropout_148[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32,    │      2,048 │ conv2d_411[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_49    │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_412 (Conv2D) │ (None, 48, 64,    │    524,544 │ up_sampling2d_49… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_412[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_413 (Conv2D) │ (None, 48, 64,    │  1,179,904 │ concatenate_14[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_413[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_50    │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_414 (Conv2D) │ (None, 96, 128,   │    131,200 │ up_sampling2d_50… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_414[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_415 (Conv2D) │ (None, 96, 128,   │    295,040 │ concatenate_15[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_415[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_51    │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_416 (Conv2D) │ (None, 192, 256,  │     32,832 │ up_sampling2d_51… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_416[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_417 (Conv2D) │ (None, 192, 256,  │     73,792 │ concatenate_16[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_417[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_418 (Conv2D) │ (None, 192, 256,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_418[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_419 (Conv2D) │ (None, 192, 256,  │         65 │ batch_normalizat… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,608,193 (17.58 MB)
#  Trainable params: 4,603,457 (17.56 MB)
#  Non-trainable params: 4,736 (18.50 KB)
# Epoch 1/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 387s 7s/step - dice_metric: 0.5949 - loss: 0.4278 - val_dice_metric: 0.1998 - val_loss: 0.6428 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 375s 7s/step - dice_metric: 0.7734 - loss: 0.2506 - val_dice_metric: 0.1290 - val_loss: 0.6748 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 377s 7s/step - dice_metric: 0.8244 - loss: 0.1864 - val_dice_metric: 0.0827 - val_loss: 0.7305 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 367s 7s/step - dice_metric: 0.8103 - loss: 0.1902 - val_dice_metric: 0.0451 - val_loss: 0.8015 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.8622 - loss: 0.1346 - val_dice_metric: 0.0470 - val_loss: 0.7966 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 359s 6s/step - dice_metric: 0.8841 - loss: 0.1143 - val_dice_metric: 0.0218 - val_loss: 0.8765 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 360s 6s/step - dice_metric: 0.9113 - loss: 0.0817 - val_dice_metric: 0.0361 - val_loss: 0.8653 - learning_rate: 5.0000e-05
# Epoch 8/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 360s 6s/step - dice_metric: 0.9099 - loss: 0.0791 - val_dice_metric: 0.0685 - val_loss: 0.8512 - learning_rate: 5.0000e-05
# Epoch 9/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9287 - loss: 0.0635 - val_dice_metric: 0.2189 - val_loss: 0.7235 - learning_rate: 5.0000e-05
# Epoch 10/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 367s 7s/step - dice_metric: 0.9305 - loss: 0.0643 - val_dice_metric: 0.5025 - val_loss: 0.4704 - learning_rate: 5.0000e-05
# Epoch 11/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 366s 7s/step - dice_metric: 0.9323 - loss: 0.0667 - val_dice_metric: 0.6596 - val_loss: 0.3207 - learning_rate: 5.0000e-05
# Epoch 12/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 360s 6s/step - dice_metric: 0.9321 - loss: 0.0609 - val_dice_metric: 0.8304 - val_loss: 0.1526 - learning_rate: 5.0000e-05
# Epoch 13/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9404 - loss: 0.0572 - val_dice_metric: 0.8998 - val_loss: 0.0841 - learning_rate: 5.0000e-05
# Epoch 14/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 359s 6s/step - dice_metric: 0.9424 - loss: 0.0503 - val_dice_metric: 0.9250 - val_loss: 0.0773 - learning_rate: 5.0000e-05
# Epoch 15/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 360s 6s/step - dice_metric: 0.9379 - loss: 0.0606 - val_dice_metric: 0.9400 - val_loss: 0.0532 - learning_rate: 5.0000e-05
# Epoch 16/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 360s 6s/step - dice_metric: 0.9455 - loss: 0.0493 - val_dice_metric: 0.9443 - val_loss: 0.0539 - learning_rate: 5.0000e-05
# Epoch 17/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 377s 7s/step - dice_metric: 0.9548 - loss: 0.0417 - val_dice_metric: 0.9384 - val_loss: 0.0629 - learning_rate: 5.0000e-05
# Epoch 18/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 366s 7s/step - dice_metric: 0.9577 - loss: 0.0384 - val_dice_metric: 0.9385 - val_loss: 0.0658 - learning_rate: 5.0000e-05
# Epoch 19/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 376s 7s/step - dice_metric: 0.9546 - loss: 0.0429 - val_dice_metric: 0.9436 - val_loss: 0.0660 - learning_rate: 5.0000e-05
# Epoch 20/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 372s 7s/step - dice_metric: 0.9570 - loss: 0.0399 - val_dice_metric: 0.9438 - val_loss: 0.0593 - learning_rate: 5.0000e-05
# Epoch 21/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 370s 7s/step - dice_metric: 0.9662 - loss: 0.0302 - val_dice_metric: 0.9520 - val_loss: 0.0462 - learning_rate: 2.5000e-05
# Epoch 22/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 366s 7s/step - dice_metric: 0.9658 - loss: 0.0306 - val_dice_metric: 0.9531 - val_loss: 0.0436 - learning_rate: 2.5000e-05
# Epoch 23/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 359s 6s/step - dice_metric: 0.9647 - loss: 0.0309 - val_dice_metric: 0.9487 - val_loss: 0.0529 - learning_rate: 2.5000e-05
# Epoch 24/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9674 - loss: 0.0293 - val_dice_metric: 0.9500 - val_loss: 0.0514 - learning_rate: 2.5000e-05
# Epoch 25/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 373s 7s/step - dice_metric: 0.9672 - loss: 0.0288 - val_dice_metric: 0.9530 - val_loss: 0.0478 - learning_rate: 2.5000e-05
# Epoch 26/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 370s 7s/step - dice_metric: 0.9685 - loss: 0.0279 - val_dice_metric: 0.9564 - val_loss: 0.0420 - learning_rate: 2.5000e-05
# Epoch 27/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3441s 62s/step - dice_metric: 0.9624 - loss: 0.0335 - val_dice_metric: 0.9515 - val_loss: 0.0532 - learning_rate: 2.5000e-05
# Epoch 28/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 363s 6s/step - dice_metric: 0.9710 - loss: 0.0258 - val_dice_metric: 0.9526 - val_loss: 0.0482 - learning_rate: 2.5000e-05
# Epoch 29/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9672 - loss: 0.0285 - val_dice_metric: 0.9514 - val_loss: 0.0525 - learning_rate: 2.5000e-05
# Epoch 30/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 363s 6s/step - dice_metric: 0.9703 - loss: 0.0264 - val_dice_metric: 0.9488 - val_loss: 0.0571 - learning_rate: 2.5000e-05
# Epoch 31/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 363s 6s/step - dice_metric: 0.9710 - loss: 0.0258 - val_dice_metric: 0.9542 - val_loss: 0.0437 - learning_rate: 2.5000e-05
# Epoch 32/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 366s 7s/step - dice_metric: 0.9700 - loss: 0.0263 - val_dice_metric: 0.9554 - val_loss: 0.0452 - learning_rate: 1.2500e-05
# Epoch 33/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 366s 7s/step - dice_metric: 0.9732 - loss: 0.0240 - val_dice_metric: 0.9581 - val_loss: 0.0405 - learning_rate: 1.2500e-05
# Epoch 34/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 371s 7s/step - dice_metric: 0.9727 - loss: 0.0233 - val_dice_metric: 0.9569 - val_loss: 0.0422 - learning_rate: 1.2500e-05
# Epoch 35/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 365s 7s/step - dice_metric: 0.9698 - loss: 0.0261 - val_dice_metric: 0.9534 - val_loss: 0.0543 - learning_rate: 1.2500e-05
# Epoch 36/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 367s 7s/step - dice_metric: 0.9700 - loss: 0.0279 - val_dice_metric: 0.9545 - val_loss: 0.0487 - learning_rate: 1.2500e-05
# Epoch 37/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 588s 11s/step - dice_metric: 0.9727 - loss: 0.0243 - val_dice_metric: 0.9573 - val_loss: 0.0433 - learning_rate: 1.2500e-05
# Epoch 38/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 547s 10s/step - dice_metric: 0.9724 - loss: 0.0237 - val_dice_metric: 0.9549 - val_loss: 0.0502 - learning_rate: 1.2500e-05
# Epoch 39/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 547s 10s/step - dice_metric: 0.9742 - loss: 0.0225 - val_dice_metric: 0.9547 - val_loss: 0.0475 - learning_rate: 6.2500e-06
# Epoch 40/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 378s 7s/step - dice_metric: 0.9765 - loss: 0.0207 - val_dice_metric: 0.9561 - val_loss: 0.0475 - learning_rate: 6.2500e-06
# Epoch 41/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 373s 7s/step - dice_metric: 0.9737 - loss: 0.0230 - val_dice_metric: 0.9547 - val_loss: 0.0518 - learning_rate: 6.2500e-06
# Epoch 42/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 363s 6s/step - dice_metric: 0.9745 - loss: 0.0215 - val_dice_metric: 0.9554 - val_loss: 0.0496 - learning_rate: 6.2500e-06
# Epoch 43/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 364s 6s/step - dice_metric: 0.9749 - loss: 0.0224 - val_dice_metric: 0.9558 - val_loss: 0.0482 - learning_rate: 6.2500e-06
# Fold 2 - Validation Loss: 0.0393, Validation Dice Metric: 0.9500
# Training Fold 3 / 5
# Model: "functional_23"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_32      │ (None, 192, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_420 (Conv2D) │ (None, 192, 256,  │        640 │ input_layer_32[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_420[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_421 (Conv2D) │ (None, 192, 256,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_421[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_78    │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_149         │ (None, 96, 128,   │          0 │ max_pooling2d_78… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_422 (Conv2D) │ (None, 96, 128,   │     73,856 │ dropout_149[0][0] │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_422[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_423 (Conv2D) │ (None, 96, 128,   │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_423[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_79    │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_150         │ (None, 48, 64,    │          0 │ max_pooling2d_79… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_424 (Conv2D) │ (None, 48, 64,    │    295,168 │ dropout_150[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_424[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_425 (Conv2D) │ (None, 48, 64,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_425[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_80    │ (None, 24, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_151         │ (None, 24, 32,    │          0 │ max_pooling2d_80… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_426 (Conv2D) │ (None, 24, 32,    │  1,180,160 │ dropout_151[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32,    │      2,048 │ conv2d_426[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_52    │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_427 (Conv2D) │ (None, 48, 64,    │    524,544 │ up_sampling2d_52… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_427[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_17      │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_428 (Conv2D) │ (None, 48, 64,    │  1,179,904 │ concatenate_17[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_428[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_53    │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_429 (Conv2D) │ (None, 96, 128,   │    131,200 │ up_sampling2d_53… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_429[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_18      │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_430 (Conv2D) │ (None, 96, 128,   │    295,040 │ concatenate_18[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_430[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_54    │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_431 (Conv2D) │ (None, 192, 256,  │     32,832 │ up_sampling2d_54… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_431[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_19      │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_432 (Conv2D) │ (None, 192, 256,  │     73,792 │ concatenate_19[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_432[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_433 (Conv2D) │ (None, 192, 256,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_433[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_434 (Conv2D) │ (None, 192, 256,  │         65 │ batch_normalizat… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,608,193 (17.58 MB)
#  Trainable params: 4,603,457 (17.56 MB)
#  Non-trainable params: 4,736 (18.50 KB)
# Epoch 1/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 374s 6s/step - dice_metric: 0.5513 - loss: 0.4699 - val_dice_metric: 0.2209 - val_loss: 0.6496 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 365s 7s/step - dice_metric: 0.7553 - loss: 0.2644 - val_dice_metric: 0.1340 - val_loss: 0.7155 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 371s 7s/step - dice_metric: 0.8151 - loss: 0.1825 - val_dice_metric: 0.0984 - val_loss: 0.7632 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 370s 7s/step - dice_metric: 0.8346 - loss: 0.1580 - val_dice_metric: 0.0341 - val_loss: 0.9088 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 366s 7s/step - dice_metric: 0.8526 - loss: 0.1452 - val_dice_metric: 0.1480 - val_loss: 0.7006 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 364s 7s/step - dice_metric: 0.8641 - loss: 0.1294 - val_dice_metric: 0.0231 - val_loss: 0.9586 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 366s 7s/step - dice_metric: 0.9042 - loss: 0.0911 - val_dice_metric: 0.0496 - val_loss: 0.9109 - learning_rate: 5.0000e-05
# Epoch 8/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 372s 7s/step - dice_metric: 0.9136 - loss: 0.0793 - val_dice_metric: 0.1061 - val_loss: 0.8786 - learning_rate: 5.0000e-05
# Epoch 9/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 368s 7s/step - dice_metric: 0.9238 - loss: 0.0685 - val_dice_metric: 0.3439 - val_loss: 0.6287 - learning_rate: 5.0000e-05
# Epoch 10/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 366s 7s/step - dice_metric: 0.9318 - loss: 0.0647 - val_dice_metric: 0.4266 - val_loss: 0.5745 - learning_rate: 5.0000e-05
# Epoch 11/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 365s 7s/step - dice_metric: 0.9349 - loss: 0.0598 - val_dice_metric: 0.7852 - val_loss: 0.2174 - learning_rate: 5.0000e-05
# Epoch 12/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 366s 7s/step - dice_metric: 0.9379 - loss: 0.0560 - val_dice_metric: 0.8454 - val_loss: 0.1473 - learning_rate: 5.0000e-05
# Epoch 13/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9395 - loss: 0.0561 - val_dice_metric: 0.9498 - val_loss: 0.0447 - learning_rate: 5.0000e-05
# Epoch 14/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9500 - loss: 0.0453 - val_dice_metric: 0.9597 - val_loss: 0.0359 - learning_rate: 5.0000e-05
# Epoch 15/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 363s 6s/step - dice_metric: 0.9450 - loss: 0.0508 - val_dice_metric: 0.9625 - val_loss: 0.0353 - learning_rate: 5.0000e-05
# Epoch 16/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9575 - loss: 0.0385 - val_dice_metric: 0.9625 - val_loss: 0.0387 - learning_rate: 5.0000e-05
# Epoch 17/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 364s 7s/step - dice_metric: 0.9588 - loss: 0.0367 - val_dice_metric: 0.9633 - val_loss: 0.0360 - learning_rate: 5.0000e-05
# Epoch 18/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9494 - loss: 0.0472 - val_dice_metric: 0.9665 - val_loss: 0.0336 - learning_rate: 5.0000e-05
# Epoch 19/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9554 - loss: 0.0406 - val_dice_metric: 0.9687 - val_loss: 0.0312 - learning_rate: 5.0000e-05
# Epoch 20/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9566 - loss: 0.0388 - val_dice_metric: 0.9660 - val_loss: 0.0402 - learning_rate: 5.0000e-05
# Epoch 21/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 363s 6s/step - dice_metric: 0.9566 - loss: 0.0406 - val_dice_metric: 0.9384 - val_loss: 0.0680 - learning_rate: 5.0000e-05
# Epoch 22/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 365s 7s/step - dice_metric: 0.9477 - loss: 0.0509 - val_dice_metric: 0.9638 - val_loss: 0.0361 - learning_rate: 5.0000e-05
# Epoch 23/1000
# ...
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_452[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_453 (Conv2D) │ (None, 96, 128,   │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_453[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_85    │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_156         │ (None, 48, 64,    │          0 │ max_pooling2d_85… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_454 (Conv2D) │ (None, 48, 64,    │    295,168 │ dropout_156[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_454[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_455 (Conv2D) │ (None, 48, 64,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_455[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_86    │ (None, 24, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_157         │ (None, 24, 32,    │          0 │ max_pooling2d_86… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_456 (Conv2D) │ (None, 24, 32,    │  1,180,160 │ dropout_157[0][0] │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32,    │      2,048 │ conv2d_456[0][0]  │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_58    │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_457 (Conv2D) │ (None, 48, 64,    │    524,544 │ up_sampling2d_58… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_457[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_23      │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_458 (Conv2D) │ (None, 48, 64,    │  1,179,904 │ concatenate_23[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_458[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_59    │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_459 (Conv2D) │ (None, 96, 128,   │    131,200 │ up_sampling2d_59… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_459[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_24      │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_460 (Conv2D) │ (None, 96, 128,   │    295,040 │ concatenate_24[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_460[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_60    │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_461 (Conv2D) │ (None, 192, 256,  │     32,832 │ up_sampling2d_60… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_461[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_25      │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_462 (Conv2D) │ (None, 192, 256,  │     73,792 │ concatenate_25[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_462[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_463 (Conv2D) │ (None, 192, 256,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_463[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_464 (Conv2D) │ (None, 192, 256,  │         65 │ batch_normalizat… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,608,193 (17.58 MB)
#  Trainable params: 4,603,457 (17.56 MB)
#  Non-trainable params: 4,736 (18.50 KB)
# Epoch 1/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 364s 6s/step - dice_metric: 0.5681 - loss: 0.4610 - val_dice_metric: 0.2148 - val_loss: 0.6431 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 355s 6s/step - dice_metric: 0.7894 - loss: 0.2366 - val_dice_metric: 0.1367 - val_loss: 0.6825 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 356s 6s/step - dice_metric: 0.8126 - loss: 0.2015 - val_dice_metric: 0.0811 - val_loss: 0.7537 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.8536 - loss: 0.1447 - val_dice_metric: 0.0465 - val_loss: 0.8229 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 355s 6s/step - dice_metric: 0.8825 - loss: 0.1132 - val_dice_metric: 0.0372 - val_loss: 0.8482 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - dice_metric: 0.8975 - loss: 0.1026 - val_dice_metric: 0.0282 - val_loss: 0.9134 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - dice_metric: 0.9102 - loss: 0.0880 - val_dice_metric: 0.1857 - val_loss: 0.7094 - learning_rate: 5.0000e-05
# Epoch 8/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - dice_metric: 0.9145 - loss: 0.0768 - val_dice_metric: 0.0957 - val_loss: 0.8488 - learning_rate: 5.0000e-05
# Epoch 9/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9267 - loss: 0.0650 - val_dice_metric: 0.3521 - val_loss: 0.6151 - learning_rate: 5.0000e-05
# Epoch 10/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 359s 6s/step - dice_metric: 0.9328 - loss: 0.0599 - val_dice_metric: 0.4986 - val_loss: 0.4638 - learning_rate: 5.0000e-05
# Epoch 11/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 356s 6s/step - dice_metric: 0.9426 - loss: 0.0524 - val_dice_metric: 0.6881 - val_loss: 0.2900 - learning_rate: 5.0000e-05
# Epoch 12/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - dice_metric: 0.9448 - loss: 0.0499 - val_dice_metric: 0.7731 - val_loss: 0.2166 - learning_rate: 5.0000e-05
# Epoch 13/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 356s 6s/step - dice_metric: 0.9391 - loss: 0.0564 - val_dice_metric: 0.8962 - val_loss: 0.0991 - learning_rate: 5.0000e-05
# Epoch 14/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9385 - loss: 0.0541 - val_dice_metric: 0.9236 - val_loss: 0.0807 - learning_rate: 5.0000e-05
# Epoch 15/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 360s 6s/step - dice_metric: 0.9546 - loss: 0.0436 - val_dice_metric: 0.9175 - val_loss: 0.0761 - learning_rate: 5.0000e-05
# Epoch 16/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 365s 7s/step - dice_metric: 0.9512 - loss: 0.0433 - val_dice_metric: 0.9330 - val_loss: 0.0686 - learning_rate: 5.0000e-05
# Epoch 17/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 356s 6s/step - dice_metric: 0.9614 - loss: 0.0355 - val_dice_metric: 0.9348 - val_loss: 0.0683 - learning_rate: 5.0000e-05
# Epoch 18/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - dice_metric: 0.9571 - loss: 0.0428 - val_dice_metric: 0.9348 - val_loss: 0.0791 - learning_rate: 5.0000e-05
# Epoch 19/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 356s 6s/step - dice_metric: 0.9600 - loss: 0.0362 - val_dice_metric: 0.9367 - val_loss: 0.0653 - learning_rate: 5.0000e-05
# Epoch 20/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - dice_metric: 0.9635 - loss: 0.0325 - val_dice_metric: 0.9329 - val_loss: 0.0833 - learning_rate: 5.0000e-05
# Epoch 21/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9625 - loss: 0.0339 - val_dice_metric: 0.9359 - val_loss: 0.0814 - learning_rate: 5.0000e-05
# Epoch 22/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - dice_metric: 0.9645 - loss: 0.0328 - val_dice_metric: 0.9431 - val_loss: 0.0590 - learning_rate: 5.0000e-05
# Epoch 23/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - dice_metric: 0.9733 - loss: 0.0233 - val_dice_metric: 0.9261 - val_loss: 0.0846 - learning_rate: 5.0000e-05
# Epoch 24/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9605 - loss: 0.0369 - val_dice_metric: 0.9419 - val_loss: 0.0574 - learning_rate: 5.0000e-05
# Epoch 25/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9674 - loss: 0.0315 - val_dice_metric: 0.9483 - val_loss: 0.0563 - learning_rate: 5.0000e-05
# Epoch 26/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 356s 6s/step - dice_metric: 0.9696 - loss: 0.0275 - val_dice_metric: 0.9409 - val_loss: 0.0710 - learning_rate: 5.0000e-05
# Epoch 27/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9651 - loss: 0.0331 - val_dice_metric: 0.9351 - val_loss: 0.0694 - learning_rate: 5.0000e-05
# Epoch 28/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9744 - loss: 0.0231 - val_dice_metric: 0.9429 - val_loss: 0.0774 - learning_rate: 5.0000e-05
# Epoch 29/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9713 - loss: 0.0271 - val_dice_metric: 0.9458 - val_loss: 0.0612 - learning_rate: 5.0000e-05
# Epoch 30/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 356s 6s/step - dice_metric: 0.9708 - loss: 0.0269 - val_dice_metric: 0.9507 - val_loss: 0.0584 - learning_rate: 5.0000e-05
# Epoch 31/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 361s 6s/step - dice_metric: 0.9753 - loss: 0.0224 - val_dice_metric: 0.9531 - val_loss: 0.0544 - learning_rate: 2.5000e-05
# Epoch 32/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 364s 6s/step - dice_metric: 0.9745 - loss: 0.0233 - val_dice_metric: 0.9480 - val_loss: 0.0675 - learning_rate: 2.5000e-05
# Epoch 33/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9750 - loss: 0.0220 - val_dice_metric: 0.9472 - val_loss: 0.0650 - learning_rate: 2.5000e-05
# Epoch 34/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 356s 6s/step - dice_metric: 0.9765 - loss: 0.0207 - val_dice_metric: 0.9493 - val_loss: 0.0635 - learning_rate: 2.5000e-05
# Epoch 35/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 360s 6s/step - dice_metric: 0.9705 - loss: 0.0262 - val_dice_metric: 0.9491 - val_loss: 0.0613 - learning_rate: 2.5000e-05
# Epoch 36/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 363s 6s/step - dice_metric: 0.9760 - loss: 0.0216 - val_dice_metric: 0.9499 - val_loss: 0.0606 - learning_rate: 2.5000e-05
# Epoch 37/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 359s 6s/step - dice_metric: 0.9743 - loss: 0.0219 - val_dice_metric: 0.9482 - val_loss: 0.0661 - learning_rate: 1.2500e-05
# Epoch 38/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - dice_metric: 0.9797 - loss: 0.0182 - val_dice_metric: 0.9535 - val_loss: 0.0519 - learning_rate: 1.2500e-05
# Epoch 39/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9769 - loss: 0.0207 - val_dice_metric: 0.9501 - val_loss: 0.0615 - learning_rate: 1.2500e-05
# Epoch 40/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9787 - loss: 0.0188 - val_dice_metric: 0.9513 - val_loss: 0.0601 - learning_rate: 1.2500e-05
# Epoch 41/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9800 - loss: 0.0180 - val_dice_metric: 0.9521 - val_loss: 0.0609 - learning_rate: 1.2500e-05
# Epoch 42/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 359s 6s/step - dice_metric: 0.9782 - loss: 0.0189 - val_dice_metric: 0.9523 - val_loss: 0.0577 - learning_rate: 1.2500e-05
# Epoch 43/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9805 - loss: 0.0177 - val_dice_metric: 0.9533 - val_loss: 0.0555 - learning_rate: 1.2500e-05
# Epoch 44/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 362s 6s/step - dice_metric: 0.9806 - loss: 0.0170 - val_dice_metric: 0.9524 - val_loss: 0.0554 - learning_rate: 6.2500e-06
# Epoch 45/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 363s 6s/step - dice_metric: 0.9803 - loss: 0.0171 - val_dice_metric: 0.9532 - val_loss: 0.0552 - learning_rate: 6.2500e-06
# Epoch 46/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 358s 6s/step - dice_metric: 0.9777 - loss: 0.0196 - val_dice_metric: 0.9522 - val_loss: 0.0596 - learning_rate: 6.2500e-06
# Epoch 47/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 359s 6s/step - dice_metric: 0.9787 - loss: 0.0187 - val_dice_metric: 0.9516 - val_loss: 0.0595 - learning_rate: 6.2500e-06
# Epoch 48/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 357s 6s/step - dice_metric: 0.9811 - loss: 0.0173 - val_dice_metric: 0.9526 - val_loss: 0.0586 - learning_rate: 6.2500e-06
# Fold 5 - Validation Loss: 0.0469, Validation Dice Metric: 0.9509

# %%
def unet_model(input_size=(192, 256, 1)):
    inputs = Input(input_size)

    # Encoder (Downsampling-Pfad)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(0.3)(pool1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(0.4)(pool2)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)

    conv4 = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4)

    # Bottleneck
    bottleneck = Conv2D(1024, 3, activation='relu', padding='same')(drop4)
    bottleneck = BatchNormalization()(bottleneck)

    # Decoder (Upsampling-Pfad)
    up6 = UpSampling2D(size=(2, 2))(bottleneck)
    up6 = Conv2D(512, 2, activation='relu', padding='same')(up6)
    up6 = BatchNormalization()(up6)
    merge6 = concatenate([drop4, up6], axis=3)

    conv6 = Conv2D(512, 3, activation='relu', padding='same')(merge6)
    conv6 = BatchNormalization()(conv6)

    up7 = UpSampling2D(size=(2, 2))(conv6)
    up7 = Conv2D(256, 2, activation='relu', padding='same')(up7)
    up7 = BatchNormalization()(up7)
    merge7 = concatenate([conv3, up7], axis=3)

    conv7 = Conv2D(256, 3, activation='relu', padding='same')(merge7)
    conv7 = BatchNormalization()(conv7)

    up8 = UpSampling2D(size=(2, 2))(conv7)
    up8 = Conv2D(128, 2, activation='relu', padding='same')(up8)
    up8 = BatchNormalization()(up8)
    merge8 = concatenate([conv2, up8], axis=3)

    conv8 = Conv2D(128, 3, activation='relu', padding='same')(merge8)
    conv8 = BatchNormalization()(conv8)

    up9 = UpSampling2D(size=(2, 2))(conv8)
    up9 = Conv2D(64, 2, activation='relu', padding='same')(up9)
    up9 = BatchNormalization()(up9)
    merge9 = concatenate([conv1, up9], axis=3)

    conv9 = Conv2D(64, 3, activation='relu', padding='same')(merge9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)

    conv9 = Conv2D(1, 1, activation='sigmoid')(conv9)

    model = Model(inputs=inputs, outputs=conv9)
    return model

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

def draw_contours_and_centroid(binary_mask, output_path):
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
    cv2.imwrite(output_path, color_mask)

def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')
    img = img.resize((256, 192))
    img = np.array(img)
    img = img / 255.0
    img = np.expand_dims(img, axis=-1)
    return img

def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)
    predicted_mask = model.predict(image)
    return np.squeeze(predicted_mask)

def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0
    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size
            if score > best_score:
                best_score = score
                best_threshold = threshold
    return best_threshold

def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)

# Modellpfade
model_paths = [
    'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-01.h5',
    'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-0.h5',
    'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-03.h5',
    'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05.h5'
]

# Eingabepfade und Ausgabeverzeichnisse
input_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testset von julia/'
output_dirs = [
    'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder 2.0/1/',
    'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder 2.0/2',
    'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder 2.0/3/',
    'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder 2.0/4/'
]

excel_file_path = 'C:/Users/chris/Documents/Testset.xlsx'
df_manual = pd.read_excel(excel_file_path, header=0)
manual_diameters = df_manual.iloc[:, 1].tolist()

scale_factor_width = 1296 / 256
scale_factor_height = 966 / 192

tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Funktionen für die Modellverarbeitung
def process_model(model, model_index, output_dir):
    predicted_diameters = []
    manual_diameters = []
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        try:
            image = load_and_preprocess_image_pillow(img_path)
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            best_threshold = find_best_threshold(predicted_mask)
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            largest_contour = max(filtered_contours, key=cv2.contourArea)
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width) * 0.994
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.3745 * scale_factor_width * 0.3745 * scale_factor_height)
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            draw_contours_and_centroid(binary_mask, output_path)
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")
        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    excel_output_path = os.path.join(output_dir, f'Durchmesser_Liste_Variante_{model_index}.xlsx')
    df_results.to_excel(excel_output_path, index=False)

    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)
        print(f"\nMetriken zur Bewertung der Modellgenauigkeit für Modell {model_index}:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")
        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print(f"Keine ausreichenden Daten zur Berechnung der Metriken für Modell {model_index} vorhanden.")

# Modelle laden
models = [tf.keras.models.load_model(path) for path in model_paths]

# Modelle verarbeiten
for i, model in enumerate(models):
    process_model(model, i + 1, output_dirs[i])

# Optional: Scatterplots erstellen
fig, axes = plt.subplots(2, 2, figsize=(12, 12))

# Für alle Modelle einen Scatterplot erstellen
for i, (model, output_dir) in enumerate(zip(models, output_dirs), start=1):
    df_results = pd.read_excel(os.path.join(output_dir, f'Durchmesser_Liste_Variante_{i}.xlsx'))
    plt.subplot(2, 2, i)
    plt.scatter(df_results['Manuell gemessene Durchmesser (µm)'], df_results['Vorhergesagte Durchmesser (µm)'])
    plt.plot([min(df_results['Manuell gemessene Durchmesser (µm)']),
              max(df_results['Manuell gemessene Durchmesser (µm)'])],
             [min(df_results['Manuell gemessene Durchmesser (µm)']),
              max(df_results['Manuell gemessene Durchmesser (µm)'])],
             color='red', linestyle='--')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title(f'Variante {i}')
    plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 175
#     172         print(f"Keine ausreichenden Daten zur Berechnung der Metriken für Modell {model_index} vorhanden.")
#     174 # Modelle laden
# --> 175 models = [tf.keras.models.load_model(path) for path in model_paths]
#     177 # Modelle verarbeiten
#     178 for i, model in enumerate(models):
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\saving\saving_api.py:183, in load_model(filepath, custom_objects, compile, safe_mode)
#     176     return saving_lib.load_model(
#     177         filepath,
#     178         custom_objects=custom_objects,
#     179         compile=compile,
#     180         safe_mode=safe_mode,
#     181     )
#     182 if str(filepath).endswith((".h5", ".hdf5")):
# --> 183     return legacy_h5_format.load_model_from_hdf5(
#     184         filepath, custom_objects=custom_objects, compile=compile
#     185     )
#     186 elif str(filepath).endswith(".keras"):
#     187     raise ValueError(
#     188         f"File not found: filepath={filepath}. "
#     189         "Please ensure the file is an accessible `.keras` "
#     190         "zip file."
#     191     )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:116, in load_model_from_hdf5(filepath, custom_objects, compile)
#     114 opened_new_file = not isinstance(filepath, h5py.File)
#     115 if opened_new_file:
# --> 116     f = h5py.File(filepath, mode="r")
#     117 else:
#     118     f = filepath
#
# File c:\Users\chris\miniconda3\Lib\site-packages\h5py\_hl\files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File c:\Users\chris\miniconda3\Lib\site-packages\h5py\_hl\files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-01.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

def draw_contours_and_centroid(binary_mask, output_path):
    # Finden der Konturen
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Erstellen eines Farbbilds zum Zeichnen
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    
    # Zeichnen der Konturen
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    
    # Berechnung und Zeichnen des Schwerpunkts
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
    
    # Speichern des Bildes mit Konturen und Schwerpunkt
    cv2.imwrite(output_path, color_mask)

# Laden und Vorverarbeiten der Bilder mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')  # Convert to grayscale
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x196)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

# Vorhersage mit dem Modell machen
def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
    predicted_mask = model.predict(image)  # Vorhersage machen
    return np.squeeze(predicted_mask)  # Batch-Dimension entfernen

# Funktion zur Berechnung der mittleren Konturgröße
def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

# Funktion zur Auswahl des besten Schwellenwerts
def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0

    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size  # Anpassen der Bewertungsmetrik nach Bedarf

            if score > best_score:
                best_score = score
                best_threshold = threshold

    return best_threshold

# Funktion zur Berechnung des mittleren Durchmessers
def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)


# Pfade definieren
model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-combo_loss2.h5'
input_dir = "C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testset von julia"
output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher test/'
excel_file_path = 'C:/Users/chris/Documents/Testset.xlsx'

#mit testset jessi sogar noch besser
#model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-combo_loss2.h5'
#input_dir = "C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Bilder Jessi"
#output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher test/'
#excel_file_path = 'C:/Users/chris/Documents/Durchmesser Sphaeroide Jessi.xlsx'

# Lade das Modell mit den definierten custom_objects
model = load_model('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_best_fold.h5', compile=False)

# Kompiliere das Modell nachträglich
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
              loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5), 
              metrics=[dice_metric])
# Modell laden
#model = tf.keras.models.load_model(model_path)


# Daten aus der Excel-Tabelle laden
predicted_diameters = []
df_manual = pd.read_excel(excel_file_path, header=0)  # Daten ab der zweiten Zeile 
manual_diameters = df_manual.iloc[:, 1].tolist()  # Durchmesser sind in der zweiten Spalte

# Debug-Ausgabe: Anzahl der manuellen Durchmesser
print(f"Anzahl der manuellen Durchmesser: {len(df_manual)}")

# Skalierungsfaktoren berechnen
scale_factor_width = 1296 / 256  # Originalbreite / skalierte Breite
scale_factor_height = 966 / 196  # Originalhöhe / skalierte Höhe

# Listen für die berechneten Durchmesser und die manuell gemessenen Durchmesser
manual_diameters = []

# Iteration über alle TIFF-Dateien im Eingabeordner
tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Debug-Ausgabe: Anzahl der TIFF-Dateien
print(f"Anzahl der TIFF-Dateien: {len(tif_files)}")

# Überprüfen, ob die Anzahl der Dateien mit der Anzahl der manuellen Messungen übereinstimmt
if len(tif_files) != len(df_manual):
    print("Die Anzahl der Bilddateien stimmt nicht mit der Anzahl der manuellen Messungen überein.")
else:
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        
        try:
            # Bild laden und vorverarbeiten
            image = load_and_preprocess_image_pillow(img_path)
            # Vorhersage mit dem Modell machen
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            # Besten Schwellenwert für Konturen finden
            best_threshold = find_best_threshold(predicted_mask)

            # Maske mit dem besten Schwellenwert erstellen
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
            
            # Konturen finden
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            # Filtere Konturen nach Schmalheitsverhältnis
            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:  # Anpassen des Schmalheitsverhältnisses nach Bedarf
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            # Die größte Kontur nach dem Flächeninhalt finden
            largest_contour = max(filtered_contours, key=cv2.contourArea)

            # Berechne den Schwerpunkt der Kontur
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

            # Berechne den mittleren Durchmesser
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width) *0.994     #mit faktor für verzerrung

            # Berechnung des Flächeninhalts
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.3745 * scale_factor_width * 0.3745 * scale_factor_height)

            # Ergebnisse hinzufügen
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])  # Manuell gemessener Durchmesser hinzufügen

            # Ausgabepfad für das segmentierte Bild definieren
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            draw_contours_and_centroid(binary_mask, output_path)

            # Maske als TIFF-Datei speichern
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")

            # Ergebnisse ausgeben
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Flächeninhalt: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    # Debug-Ausgabe: Anzahl der erfolgreichen Vorhersagen und manuell gemessenen Durchmesser
    print(f"Anzahl der erfolgreichen Vorhersagen: {len(predicted_diameters)}")
    print(f"Anzahl der zugehörigen manuellen Durchmesser: {len(manual_diameters)}")

    # Ergebnisse in ein DataFrame konvertieren
    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    # Ergebnisse in eine Excel-Datei exportieren
    excel_output_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx'
    df_results.to_excel(excel_output_path, index=False)

    # Berechnung der Metriken zur Bewertung der Modellgenauigkeit
    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)

        print(f"\nMetriken zur Bewertung der Modellgenauigkeit:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")

        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print("Keine ausreichenden Daten zur Berechnung der Metriken vorhanden.")

    # Scatterplot erstellen
    plt.figure(figsize=(10, 6))
    plt.scatter(manual_diameters, predicted_diameters, color='blue', label='Vorhergesagt vs. Manuell')
    plt.plot([min(manual_diameters), max(manual_diameters)], [min(manual_diameters), max(manual_diameters)], color='red', linestyle='--', label='Perfekte Übereinstimmung')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title('Vergleich von manuellen und vorhergesagten Durchmessern')
    plt.legend()
    plt.grid(True)
    plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/scatterplot.png')
    plt.show()

#7 , 36 , 38 , 19 reißen
# Out:
# Anzahl der manuellen Durchmesser: 50
# Anzahl der TIFF-Dateien: 50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 822ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_B8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_B8_ch00.tif, Durchmesser: 121.92 µm, Flächeninhalt: 11586.41 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_D7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_D7_ch00.tif, Durchmesser: 120.32 µm, Flächeninhalt: 11274.97 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E7_ch00.tif, Durchmesser: 122.70 µm, Flächeninhalt: 11710.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E8_ch00.tif, Durchmesser: 125.83 µm, Flächeninhalt: 12307.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F7_ch00.tif, Durchmesser: 127.90 µm, Flächeninhalt: 12725.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F8_ch00.tif, Durchmesser: 120.50 µm, Flächeninhalt: 11337.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_C5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_C5_ch00.tif, Durchmesser: 9.24 µm, Flächeninhalt: 80.49 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D5_ch00.tif, Durchmesser: 95.54 µm, Flächeninhalt: 7142.21 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D6_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D6_ch00.tif, Durchmesser: 93.82 µm, Flächeninhalt: 6862.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_E5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_E5_ch00.tif, Durchmesser: 88.68 µm, Flächeninhalt: 6144.89 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_F6_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_F6_ch00.tif, Durchmesser: 88.42 µm, Flächeninhalt: 6113.40 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C11_ch00.tif, Durchmesser: 131.37 µm, Flächeninhalt: 13435.83 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C12_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C12_ch00.tif, Durchmesser: 121.85 µm, Flächeninhalt: 11567.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_D11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_D11_ch00.tif, Durchmesser: 131.36 µm, Flächeninhalt: 13423.58 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_G11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_G11_ch00.tif, Durchmesser: 125.00 µm, Flächeninhalt: 12181.30 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D10_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D10_ch00.tif, Durchmesser: 109.00 µm, Flächeninhalt: 9294.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D9_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D9_ch00.tif, Durchmesser: 107.60 µm, Flächeninhalt: 9038.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E10_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E10_ch00.tif, Durchmesser: 104.14 µm, Flächeninhalt: 8452.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E9_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E9_ch00.tif, Durchmesser: 3.07 µm, Flächeninhalt: 8.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_B8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_B8_ch00.tif, Durchmesser: 141.44 µm, Flächeninhalt: 15582.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_D7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_D7_ch00.tif, Durchmesser: 145.08 µm, Flächeninhalt: 16368.30 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E7_ch00.tif, Durchmesser: 145.39 µm, Flächeninhalt: 16452.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 549ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E8_ch00.tif, Durchmesser: 146.76 µm, Flächeninhalt: 16779.47 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_F8_ch00.tif, Durchmesser: 145.01 µm, Flächeninhalt: 16412.04 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_C5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_C5_ch00.tif, Durchmesser: 102.06 µm, Flächeninhalt: 8151.78 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D5_ch00.tif, Durchmesser: 108.20 µm, Flächeninhalt: 9133.35 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D6_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D6_ch00.tif, Durchmesser: 112.56 µm, Flächeninhalt: 9883.97 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 645ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_E5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_E5_ch00.tif, Durchmesser: 104.59 µm, Flächeninhalt: 8564.71 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 562ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_F6_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_F6_ch00.tif, Durchmesser: 106.38 µm, Flächeninhalt: 8835.91 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_C11_ch00.tif, Durchmesser: 154.15 µm, Flächeninhalt: 18495.91 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_D11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_D11_ch00.tif, Durchmesser: 151.27 µm, Flächeninhalt: 17832.78 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_F11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_F11_ch00.tif, Durchmesser: 153.77 µm, Flächeninhalt: 18457.42 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_G11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_G11_ch00.tif, Durchmesser: 136.64 µm, Flächeninhalt: 14532.88 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_D10_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_D10_ch00.tif, Durchmesser: 125.15 µm, Flächeninhalt: 12214.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_E10_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_E10_ch00.tif, Durchmesser: 117.98 µm, Flächeninhalt: 10835.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 mit Rock_G3_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 mit Rock_G3_ch00.tif, Durchmesser: 146.61 µm, Flächeninhalt: 16732.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_C2_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_C2_ch00.tif, Durchmesser: 95.17 µm, Flächeninhalt: 7086.22 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_E2_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_E2_ch00.tif, Durchmesser: 101.01 µm, Flächeninhalt: 7959.31 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E7_ch00.tif, Durchmesser: 180.36 µm, Flächeninhalt: 25317.93 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E8_ch00.tif, Durchmesser: 181.50 µm, Flächeninhalt: 25618.88 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F7_ch00.tif, Durchmesser: 188.69 µm, Flächeninhalt: 27683.51 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F8_ch00.tif, Durchmesser: 182.12 µm, Flächeninhalt: 25809.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_3.000 mit Rock_E7_ch00.tif, Durchmesser: 211.21 µm, Flächeninhalt: 34684.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_C11_ch00.tif, Durchmesser: 204.59 µm, Flächeninhalt: 32526.63 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_F11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_F11_ch00.tif, Durchmesser: 214.25 µm, Flächeninhalt: 35690.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2,.000 ohne Rock_D2_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2,.000 ohne Rock_D2_ch00.tif, Durchmesser: 114.81 µm, Flächeninhalt: 10312.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 647ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 mit Rock_D4_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 mit Rock_D4_ch00.tif, Durchmesser: 254.36 µm, Flächeninhalt: 50243.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_C2_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_C2_ch00.tif, Durchmesser: 118.55 µm, Flächeninhalt: 10967.02 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_E2_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_E2_ch00.tif, Durchmesser: 125.14 µm, Flächeninhalt: 12216.30 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_3.000 mit Rock_E8_ch00.tif, Durchmesser: 263.93 µm, Flächeninhalt: 54126.49 µm²
# Anzahl der erfolgreichen Vorhersagen: 50
# Anzahl der zugehörigen manuellen Durchmesser: 50
#
# Metriken zur Bewertung der Modellgenauigkeit:
# MAE (Mean Absolute Error): 6.06 µm
# MSE (Mean Squared Error): 334.32 µm²
# R2 Score (Coefficient of Determination): 0.81
# Ergebnisse und Metriken wurden in C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx gespeichert.

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

def dice_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice

# Benutzerdefinierte Verlustfunktion
def combined_loss(y_true, y_pred, smooth=1e-6, binary_weight=0.5, dice_weight=0.5):
    # Binary Crossentropy
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    
    # Dice Loss
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice_loss = 1 - (2. * intersection + smooth) / (union + smooth)
    
    return binary_weight * bce + dice_weight * dice_loss


def draw_contours_and_centroid(binary_mask, output_path):
    # Finden der Konturen
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Erstellen eines Farbbilds zum Zeichnen
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    
    # Zeichnen der Konturen
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    
    # Berechnung und Zeichnen des Schwerpunkts
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
    
    # Speichern des Bildes mit Konturen und Schwerpunkt
    cv2.imwrite(output_path, color_mask)

# Laden und Vorverarbeiten der Bilder mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')  # Convert to grayscale
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x196)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

# Vorhersage mit dem Modell machen
def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
    predicted_mask = model.predict(image)  # Vorhersage machen
    return np.squeeze(predicted_mask)  # Batch-Dimension entfernen

# Funktion zur Berechnung der mittleren Konturgröße
def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

# Funktion zur Auswahl des besten Schwellenwerts
def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0

    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size  # Anpassen der Bewertungsmetrik nach Bedarf

            if score > best_score:
                best_score = score
                best_threshold = threshold

    return best_threshold

# Funktion zur Berechnung des mittleren Durchmessers
def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)


# Pfade definieren
#model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-combo_loss2.h5'
#input_dir = "C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testset von julia"
#output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher test/'
#excel_file_path = 'C:/Users/chris/Documents/Testset.xlsx'

#mit testset jessi sogar noch besser
model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-combo_loss2.h5'
input_dir = "C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Bilder Jessi"
output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher test/'
excel_file_path = 'C:/Users/chris/Documents/Durchmesser Sphaeroide Jessi.xlsx'

# Lade das Modell mit den definierten custom_objects
model = load_model('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_best_fold.h5', compile=False)

# Kompiliere das Modell nachträglich
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
              loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5), 
              metrics=[dice_metric])
# Modell laden
#model = tf.keras.models.load_model(model_path)


# Daten aus der Excel-Tabelle laden
predicted_diameters = []
df_manual = pd.read_excel(excel_file_path, header=0)  # Daten ab der zweiten Zeile 
manual_diameters = df_manual.iloc[:, 1].tolist()  # Durchmesser sind in der zweiten Spalte

# Debug-Ausgabe: Anzahl der manuellen Durchmesser
print(f"Anzahl der manuellen Durchmesser: {len(df_manual)}")

# Skalierungsfaktoren berechnen
scale_factor_width = 1296 / 256  # Originalbreite / skalierte Breite
scale_factor_height = 966 / 196  # Originalhöhe / skalierte Höhe

# Listen für die berechneten Durchmesser und die manuell gemessenen Durchmesser
manual_diameters = []

# Iteration über alle TIFF-Dateien im Eingabeordner
tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Debug-Ausgabe: Anzahl der TIFF-Dateien
print(f"Anzahl der TIFF-Dateien: {len(tif_files)}")

# Überprüfen, ob die Anzahl der Dateien mit der Anzahl der manuellen Messungen übereinstimmt
if len(tif_files) != len(df_manual):
    print("Die Anzahl der Bilddateien stimmt nicht mit der Anzahl der manuellen Messungen überein.")
else:
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        
        try:
            # Bild laden und vorverarbeiten
            image = load_and_preprocess_image_pillow(img_path)
            # Vorhersage mit dem Modell machen
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            # Besten Schwellenwert für Konturen finden
            best_threshold = find_best_threshold(predicted_mask)

            # Maske mit dem besten Schwellenwert erstellen
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
            
            # Konturen finden
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            # Filtere Konturen nach Schmalheitsverhältnis
            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:  # Anpassen des Schmalheitsverhältnisses nach Bedarf
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            # Die größte Kontur nach dem Flächeninhalt finden
            largest_contour = max(filtered_contours, key=cv2.contourArea)

            # Berechne den Schwerpunkt der Kontur
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

            # Berechne den mittleren Durchmesser
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745/2 * scale_factor_width) *0.994     #mit faktor für verzerrung

            # Berechnung des Flächeninhalts
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.3745/2 * scale_factor_width * 0.3745/2 * scale_factor_height)

            # Ergebnisse hinzufügen
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])  # Manuell gemessener Durchmesser hinzufügen

            # Ausgabepfad für das segmentierte Bild definieren
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            draw_contours_and_centroid(binary_mask, output_path)

            # Maske als TIFF-Datei speichern
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")

            # Ergebnisse ausgeben
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Flächeninhalt: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    # Debug-Ausgabe: Anzahl der erfolgreichen Vorhersagen und manuell gemessenen Durchmesser
    print(f"Anzahl der erfolgreichen Vorhersagen: {len(predicted_diameters)}")
    print(f"Anzahl der zugehörigen manuellen Durchmesser: {len(manual_diameters)}")

    # Ergebnisse in ein DataFrame konvertieren
    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    # Ergebnisse in eine Excel-Datei exportieren
    excel_output_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx'
    df_results.to_excel(excel_output_path, index=False)

    # Berechnung der Metriken zur Bewertung der Modellgenauigkeit
    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)

        print(f"\nMetriken zur Bewertung der Modellgenauigkeit:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")

        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print("Keine ausreichenden Daten zur Berechnung der Metriken vorhanden.")

    # Scatterplot erstellen
    plt.figure(figsize=(10, 6))
    plt.scatter(manual_diameters, predicted_diameters, color='blue', label='Vorhergesagt vs. Manuell')
    plt.plot([min(manual_diameters), max(manual_diameters)], [min(manual_diameters), max(manual_diameters)], color='red', linestyle='--', label='Perfekte Übereinstimmung')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title('Vergleich von manuellen und vorhergesagten Durchmessern')
    plt.legend()
    plt.grid(True)
    plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/scatterplot.png')
    plt.show()

#7 , 36 , 38 , 19 reißen
# Out:
# Anzahl der manuellen Durchmesser: 115
# Anzahl der TIFF-Dateien: 115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 887ms/step
# Segmentiertes Bild für 018_001_001_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_001_001_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 61.50 µm, Flächeninhalt: 2944.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Segmentiertes Bild für 018_002_002_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_002_002_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 58.28 µm, Flächeninhalt: 2648.58 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Segmentiertes Bild für 018_003_003_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_003_003_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 58.39 µm, Flächeninhalt: 2652.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# Segmentiertes Bild für 018_004_004_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_004_004_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 57.04 µm, Flächeninhalt: 2544.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Segmentiertes Bild für 018_005_005_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_005_005_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 61.96 µm, Flächeninhalt: 2997.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Segmentiertes Bild für 018_006_006_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_006_006_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 58.62 µm, Flächeninhalt: 2677.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# Segmentiertes Bild für 018_007_007_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_007_007_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 55.91 µm, Flächeninhalt: 2429.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Segmentiertes Bild für 018_008_008_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_008_008_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 57.87 µm, Flächeninhalt: 2610.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Segmentiertes Bild für 018_009_009_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_009_009_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 62.89 µm, Flächeninhalt: 3079.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Segmentiertes Bild für 018_010_010_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_010_010_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 63.30 µm, Flächeninhalt: 3119.25 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# Segmentiertes Bild für 018_011_011_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_011_011_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 59.06 µm, Flächeninhalt: 2719.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# Segmentiertes Bild für 018_012_012_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_012_012_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 58.40 µm, Flächeninhalt: 2652.52 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# Segmentiertes Bild für 018_013_013_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_013_013_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 68.13 µm, Flächeninhalt: 3682.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/step
# Segmentiertes Bild für 018_014_014_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_014_014_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 64.12 µm, Flächeninhalt: 3190.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# Segmentiertes Bild für 018_015_015_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_015_015_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 59.82 µm, Flächeninhalt: 2788.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Segmentiertes Bild für 018_016_016_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_016_016_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 59.03 µm, Flächeninhalt: 2727.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# Segmentiertes Bild für 018_017_017_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_017_017_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 61.78 µm, Flächeninhalt: 2976.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Segmentiertes Bild für 018_018_018_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_018_018_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 66.89 µm, Flächeninhalt: 3473.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Segmentiertes Bild für 018_019_019_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_019_019_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 57.82 µm, Flächeninhalt: 2610.09 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# Segmentiertes Bild für 018_020_020_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_020_020_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 60.69 µm, Flächeninhalt: 2874.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Segmentiertes Bild für 018_021_021_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_021_021_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 59.84 µm, Flächeninhalt: 2785.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# Segmentiertes Bild für 018_022_022_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_022_022_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 63.05 µm, Flächeninhalt: 3096.50 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# Segmentiertes Bild für 018_023_023_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_023_023_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 66.55 µm, Flächeninhalt: 3522.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Segmentiertes Bild für 018_024_024_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_024_024_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 0.92 µm, Flächeninhalt: 0.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Segmentiertes Bild für 018_025_025_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_025_025_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 80.54 µm, Flächeninhalt: 5042.59 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# Segmentiertes Bild für 018_026_026_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_026_026_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 82.03 µm, Flächeninhalt: 5233.31 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Segmentiertes Bild für 018_027_027_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_027_027_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 87.49 µm, Flächeninhalt: 5951.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Segmentiertes Bild für 018_028_028_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_028_028_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 88.17 µm, Flächeninhalt: 6050.41 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Segmentiertes Bild für 018_029_029_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_029_029_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 78.12 µm, Flächeninhalt: 4740.33 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# Segmentiertes Bild für 018_030_030_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_030_030_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 85.13 µm, Flächeninhalt: 5633.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Segmentiertes Bild für 018_031_031_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_031_031_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 92.34 µm, Flächeninhalt: 6631.74 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# Segmentiertes Bild für 018_032_032_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_032_032_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 96.62 µm, Flächeninhalt: 7248.51 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# Segmentiertes Bild für 018_033_033_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_033_033_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 82.66 µm, Flächeninhalt: 5319.92 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# Segmentiertes Bild für 018_034_034_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_034_034_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 87.00 µm, Flächeninhalt: 5886.38 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# Segmentiertes Bild für 018_035_035_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_035_035_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 92.59 µm, Flächeninhalt: 6668.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# Segmentiertes Bild für 018_036_036_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_036_036_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 98.25 µm, Flächeninhalt: 7513.58 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# Segmentiertes Bild für 018_037_037_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_037_037_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 78.63 µm, Flächeninhalt: 4818.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# Segmentiertes Bild für 018_038_038_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_038_038_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 86.36 µm, Flächeninhalt: 5791.89 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# Segmentiertes Bild für 018_039_039_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_039_039_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 93.17 µm, Flächeninhalt: 6750.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# Segmentiertes Bild für 018_040_040_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_040_040_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 99.58 µm, Flächeninhalt: 7698.61 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# Segmentiertes Bild für 018_041_041_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_041_041_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 82.14 µm, Flächeninhalt: 5249.93 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# Segmentiertes Bild für 018_042_042_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_042_042_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 87.62 µm, Flächeninhalt: 5976.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 567ms/step
# Segmentiertes Bild für 018_043_043_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_043_043_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 92.69 µm, Flächeninhalt: 6675.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# Segmentiertes Bild für 018_044_044_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_044_044_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 97.01 µm, Flächeninhalt: 7313.24 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# Segmentiertes Bild für 018_045_049_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_045_049_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 93.51 µm, Flächeninhalt: 6820.27 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# Segmentiertes Bild für 018_046_050_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_046_050_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 107.74 µm, Flächeninhalt: 9007.38 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 576ms/step
# Segmentiertes Bild für 018_047_051_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_047_051_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 114.06 µm, Flächeninhalt: 10110.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Segmentiertes Bild für 018_048_052_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_048_052_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 119.93 µm, Flächeninhalt: 11157.74 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Segmentiertes Bild für 018_049_053_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_049_053_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 89.10 µm, Flächeninhalt: 6189.51 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# Segmentiertes Bild für 018_050_054_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_050_054_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 104.17 µm, Flächeninhalt: 8421.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# Segmentiertes Bild für 018_051_055_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_051_055_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 114.32 µm, Flächeninhalt: 10142.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# Segmentiertes Bild für 018_052_056_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_052_056_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 125.25 µm, Flächeninhalt: 12191.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# Segmentiertes Bild für 018_053_057_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_053_057_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 103.66 µm, Flächeninhalt: 8343.81 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step
# Segmentiertes Bild für 018_054_058_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_054_058_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 114.80 µm, Flächeninhalt: 10259.27 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step
# Segmentiertes Bild für 018_055_059_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_055_059_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 124.53 µm, Flächeninhalt: 12037.83 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/step
# Segmentiertes Bild für 018_056_061_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid + Tail_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_056_061_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid + Tail_20x_240702_ch00.tif, Durchmesser: 95.80 µm, Flächeninhalt: 7150.52 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# Segmentiertes Bild für 018_057_062_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_057_062_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 108.14 µm, Flächeninhalt: 9096.61 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# Segmentiertes Bild für 018_058_063_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_058_063_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 120.07 µm, Flächeninhalt: 11193.61 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# Segmentiertes Bild für 018_059_064_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_059_064_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 128.64 µm, Flächeninhalt: 12854.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# Segmentiertes Bild für 018_060_065_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_060_065_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 99.70 µm, Flächeninhalt: 7723.11 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Segmentiertes Bild für 018_061_066_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_061_066_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 109.41 µm, Flächeninhalt: 9298.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# Segmentiertes Bild für 018_062_067_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_062_067_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 119.10 µm, Flächeninhalt: 11017.33 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# Segmentiertes Bild für 018_063_068_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_063_068_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 130.22 µm, Flächeninhalt: 13189.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Segmentiertes Bild für 018_064_069_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_064_069_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 92.16 µm, Flächeninhalt: 6616.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Segmentiertes Bild für 018_065_070_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_065_070_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 107.59 µm, Flächeninhalt: 9017.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# Segmentiertes Bild für 018_066_071_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_066_071_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 110.91 µm, Flächeninhalt: 9556.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Segmentiertes Bild für 018_067_072_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_067_072_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 118.05 µm, Flächeninhalt: 10818.74 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Segmentiertes Bild für 018_068_073_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_068_073_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 105.18 µm, Flächeninhalt: 8587.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Segmentiertes Bild für 018_069_074_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_069_074_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 117.06 µm, Flächeninhalt: 10635.89 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Segmentiertes Bild für 018_070_075_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_070_075_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 127.40 µm, Flächeninhalt: 12596.42 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# Segmentiertes Bild für 018_071_076_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_071_076_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 129.69 µm, Flächeninhalt: 13061.83 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Segmentiertes Bild für 018_072_077_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_072_077_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 101.59 µm, Flächeninhalt: 8018.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Segmentiertes Bild für 018_073_078_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_073_078_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 112.91 µm, Flächeninhalt: 9897.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Segmentiertes Bild für 018_074_079_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_074_079_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 124.98 µm, Flächeninhalt: 12126.63 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Segmentiertes Bild für 018_075_080_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_075_080_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 132.37 µm, Flächeninhalt: 13616.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Segmentiertes Bild für 018_076_081_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_076_081_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 98.41 µm, Flächeninhalt: 7520.58 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Segmentiertes Bild für 018_077_082_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_077_082_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 109.50 µm, Flächeninhalt: 9322.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# Segmentiertes Bild für 018_078_083_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_078_083_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 120.14 µm, Flächeninhalt: 11190.11 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Segmentiertes Bild für 018_079_084_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_079_084_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 130.64 µm, Flächeninhalt: 13242.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Segmentiertes Bild für 018_080_085_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_080_085_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 104.70 µm, Flächeninhalt: 8522.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Segmentiertes Bild für 018_081_086_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_081_086_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 113.64 µm, Flächeninhalt: 10011.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Segmentiertes Bild für 018_082_087_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_082_087_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 125.63 µm, Flächeninhalt: 12254.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Segmentiertes Bild für 018_083_088_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_083_088_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 135.63 µm, Flächeninhalt: 14288.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# Segmentiertes Bild für 018_084_089_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_084_089_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 99.03 µm, Flächeninhalt: 7613.31 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step
# Segmentiertes Bild für 018_085_090_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_085_090_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 110.84 µm, Flächeninhalt: 9524.84 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# Segmentiertes Bild für 018_086_091_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_086_091_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 121.26 µm, Flächeninhalt: 11428.50 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Segmentiertes Bild für 018_087_092_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_087_092_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 131.83 µm, Flächeninhalt: 13502.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Segmentiertes Bild für 018_088_093_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_088_093_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 98.29 µm, Flächeninhalt: 7508.33 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# Segmentiertes Bild für 018_089_094_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_089_094_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 111.10 µm, Flächeninhalt: 9585.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Segmentiertes Bild für 018_090_095_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_090_095_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 115.80 µm, Flächeninhalt: 10414.12 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Segmentiertes Bild für 018_091_096_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_091_096_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 121.26 µm, Flächeninhalt: 11419.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# Segmentiertes Bild für 018_092_097_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_092_097_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 119.24 µm, Flächeninhalt: 11132.37 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# Segmentiertes Bild für 018_093_098_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_093_098_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 135.86 µm, Flächeninhalt: 14370.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# Segmentiertes Bild für 018_094_099_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_094_099_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 135.91 µm, Flächeninhalt: 14369.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# Segmentiertes Bild für 018_095_100_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_095_100_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 137.99 µm, Flächeninhalt: 14810.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# Segmentiertes Bild für 018_096_101_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_096_101_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 115.84 µm, Flächeninhalt: 10428.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# Segmentiertes Bild für 018_097_102_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_097_102_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 130.80 µm, Flächeninhalt: 13260.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# Segmentiertes Bild für 018_098_103_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_098_103_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 143.84 µm, Flächeninhalt: 16053.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Segmentiertes Bild für 018_099_104_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_099_104_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 146.43 µm, Flächeninhalt: 16644.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Segmentiertes Bild für 018_100_105_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_100_105_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 111.90 µm, Flächeninhalt: 9724.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# Segmentiertes Bild für 018_101_106_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_101_106_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 126.98 µm, Flächeninhalt: 12539.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# Segmentiertes Bild für 018_102_107_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_102_107_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 140.30 µm, Flächeninhalt: 15276.50 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# Segmentiertes Bild für 018_103_108_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_103_108_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 141.71 µm, Flächeninhalt: 15569.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Segmentiertes Bild für 018_104_109_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_104_109_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 121.30 µm, Flächeninhalt: 11414.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Segmentiertes Bild für 018_105_110_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_105_110_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 138.98 µm, Flächeninhalt: 14986.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Segmentiertes Bild für 018_106_111_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_106_111_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 148.12 µm, Flächeninhalt: 17009.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Segmentiertes Bild für 018_107_112_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_107_112_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 144.98 µm, Flächeninhalt: 16271.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Segmentiertes Bild für 018_108_113_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid + tail_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_108_113_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid + tail_20x_240705_ch00.tif, Durchmesser: 146.20 µm, Flächeninhalt: 16618.07 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# Segmentiertes Bild für 018_109_114_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_109_114_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 117.31 µm, Flächeninhalt: 10680.51 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Segmentiertes Bild für 018_110_115_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_110_115_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 133.24 µm, Flächeninhalt: 13802.82 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Segmentiertes Bild für 018_111_116_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_111_116_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 142.06 µm, Flächeninhalt: 15661.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# Segmentiertes Bild für 018_112_117_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_112_117_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 112.21 µm, Flächeninhalt: 9775.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Segmentiertes Bild für 018_113_118_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_113_118_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 123.88 µm, Flächeninhalt: 11902.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# Segmentiertes Bild für 018_114_119_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_114_119_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 132.92 µm, Flächeninhalt: 13711.40 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# Segmentiertes Bild für 018_115_120_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_115_120_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 132.12 µm, Flächeninhalt: 13554.81 µm²
# Anzahl der erfolgreichen Vorhersagen: 115
# Anzahl der zugehörigen manuellen Durchmesser: 115
#
# Metriken zur Bewertung der Modellgenauigkeit:
# MAE (Mean Absolute Error): 2.44 µm
# MSE (Mean Squared Error): 42.55 µm²
# R2 Score (Coefficient of Determination): 0.94
# Ergebnisse und Metriken wurden in C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx gespeichert.

# %%
from tensorflow.keras.models import load_model

# Pfad zur gespeicherten .h5-Datei
model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-combo_loss2.h5'

# Kompiliere das Modell nachträglich
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
              loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5), 
              metrics=[dice_metric])
# Modell laden
model = load_model(model_path, compile=False)
print(type(model))  # Dies sollte <class 'tensorflow.python.keras.engine.training.Model'> anzeigen für ein Functional Model
# Modellzusammenfassung anzeigen
model.summary()

# Kompilierungsinformationen anzeigen
if model.optimizer:
    print(f"Optimizer: {model.optimizer}")
    print(f"Loss: {model.loss}")
    print(f"Metriken: {model.metrics_names}")
# Out:
# <class 'keras.src.models.sequential.Sequential'>
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_57 (Conv2D)              │ (None, 192, 256, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_37          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_58 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_38          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_59 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_60 (Conv2D)              │ (None, 96, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_39          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_61 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_40          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_62 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_63 (Conv2D)              │ (None, 48, 64, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_41          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_23 (Dropout)            │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_64 (Conv2D)              │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_42          │ (None, 48, 64, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_65 (Conv2D)              │ (None, 48, 64, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_9 (UpSampling2D)  │ (None, 96, 128, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_66 (Conv2D)              │ (None, 96, 128, 128)   │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_43          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_24 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_67 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_44          │ (None, 96, 128, 128)   │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_68 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_10 (UpSampling2D) │ (None, 192, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_69 (Conv2D)              │ (None, 192, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_45          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_25 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_70 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 192, 256, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_71 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_72 (Conv2D)              │ (None, 192, 256, 1)    │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,662,401 (10.16 MB)
#  Trainable params: 2,659,841 (10.15 MB)
#  Non-trainable params: 2,560 (10.00 KB)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 17
#      14 model.summary()
#      16 # Kompilierungsinformationen anzeigen
# ---> 17 if model.optimizer:
#      18     print(f"Optimizer: {model.optimizer}")
#      19     print(f"Loss: {model.loss}")
#
# AttributeError: 'Sequential' object has no attribute 'optimizer'

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken/'

# Bild- und Maskenpfade laden
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Funktionen zum Laden und Vorverarbeiten
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))
    img = np.array(img)
    img = img / 255.0
    img = np.expand_dims(img, axis=-1)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))
    mask = np.array(mask)
    mask = np.where(mask > 128, 1, 0)
    mask = np.expand_dims(mask, axis=-1)
    return mask

# Daten laden
X = [load_and_preprocess_image_pillow(path) for path in image_paths]
Y = [load_and_preprocess_mask_pillow(path) for path in mask_paths]

X = np.array(X)
Y = np.array(Y)

print(f'Form von X: {X.shape}')
print(f'Form von Y: {Y.shape}')

# Dice Metric
def dice_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice

# Benutzerdefinierte Verlustfunktion
def combined_loss(y_true, y_pred, smooth=1e-6, binary_weight=0.5, dice_weight=0.5):
    # Binary Crossentropy
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    
    # Dice Loss
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice_loss = 1 - (2. * intersection + smooth) / (union + smooth)
    
    return binary_weight * bce + dice_weight * dice_loss

# Sequential Modell
def sequential_model(input_size=(192, 256, 1)):
    model = Sequential()

    model.add(InputLayer(input_shape=input_size))

    # Encoder (Downsampling Path)
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))  # 32
    model.add(BatchNormalization())
    model.add(Conv2D(32, (3, 3), activation='relu', padding='same'))  # 32
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))  # 2
    model.add(Dropout(0.3))

    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))  # 64
    model.add(BatchNormalization())
    model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))  # 64
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))  # 2
    model.add(Dropout(0.4))

    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))  # 128
    model.add(BatchNormalization())
    model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))  # 128
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))  # 2
    model.add(Dropout(0.5))

    # Bottleneck
    model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))  # 256
    model.add(BatchNormalization())

    # Decoder (Upsampling Path)
    model.add(UpSampling2D(size=(2, 2)))
    model.add(Conv2D(128, (2, 2), activation='relu', padding='same'))  # 128
    model.add(BatchNormalization())
    
    model.add(UpSampling2D(size=(2, 2)))
    model.add(Conv2D(64, (2, 2), activation='relu', padding='same'))  # 64
    model.add(BatchNormalization())

    model.add(UpSampling2D(size=(2, 2)))
    model.add(Conv2D(32, (2, 2), activation='relu', padding='same'))  # 32
    model.add(BatchNormalization())

    model.add(Conv2D(1, (1, 1), activation='sigmoid'))  # Output Layer

    return model

# Training ohne Cross-Validation
X_train, Y_train = X, Y

# Modell erstellen
model = sequential_model()

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

# Modell kompilieren
optimizer = Adam(learning_rate=1e-4)
model.compile(optimizer=optimizer, loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5), metrics=[dice_metric])

# Modellzusammenfassung
model.summary()

# Training (optional: validation_split=0.2 für einen Validierungssplit)
history = model.fit(X_train, Y_train, batch_size=8, epochs=1000, validation_split=0.2, callbacks=[early_stopping, reduce_lr])

# Modell speichern
model.save(f'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_sequential_trained.h5')

# Training History plotten
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Verlust
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Dice Metric
    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_metric'], label='Training Dice Metric')
    plt.plot(history.history['val_dice_metric'], label='Validation Dice Metric')
    plt.title('Training and Validation Dice Metric')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Metric')
    plt.legend()

    plt.show()

# Plotting History for the model
plot_training_history(history)
# Out:
# Form von X: (675, 192, 256, 1)
# Form von Y: (675, 192, 256, 1)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_84 (Conv2D)              │ (None, 192, 256, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_51          │ (None, 192, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_85 (Conv2D)              │ (None, 192, 256, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_52          │ (None, 192, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 96, 128, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 96, 128, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_86 (Conv2D)              │ (None, 96, 128, 64)    │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_53          │ (None, 96, 128, 64)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_87 (Conv2D)              │ (None, 96, 128, 64)    │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_54          │ (None, 96, 128, 64)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 48, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 48, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_88 (Conv2D)              │ (None, 48, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_55          │ (None, 48, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_89 (Conv2D)              │ (None, 48, 64, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_56          │ (None, 48, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 24, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 24, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_90 (Conv2D)              │ (None, 24, 32, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_57          │ (None, 24, 32, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_16 (UpSampling2D) │ (None, 48, 64, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_91 (Conv2D)              │ (None, 48, 64, 128)    │       131,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_58          │ (None, 48, 64, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_17 (UpSampling2D) │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_92 (Conv2D)              │ (None, 96, 128, 64)    │        32,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_59          │ (None, 96, 128, 64)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_18 (UpSampling2D) │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_93 (Conv2D)              │ (None, 192, 256, 32)   │         8,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_60          │ (None, 192, 256, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_94 (Conv2D)              │ (None, 192, 256, 1)    │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 757,601 (2.89 MB)
#  Trainable params: 755,745 (2.88 MB)
#  Non-trainable params: 1,856 (7.25 KB)
# Epoch 1/1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 136
#     133 model.summary()
#     135 # Training (optional: validation_split=0.2 für einen Validierungssplit)
# --> 136 history = model.fit(X_train, Y_train, batch_size=8, epochs=1000, validation_split=0.2, callbacks=[early_stopping, reduce_lr])
#     138 # Modell speichern
#     139 model.save(f'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_sequential_trained.h5')
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:919, in Function._call(self, *args, **kwds)
#     913   # If we did not create any variables the trace we have is good enough.
#     914   filtered_flat_args = (
#     915       self._concrete_variable_creation_fn.function_type.unpack_inputs(
#     916           bound_args
#     917       )
#     918   )
# --> 919   return self._concrete_variable_creation_fn._call_flat(  # pylint: disable=protected-access
#     920       filtered_flat_args,
#     921       self._concrete_variable_creation_fn.captured_inputs,
#     922   )
#     924 def fn_with_cond(inner_args, inner_kwds):
#     925   """Conditionally runs initialization if it's needed."""
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
