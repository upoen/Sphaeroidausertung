# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken/'

# Bild- und Maskenpfade laden
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Funktionen zum Laden und Vorverarbeiten
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))
    img = np.array(img)
    img = img / 255.0
    img = np.expand_dims(img, axis=-1)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))
    mask = np.array(mask)
    mask = np.where(mask > 128, 1, 0)
    mask = np.expand_dims(mask, axis=-1)
    return mask

# Daten laden
X = [load_and_preprocess_image_pillow(path) for path in image_paths]
Y = [load_and_preprocess_mask_pillow(path) for path in mask_paths]

X = np.array(X)
Y = np.array(Y)

print(f'Form von X: {X.shape}')
print(f'Form von Y: {Y.shape}')

# Dice Metric
def dice_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice

# Benutzerdefinierte Verlustfunktion
def combined_loss(y_true, y_pred, smooth=1e-6, binary_weight=0.5, dice_weight=0.5):
    # Binary Crossentropy
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    
    # Dice Loss
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice_loss = 1 - (2. * intersection + smooth) / (union + smooth)
    
    return binary_weight * bce + dice_weight * dice_loss

# U-Net Modell
def unet_model(input_size=(192, 256, 1)):
    inputs = Input(input_size)

    # Encoder (Downsampling Path)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(0.3)(pool1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(0.4)(pool2)

    conv4 = Conv2D(128, 3, activation='relu', padding='same')(pool2)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(128, 3, activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = Dropout(0.4)(pool4)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)

    # Bottleneck
    bottleneck = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    bottleneck = BatchNormalization()(bottleneck)

    # Decoder (Upsampling Path)
    up6 = UpSampling2D(size=(2, 2))(bottleneck)
    up6 = Conv2D(256, 2, activation='relu', padding='same')(up6)
    up6 = BatchNormalization()(up6)
    merge6 = concatenate([conv3, up6], axis=3)

    conv6 = Conv2D(256, 3, activation='relu', padding='same')(merge6)
    conv6 = BatchNormalization()(conv6)

    up7 = UpSampling2D(size=(2, 2))(conv6)
    up7 = Conv2D(128, 2, activation='relu', padding='same')(up7)
    up7 = BatchNormalization()(up7)
    merge7 = concatenate([conv2, up7], axis=3)

    conv7 = Conv2D(128, 3, activation='relu', padding='same')(merge7)
    conv7 = BatchNormalization()(conv7)

    up8 = UpSampling2D(size=(2, 2))(conv7)
    up8 = Conv2D(64, 2, activation='relu', padding='same')(up8)
    up8 = BatchNormalization()(up8)
    merge8 = concatenate([conv1, up8], axis=3)

    conv8 = Conv2D(64, 3, activation='relu', padding='same')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(64, 3, activation='relu', padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)

    conv8 = Conv2D(1, 1, activation='sigmoid')(conv8)

    model = Model(inputs=inputs, outputs=conv8)
    return model

# Training ohne Cross-Validation
X_train, Y_train = X, Y

# Modell erstellen
model = unet_model()

# Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=25, restore_best_weights=True)

# Modell kompilieren
optimizer = Adam(learning_rate=1e-4)
model.compile(optimizer=optimizer, loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5), metrics=[dice_metric])

# Modellzusammenfassung
model.summary()

# Training (optional: validation_split=0.2 für einen Validierungssplit)
history = model.fit(X_train, Y_train, batch_size=8, epochs=1000, validation_split=0.2, callbacks=[early_stopping, reduce_lr])

# Modell speichern
model.save(f'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_trained2.h5')

# Training History plotten
def plot_training_history(history):
    plt.figure(figsize=(12, 6))

    # Verlust
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Dice Metric
    plt.subplot(1, 2, 2)
    plt.plot(history.history['dice_metric'], label='Training Dice Metric')
    plt.plot(history.history['val_dice_metric'], label='Validation Dice Metric')
    plt.title('Training and Validation Dice Metric')
    plt.xlabel('Epochs')
    plt.ylabel('Dice Metric')
    plt.legend()

    plt.show()

# Plotting History for the model
plot_training_history(history)
# Out:
# Form von X: (675, 192, 256, 1)
# Form von Y: (675, 192, 256, 1)
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 192, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (None, 192, 256,  │        640 │ input_layer_4[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_62[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_63 (Conv2D)  │ (None, 192, 256,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_63[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_13    │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 96, 128,   │          0 │ max_pooling2d_13… │
# │ (Dropout)           │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_64 (Conv2D)  │ (None, 96, 128,   │     73,856 │ dropout_13[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_64[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_65 (Conv2D)  │ (None, 96, 128,   │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_65[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_14    │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 48, 64,    │          0 │ max_pooling2d_14… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_68 (Conv2D)  │ (None, 48, 64,    │    295,168 │ dropout_14[0][0]  │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_68[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_69 (Conv2D)  │ (None, 48, 64,    │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_69[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_16    │ (None, 24, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_16          │ (None, 24, 32,    │          0 │ max_pooling2d_16… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_70 (Conv2D)  │ (None, 24, 32,    │  1,180,160 │ dropout_16[0][0]  │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 24, 32,    │      2,048 │ conv2d_70[0][0]   │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_12    │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_71 (Conv2D)  │ (None, 48, 64,    │    524,544 │ up_sampling2d_12… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_71[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, 48, 64,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 512)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_72 (Conv2D)  │ (None, 48, 64,    │  1,179,904 │ concatenate_12[0… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 48, 64,    │      1,024 │ conv2d_72[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_13    │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_73 (Conv2D)  │ (None, 96, 128,   │    131,200 │ up_sampling2d_13… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_73[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, 96, 128,   │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 256)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_74 (Conv2D)  │ (None, 96, 128,   │    295,040 │ concatenate_13[0… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 96, 128,   │        512 │ conv2d_74[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_14    │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_75 (Conv2D)  │ (None, 192, 256,  │     32,832 │ up_sampling2d_14… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_75[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, 192, 256,  │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 128)              │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_76 (Conv2D)  │ (None, 192, 256,  │     73,792 │ concatenate_14[0… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_76[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_77 (Conv2D)  │ (None, 192, 256,  │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 192, 256,  │        256 │ conv2d_77[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_78 (Conv2D)  │ (None, 192, 256,  │         65 │ batch_normalizat… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,608,193 (17.58 MB)
#  Trainable params: 4,603,457 (17.56 MB)
#  Non-trainable params: 4,736 (18.50 KB)
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 416s 6s/step - dice_metric: 0.5852 - loss: 0.4170 - val_dice_metric: 0.1418 - val_loss: 0.6381 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 402s 6s/step - dice_metric: 0.7959 - loss: 0.1913 - val_dice_metric: 0.0691 - val_loss: 0.6637 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 401s 6s/step - dice_metric: 0.8438 - loss: 0.1492 - val_dice_metric: 0.0345 - val_loss: 0.7186 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 403s 6s/step - dice_metric: 0.8899 - loss: 0.1020 - val_dice_metric: 0.0367 - val_loss: 0.7131 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 402s 6s/step - dice_metric: 0.9009 - loss: 0.1078 - val_dice_metric: 0.0355 - val_loss: 0.7365 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 401s 6s/step - dice_metric: 0.9153 - loss: 0.0799 - val_dice_metric: 0.0512 - val_loss: 0.7447 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 402s 6s/step - dice_metric: 0.9262 - loss: 0.0731 - val_dice_metric: 0.2298 - val_loss: 0.6210 - learning_rate: 5.0000e-05
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 405s 6s/step - dice_metric: 0.9403 - loss: 0.0568 - val_dice_metric: 0.4666 - val_loss: 0.4953 - learning_rate: 5.0000e-05
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 404s 6s/step - dice_metric: 0.9332 - loss: 0.0625 - val_dice_metric: 0.5889 - val_loss: 0.4613 - learning_rate: 5.0000e-05
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 402s 6s/step - dice_metric: 0.9375 - loss: 0.0612 - val_dice_metric: 0.6725 - val_loss: 0.5035 - learning_rate: 5.0000e-05
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 404s 6s/step - dice_metric: 0.9498 - loss: 0.0477 - val_dice_metric: 0.6921 - val_loss: 0.5653 - learning_rate: 5.0000e-05
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 402s 6s/step - dice_metric: 0.9538 - loss: 0.0442 - val_dice_metric: 0.6908 - val_loss: 0.5559 - learning_rate: 5.0000e-05
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 403s 6s/step - dice_metric: 0.9555 - loss: 0.0435 - val_dice_metric: 0.7133 - val_loss: 0.4413 - learning_rate: 5.0000e-05
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 402s 6s/step - dice_metric: 0.9561 - loss: 0.0411 - val_dice_metric: 0.7068 - val_loss: 0.4862 - learning_rate: 5.0000e-05
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 402s 6s/step - dice_metric: 0.9615 - loss: 0.0355 - val_dice_metric: 0.7057 - val_loss: 0.5238 - learning_rate: 5.0000e-05
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 400s 6s/step - dice_metric: 0.9559 - loss: 0.0418 - val_dice_metric: 0.7107 - val_loss: 0.5113 - learning_rate: 5.0000e-05
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 408s 6s/step - dice_metric: 0.9616 - loss: 0.0379 - val_dice_metric: 0.7008 - val_loss: 0.6767 - learning_rate: 5.0000e-05
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 403s 6s/step - dice_metric: 0.9618 - loss: 0.0351 - val_dice_metric: 0.7165 - val_loss: 0.5559 - learning_rate: 5.0000e-05
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 416s 6s/step - dice_metric: 0.9670 - loss: 0.0298 - val_dice_metric: 0.7121 - val_loss: 0.5646 - learning_rate: 2.5000e-05
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 404s 6s/step - dice_metric: 0.9703 - loss: 0.0290 - val_dice_metric: 0.7152 - val_loss: 0.4919 - learning_rate: 2.5000e-05
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 403s 6s/step - dice_metric: 0.9711 - loss: 0.0269 - val_dice_metric: 0.7170 - val_loss: 0.5462 - learning_rate: 2.5000e-05
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 403s 6s/step - dice_metric: 0.9664 - loss: 0.0327 - val_dice_metric: 0.7127 - val_loss: 0.5658 - learning_rate: 2.5000e-05
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 401s 6s/step - dice_metric: 0.9705 - loss: 0.0281 - val_dice_metric: 0.7152 - val_loss: 0.5325 - learning_rate: 2.5000e-05
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 401s 6s/step - dice_metric: 0.9727 - loss: 0.0267 - val_dice_metric: 0.7148 - val_loss: 0.5427 - learning_rate: 1.2500e-05
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 402s 6s/step - dice_metric: 0.9720 - loss: 0.0259 - val_dice_metric: 0.7208 - val_loss: 0.5389 - learning_rate: 1.2500e-05
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 416s 6s/step - dice_metric: 0.9748 - loss: 0.0230 - val_dice_metric: 0.7173 - val_loss: 0.5504 - learning_rate: 1.2500e-05
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 444s 7s/step - dice_metric: 0.9728 - loss: 0.0241 - val_dice_metric: 0.7140 - val_loss: 0.5583 - learning_rate: 1.2500e-05
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 426s 6s/step - dice_metric: 0.9705 - loss: 0.0277 - val_dice_metric: 0.7218 - val_loss: 0.5624 - learning_rate: 1.2500e-05
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 419s 6s/step - dice_metric: 0.9743 - loss: 0.0241 - val_dice_metric: 0.7232 - val_loss: 0.5384 - learning_rate: 6.2500e-06
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 417s 6s/step - dice_metric: 0.9736 - loss: 0.0245 - val_dice_metric: 0.7198 - val_loss: 0.5345 - learning_rate: 6.2500e-06
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 443s 7s/step - dice_metric: 0.9707 - loss: 0.0288 - val_dice_metric: 0.7180 - val_loss: 0.5440 - learning_rate: 6.2500e-06
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 433s 6s/step - dice_metric: 0.9757 - loss: 0.0223 - val_dice_metric: 0.7179 - val_loss: 0.5543 - learning_rate: 6.2500e-06
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 427s 6s/step - dice_metric: 0.9749 - loss: 0.0227 - val_dice_metric: 0.7211 - val_loss: 0.5514 - learning_rate: 6.2500e-06
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 425s 6s/step - dice_metric: 0.9721 - loss: 0.0249 - val_dice_metric: 0.7232 - val_loss: 0.5430 - learning_rate: 3.1250e-06
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 426s 6s/step - dice_metric: 0.9683 - loss: 0.0272 - val_dice_metric: 0.7202 - val_loss: 0.5529 - learning_rate: 3.1250e-06
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 433s 6s/step - dice_metric: 0.9738 - loss: 0.0236 - val_dice_metric: 0.7235 - val_loss: 0.5518 - learning_rate: 3.1250e-06
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 426s 6s/step - dice_metric: 0.9758 - loss: 0.0216 - val_dice_metric: 0.7235 - val_loss: 0.5592 - learning_rate: 3.1250e-06
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 425s 6s/step - dice_metric: 0.9734 - loss: 0.0233 - val_dice_metric: 0.7208 - val_loss: 0.5519 - learning_rate: 3.1250e-06
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
import numpy as np   
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from sklearn.model_selection import KFold
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import json

# Bild- und Maskenpfade laden
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testbilder/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testmasken/'

image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Funktionen zum Laden und Vorverarbeiten
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))
    img = np.array(img)
    img = img / 255.0
    img = np.expand_dims(img, axis=-1)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))
    mask = np.array(mask)
    mask = np.where(mask > 128, 1, 0)
    mask = np.expand_dims(mask, axis=-1)
    return mask

# Daten laden
X = np.array([load_and_preprocess_image_pillow(path) for path in image_paths])
Y = np.array([load_and_preprocess_mask_pillow(path) for path in mask_paths])

# Dice Metric
def dice_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice

# Benutzerdefinierte Verlustfunktion
def combined_loss(y_true, y_pred, smooth=1e-6, binary_weight=0.5, dice_weight=0.5):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice_loss = 1 - (2. * intersection + smooth) / (union + smooth)
    return binary_weight * bce + dice_weight * dice_loss

# U-Net Modell
def unet_model(input_size=(192, 256, 1)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    pool1 = Dropout(0.3)(pool1)

    conv2 = Conv2D(128, 3, activation='relu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    pool2 = Dropout(0.4)(pool2)

    conv4 = Conv2D(128, 3, activation='relu', padding='same')(pool2)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(128, 3, activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)
    pool4 = Dropout(0.4)(pool4)

    conv3 = Conv2D(256, 3, activation='relu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    pool3 = Dropout(0.5)(pool3)

    bottleneck = Conv2D(512, 3, activation='relu', padding='same')(pool3)
    bottleneck = BatchNormalization()(bottleneck)

    up6 = UpSampling2D(size=(2, 2))(bottleneck)
    up6 = Conv2D(256, 2, activation='relu', padding='same')(up6)
    up6 = BatchNormalization()(up6)
    merge6 = concatenate([conv3, up6], axis=3)

    conv6 = Conv2D(256, 3, activation='relu', padding='same')(merge6)
    conv6 = BatchNormalization()(conv6)

    up7 = UpSampling2D(size=(2, 2))(conv6)
    up7 = Conv2D(128, 2, activation='relu', padding='same')(up7)
    up7 = BatchNormalization()(up7)
    merge7 = concatenate([conv2, up7], axis=3)

    conv7 = Conv2D(128, 3, activation='relu', padding='same')(merge7)
    conv7 = BatchNormalization()(conv7)

    up8 = UpSampling2D(size=(2, 2))(conv7)
    up8 = Conv2D(64, 2, activation='relu', padding='same')(up8)
    up8 = BatchNormalization()(up8)
    merge8 = concatenate([conv1, up8], axis=3)

    conv8 = Conv2D(64, 3, activation='relu', padding='same')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv2D(64, 3, activation='relu', padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)

    conv8 = Conv2D(1, 1, activation='sigmoid')(conv8)

    model = Model(inputs=inputs, outputs=conv8)
    return model

# K-Fold Cross-Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)

best_val_loss = np.inf
best_model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_trained3.1.h5'

for fold, (train_index, val_index) in enumerate(kf.split(X)):
    print(f"Fold {fold+1}")

    X_train, X_val = X[train_index], X[val_index]
    Y_train, Y_val = Y[train_index], Y[val_index]

    model = unet_model()

    # Callbacks
    reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Modell kompilieren
    optimizer = Adam(learning_rate=1e-4)
    model.compile(optimizer=optimizer, loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5), metrics=[dice_metric])

    
    # Training
    history = model.fit(X_train, Y_train, batch_size=8, epochs=1000, validation_data=(X_val, Y_val), callbacks=[early_stopping, reduce_lr], verbose=1)

    history_file = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/training_history.json_spheroid_segmentation_unet_trained3.1'
    with open(history_file, 'w') as f:
        json.dump(history.history, f)
        
    # Überprüfen, ob dieses Modell das beste ist
    val_loss = min(history.history['val_loss'])
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        model.save(best_model_path)  # Speichern des besten Modells

print(f"Bestes Modell wurde unter {best_model_path} gespeichert.")
print(f"Training Historie wurde unter {history_file} gespeichert.")
# Out:
# Fold 1
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 539s 8s/step - dice_metric: 0.5204 - loss: 0.5072 - val_dice_metric: 0.1940 - val_loss: 0.6552 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 529s 8s/step - dice_metric: 0.7285 - loss: 0.3039 - val_dice_metric: 0.1160 - val_loss: 0.6996 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 514s 8s/step - dice_metric: 0.7985 - loss: 0.2124 - val_dice_metric: 0.2120 - val_loss: 0.6127 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 505s 7s/step - dice_metric: 0.8306 - loss: 0.1801 - val_dice_metric: 0.0563 - val_loss: 0.7902 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 500s 7s/step - dice_metric: 0.8331 - loss: 0.1643 - val_dice_metric: 0.1728 - val_loss: 0.6692 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 503s 7s/step - dice_metric: 0.8685 - loss: 0.1261 - val_dice_metric: 0.1212 - val_loss: 0.7583 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.8777 - loss: 0.1251 - val_dice_metric: 0.0930 - val_loss: 0.8450 - learning_rate: 1.0000e-04
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 499s 7s/step - dice_metric: 0.8839 - loss: 0.1204 - val_dice_metric: 0.3120 - val_loss: 0.6578 - learning_rate: 1.0000e-04
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9005 - loss: 0.0995 - val_dice_metric: 0.5515 - val_loss: 0.4015 - learning_rate: 5.0000e-05
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 499s 7s/step - dice_metric: 0.9166 - loss: 0.0793 - val_dice_metric: 0.8380 - val_loss: 0.1400 - learning_rate: 5.0000e-05
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 501s 7s/step - dice_metric: 0.9113 - loss: 0.0829 - val_dice_metric: 0.8926 - val_loss: 0.0919 - learning_rate: 5.0000e-05
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 512s 8s/step - dice_metric: 0.9125 - loss: 0.0875 - val_dice_metric: 0.9076 - val_loss: 0.0803 - learning_rate: 5.0000e-05
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9243 - loss: 0.0741 - val_dice_metric: 0.9251 - val_loss: 0.0743 - learning_rate: 5.0000e-05
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 501s 7s/step - dice_metric: 0.9207 - loss: 0.0776 - val_dice_metric: 0.9091 - val_loss: 0.1057 - learning_rate: 5.0000e-05
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9390 - loss: 0.0584 - val_dice_metric: 0.9138 - val_loss: 0.0751 - learning_rate: 5.0000e-05
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 498s 7s/step - dice_metric: 0.9344 - loss: 0.0627 - val_dice_metric: 0.9348 - val_loss: 0.0638 - learning_rate: 5.0000e-05
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 501s 7s/step - dice_metric: 0.9347 - loss: 0.0649 - val_dice_metric: 0.9224 - val_loss: 0.0687 - learning_rate: 5.0000e-05
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 511s 8s/step - dice_metric: 0.9138 - loss: 0.0853 - val_dice_metric: 0.9088 - val_loss: 0.0851 - learning_rate: 5.0000e-05
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 515s 8s/step - dice_metric: 0.9289 - loss: 0.0692 - val_dice_metric: 0.9358 - val_loss: 0.0582 - learning_rate: 5.0000e-05
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9418 - loss: 0.0564 - val_dice_metric: 0.9330 - val_loss: 0.0582 - learning_rate: 5.0000e-05
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 500s 7s/step - dice_metric: 0.9381 - loss: 0.0601 - val_dice_metric: 0.9373 - val_loss: 0.0572 - learning_rate: 5.0000e-05
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.9484 - loss: 0.0498 - val_dice_metric: 0.9361 - val_loss: 0.0553 - learning_rate: 5.0000e-05
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9429 - loss: 0.0547 - val_dice_metric: 0.9304 - val_loss: 0.0797 - learning_rate: 5.0000e-05
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9439 - loss: 0.0554 - val_dice_metric: 0.9139 - val_loss: 0.0902 - learning_rate: 5.0000e-05
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9504 - loss: 0.0505 - val_dice_metric: 0.9327 - val_loss: 0.0651 - learning_rate: 5.0000e-05
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.9459 - loss: 0.0510 - val_dice_metric: 0.9398 - val_loss: 0.0533 - learning_rate: 5.0000e-05
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9507 - loss: 0.0475 - val_dice_metric: 0.9116 - val_loss: 0.0828 - learning_rate: 5.0000e-05
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9466 - loss: 0.0517 - val_dice_metric: 0.9352 - val_loss: 0.0647 - learning_rate: 5.0000e-05
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9422 - loss: 0.0572 - val_dice_metric: 0.9269 - val_loss: 0.0843 - learning_rate: 5.0000e-05
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9408 - loss: 0.0550 - val_dice_metric: 0.9425 - val_loss: 0.0517 - learning_rate: 5.0000e-05
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9521 - loss: 0.0468 - val_dice_metric: 0.9392 - val_loss: 0.0541 - learning_rate: 5.0000e-05
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.9486 - loss: 0.0489 - val_dice_metric: 0.9431 - val_loss: 0.0510 - learning_rate: 5.0000e-05
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 497s 7s/step - dice_metric: 0.9497 - loss: 0.0509 - val_dice_metric: 0.9360 - val_loss: 0.0627 - learning_rate: 5.0000e-05
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9479 - loss: 0.0485 - val_dice_metric: 0.9420 - val_loss: 0.0520 - learning_rate: 5.0000e-05
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9567 - loss: 0.0407 - val_dice_metric: 0.9435 - val_loss: 0.0509 - learning_rate: 5.0000e-05
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9519 - loss: 0.0452 - val_dice_metric: 0.9477 - val_loss: 0.0472 - learning_rate: 5.0000e-05
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9614 - loss: 0.0366 - val_dice_metric: 0.9482 - val_loss: 0.0468 - learning_rate: 5.0000e-05
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9466 - loss: 0.0480 - val_dice_metric: 0.9470 - val_loss: 0.0471 - learning_rate: 5.0000e-05
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9621 - loss: 0.0362 - val_dice_metric: 0.9479 - val_loss: 0.0460 - learning_rate: 5.0000e-05
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9616 - loss: 0.0355 - val_dice_metric: 0.9399 - val_loss: 0.0544 - learning_rate: 5.0000e-05
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 497s 7s/step - dice_metric: 0.9628 - loss: 0.0364 - val_dice_metric: 0.9238 - val_loss: 0.0696 - learning_rate: 5.0000e-05
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9525 - loss: 0.0468 - val_dice_metric: 0.9379 - val_loss: 0.0614 - learning_rate: 5.0000e-05
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 497s 7s/step - dice_metric: 0.9576 - loss: 0.0397 - val_dice_metric: 0.9417 - val_loss: 0.0538 - learning_rate: 5.0000e-05
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9645 - loss: 0.0337 - val_dice_metric: 0.9507 - val_loss: 0.0436 - learning_rate: 5.0000e-05
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.9588 - loss: 0.0389 - val_dice_metric: 0.9480 - val_loss: 0.0485 - learning_rate: 5.0000e-05
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9661 - loss: 0.0320 - val_dice_metric: 0.9476 - val_loss: 0.0460 - learning_rate: 5.0000e-05
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9603 - loss: 0.0376 - val_dice_metric: 0.9501 - val_loss: 0.0507 - learning_rate: 5.0000e-05
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9670 - loss: 0.0321 - val_dice_metric: 0.9394 - val_loss: 0.0515 - learning_rate: 5.0000e-05
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9607 - loss: 0.0385 - val_dice_metric: 0.9248 - val_loss: 0.0733 - learning_rate: 5.0000e-05
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9613 - loss: 0.0366 - val_dice_metric: 0.9536 - val_loss: 0.0418 - learning_rate: 2.5000e-05
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.9648 - loss: 0.0333 - val_dice_metric: 0.9527 - val_loss: 0.0426 - learning_rate: 2.5000e-05
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9592 - loss: 0.0400 - val_dice_metric: 0.9479 - val_loss: 0.0465 - learning_rate: 2.5000e-05
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9617 - loss: 0.0364 - val_dice_metric: 0.9526 - val_loss: 0.0421 - learning_rate: 2.5000e-05
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9705 - loss: 0.0276 - val_dice_metric: 0.9531 - val_loss: 0.0422 - learning_rate: 2.5000e-05
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9613 - loss: 0.0360 - val_dice_metric: 0.9523 - val_loss: 0.0432 - learning_rate: 2.5000e-05
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9627 - loss: 0.0343 - val_dice_metric: 0.9547 - val_loss: 0.0406 - learning_rate: 1.2500e-05
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9670 - loss: 0.0311 - val_dice_metric: 0.9521 - val_loss: 0.0415 - learning_rate: 1.2500e-05
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9687 - loss: 0.0287 - val_dice_metric: 0.9526 - val_loss: 0.0425 - learning_rate: 1.2500e-05
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9684 - loss: 0.0301 - val_dice_metric: 0.9525 - val_loss: 0.0420 - learning_rate: 1.2500e-05
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9692 - loss: 0.0277 - val_dice_metric: 0.9505 - val_loss: 0.0433 - learning_rate: 1.2500e-05
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9703 - loss: 0.0271 - val_dice_metric: 0.9513 - val_loss: 0.0429 - learning_rate: 1.2500e-05
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9688 - loss: 0.0280 - val_dice_metric: 0.9539 - val_loss: 0.0408 - learning_rate: 6.2500e-06
# Epoch 63/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9692 - loss: 0.0287 - val_dice_metric: 0.9530 - val_loss: 0.0414 - learning_rate: 6.2500e-06
# Epoch 64/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9682 - loss: 0.0285 - val_dice_metric: 0.9531 - val_loss: 0.0416 - learning_rate: 6.2500e-06
# Epoch 65/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9657 - loss: 0.0313 - val_dice_metric: 0.9535 - val_loss: 0.0412 - learning_rate: 6.2500e-06
# Epoch 66/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9691 - loss: 0.0284 - val_dice_metric: 0.9529 - val_loss: 0.0417 - learning_rate: 6.2500e-06
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 2
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 512s 7s/step - dice_metric: 0.5644 - loss: 0.4638 - val_dice_metric: 0.1882 - val_loss: 0.6483 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.7294 - loss: 0.2869 - val_dice_metric: 0.1050 - val_loss: 0.7076 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.7905 - loss: 0.2085 - val_dice_metric: 0.0867 - val_loss: 0.7304 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.8131 - loss: 0.1905 - val_dice_metric: 0.0661 - val_loss: 0.7639 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 502s 7s/step - dice_metric: 0.8501 - loss: 0.1430 - val_dice_metric: 0.0348 - val_loss: 0.8394 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 499s 7s/step - dice_metric: 0.8594 - loss: 0.1361 - val_dice_metric: 0.5165 - val_loss: 0.3800 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.8649 - loss: 0.1332 - val_dice_metric: 0.4275 - val_loss: 0.4811 - learning_rate: 1.0000e-04
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.8905 - loss: 0.1160 - val_dice_metric: 0.5081 - val_loss: 0.4507 - learning_rate: 1.0000e-04
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.8963 - loss: 0.1087 - val_dice_metric: 0.8154 - val_loss: 0.1610 - learning_rate: 1.0000e-04
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9074 - loss: 0.0884 - val_dice_metric: 0.7381 - val_loss: 0.2435 - learning_rate: 1.0000e-04
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9094 - loss: 0.0943 - val_dice_metric: 0.9067 - val_loss: 0.0845 - learning_rate: 1.0000e-04
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9117 - loss: 0.0867 - val_dice_metric: 0.9254 - val_loss: 0.0755 - learning_rate: 1.0000e-04
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9214 - loss: 0.0793 - val_dice_metric: 0.9349 - val_loss: 0.0642 - learning_rate: 1.0000e-04
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9293 - loss: 0.0694 - val_dice_metric: 0.9277 - val_loss: 0.0752 - learning_rate: 1.0000e-04
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9295 - loss: 0.0700 - val_dice_metric: 0.9131 - val_loss: 0.0810 - learning_rate: 1.0000e-04
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9415 - loss: 0.0534 - val_dice_metric: 0.9341 - val_loss: 0.0630 - learning_rate: 1.0000e-04
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9313 - loss: 0.0666 - val_dice_metric: 0.9266 - val_loss: 0.0834 - learning_rate: 1.0000e-04
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9383 - loss: 0.0592 - val_dice_metric: 0.9131 - val_loss: 0.0915 - learning_rate: 1.0000e-04
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9477 - loss: 0.0504 - val_dice_metric: 0.9376 - val_loss: 0.0608 - learning_rate: 1.0000e-04
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 497s 7s/step - dice_metric: 0.9448 - loss: 0.0527 - val_dice_metric: 0.9389 - val_loss: 0.0724 - learning_rate: 1.0000e-04
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9273 - loss: 0.0773 - val_dice_metric: 0.8795 - val_loss: 0.1398 - learning_rate: 1.0000e-04
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9458 - loss: 0.0532 - val_dice_metric: 0.9404 - val_loss: 0.0629 - learning_rate: 1.0000e-04
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.9464 - loss: 0.0501 - val_dice_metric: 0.9425 - val_loss: 0.0555 - learning_rate: 1.0000e-04
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9487 - loss: 0.0504 - val_dice_metric: 0.9273 - val_loss: 0.0675 - learning_rate: 1.0000e-04
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9555 - loss: 0.0430 - val_dice_metric: 0.9427 - val_loss: 0.0536 - learning_rate: 1.0000e-04
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 497s 7s/step - dice_metric: 0.9555 - loss: 0.0421 - val_dice_metric: 0.9398 - val_loss: 0.0523 - learning_rate: 1.0000e-04
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.9540 - loss: 0.0428 - val_dice_metric: 0.9471 - val_loss: 0.0521 - learning_rate: 1.0000e-04
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 497s 7s/step - dice_metric: 0.9521 - loss: 0.0462 - val_dice_metric: 0.9381 - val_loss: 0.0637 - learning_rate: 1.0000e-04
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9583 - loss: 0.0390 - val_dice_metric: 0.9402 - val_loss: 0.0663 - learning_rate: 1.0000e-04
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9548 - loss: 0.0412 - val_dice_metric: 0.9440 - val_loss: 0.0526 - learning_rate: 1.0000e-04
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9533 - loss: 0.0434 - val_dice_metric: 0.9494 - val_loss: 0.0488 - learning_rate: 1.0000e-04
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9521 - loss: 0.0484 - val_dice_metric: 0.9428 - val_loss: 0.0611 - learning_rate: 1.0000e-04
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 506s 7s/step - dice_metric: 0.9597 - loss: 0.0370 - val_dice_metric: 0.9431 - val_loss: 0.0555 - learning_rate: 1.0000e-04
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 502s 7s/step - dice_metric: 0.9614 - loss: 0.0369 - val_dice_metric: 0.9488 - val_loss: 0.0501 - learning_rate: 1.0000e-04
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9582 - loss: 0.0401 - val_dice_metric: 0.9476 - val_loss: 0.0511 - learning_rate: 1.0000e-04
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9584 - loss: 0.0386 - val_dice_metric: 0.9504 - val_loss: 0.0479 - learning_rate: 1.0000e-04
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9638 - loss: 0.0335 - val_dice_metric: 0.9405 - val_loss: 0.0734 - learning_rate: 1.0000e-04
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 507s 7s/step - dice_metric: 0.9636 - loss: 0.0352 - val_dice_metric: 0.9515 - val_loss: 0.0517 - learning_rate: 1.0000e-04
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 502s 7s/step - dice_metric: 0.9642 - loss: 0.0335 - val_dice_metric: 0.9522 - val_loss: 0.0536 - learning_rate: 1.0000e-04
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 496s 7s/step - dice_metric: 0.9662 - loss: 0.0332 - val_dice_metric: 0.9509 - val_loss: 0.0513 - learning_rate: 1.0000e-04
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9652 - loss: 0.0323 - val_dice_metric: 0.9548 - val_loss: 0.0485 - learning_rate: 1.0000e-04
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 509s 7s/step - dice_metric: 0.9655 - loss: 0.0319 - val_dice_metric: 0.9529 - val_loss: 0.0512 - learning_rate: 5.0000e-05
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9660 - loss: 0.0306 - val_dice_metric: 0.9547 - val_loss: 0.0480 - learning_rate: 5.0000e-05
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 506s 7s/step - dice_metric: 0.9691 - loss: 0.0286 - val_dice_metric: 0.9517 - val_loss: 0.0509 - learning_rate: 5.0000e-05
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 539s 8s/step - dice_metric: 0.9671 - loss: 0.0304 - val_dice_metric: 0.9539 - val_loss: 0.0481 - learning_rate: 5.0000e-05
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 516s 8s/step - dice_metric: 0.9694 - loss: 0.0286 - val_dice_metric: 0.9520 - val_loss: 0.0506 - learning_rate: 5.0000e-05
# Fold 3
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 522s 7s/step - dice_metric: 0.5469 - loss: 0.4799 - val_dice_metric: 0.1921 - val_loss: 0.6490 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 506s 7s/step - dice_metric: 0.7714 - loss: 0.2439 - val_dice_metric: 0.1026 - val_loss: 0.7133 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.7950 - loss: 0.2111 - val_dice_metric: 0.0751 - val_loss: 0.7527 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.8433 - loss: 0.1476 - val_dice_metric: 0.0312 - val_loss: 0.8523 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.8599 - loss: 0.1457 - val_dice_metric: 0.1692 - val_loss: 0.6634 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 501s 7s/step - dice_metric: 0.8748 - loss: 0.1247 - val_dice_metric: 0.1295 - val_loss: 0.7908 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 488s 7s/step - dice_metric: 0.8875 - loss: 0.1100 - val_dice_metric: 0.2624 - val_loss: 0.6790 - learning_rate: 5.0000e-05
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9090 - loss: 0.0907 - val_dice_metric: 0.3901 - val_loss: 0.5581 - learning_rate: 5.0000e-05
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.9051 - loss: 0.0898 - val_dice_metric: 0.7722 - val_loss: 0.2115 - learning_rate: 5.0000e-05
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9200 - loss: 0.0771 - val_dice_metric: 0.8413 - val_loss: 0.1408 - learning_rate: 5.0000e-05
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 488s 7s/step - dice_metric: 0.9126 - loss: 0.0863 - val_dice_metric: 0.8697 - val_loss: 0.1423 - learning_rate: 5.0000e-05
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 487s 7s/step - dice_metric: 0.9105 - loss: 0.0817 - val_dice_metric: 0.8841 - val_loss: 0.1062 - learning_rate: 5.0000e-05
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9261 - loss: 0.0731 - val_dice_metric: 0.9062 - val_loss: 0.0924 - learning_rate: 5.0000e-05
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 488s 7s/step - dice_metric: 0.9274 - loss: 0.0690 - val_dice_metric: 0.8973 - val_loss: 0.1071 - learning_rate: 5.0000e-05
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9359 - loss: 0.0617 - val_dice_metric: 0.9090 - val_loss: 0.0889 - learning_rate: 5.0000e-05
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9321 - loss: 0.0654 - val_dice_metric: 0.9101 - val_loss: 0.0973 - learning_rate: 5.0000e-05
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 505s 7s/step - dice_metric: 0.9424 - loss: 0.0555 - val_dice_metric: 0.9056 - val_loss: 0.0973 - learning_rate: 5.0000e-05
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.9377 - loss: 0.0594 - val_dice_metric: 0.9107 - val_loss: 0.0984 - learning_rate: 5.0000e-05
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 502s 7s/step - dice_metric: 0.9473 - loss: 0.0505 - val_dice_metric: 0.9099 - val_loss: 0.0895 - learning_rate: 5.0000e-05
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.9483 - loss: 0.0467 - val_dice_metric: 0.9142 - val_loss: 0.0882 - learning_rate: 5.0000e-05
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 494s 7s/step - dice_metric: 0.9384 - loss: 0.0575 - val_dice_metric: 0.9041 - val_loss: 0.0993 - learning_rate: 5.0000e-05
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 487s 7s/step - dice_metric: 0.9353 - loss: 0.0613 - val_dice_metric: 0.9104 - val_loss: 0.0932 - learning_rate: 5.0000e-05
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9556 - loss: 0.0406 - val_dice_metric: 0.9204 - val_loss: 0.0792 - learning_rate: 5.0000e-05
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 503s 7s/step - dice_metric: 0.9414 - loss: 0.0546 - val_dice_metric: 0.9070 - val_loss: 0.1187 - learning_rate: 5.0000e-05
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9486 - loss: 0.0491 - val_dice_metric: 0.9211 - val_loss: 0.0799 - learning_rate: 5.0000e-05
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 488s 7s/step - dice_metric: 0.9456 - loss: 0.0510 - val_dice_metric: 0.9146 - val_loss: 0.0872 - learning_rate: 5.0000e-05
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 488s 7s/step - dice_metric: 0.9456 - loss: 0.0517 - val_dice_metric: 0.9212 - val_loss: 0.0986 - learning_rate: 5.0000e-05
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9612 - loss: 0.0363 - val_dice_metric: 0.9253 - val_loss: 0.0746 - learning_rate: 5.0000e-05
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 500s 7s/step - dice_metric: 0.9591 - loss: 0.0382 - val_dice_metric: 0.9273 - val_loss: 0.0723 - learning_rate: 5.0000e-05
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 518s 8s/step - dice_metric: 0.9530 - loss: 0.0435 - val_dice_metric: 0.9273 - val_loss: 0.0821 - learning_rate: 5.0000e-05
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9504 - loss: 0.0457 - val_dice_metric: 0.9277 - val_loss: 0.0812 - learning_rate: 5.0000e-05
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.9551 - loss: 0.0432 - val_dice_metric: 0.9287 - val_loss: 0.0745 - learning_rate: 5.0000e-05
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 484s 7s/step - dice_metric: 0.9556 - loss: 0.0405 - val_dice_metric: 0.9265 - val_loss: 0.0719 - learning_rate: 5.0000e-05
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 501s 7s/step - dice_metric: 0.9537 - loss: 0.0438 - val_dice_metric: 0.9327 - val_loss: 0.0743 - learning_rate: 5.0000e-05
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 531s 8s/step - dice_metric: 0.9604 - loss: 0.0374 - val_dice_metric: 0.9140 - val_loss: 0.1004 - learning_rate: 5.0000e-05
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 527s 8s/step - dice_metric: 0.9591 - loss: 0.0392 - val_dice_metric: 0.9282 - val_loss: 0.0756 - learning_rate: 5.0000e-05
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 525s 8s/step - dice_metric: 0.9597 - loss: 0.0396 - val_dice_metric: 0.9137 - val_loss: 0.1013 - learning_rate: 5.0000e-05
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 538s 8s/step - dice_metric: 0.9584 - loss: 0.0413 - val_dice_metric: 0.9251 - val_loss: 0.0825 - learning_rate: 5.0000e-05
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 540s 8s/step - dice_metric: 0.9650 - loss: 0.0326 - val_dice_metric: 0.9280 - val_loss: 0.0735 - learning_rate: 2.5000e-05
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 536s 8s/step - dice_metric: 0.9648 - loss: 0.0311 - val_dice_metric: 0.9329 - val_loss: 0.0728 - learning_rate: 2.5000e-05
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 540s 8s/step - dice_metric: 0.9650 - loss: 0.0317 - val_dice_metric: 0.9300 - val_loss: 0.0798 - learning_rate: 2.5000e-05
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 540s 8s/step - dice_metric: 0.9676 - loss: 0.0316 - val_dice_metric: 0.9327 - val_loss: 0.0744 - learning_rate: 2.5000e-05
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 544s 8s/step - dice_metric: 0.9581 - loss: 0.0391 - val_dice_metric: 0.9325 - val_loss: 0.0756 - learning_rate: 2.5000e-05
# Fold 4
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 558s 8s/step - dice_metric: 0.5438 - loss: 0.4741 - val_dice_metric: 0.1897 - val_loss: 0.6457 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 543s 8s/step - dice_metric: 0.7556 - loss: 0.2570 - val_dice_metric: 0.1201 - val_loss: 0.6972 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 535s 8s/step - dice_metric: 0.8246 - loss: 0.1725 - val_dice_metric: 0.0472 - val_loss: 0.8168 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 507s 7s/step - dice_metric: 0.8473 - loss: 0.1439 - val_dice_metric: 0.0271 - val_loss: 0.8802 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.8688 - loss: 0.1259 - val_dice_metric: 0.0218 - val_loss: 0.9028 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.8678 - loss: 0.1288 - val_dice_metric: 0.0198 - val_loss: 0.9306 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 485s 7s/step - dice_metric: 0.8905 - loss: 0.1078 - val_dice_metric: 0.5390 - val_loss: 0.3996 - learning_rate: 5.0000e-05
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 478s 7s/step - dice_metric: 0.9006 - loss: 0.0942 - val_dice_metric: 0.5482 - val_loss: 0.4097 - learning_rate: 5.0000e-05
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 475s 7s/step - dice_metric: 0.9126 - loss: 0.0826 - val_dice_metric: 0.7116 - val_loss: 0.2721 - learning_rate: 5.0000e-05
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 476s 7s/step - dice_metric: 0.9212 - loss: 0.0730 - val_dice_metric: 0.8379 - val_loss: 0.1550 - learning_rate: 5.0000e-05
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 488s 7s/step - dice_metric: 0.9225 - loss: 0.0749 - val_dice_metric: 0.8880 - val_loss: 0.1142 - learning_rate: 5.0000e-05
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 503s 7s/step - dice_metric: 0.9322 - loss: 0.0636 - val_dice_metric: 0.9033 - val_loss: 0.1055 - learning_rate: 5.0000e-05
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9233 - loss: 0.0723 - val_dice_metric: 0.9120 - val_loss: 0.1076 - learning_rate: 5.0000e-05
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9234 - loss: 0.0717 - val_dice_metric: 0.8859 - val_loss: 0.1464 - learning_rate: 5.0000e-05
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.9329 - loss: 0.0635 - val_dice_metric: 0.9171 - val_loss: 0.1083 - learning_rate: 5.0000e-05
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9343 - loss: 0.0625 - val_dice_metric: 0.9196 - val_loss: 0.1068 - learning_rate: 5.0000e-05
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9406 - loss: 0.0567 - val_dice_metric: 0.9182 - val_loss: 0.0993 - learning_rate: 5.0000e-05
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 501s 7s/step - dice_metric: 0.9231 - loss: 0.0720 - val_dice_metric: 0.9125 - val_loss: 0.1075 - learning_rate: 5.0000e-05
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9348 - loss: 0.0636 - val_dice_metric: 0.9151 - val_loss: 0.0911 - learning_rate: 5.0000e-05
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9465 - loss: 0.0501 - val_dice_metric: 0.9213 - val_loss: 0.1003 - learning_rate: 5.0000e-05
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9416 - loss: 0.0543 - val_dice_metric: 0.9098 - val_loss: 0.1070 - learning_rate: 5.0000e-05
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.9352 - loss: 0.0623 - val_dice_metric: 0.9216 - val_loss: 0.0994 - learning_rate: 5.0000e-05
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9455 - loss: 0.0495 - val_dice_metric: 0.9254 - val_loss: 0.0891 - learning_rate: 5.0000e-05
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.9413 - loss: 0.0550 - val_dice_metric: 0.9277 - val_loss: 0.0832 - learning_rate: 5.0000e-05
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9518 - loss: 0.0459 - val_dice_metric: 0.9240 - val_loss: 0.0889 - learning_rate: 5.0000e-05
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 495s 7s/step - dice_metric: 0.9526 - loss: 0.0430 - val_dice_metric: 0.9297 - val_loss: 0.0867 - learning_rate: 5.0000e-05
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9451 - loss: 0.0530 - val_dice_metric: 0.9283 - val_loss: 0.0838 - learning_rate: 5.0000e-05
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.9537 - loss: 0.0442 - val_dice_metric: 0.9303 - val_loss: 0.0866 - learning_rate: 5.0000e-05
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9587 - loss: 0.0383 - val_dice_metric: 0.9328 - val_loss: 0.0758 - learning_rate: 5.0000e-05
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9571 - loss: 0.0392 - val_dice_metric: 0.9363 - val_loss: 0.0722 - learning_rate: 5.0000e-05
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9532 - loss: 0.0470 - val_dice_metric: 0.9253 - val_loss: 0.0967 - learning_rate: 5.0000e-05
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.9394 - loss: 0.0584 - val_dice_metric: 0.9302 - val_loss: 0.0879 - learning_rate: 5.0000e-05
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.9495 - loss: 0.0492 - val_dice_metric: 0.9249 - val_loss: 0.1029 - learning_rate: 5.0000e-05
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.9459 - loss: 0.0506 - val_dice_metric: 0.9346 - val_loss: 0.0821 - learning_rate: 5.0000e-05
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9531 - loss: 0.0445 - val_dice_metric: 0.9329 - val_loss: 0.0894 - learning_rate: 5.0000e-05
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 488s 7s/step - dice_metric: 0.9571 - loss: 0.0420 - val_dice_metric: 0.9368 - val_loss: 0.0808 - learning_rate: 2.5000e-05
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9615 - loss: 0.0365 - val_dice_metric: 0.9363 - val_loss: 0.0765 - learning_rate: 2.5000e-05
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9649 - loss: 0.0319 - val_dice_metric: 0.9368 - val_loss: 0.0739 - learning_rate: 2.5000e-05
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.9627 - loss: 0.0340 - val_dice_metric: 0.9373 - val_loss: 0.0763 - learning_rate: 2.5000e-05
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 498s 7s/step - dice_metric: 0.9568 - loss: 0.0395 - val_dice_metric: 0.9384 - val_loss: 0.0810 - learning_rate: 2.5000e-05
# Fold 5
# Epoch 1/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 515s 7s/step - dice_metric: 0.5701 - loss: 0.4609 - val_dice_metric: 0.1922 - val_loss: 0.6408 - learning_rate: 1.0000e-04
# Epoch 2/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.7726 - loss: 0.2583 - val_dice_metric: 0.1375 - val_loss: 0.6735 - learning_rate: 1.0000e-04
# Epoch 3/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 493s 7s/step - dice_metric: 0.7847 - loss: 0.2207 - val_dice_metric: 0.0688 - val_loss: 0.7640 - learning_rate: 1.0000e-04
# Epoch 4/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 487s 7s/step - dice_metric: 0.8377 - loss: 0.1696 - val_dice_metric: 0.0459 - val_loss: 0.8114 - learning_rate: 1.0000e-04
# Epoch 5/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 492s 7s/step - dice_metric: 0.8428 - loss: 0.1510 - val_dice_metric: 0.0204 - val_loss: 0.8966 - learning_rate: 1.0000e-04
# Epoch 6/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 487s 7s/step - dice_metric: 0.8903 - loss: 0.1039 - val_dice_metric: 0.0263 - val_loss: 0.8750 - learning_rate: 1.0000e-04
# Epoch 7/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.8975 - loss: 0.1012 - val_dice_metric: 0.1430 - val_loss: 0.7569 - learning_rate: 5.0000e-05
# Epoch 8/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 489s 7s/step - dice_metric: 0.9077 - loss: 0.0902 - val_dice_metric: 0.4080 - val_loss: 0.5322 - learning_rate: 5.0000e-05
# Epoch 9/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 491s 7s/step - dice_metric: 0.8987 - loss: 0.0968 - val_dice_metric: 0.5488 - val_loss: 0.4149 - learning_rate: 5.0000e-05
# Epoch 10/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 488s 7s/step - dice_metric: 0.9070 - loss: 0.0899 - val_dice_metric: 0.7801 - val_loss: 0.1930 - learning_rate: 5.0000e-05
# Epoch 11/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 490s 7s/step - dice_metric: 0.9282 - loss: 0.0699 - val_dice_metric: 0.9090 - val_loss: 0.0812 - learning_rate: 5.0000e-05
# Epoch 12/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 484s 7s/step - dice_metric: 0.9184 - loss: 0.0777 - val_dice_metric: 0.9160 - val_loss: 0.0788 - learning_rate: 5.0000e-05
# Epoch 13/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 473s 7s/step - dice_metric: 0.9225 - loss: 0.0740 - val_dice_metric: 0.9265 - val_loss: 0.0674 - learning_rate: 5.0000e-05
# Epoch 14/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9284 - loss: 0.0658 - val_dice_metric: 0.9162 - val_loss: 0.0741 - learning_rate: 5.0000e-05
# Epoch 15/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 471s 7s/step - dice_metric: 0.9306 - loss: 0.0672 - val_dice_metric: 0.9316 - val_loss: 0.0642 - learning_rate: 5.0000e-05
# Epoch 16/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 467s 7s/step - dice_metric: 0.9210 - loss: 0.0799 - val_dice_metric: 0.9247 - val_loss: 0.0683 - learning_rate: 5.0000e-05
# Epoch 17/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 469s 7s/step - dice_metric: 0.9348 - loss: 0.0632 - val_dice_metric: 0.9315 - val_loss: 0.0624 - learning_rate: 5.0000e-05
# Epoch 18/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9371 - loss: 0.0634 - val_dice_metric: 0.9315 - val_loss: 0.0680 - learning_rate: 5.0000e-05
# Epoch 19/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - dice_metric: 0.9350 - loss: 0.0641 - val_dice_metric: 0.9309 - val_loss: 0.0614 - learning_rate: 5.0000e-05
# Epoch 20/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9437 - loss: 0.0530 - val_dice_metric: 0.9327 - val_loss: 0.0607 - learning_rate: 5.0000e-05
# Epoch 21/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 471s 7s/step - dice_metric: 0.9457 - loss: 0.0537 - val_dice_metric: 0.9382 - val_loss: 0.0576 - learning_rate: 5.0000e-05
# Epoch 22/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9482 - loss: 0.0502 - val_dice_metric: 0.9259 - val_loss: 0.0728 - learning_rate: 5.0000e-05
# Epoch 23/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9455 - loss: 0.0552 - val_dice_metric: 0.9392 - val_loss: 0.0567 - learning_rate: 5.0000e-05
# Epoch 24/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 469s 7s/step - dice_metric: 0.9511 - loss: 0.0470 - val_dice_metric: 0.9267 - val_loss: 0.0728 - learning_rate: 5.0000e-05
# Epoch 25/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9495 - loss: 0.0489 - val_dice_metric: 0.9325 - val_loss: 0.0611 - learning_rate: 5.0000e-05
# Epoch 26/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - dice_metric: 0.9458 - loss: 0.0511 - val_dice_metric: 0.9258 - val_loss: 0.0659 - learning_rate: 5.0000e-05
# Epoch 27/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - dice_metric: 0.9395 - loss: 0.0584 - val_dice_metric: 0.9288 - val_loss: 0.0687 - learning_rate: 5.0000e-05
# Epoch 28/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 469s 7s/step - dice_metric: 0.9552 - loss: 0.0436 - val_dice_metric: 0.9414 - val_loss: 0.0546 - learning_rate: 5.0000e-05
# Epoch 29/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9540 - loss: 0.0427 - val_dice_metric: 0.9405 - val_loss: 0.0562 - learning_rate: 5.0000e-05
# Epoch 30/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - dice_metric: 0.9538 - loss: 0.0446 - val_dice_metric: 0.9393 - val_loss: 0.0534 - learning_rate: 5.0000e-05
# Epoch 31/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 471s 7s/step - dice_metric: 0.9567 - loss: 0.0402 - val_dice_metric: 0.9400 - val_loss: 0.0552 - learning_rate: 5.0000e-05
# Epoch 32/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 467s 7s/step - dice_metric: 0.9534 - loss: 0.0435 - val_dice_metric: 0.9421 - val_loss: 0.0524 - learning_rate: 5.0000e-05
# Epoch 33/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 469s 7s/step - dice_metric: 0.9614 - loss: 0.0366 - val_dice_metric: 0.9324 - val_loss: 0.0638 - learning_rate: 5.0000e-05
# Epoch 34/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9561 - loss: 0.0422 - val_dice_metric: 0.9388 - val_loss: 0.0564 - learning_rate: 5.0000e-05
# Epoch 35/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 471s 7s/step - dice_metric: 0.9577 - loss: 0.0403 - val_dice_metric: 0.9462 - val_loss: 0.0515 - learning_rate: 5.0000e-05
# Epoch 36/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9493 - loss: 0.0480 - val_dice_metric: 0.9411 - val_loss: 0.0562 - learning_rate: 5.0000e-05
# Epoch 37/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 471s 7s/step - dice_metric: 0.9596 - loss: 0.0387 - val_dice_metric: 0.9367 - val_loss: 0.0569 - learning_rate: 5.0000e-05
# Epoch 38/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9591 - loss: 0.0390 - val_dice_metric: 0.9415 - val_loss: 0.0556 - learning_rate: 5.0000e-05
# Epoch 39/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - dice_metric: 0.9616 - loss: 0.0368 - val_dice_metric: 0.9488 - val_loss: 0.0488 - learning_rate: 5.0000e-05
# Epoch 40/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 467s 7s/step - dice_metric: 0.9596 - loss: 0.0394 - val_dice_metric: 0.9440 - val_loss: 0.0533 - learning_rate: 5.0000e-05
# Epoch 41/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - dice_metric: 0.9610 - loss: 0.0389 - val_dice_metric: 0.9431 - val_loss: 0.0546 - learning_rate: 5.0000e-05
# Epoch 42/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9652 - loss: 0.0335 - val_dice_metric: 0.9425 - val_loss: 0.0518 - learning_rate: 5.0000e-05
# Epoch 43/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - dice_metric: 0.9651 - loss: 0.0325 - val_dice_metric: 0.9418 - val_loss: 0.0517 - learning_rate: 5.0000e-05
# Epoch 44/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 467s 7s/step - dice_metric: 0.9594 - loss: 0.0374 - val_dice_metric: 0.9431 - val_loss: 0.0519 - learning_rate: 5.0000e-05
# Epoch 45/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - dice_metric: 0.9604 - loss: 0.0372 - val_dice_metric: 0.9373 - val_loss: 0.0580 - learning_rate: 2.5000e-05
# Epoch 46/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9684 - loss: 0.0298 - val_dice_metric: 0.9458 - val_loss: 0.0487 - learning_rate: 2.5000e-05
# Epoch 47/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 474s 7s/step - dice_metric: 0.9557 - loss: 0.0392 - val_dice_metric: 0.9483 - val_loss: 0.0469 - learning_rate: 2.5000e-05
# Epoch 48/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 471s 7s/step - dice_metric: 0.9613 - loss: 0.0360 - val_dice_metric: 0.9451 - val_loss: 0.0513 - learning_rate: 2.5000e-05
# Epoch 49/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 480s 7s/step - dice_metric: 0.9617 - loss: 0.0364 - val_dice_metric: 0.9455 - val_loss: 0.0502 - learning_rate: 2.5000e-05
# Epoch 50/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9694 - loss: 0.0287 - val_dice_metric: 0.9454 - val_loss: 0.0495 - learning_rate: 2.5000e-05
# Epoch 51/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 471s 7s/step - dice_metric: 0.9625 - loss: 0.0348 - val_dice_metric: 0.9442 - val_loss: 0.0504 - learning_rate: 2.5000e-05
# Epoch 52/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 467s 7s/step - dice_metric: 0.9685 - loss: 0.0291 - val_dice_metric: 0.9491 - val_loss: 0.0465 - learning_rate: 2.5000e-05
# Epoch 53/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 471s 7s/step - dice_metric: 0.9683 - loss: 0.0286 - val_dice_metric: 0.9469 - val_loss: 0.0483 - learning_rate: 2.5000e-05
# Epoch 54/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 471s 7s/step - dice_metric: 0.9651 - loss: 0.0319 - val_dice_metric: 0.9448 - val_loss: 0.0526 - learning_rate: 2.5000e-05
# Epoch 55/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 469s 7s/step - dice_metric: 0.9653 - loss: 0.0331 - val_dice_metric: 0.9421 - val_loss: 0.0526 - learning_rate: 2.5000e-05
# Epoch 56/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9654 - loss: 0.0317 - val_dice_metric: 0.9468 - val_loss: 0.0491 - learning_rate: 2.5000e-05
# Epoch 57/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - dice_metric: 0.9649 - loss: 0.0320 - val_dice_metric: 0.9440 - val_loss: 0.0494 - learning_rate: 2.5000e-05
# Epoch 58/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 471s 7s/step - dice_metric: 0.9701 - loss: 0.0269 - val_dice_metric: 0.9445 - val_loss: 0.0498 - learning_rate: 1.2500e-05
# Epoch 59/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 470s 7s/step - dice_metric: 0.9685 - loss: 0.0286 - val_dice_metric: 0.9458 - val_loss: 0.0498 - learning_rate: 1.2500e-05
# Epoch 60/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9674 - loss: 0.0291 - val_dice_metric: 0.9435 - val_loss: 0.0517 - learning_rate: 1.2500e-05
# Epoch 61/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 469s 7s/step - dice_metric: 0.9707 - loss: 0.0273 - val_dice_metric: 0.9420 - val_loss: 0.0531 - learning_rate: 1.2500e-05
# Epoch 62/1000
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 468s 7s/step - dice_metric: 0.9706 - loss: 0.0263 - val_dice_metric: 0.9445 - val_loss: 0.0504 - learning_rate: 1.2500e-05
# Bestes Modell wurde unter C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_trained3.1.h5 gespeichert.
# Training Historie wurde unter C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/training_history.json_spheroid_segmentation_unet_trained3.1 gespeichert.

# %%
import json
import matplotlib.pyplot as plt

# Lade den Trainingsverlauf aus der JSON-Datei
history_file = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/training_history.json_spheroid_segmentation_unet_trained3.1'

# Öffnen und Laden der JSON-Datei
with open(history_file, 'r') as Trainingsverlauf:
    history = json.load(Trainingsverlauf)

# Plotten
plt.figure(figsize=(12, 6))  # Breite und Höhe des gesamten Plots

# Verlust (Loss)
plt.subplot(1, 2, 1)  # 1 Zeile, 2 Spalten, 1. Plot
plt.plot(history['loss'], label='Training Loss', color='blue', linewidth=2)
plt.plot(history['val_loss'], label='Validation Loss', color='orange', linewidth=2)
plt.title('Training and Validation Loss', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Loss', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True)

# Dice Metric
plt.subplot(1, 2, 2)  # 1 Zeile, 2 Spalten, 2. Plot
plt.plot(history['dice_metric'], label='Training Dice Metric', color='blue', linewidth=2)
plt.plot(history['val_dice_metric'], label='Validation Dice Metric', color='orange', linewidth=2)
plt.title('Training and Validation Dice Metric', fontsize=14)
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Dice Metric', fontsize=12)
plt.legend(fontsize=10)
plt.grid(True)

# Abstände zwischen den Subplots anpassen
plt.tight_layout()

# Plot anzeigen und speichern
plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/training_history_spheroid_segmentation_unet_trained3.1.png')
plt.show()

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

def draw_contours_and_centroid(binary_mask, output_path):
    # Finden der Konturen
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Erstellen eines Farbbilds zum Zeichnen
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    
    # Zeichnen der Konturen
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    
    # Berechnung und Zeichnen des Schwerpunkts
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
    
    # Speichern des Bildes mit Konturen und Schwerpunkt
    cv2.imwrite(output_path, color_mask)

# Laden und Vorverarbeiten der Bilder mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')  # Convert to grayscale
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x196)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

# Vorhersage mit dem Modell machen
def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
    predicted_mask = model.predict(image)  # Vorhersage machen
    return np.squeeze(predicted_mask)  # Batch-Dimension entfernen

# Funktion zur Berechnung der mittleren Konturgröße
def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

# Funktion zur Auswahl des besten Schwellenwerts
def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0

    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size  # Anpassen der Bewertungsmetrik nach Bedarf

            if score > best_score:
                best_score = score
                best_threshold = threshold

    return best_threshold

# Funktion zur Berechnung des mittleren Durchmessers
def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)


# Pfade definieren
input_dir = "C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testset von julia"
output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher test/'
excel_file_path = 'C:/Users/chris/Documents/Testset.xlsx'


# Lade das Modell mit den definierten custom_objects
model = load_model('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_trained3.h5', compile=False)

# Kompiliere das Modell nachträglich
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
              loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5), 
              metrics=[dice_metric])
# Modell laden
#model = tf.keras.models.load_model(model_path)


# Daten aus der Excel-Tabelle laden
predicted_diameters = []
df_manual = pd.read_excel(excel_file_path, header=0)  # Daten ab der zweiten Zeile 
manual_diameters = df_manual.iloc[:, 1].tolist()  # Durchmesser sind in der zweiten Spalte

# Debug-Ausgabe: Anzahl der manuellen Durchmesser
print(f"Anzahl der manuellen Durchmesser: {len(df_manual)}")

# Skalierungsfaktoren berechnen
scale_factor_width = 1296 / 256  # Originalbreite / skalierte Breite
scale_factor_height = 966 / 196  # Originalhöhe / skalierte Höhe

# Listen für die berechneten Durchmesser und die manuell gemessenen Durchmesser
manual_diameters = []

# Iteration über alle TIFF-Dateien im Eingabeordner
tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Debug-Ausgabe: Anzahl der TIFF-Dateien
print(f"Anzahl der TIFF-Dateien: {len(tif_files)}")

# Überprüfen, ob die Anzahl der Dateien mit der Anzahl der manuellen Messungen übereinstimmt
if len(tif_files) != len(df_manual):
    print("Die Anzahl der Bilddateien stimmt nicht mit der Anzahl der manuellen Messungen überein.")
else:
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        
        try:
            # Bild laden und vorverarbeiten
            image = load_and_preprocess_image_pillow(img_path)
            # Vorhersage mit dem Modell machen
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            # Besten Schwellenwert für Konturen finden
            best_threshold = find_best_threshold(predicted_mask)

            # Maske mit dem besten Schwellenwert erstellen
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
            
            # Konturen finden
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            # Filtere Konturen nach Schmalheitsverhältnis
            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:  # Anpassen des Schmalheitsverhältnisses nach Bedarf
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            # Die größte Kontur nach dem Flächeninhalt finden
            largest_contour = max(filtered_contours, key=cv2.contourArea)

            # Berechne den Schwerpunkt der Kontur
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

            # Berechne den mittleren Durchmesser
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width) *0.994     #mit faktor für verzerrung

            # Berechnung des Flächeninhalts
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.3745 * scale_factor_width * 0.3745 * scale_factor_height)

            # Ergebnisse hinzufügen
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])  # Manuell gemessener Durchmesser hinzufügen

            # Ausgabepfad für das segmentierte Bild definieren
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            draw_contours_and_centroid(binary_mask, output_path)

            # Maske als TIFF-Datei speichern
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")

            # Ergebnisse ausgeben
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Flächeninhalt: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    # Debug-Ausgabe: Anzahl der erfolgreichen Vorhersagen und manuell gemessenen Durchmesser
    print(f"Anzahl der erfolgreichen Vorhersagen: {len(predicted_diameters)}")
    print(f"Anzahl der zugehörigen manuellen Durchmesser: {len(manual_diameters)}")

    # Ergebnisse in ein DataFrame konvertieren
    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    # Ergebnisse in eine Excel-Datei exportieren
    excel_output_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx'
    df_results.to_excel(excel_output_path, index=False)

    # Berechnung der Metriken zur Bewertung der Modellgenauigkeit
    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)

        print(f"\nMetriken zur Bewertung der Modellgenauigkeit:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")

        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print("Keine ausreichenden Daten zur Berechnung der Metriken vorhanden.")

    # Scatterplot erstellen
    plt.figure(figsize=(10, 6))
    plt.scatter(manual_diameters, predicted_diameters, color='blue', label='Vorhergesagt vs. Manuell')
    plt.plot([min(manual_diameters), max(manual_diameters)], [min(manual_diameters), max(manual_diameters)], color='red', linestyle='--', label='Perfekte Übereinstimmung')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title('Vergleich von manuellen und vorhergesagten Durchmessern')
    plt.legend()
    plt.grid(True)
    plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/scatterplot.png')
    plt.show()

#7 , 36 , 38 , 19 reißen
# Out:
# Anzahl der manuellen Durchmesser: 50
# Anzahl der TIFF-Dateien: 50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 951ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_B8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_B8_ch00.tif, Durchmesser: 121.41 µm, Flächeninhalt: 11486.68 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_D7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_D7_ch00.tif, Durchmesser: 120.76 µm, Flächeninhalt: 11362.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E7_ch00.tif, Durchmesser: 122.34 µm, Flächeninhalt: 11640.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E8_ch00.tif, Durchmesser: 125.70 µm, Flächeninhalt: 12310.78 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 576ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F7_ch00.tif, Durchmesser: 126.88 µm, Flächeninhalt: 12543.49 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F8_ch00.tif, Durchmesser: 120.96 µm, Flächeninhalt: 11409.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_C5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_C5_ch00.tif, Durchmesser: 93.05 µm, Flächeninhalt: 6757.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D5_ch00.tif, Durchmesser: 93.32 µm, Flächeninhalt: 6808.02 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D6_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D6_ch00.tif, Durchmesser: 94.06 µm, Flächeninhalt: 6897.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_E5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_E5_ch00.tif, Durchmesser: 86.12 µm, Flächeninhalt: 5812.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_F6_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_F6_ch00.tif, Durchmesser: 87.14 µm, Flächeninhalt: 5945.43 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C11_ch00.tif, Durchmesser: 130.77 µm, Flächeninhalt: 13308.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C12_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C12_ch00.tif, Durchmesser: 121.98 µm, Flächeninhalt: 11577.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_D11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_D11_ch00.tif, Durchmesser: 130.88 µm, Flächeninhalt: 13330.85 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_G11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_G11_ch00.tif, Durchmesser: 125.56 µm, Flächeninhalt: 12293.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D10_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D10_ch00.tif, Durchmesser: 109.61 µm, Flächeninhalt: 9352.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D9_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D9_ch00.tif, Durchmesser: 104.76 µm, Flächeninhalt: 8545.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E10_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E10_ch00.tif, Durchmesser: 101.32 µm, Flächeninhalt: 8013.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E9_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E9_ch00.tif, Durchmesser: 104.11 µm, Flächeninhalt: 8433.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_B8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_B8_ch00.tif, Durchmesser: 141.12 µm, Flächeninhalt: 15514.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_D7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_D7_ch00.tif, Durchmesser: 145.48 µm, Flächeninhalt: 16483.78 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E7_ch00.tif, Durchmesser: 144.40 µm, Flächeninhalt: 16254.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E8_ch00.tif, Durchmesser: 146.21 µm, Flächeninhalt: 16670.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_F8_ch00.tif, Durchmesser: 145.40 µm, Flächeninhalt: 16494.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_C5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_C5_ch00.tif, Durchmesser: 102.06 µm, Flächeninhalt: 8153.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D5_ch00.tif, Durchmesser: 107.64 µm, Flächeninhalt: 9045.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D6_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D6_ch00.tif, Durchmesser: 113.06 µm, Flächeninhalt: 9966.20 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_E5_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_E5_ch00.tif, Durchmesser: 104.49 µm, Flächeninhalt: 8555.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_F6_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_F6_ch00.tif, Durchmesser: 106.47 µm, Flächeninhalt: 8844.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_C11_ch00.tif, Durchmesser: 153.44 µm, Flächeninhalt: 18331.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_D11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_D11_ch00.tif, Durchmesser: 151.57 µm, Flächeninhalt: 17888.77 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_F11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_F11_ch00.tif, Durchmesser: 154.99 µm, Flächeninhalt: 18707.63 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_G11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_G11_ch00.tif, Durchmesser: 136.15 µm, Flächeninhalt: 14438.40 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_D10_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_D10_ch00.tif, Durchmesser: 125.34 µm, Flächeninhalt: 12242.54 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_E10_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_E10_ch00.tif, Durchmesser: 117.79 µm, Flächeninhalt: 10797.30 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 mit Rock_G3_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 mit Rock_G3_ch00.tif, Durchmesser: 146.73 µm, Flächeninhalt: 16760.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_C2_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_C2_ch00.tif, Durchmesser: 96.96 µm, Flächeninhalt: 7359.17 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_E2_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_E2_ch00.tif, Durchmesser: 100.75 µm, Flächeninhalt: 7917.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E7_ch00.tif, Durchmesser: 180.96 µm, Flächeninhalt: 25454.41 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E8_ch00.tif, Durchmesser: 182.75 µm, Flächeninhalt: 25972.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F7_ch00.tif, Durchmesser: 189.42 µm, Flächeninhalt: 27881.22 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F8_ch00.tif, Durchmesser: 183.01 µm, Flächeninhalt: 26042.30 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_3.000 mit Rock_E7_ch00.tif, Durchmesser: 211.27 µm, Flächeninhalt: 34694.49 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_C11_ch00.tif, Durchmesser: 206.11 µm, Flächeninhalt: 33025.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_F11_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_F11_ch00.tif, Durchmesser: 214.10 µm, Flächeninhalt: 35625.33 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2,.000 ohne Rock_D2_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2,.000 ohne Rock_D2_ch00.tif, Durchmesser: 112.90 µm, Flächeninhalt: 9938.21 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 mit Rock_D4_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 mit Rock_D4_ch00.tif, Durchmesser: 254.46 µm, Flächeninhalt: 50256.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_C2_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_C2_ch00.tif, Durchmesser: 118.59 µm, Flächeninhalt: 11003.77 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_E2_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_E2_ch00.tif, Durchmesser: 126.11 µm, Flächeninhalt: 12412.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Segmentiertes Bild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Bild: hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_3.000 mit Rock_E8_ch00.tif, Durchmesser: 263.18 µm, Flächeninhalt: 53743.31 µm²
# Anzahl der erfolgreichen Vorhersagen: 50
# Anzahl der zugehörigen manuellen Durchmesser: 50
#
# Metriken zur Bewertung der Modellgenauigkeit:
# MAE (Mean Absolute Error): 2.53 µm
# MSE (Mean Squared Error): 21.10 µm²
# R2 Score (Coefficient of Determination): 0.99
# Ergebnisse und Metriken wurden in C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx gespeichert.

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

def draw_contours_and_centroid(binary_mask, output_path):
    # Finden der Konturen
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Erstellen eines Farbbilds zum Zeichnen
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    
    # Zeichnen der Konturen
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    
    # Berechnung und Zeichnen des Schwerpunkts
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
    
    # Speichern des Bildes mit Konturen und Schwerpunkt
    cv2.imwrite(output_path, color_mask)

# Laden und Vorverarbeiten der Bilder mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')  # Convert to grayscale
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x196)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

# Vorhersage mit dem Modell machen
def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
    predicted_mask = model.predict(image)  # Vorhersage machen
    return np.squeeze(predicted_mask)  # Batch-Dimension entfernen

# Funktion zur Berechnung der mittleren Konturgröße
def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

# Funktion zur Auswahl des besten Schwellenwerts
def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0

    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size  # Anpassen der Bewertungsmetrik nach Bedarf

            if score > best_score:
                best_score = score
                best_threshold = threshold

    return best_threshold

# Funktion zur Berechnung des mittleren Durchmessers
def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)


# Pfade definieren
#model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_trained3.h5'
#input_dir = "C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Testset von julia"
#output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher test/'
#excel_file_path = 'C:/Users/chris/Documents/Testset.xlsx'

#mit testset jessi sogar noch besser
model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_2-05-combo_loss2.h5'
input_dir = "C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Bilder Jessi"
output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher test/'
excel_file_path = 'C:/Users/chris/Documents/Durchmesser Sphaeroide Jessi.xlsx'

# Lade das Modell mit den definierten custom_objects
model = load_model('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_trained3.h5', compile=False)

# Kompiliere das Modell nachträglich
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), 
              loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5), 
              metrics=[dice_metric])
# Modell laden
#model = tf.keras.models.load_model(model_path)


# Daten aus der Excel-Tabelle laden
predicted_diameters = []
df_manual = pd.read_excel(excel_file_path, header=0)  # Daten ab der zweiten Zeile 
manual_diameters = df_manual.iloc[:, 1].tolist()  # Durchmesser sind in der zweiten Spalte

# Debug-Ausgabe: Anzahl der manuellen Durchmesser
print(f"Anzahl der manuellen Durchmesser: {len(df_manual)}")

# Skalierungsfaktoren berechnen
scale_factor_width = 1296 / 256  # Originalbreite / skalierte Breite
scale_factor_height = 966 / 196  # Originalhöhe / skalierte Höhe

# Listen für die berechneten Durchmesser und die manuell gemessenen Durchmesser
manual_diameters = []

# Iteration über alle TIFF-Dateien im Eingabeordner
tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Debug-Ausgabe: Anzahl der TIFF-Dateien
print(f"Anzahl der TIFF-Dateien: {len(tif_files)}")

# Überprüfen, ob die Anzahl der Dateien mit der Anzahl der manuellen Messungen übereinstimmt
if len(tif_files) != len(df_manual):
    print("Die Anzahl der Bilddateien stimmt nicht mit der Anzahl der manuellen Messungen überein.")
else:
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        
        try:
            # Bild laden und vorverarbeiten
            image = load_and_preprocess_image_pillow(img_path)
            # Vorhersage mit dem Modell machen
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            # Besten Schwellenwert für Konturen finden
            best_threshold = find_best_threshold(predicted_mask)

            # Maske mit dem besten Schwellenwert erstellen
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
            
            # Konturen finden
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            # Filtere Konturen nach Schmalheitsverhältnis
            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:  # Anpassen des Schmalheitsverhältnisses nach Bedarf
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            # Die größte Kontur nach dem Flächeninhalt finden
            largest_contour = max(filtered_contours, key=cv2.contourArea)

            # Berechne den Schwerpunkt der Kontur
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

            # Berechne den mittleren Durchmesser
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745/2 * scale_factor_width) *0.994     #mit faktor für verzerrung

            # Berechnung des Flächeninhalts
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.3745/2 * scale_factor_width * 0.3745/2 * scale_factor_height)

            # Ergebnisse hinzufügen
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])  # Manuell gemessener Durchmesser hinzufügen

            # Ausgabepfad für das segmentierte Bild definieren
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            draw_contours_and_centroid(binary_mask, output_path)

            # Maske als TIFF-Datei speichern
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")

            # Ergebnisse ausgeben
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Flächeninhalt: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    # Debug-Ausgabe: Anzahl der erfolgreichen Vorhersagen und manuell gemessenen Durchmesser
    print(f"Anzahl der erfolgreichen Vorhersagen: {len(predicted_diameters)}")
    print(f"Anzahl der zugehörigen manuellen Durchmesser: {len(manual_diameters)}")

    # Ergebnisse in ein DataFrame konvertieren
    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    # Ergebnisse in eine Excel-Datei exportieren
    excel_output_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx'
    df_results.to_excel(excel_output_path, index=False)

    # Berechnung der Metriken zur Bewertung der Modellgenauigkeit
    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)

        print(f"\nMetriken zur Bewertung der Modellgenauigkeit:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")

        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print("Keine ausreichenden Daten zur Berechnung der Metriken vorhanden.")

    # Scatterplot erstellen
    plt.figure(figsize=(10, 6))
    plt.scatter(manual_diameters, predicted_diameters, color='blue', label='Vorhergesagt vs. Manuell')
    plt.plot([min(manual_diameters), max(manual_diameters)], [min(manual_diameters), max(manual_diameters)], color='red', linestyle='--', label='Perfekte Übereinstimmung')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title('Vergleich von manuellen und vorhergesagten Durchmessern')
    plt.legend()
    plt.grid(True)
    plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/scatterplot.png')
    plt.show()

#7 , 36 , 38 , 19 reißen
# Out:
# Anzahl der manuellen Durchmesser: 115
# Anzahl der TIFF-Dateien: 115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 837ms/step
# Segmentiertes Bild für 018_001_001_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_001_001_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 60.27 µm, Flächeninhalt: 2828.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# Segmentiertes Bild für 018_002_002_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_002_002_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 58.29 µm, Flächeninhalt: 2642.90 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Segmentiertes Bild für 018_003_003_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_003_003_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 59.91 µm, Flächeninhalt: 2797.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Segmentiertes Bild für 018_004_004_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_004_004_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 57.35 µm, Flächeninhalt: 2570.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# Segmentiertes Bild für 018_005_005_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_005_005_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 61.99 µm, Flächeninhalt: 2998.08 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Segmentiertes Bild für 018_006_006_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_006_006_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 57.15 µm, Flächeninhalt: 2545.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# Segmentiertes Bild für 018_007_007_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_007_007_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 56.87 µm, Flächeninhalt: 2518.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 559ms/step
# Segmentiertes Bild für 018_008_008_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_008_008_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 59.63 µm, Flächeninhalt: 2774.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# Segmentiertes Bild für 018_009_009_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_009_009_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 63.13 µm, Flächeninhalt: 3104.82 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# Segmentiertes Bild für 018_010_010_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_010_010_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 59.97 µm, Flächeninhalt: 2809.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 541ms/step
# Segmentiertes Bild für 018_011_011_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_011_011_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 61.88 µm, Flächeninhalt: 2987.15 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Segmentiertes Bild für 018_012_012_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_012_012_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 58.22 µm, Flächeninhalt: 2638.09 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Segmentiertes Bild für 018_013_013_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_013_013_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 68.37 µm, Flächeninhalt: 3708.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# Segmentiertes Bild für 018_014_014_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_014_014_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 61.43 µm, Flächeninhalt: 2932.47 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Segmentiertes Bild für 018_015_015_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_015_015_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 58.91 µm, Flächeninhalt: 2705.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Segmentiertes Bild für 018_016_016_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_016_016_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 59.79 µm, Flächeninhalt: 2791.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# Segmentiertes Bild für 018_017_017_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_017_017_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 60.62 µm, Flächeninhalt: 2863.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Segmentiertes Bild für 018_018_018_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_018_018_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 65.57 µm, Flächeninhalt: 3339.71 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# Segmentiertes Bild für 018_019_019_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_019_019_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 57.88 µm, Flächeninhalt: 2607.03 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Segmentiertes Bild für 018_020_020_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_020_020_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 60.83 µm, Flächeninhalt: 2882.61 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# Segmentiertes Bild für 018_021_021_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_021_021_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 58.77 µm, Flächeninhalt: 2690.58 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Segmentiertes Bild für 018_022_022_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_022_022_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 61.02 µm, Flächeninhalt: 2902.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# Segmentiertes Bild für 018_023_023_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_023_023_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 56.84 µm, Flächeninhalt: 2549.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Segmentiertes Bild für 018_024_024_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_024_024_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 53.83 µm, Flächeninhalt: 2278.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# Segmentiertes Bild für 018_025_025_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_025_025_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 79.90 µm, Flächeninhalt: 4974.35 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Segmentiertes Bild für 018_026_026_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_026_026_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 81.70 µm, Flächeninhalt: 5199.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Segmentiertes Bild für 018_027_027_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_027_027_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 88.08 µm, Flächeninhalt: 6029.41 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Segmentiertes Bild für 018_028_028_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_028_028_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 88.36 µm, Flächeninhalt: 6073.59 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# Segmentiertes Bild für 018_029_029_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_029_029_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 78.55 µm, Flächeninhalt: 4793.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# Segmentiertes Bild für 018_030_030_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_030_030_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 84.95 µm, Flächeninhalt: 5609.49 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# Segmentiertes Bild für 018_031_031_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_031_031_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 92.22 µm, Flächeninhalt: 6615.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Segmentiertes Bild für 018_032_032_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_032_032_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 96.53 µm, Flächeninhalt: 7248.07 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# Segmentiertes Bild für 018_033_033_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_033_033_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 83.51 µm, Flächeninhalt: 5438.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Segmentiertes Bild für 018_034_034_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_034_034_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 86.82 µm, Flächeninhalt: 5861.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Segmentiertes Bild für 018_035_035_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_035_035_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 91.64 µm, Flächeninhalt: 6538.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# Segmentiertes Bild für 018_036_036_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_036_036_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 98.71 µm, Flächeninhalt: 7589.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# Segmentiertes Bild für 018_037_037_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_037_037_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 78.48 µm, Flächeninhalt: 4795.89 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step
# Segmentiertes Bild für 018_038_038_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_038_038_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 86.83 µm, Flächeninhalt: 5859.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Segmentiertes Bild für 018_039_039_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_039_039_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 93.57 µm, Flächeninhalt: 6813.71 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Segmentiertes Bild für 018_040_040_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_040_040_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C7_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 99.22 µm, Flächeninhalt: 7660.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Segmentiertes Bild für 018_041_041_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_041_041_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 82.45 µm, Flächeninhalt: 5293.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step
# Segmentiertes Bild für 018_042_042_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_042_042_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 87.84 µm, Flächeninhalt: 5994.42 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# Segmentiertes Bild für 018_043_043_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_043_043_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 92.16 µm, Flächeninhalt: 6605.93 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# Segmentiertes Bild für 018_044_044_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_044_044_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C8_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 97.05 µm, Flächeninhalt: 7311.49 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# Segmentiertes Bild für 018_045_049_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_045_049_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 92.71 µm, Flächeninhalt: 6719.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Segmentiertes Bild für 018_046_050_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_046_050_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 108.72 µm, Flächeninhalt: 9186.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# Segmentiertes Bild für 018_047_051_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_047_051_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 113.85 µm, Flächeninhalt: 10073.37 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Segmentiertes Bild für 018_048_052_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_048_052_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D4_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 119.11 µm, Flächeninhalt: 10994.58 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# Segmentiertes Bild für 018_049_053_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_049_053_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 89.69 µm, Flächeninhalt: 6252.50 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Segmentiertes Bild für 018_050_054_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_050_054_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 103.33 µm, Flächeninhalt: 8292.63 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Segmentiertes Bild für 018_051_055_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_051_055_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 114.24 µm, Flächeninhalt: 10141.61 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# Segmentiertes Bild für 018_052_056_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_052_056_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D5_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 125.24 µm, Flächeninhalt: 12193.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Segmentiertes Bild für 018_053_057_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_053_057_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 103.83 µm, Flächeninhalt: 8362.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# Segmentiertes Bild für 018_054_058_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_054_058_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 114.46 µm, Flächeninhalt: 10173.54 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Segmentiertes Bild für 018_055_059_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_055_059_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D6_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 124.68 µm, Flächeninhalt: 12063.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# Segmentiertes Bild für 018_056_061_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid + Tail_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_056_061_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid + Tail_20x_240702_ch00.tif, Durchmesser: 95.70 µm, Flächeninhalt: 7144.40 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Segmentiertes Bild für 018_057_062_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_057_062_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 108.54 µm, Flächeninhalt: 9166.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Segmentiertes Bild für 018_058_063_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_058_063_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 119.56 µm, Flächeninhalt: 11109.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Segmentiertes Bild für 018_059_064_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_059_064_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D7_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 128.64 µm, Flächeninhalt: 12846.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# Segmentiertes Bild für 018_060_065_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_060_065_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 99.86 µm, Flächeninhalt: 7755.04 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Segmentiertes Bild für 018_061_066_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_061_066_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 109.43 µm, Flächeninhalt: 9304.82 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# Segmentiertes Bild für 018_062_067_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_062_067_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 118.92 µm, Flächeninhalt: 10977.52 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Segmentiertes Bild für 018_063_068_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_063_068_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D8_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 129.84 µm, Flächeninhalt: 13106.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Segmentiertes Bild für 018_064_069_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_064_069_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 91.85 µm, Flächeninhalt: 6580.13 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 555ms/step
# Segmentiertes Bild für 018_065_070_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_065_070_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 106.95 µm, Flächeninhalt: 8896.71 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# Segmentiertes Bild für 018_066_071_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_066_071_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 110.67 µm, Flächeninhalt: 9508.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# Segmentiertes Bild für 018_067_072_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_067_072_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_D9_3000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 117.73 µm, Flächeninhalt: 10756.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# Segmentiertes Bild für 018_068_073_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_068_073_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 104.47 µm, Flächeninhalt: 8481.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 574ms/step
# Segmentiertes Bild für 018_069_074_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_069_074_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 117.67 µm, Flächeninhalt: 10743.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Segmentiertes Bild für 018_070_075_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_070_075_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 127.05 µm, Flächeninhalt: 12541.30 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# Segmentiertes Bild für 018_071_076_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_071_076_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E4_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 128.99 µm, Flächeninhalt: 12920.11 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Segmentiertes Bild für 018_072_077_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_072_077_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 101.74 µm, Flächeninhalt: 8041.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# Segmentiertes Bild für 018_073_078_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_073_078_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 113.15 µm, Flächeninhalt: 9947.83 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# Segmentiertes Bild für 018_074_079_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_074_079_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 124.48 µm, Flächeninhalt: 12036.52 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# Segmentiertes Bild für 018_075_080_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_075_080_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E5_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 132.48 µm, Flächeninhalt: 13621.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# Segmentiertes Bild für 018_076_081_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_076_081_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 97.93 µm, Flächeninhalt: 7452.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Segmentiertes Bild für 018_077_082_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_077_082_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 109.25 µm, Flächeninhalt: 9275.08 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Segmentiertes Bild für 018_078_083_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_078_083_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 119.67 µm, Flächeninhalt: 11107.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# Segmentiertes Bild für 018_079_084_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_079_084_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E6_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 130.10 µm, Flächeninhalt: 13137.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Segmentiertes Bild für 018_080_085_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_080_085_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 103.98 µm, Flächeninhalt: 8395.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Segmentiertes Bild für 018_081_086_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_081_086_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 113.91 µm, Flächeninhalt: 10082.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# Segmentiertes Bild für 018_082_087_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_082_087_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 124.41 µm, Flächeninhalt: 12023.83 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# Segmentiertes Bild für 018_083_088_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_083_088_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E7_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 135.51 µm, Flächeninhalt: 14258.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Segmentiertes Bild für 018_084_089_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_084_089_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 99.29 µm, Flächeninhalt: 7659.68 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# Segmentiertes Bild für 018_085_090_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_085_090_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 111.37 µm, Flächeninhalt: 9621.95 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Segmentiertes Bild für 018_086_091_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_086_091_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 121.75 µm, Flächeninhalt: 11520.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# Segmentiertes Bild für 018_087_092_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_087_092_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E8_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 132.00 µm, Flächeninhalt: 13523.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Segmentiertes Bild für 018_088_093_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_088_093_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 97.89 µm, Flächeninhalt: 7444.91 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# Segmentiertes Bild für 018_089_094_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_089_094_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 111.34 µm, Flächeninhalt: 9637.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# Segmentiertes Bild für 018_090_095_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_090_095_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 114.85 µm, Flächeninhalt: 10246.15 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Segmentiertes Bild für 018_091_096_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_091_096_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_E9_4000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 121.07 µm, Flächeninhalt: 11381.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Segmentiertes Bild für 018_092_097_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_092_097_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 118.28 µm, Flächeninhalt: 10939.03 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Segmentiertes Bild für 018_093_098_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_093_098_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 132.49 µm, Flächeninhalt: 13682.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step
# Segmentiertes Bild für 018_094_099_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_094_099_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 135.60 µm, Flächeninhalt: 14304.11 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# Segmentiertes Bild für 018_095_100_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_095_100_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F4_5000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 135.48 µm, Flächeninhalt: 14262.12 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Segmentiertes Bild für 018_096_101_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_096_101_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 115.49 µm, Flächeninhalt: 10371.25 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Segmentiertes Bild für 018_097_102_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_097_102_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 131.02 µm, Flächeninhalt: 13316.85 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Segmentiertes Bild für 018_098_103_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_098_103_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 143.74 µm, Flächeninhalt: 16058.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step
# Segmentiertes Bild für 018_099_104_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_099_104_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F5_5000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 145.13 µm, Flächeninhalt: 16366.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Segmentiertes Bild für 018_100_105_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_100_105_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 111.03 µm, Flächeninhalt: 9575.59 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Segmentiertes Bild für 018_101_106_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_101_106_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 127.36 µm, Flächeninhalt: 12580.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# Segmentiertes Bild für 018_102_107_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_102_107_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 139.97 µm, Flächeninhalt: 15210.88 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Segmentiertes Bild für 018_103_108_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_103_108_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F6_5000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 141.51 µm, Flächeninhalt: 15547.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Segmentiertes Bild für 018_104_109_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_104_109_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 121.18 µm, Flächeninhalt: 11425.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Segmentiertes Bild für 018_105_110_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_105_110_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 138.81 µm, Flächeninhalt: 14949.74 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Segmentiertes Bild für 018_106_111_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_106_111_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 146.49 µm, Flächeninhalt: 16648.25 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Segmentiertes Bild für 018_107_112_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_107_112_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F7_5000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 144.36 µm, Flächeninhalt: 16158.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# Segmentiertes Bild für 018_108_113_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid + tail_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_108_113_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid + tail_20x_240705_ch00.tif, Durchmesser: 144.10 µm, Flächeninhalt: 16186.33 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# Segmentiertes Bild für 018_109_114_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_109_114_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 117.11 µm, Flächeninhalt: 10654.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# Segmentiertes Bild für 018_110_115_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_110_115_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 133.30 µm, Flächeninhalt: 13805.89 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# Segmentiertes Bild für 018_111_116_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_111_116_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F8_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 142.81 µm, Flächeninhalt: 15823.71 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 545ms/step
# Segmentiertes Bild für 018_112_117_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 018_112_117_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 111.91 µm, Flächeninhalt: 9718.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# Segmentiertes Bild für 018_113_118_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_113_118_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 121.98 µm, Flächeninhalt: 11516.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Segmentiertes Bild für 018_114_119_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 018_114_119_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 132.41 µm, Flächeninhalt: 13604.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# Segmentiertes Bild für 018_115_120_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 018_115_120_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_F9_5000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 131.91 µm, Flächeninhalt: 13503.19 µm²
# Anzahl der erfolgreichen Vorhersagen: 115
# Anzahl der zugehörigen manuellen Durchmesser: 115
#
# Metriken zur Bewertung der Modellgenauigkeit:
# MAE (Mean Absolute Error): 2.06 µm
# MSE (Mean Squared Error): 13.15 µm²
# R2 Score (Coefficient of Determination): 0.98
# Ergebnisse und Metriken wurden in C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx gespeichert.
