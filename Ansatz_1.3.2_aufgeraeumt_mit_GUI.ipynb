# %%
# exe erstellen mit: pyinstaller --onefile --add-data "C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_trained3.1.h5;." your_script_name.py

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
import tkinter as tk
from tkinter import filedialog, messagebox
from tkinter import ttk
import threading
from tensorflow.keras.models import load_model


# Globale Variablen für den Abbrechen-Mechanismus und Fortschrittsanzeige
process_running = threading.Event()
progress_var = None

def dice_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice

# Benutzerdefinierte Verlustfunktion
def combined_loss(y_true, y_pred, smooth=1e-6, binary_weight=0.5, dice_weight=0.5):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice_loss = 1 - (2. * intersection + smooth) / (union + smooth)
    return binary_weight * bce + dice_weight * dice_loss

def draw_contours_and_centroid(binary_mask, output_path):
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
            centroid = (cX, cY)  # Speichere den Schwerpunkt
    cv2.imwrite(output_path, color_mask)
    return centroid

def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')
    img = img.resize((256, 192))
    img = np.array(img)
    img = img / 255.0
    img = np.expand_dims(img, axis=-1)
    return img

def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)
    predicted_mask = model.predict(image)
    return np.squeeze(predicted_mask)

def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0
    for threshold in np.arange(0.1, 1, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size
            if score > best_score:
                best_score = score
                best_threshold = threshold
    return best_threshold

def create_heatmap(predicted_mask):
    # Normiere die Vorhersagewerte auf den Bereich [0, 1]
    normalized_mask = (predicted_mask - np.min(predicted_mask)) / (np.max(predicted_mask) - np.min(predicted_mask))
    
    # Wandle die normalisierte Maske in eine Heatmap um (z.B. Jet Colormap)
    heatmap = cv2.applyColorMap((normalized_mask * 255).astype(np.uint8), cv2.COLORMAP_JET)
    
    return heatmap

def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)

def start_processing():
    global process_running
    input_dir = input_folder_entry.get()
    output_dir = output_folder_entry.get()

    if not (os.path.isdir(input_dir) and os.path.isdir(output_dir)):
        messagebox.showerror("Fehler", "Bitte überprüfen Sie die angegebenen Pfade.")
        return

    process_running.set()  # Signal, dass der Prozess läuft
    progress_var.set(0)
    processing_thread = threading.Thread(target=run_processing, args=(input_dir, output_dir))
    processing_thread.start()
    root.after(100, check_thread, processing_thread)

def run_processing(input_dir, output_dir):
    model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_trained3.1.h5'
    model = load_model(model_path, compile=False)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                      loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5),
                      metrics=[])
    
    results = []

    scale_factor_width = 1296 / 256
    scale_factor_height = 966 / 192

    tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

    total_files = len(tif_files)
    for i, filename in enumerate(tif_files):
        if not process_running.is_set():
            break

        img_path = os.path.join(input_dir, filename)
        try:
            image = load_and_preprocess_image_pillow(img_path)
            predicted_mask = predict_with_model(model, image)
            print("Shape der Vorhersage:", predicted_mask.shape)
            print("Einige Werte der Vorhersage:", predicted_mask.flatten()[:10])  # Geben Sie die ersten 10 Werte aus

            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            heatmap = create_heatmap(predicted_mask)
            heatmap_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_heatmap.tif")
            cv2.imwrite(heatmap_path, heatmap)
            print(f"Heatmap für {filename} wurde gespeichert.")
            
            best_threshold = find_best_threshold(predicted_mask)
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            largest_contour = max(filtered_contours, key=cv2.contourArea)
            centroid = draw_contours_and_centroid(binary_mask, os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif"))
            if centroid is None:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue

            avg_diameter_pixels = calculate_average_diameter(largest_contour, centroid)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width) * 0.994

            area_micrometers = cv2.contourArea(largest_contour) * (0.3745 * scale_factor_width) * (0.3745 * scale_factor_height)
            
            results.append([filename, avg_diameter_micrometers, area_micrometers])

            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            draw_contours_and_centroid(binary_mask, output_path)
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Fläche: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

        progress = (i + 1) / total_files * 100
        progress_var.set(progress)
        root.update_idletasks()

    # Excel-Ausgabe nach Verarbeitung aller Bilder
    save_excel_file(output_dir, results)

    # Öffnen des Ausgabeordners
    open_output_folder(output_dir)

    # Signalisieren, dass der Prozess abgeschlossen ist
    process_running.clear()

def save_excel_file(output_dir, results):
    save_path = filedialog.asksaveasfilename(defaultextension=".xlsx",
                                             filetypes=[("Excel files", "*.xlsx")],
                                             initialdir=output_dir,
                                             title="Speichern Sie die Excel-Datei")
    if not save_path:
        return

    df = pd.DataFrame(results, columns=['Bildname', 'Durchmesser (µm)', 'Flächeninhalt (µm²)'])
    df.to_excel(save_path, index=False)
    print(f"Ergebnisse wurden in {save_path} gespeichert.")

def cancel_process():
    global process_running
    process_running.clear()  # Signal, dass der Prozess abgebrochen wurde
    messagebox.showinfo("Abbruch", "Die Verarbeitung wurde abgebrochen.")

def check_thread(thread):
    if thread.is_alive():
        root.after(100, check_thread, thread)
    else:
        progress_var.set(100)  # Fortschritt auf 100% setzen, wenn abgeschlossen
        root.update_idletasks()
        root.after(500, close_window)  # Fenster nach 500 ms schließen

def close_window():
    root.quit()  # Beendet die Tkinter-Hauptschleife
    root.destroy()  # Bereinigt alle Tkinter-Ressourcen und schließt das Fenster

def open_output_folder(output_dir):
    try:
        if os.name == 'nt':  # Windows
            os.startfile(output_dir)
        elif os.name == 'posix':  # macOS/Linux
            os.system(f'open "{output_dir}"')  # macOS
            # os.system(f'xdg-open "{output_dir}"')  # Linux (entfernen das Kommentarzeichen wenn auf Linux verwenden)
    except Exception as e:
        print(f"Fehler beim Öffnen des Ausgabeordners: {e}")

def select_folder(title):
    folder_path = filedialog.askdirectory(title=title)
    return folder_path

def main():
    global input_folder_entry, output_folder_entry, progress_var, root

    root = tk.Tk()
    root.title("Sphäroid-Auswertung")

    # Setze das Fenster im Vordergrund
    root.attributes("-topmost", True)

    progress_var = tk.DoubleVar()

    tk.Label(root, text="Eingabeordner:").grid(row=0, column=0, padx=10, pady=5)
    input_folder_entry = tk.Entry(root, width=50)
    input_folder_entry.grid(row=0, column=1, padx=10, pady=5)
    tk.Button(root, text="Durchsuchen...", command=lambda: input_folder_entry.insert(0, select_folder("Wählen Sie den Eingabeordner"))).grid(row=0, column=2, padx=10, pady=5)

    tk.Label(root, text="Ausgabeordner:").grid(row=1, column=0, padx=10, pady=5)
    output_folder_entry = tk.Entry(root, width=50)
    output_folder_entry.grid(row=1, column=1, padx=10, pady=5)
    tk.Button(root, text="Durchsuchen...", command=lambda: output_folder_entry.insert(0, select_folder("Wählen Sie den Ausgabeordner"))).grid(row=1, column=2, padx=10, pady=5)

    tk.Button(root, text="Verarbeitung starten", command=start_processing).grid(row=2, column=1, pady=20)

    progress_bar = ttk.Progressbar(root, orient='horizontal', length=400, mode='determinate', variable=progress_var)
    progress_bar.grid(row=3, column=0, columnspan=3, padx=10, pady=5)
    
    tk.Button(root, text="Abbrechen", command=cancel_process).grid(row=4, column=1, pady=20)

    root.mainloop()


if __name__ == "__main__":
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 744ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06427066 0.00488209 0.00251454 0.00120369 0.0007841  0.00077605
#  0.00115325 0.0012611  0.00127889 0.00145491]
# Heatmap für CQ MSC Spheroids Tag4_B10 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_B10 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_B10 3000 cells_ch00.tif, Durchmesser: 82.53 µm, Fläche: 5487.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05256375 0.005762   0.00160982 0.0012711  0.00112009 0.00094903
#  0.00108199 0.00100239 0.00111327 0.00125803]
# Heatmap für CQ MSC Spheroids Tag4_B2 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_B2 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_B2 3000 cells_ch00.tif, Durchmesser: 7.22 µm, Fläche: 42.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06007745 0.00569871 0.00196917 0.00121069 0.00076403 0.00073144
#  0.00085977 0.00104056 0.00112918 0.00113594]
# Heatmap für CQ MSC Spheroids Tag4_B3 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_B3 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_B3 3000 cells_ch00.tif, Durchmesser: 4.48 µm, Fläche: 33.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06217535 0.00461181 0.00219938 0.00115447 0.00087073 0.00102096
#  0.00151445 0.00133619 0.00110419 0.00124075]
# Heatmap für CQ MSC Spheroids Tag4_B5 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_B5 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_B5 3000 cells_ch00.tif, Durchmesser: 76.96 µm, Fläche: 8157.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05708622 0.00468264 0.00239718 0.00134772 0.00084169 0.00075414
#  0.00101982 0.0010651  0.00105724 0.0010856 ]
# Heatmap für CQ MSC Spheroids Tag4_B6 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_B6 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_B6 3000 cells_ch00.tif, Durchmesser: 61.62 µm, Fläche: 5285.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06223853 0.0053337  0.00215658 0.00124472 0.00078553 0.00080361
#  0.00110182 0.00123617 0.00117452 0.00125006]
# Heatmap für CQ MSC Spheroids Tag4_B7 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_B7 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_B7 3000 cells_ch00.tif, Durchmesser: 92.53 µm, Fläche: 6957.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06021517 0.00482232 0.00214809 0.00119336 0.00083611 0.00087107
#  0.00116321 0.00119547 0.00106672 0.00115692]
# Heatmap für CQ MSC Spheroids Tag4_B8 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_B8 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_B8 3000 cells_ch00.tif, Durchmesser: 53.22 µm, Fläche: 4702.90 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 531ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05946897 0.00421602 0.00234634 0.0012272  0.00083723 0.00079951
#  0.00105596 0.0011239  0.00111259 0.00129038]
# Heatmap für CQ MSC Spheroids Tag4_B9 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_B9 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_B9 3000 cells_ch00.tif, Durchmesser: 13.86 µm, Fläche: 337.58 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06283301 0.00672095 0.00218347 0.00127942 0.00081167 0.00072377
#  0.00094322 0.00100292 0.00098678 0.00104375]
# Heatmap für CQ MSC Spheroids Tag4_C10 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_C10 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_C10 3000 cells_ch00.tif, Durchmesser: 7.23 µm, Fläche: 98.24 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.10495182 0.00709433 0.00189006 0.00179327 0.00185755 0.00156483
#  0.00174557 0.00163964 0.00172315 0.00179067]
# Heatmap für CQ MSC Spheroids Tag4_C11 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_C11 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_C11 3000 cells_ch00.tif, Durchmesser: 3.77 µm, Fläche: 5.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06529691 0.00497992 0.00235841 0.00129724 0.00084265 0.00084237
#  0.00120324 0.00130639 0.00117563 0.00123291]
# Heatmap für CQ MSC Spheroids Tag4_C2 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_C2 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_C2 3000 cells_ch00.tif, Durchmesser: 98.84 µm, Fläche: 7803.63 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06239952 0.00517772 0.00235039 0.00134269 0.00087373 0.00086117
#  0.00126576 0.00128004 0.00115839 0.00115363]
# Heatmap für CQ MSC Spheroids Tag4_C3 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_C3 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_C3 3000 cells_ch00.tif, Durchmesser: 78.62 µm, Fläche: 8928.90 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06283233 0.00583629 0.00213445 0.00138513 0.00084163 0.00076575
#  0.00095395 0.00116227 0.00127773 0.00123552]
# Heatmap für CQ MSC Spheroids Tag4_C5 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_C5 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_C5 3000 cells_ch00.tif, Durchmesser: 17.95 µm, Fläche: 289.35 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06400924 0.00627917 0.00210806 0.00133458 0.00087065 0.00076366
#  0.00100328 0.00108526 0.00108786 0.00123423]
# Heatmap für CQ MSC Spheroids Tag4_C6 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_C6 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_C6 3000 cells_ch00.tif, Durchmesser: 4.02 µm, Fläche: 42.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05936421 0.00591187 0.00205071 0.0012467  0.0008759  0.0007164
#  0.00091939 0.0009839  0.00097184 0.00105853]
# Heatmap für CQ MSC Spheroids Tag4_C7 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_C7 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_C7 3000 cells_ch00.tif, Durchmesser: 98.48 µm, Fläche: 7762.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06262896 0.00510165 0.0022703  0.00130719 0.00082212 0.00082859
#  0.00115727 0.00120256 0.0011671  0.00135557]
# Heatmap für CQ MSC Spheroids Tag4_C8 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_C8 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_C8 3000 cells_ch00.tif, Durchmesser: 95.08 µm, Fläche: 7210.63 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 692ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06540005 0.00532722 0.00216897 0.00120088 0.00078021 0.00073445
#  0.00104641 0.00121936 0.0012661  0.00135179]
# Heatmap für CQ MSC Spheroids Tag4_C9 3000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_C9 3000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_C9 3000 cells_ch00.tif, Durchmesser: 62.50 µm, Fläche: 4915.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.0553339  0.00632302 0.00194878 0.00130408 0.00096993 0.0008351
#  0.00110709 0.0010416  0.00112079 0.00125542]
# Heatmap für CQ MSC Spheroids Tag4_D10 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_D10 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_D10 1000 cells_ch00.tif, Durchmesser: 18.59 µm, Fläche: 496.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05303131 0.00629488 0.00194909 0.00140245 0.00112704 0.00093967
#  0.00118254 0.00116185 0.00124525 0.00130138]
# Heatmap für CQ MSC Spheroids Tag4_D11 1000 cells_ch00.tif wurde gespeichert.
# Keine geeigneten Konturen im Bild CQ MSC Spheroids Tag4_D11 1000 cells_ch00.tif gefunden.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06322136 0.00583236 0.00210944 0.00115832 0.00079885 0.00074431
#  0.00092705 0.00104029 0.00108115 0.00115789]
# Heatmap für CQ MSC Spheroids Tag4_D2 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_D2 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_D2 1000 cells_ch00.tif, Durchmesser: 72.46 µm, Fläche: 4136.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06630981 0.00568702 0.00221456 0.00141616 0.00085953 0.00073727
#  0.00095355 0.00118128 0.00120173 0.00123903]
# Heatmap für CQ MSC Spheroids Tag4_D3 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_D3 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_D3 1000 cells_ch00.tif, Durchmesser: 16.73 µm, Fläche: 796.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05898812 0.00526269 0.00231446 0.00155445 0.00097275 0.00063007
#  0.00097687 0.00128469 0.00131595 0.0014917 ]
# Heatmap für CQ MSC Spheroids Tag4_D4 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_D4 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_D4 1000 cells_ch00.tif, Durchmesser: 46.62 µm, Fläche: 2155.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06219307 0.0064004  0.00215656 0.00144537 0.00088954 0.00067383
#  0.00085458 0.00093803 0.00094733 0.00109233]
# Heatmap für CQ MSC Spheroids Tag4_D5 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_D5 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_D5 1000 cells_ch00.tif, Durchmesser: 12.06 µm, Fläche: 119.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06183162 0.00625198 0.0020658  0.00123263 0.00081091 0.00072065
#  0.00087089 0.0010848  0.00114622 0.00120307]
# Heatmap für CQ MSC Spheroids Tag4_D6 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_D6 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_D6 1000 cells_ch00.tif, Durchmesser: 27.98 µm, Fläche: 1532.50 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06223565 0.0060584  0.00204227 0.00136144 0.00081393 0.00075192
#  0.00094556 0.00102016 0.0010611  0.00123575]
# Heatmap für CQ MSC Spheroids Tag4_D7 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_D7 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_D7 1000 cells_ch00.tif, Durchmesser: 39.29 µm, Fläche: 1269.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.0630433  0.00569239 0.00203447 0.00114727 0.00076903 0.00076451
#  0.00100528 0.00119405 0.00121833 0.00125115]
# Heatmap für CQ MSC Spheroids Tag4_D8 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_D8 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_D8 1000 cells_ch00.tif, Durchmesser: 8.48 µm, Fläche: 73.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06171599 0.00572961 0.00215616 0.00128248 0.00085409 0.00070759
#  0.00088961 0.00101629 0.00114182 0.0012996 ]
# Heatmap für CQ MSC Spheroids Tag4_D9 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_D9 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_D9 1000 cells_ch00.tif, Durchmesser: 36.95 µm, Fläche: 1250.30 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06243988 0.00646207 0.00214313 0.00144795 0.00083209 0.00070478
#  0.00091861 0.00094096 0.00094091 0.00095221]
# Heatmap für CQ MSC Spheroids Tag4_E10 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_E10 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_E10 1000 cells_ch00.tif, Durchmesser: 10.33 µm, Fläche: 232.20 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05774733 0.00596188 0.00191932 0.00141542 0.00100569 0.00081755
#  0.00101541 0.00099243 0.00109212 0.00116192]
# Heatmap für CQ MSC Spheroids Tag4_E11 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_E11 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_E11 1000 cells_ch00.tif, Durchmesser: 6.29 µm, Fläche: 55.37 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06561049 0.00601126 0.00219061 0.00133773 0.00084187 0.00080713
#  0.00107518 0.00120882 0.00106413 0.00132749]
# Heatmap für CQ MSC Spheroids Tag4_E2 1000 cells_ch00.tif wurde gespeichert.
# Keine geeigneten Konturen im Bild CQ MSC Spheroids Tag4_E2 1000 cells_ch00.tif gefunden.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06344508 0.00625284 0.00209704 0.00126898 0.00079534 0.00066001
#  0.00095521 0.00103913 0.00105048 0.00127418]
# Heatmap für CQ MSC Spheroids Tag4_E3 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_E3 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_E3 1000 cells_ch00.tif, Durchmesser: 49.43 µm, Fläche: 4565.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06225568 0.00601575 0.00206415 0.00119575 0.00088934 0.00078966
#  0.00094987 0.00102713 0.00105871 0.00123724]
# Heatmap für CQ MSC Spheroids Tag4_E4 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_E4 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_E4 1000 cells_ch00.tif, Durchmesser: 18.91 µm, Fläche: 469.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06102056 0.00645232 0.00198016 0.00120024 0.0009062  0.00089715
#  0.00122183 0.0011842  0.00112072 0.00120906]
# Heatmap für CQ MSC Spheroids Tag4_E5 1000 cells_ch00.tif wurde gespeichert.
# Keine geeigneten Konturen im Bild CQ MSC Spheroids Tag4_E5 1000 cells_ch00.tif gefunden.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05102365 0.00552838 0.00156548 0.00119789 0.00105331 0.00097925
#  0.00116006 0.00109709 0.00122542 0.00128784]
# Heatmap für CQ MSC Spheroids Tag4_E6 1000 cells_ch00.tif wurde gespeichert.
# Keine geeigneten Konturen im Bild CQ MSC Spheroids Tag4_E6 1000 cells_ch00.tif gefunden.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.07105912 0.00574375 0.00192825 0.00131522 0.00099313 0.00073468
#  0.00071231 0.00098015 0.0011539  0.00134389]
# Heatmap für CQ MSC Spheroids Tag4_E7 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_E7 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_E7 1000 cells_ch00.tif, Durchmesser: 43.79 µm, Fläche: 1809.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.0649742  0.00541716 0.00224806 0.00139178 0.00082546 0.00073969
#  0.00100734 0.00122704 0.00122484 0.00118796]
# Heatmap für CQ MSC Spheroids Tag4_E8 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_E8 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_E8 1000 cells_ch00.tif, Durchmesser: 55.64 µm, Fläche: 2495.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06087215 0.00548598 0.00188787 0.00130158 0.00085829 0.00069065
#  0.00109963 0.00171662 0.00158873 0.00148192]
# Heatmap für CQ MSC Spheroids Tag4_E9 1000 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_E9 1000 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_E9 1000 cells_ch00.tif, Durchmesser: 21.47 µm, Fläche: 410.81 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06073723 0.00643042 0.00211393 0.0013616  0.0008722  0.00072909
#  0.0008847  0.00097424 0.00102268 0.00111478]
# Heatmap für CQ MSC Spheroids Tag4_F10 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_F10 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_F10 500 cells_ch00.tif, Durchmesser: 2.67 µm, Fläche: 3.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05669706 0.00603102 0.00188039 0.00123714 0.00102046 0.00085978
#  0.00108467 0.00109674 0.00107475 0.00120729]
# Heatmap für CQ MSC Spheroids Tag4_F11 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_F11 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_F11 500 cells_ch00.tif, Durchmesser: 48.64 µm, Fläche: 1945.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.0629062  0.00651313 0.00209779 0.00119315 0.00084556 0.00076935
#  0.00097747 0.00094855 0.00099023 0.00109811]
# Heatmap für CQ MSC Spheroids Tag4_F2 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_F2 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_F2 500 cells_ch00.tif, Durchmesser: 19.44 µm, Fläche: 778.76 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.061403   0.00659654 0.0020301  0.00130355 0.0008639  0.00075765
#  0.00094574 0.00105591 0.00106204 0.00104009]
# Heatmap für CQ MSC Spheroids Tag4_F3 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_F3 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_F3 500 cells_ch00.tif, Durchmesser: 8.57 µm, Fläche: 125.03 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06012945 0.00646532 0.00208514 0.00149101 0.00108637 0.00086905
#  0.00098439 0.0010405  0.00108886 0.00112454]
# Heatmap für CQ MSC Spheroids Tag4_F4 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_F4 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_F4 500 cells_ch00.tif, Durchmesser: 25.79 µm, Fläche: 546.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05989408 0.00654249 0.00221444 0.00135595 0.00098433 0.00081337
#  0.00100338 0.0010059  0.00105374 0.00121398]
# Heatmap für CQ MSC Spheroids Tag4_F5 500 cells_ch00.tif wurde gespeichert.
# Keine geeigneten Konturen im Bild CQ MSC Spheroids Tag4_F5 500 cells_ch00.tif gefunden.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06030509 0.00656735 0.00223102 0.00135309 0.00088786 0.00082231
#  0.00108891 0.00101184 0.00106138 0.00113852]
# Heatmap für CQ MSC Spheroids Tag4_F6 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_F6 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_F6 500 cells_ch00.tif, Durchmesser: 9.80 µm, Fläche: 166.11 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06302695 0.00662255 0.00222204 0.00137769 0.00093914 0.00072316
#  0.00092946 0.00104032 0.00105632 0.0011047 ]
# Heatmap für CQ MSC Spheroids Tag4_F7 500 cells_ch00.tif wurde gespeichert.
# Keine geeigneten Konturen im Bild CQ MSC Spheroids Tag4_F7 500 cells_ch00.tif gefunden.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05927979 0.0063062  0.00212294 0.0014281  0.00098007 0.00078713
#  0.00094991 0.00100538 0.00109381 0.00119799]
# Heatmap für CQ MSC Spheroids Tag4_F8 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_F8 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_F8 500 cells_ch00.tif, Durchmesser: 7.69 µm, Fläche: 44.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 543ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06056171 0.00642806 0.00211399 0.00142523 0.00096723 0.00079973
#  0.00103225 0.00107022 0.00110743 0.00112737]
# Heatmap für CQ MSC Spheroids Tag4_F9 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_F9 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_F9 500 cells_ch00.tif, Durchmesser: 11.36 µm, Fläche: 110.74 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 538ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05812144 0.00658385 0.00213272 0.00138831 0.00094382 0.00078656
#  0.00103202 0.00113242 0.00127389 0.00134193]
# Heatmap für CQ MSC Spheroids Tag4_G10 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_G10 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_G10 500 cells_ch00.tif, Durchmesser: 14.02 µm, Fläche: 496.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05730436 0.00611723 0.0021758  0.00140903 0.00108479 0.00084827
#  0.00102699 0.00102819 0.001101   0.0011059 ]
# Heatmap für CQ MSC Spheroids Tag4_G2 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_G2 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_G2 500 cells_ch00.tif, Durchmesser: 69.54 µm, Fläche: 3961.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05420988 0.00629787 0.00187498 0.00128401 0.00100604 0.00086686
#  0.00107366 0.00103753 0.00108957 0.00117224]
# Heatmap für CQ MSC Spheroids Tag4_G3 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_G3 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_G3 500 cells_ch00.tif, Durchmesser: 28.70 µm, Fläche: 2161.22 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05936144 0.00633546 0.00207745 0.00129757 0.00098176 0.00086502
#  0.00111561 0.00108572 0.00113664 0.0011168 ]
# Heatmap für CQ MSC Spheroids Tag4_G4 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_G4 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_G4 500 cells_ch00.tif, Durchmesser: 51.21 µm, Fläche: 2157.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05913335 0.00654021 0.00206758 0.00134859 0.00091753 0.00078281
#  0.00097694 0.00100002 0.00102178 0.00103406]
# Heatmap für CQ MSC Spheroids Tag4_G5 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_G5 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_G5 500 cells_ch00.tif, Durchmesser: 6.35 µm, Fläche: 58.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.0599186  0.00653539 0.00217614 0.00137808 0.00092566 0.00077594
#  0.00104041 0.00121999 0.0011939  0.00116156]
# Heatmap für CQ MSC Spheroids Tag4_G6 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_G6 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_G6 500 cells_ch00.tif, Durchmesser: 17.68 µm, Fläche: 517.98 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 539ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05761223 0.00612613 0.00186874 0.00128786 0.00091752 0.00083898
#  0.00105366 0.00105325 0.00107105 0.0010666 ]
# Heatmap für CQ MSC Spheroids Tag4_G7 500 cells_ch00.tif wurde gespeichert.
# Keine geeigneten Konturen im Bild CQ MSC Spheroids Tag4_G7 500 cells_ch00.tif gefunden.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06064304 0.00654279 0.00212425 0.00133831 0.00092918 0.00081188
#  0.00103556 0.00110378 0.00107598 0.00105846]
# Heatmap für CQ MSC Spheroids Tag4_G8 500 cells_ch00.tif wurde gespeichert.
# Segmentiertes Bild für CQ MSC Spheroids Tag4_G8 500 cells_ch00.tif wurde gespeichert.
# Bild: CQ MSC Spheroids Tag4_G8 500 cells_ch00.tif, Durchmesser: 15.42 µm, Fläche: 237.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05944071 0.006461   0.00218632 0.0013774  0.00093707 0.00079023
#  0.00108969 0.00116659 0.00110877 0.00108458]
# Heatmap für CQ MSC Spheroids Tag4_G9 500 cells_ch00.tif wurde gespeichert.
# Keine geeigneten Konturen im Bild CQ MSC Spheroids Tag4_G9 500 cells_ch00.tif gefunden.
# Ergebnisse wurden in C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/testordner/test.xlsx gespeichert.
