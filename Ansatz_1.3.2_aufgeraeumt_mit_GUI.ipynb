# %%
# exe erstellen mit: pyinstaller --onefile --add-data "C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_trained3.1.h5;." your_script_name.py

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
import tkinter as tk
from tkinter import filedialog, messagebox
from tkinter import ttk
import threading
from tensorflow.keras.models import load_model


# Globale Variablen für den Abbrechen-Mechanismus und Fortschrittsanzeige
process_running = threading.Event()
progress_var = None



def dice_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice

# Benutzerdefinierte Verlustfunktion
def combined_loss(y_true, y_pred, smooth=1e-6, binary_weight=0.5, dice_weight=0.5):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    y_true_f = tf.cast(tf.reshape(y_true, [-1]), tf.float32)
    y_pred_f = tf.cast(tf.reshape(y_pred, [-1]), tf.float32)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f)
    dice_loss = 1 - (2. * intersection + smooth) / (union + smooth)
    return binary_weight * bce + dice_weight * dice_loss

def draw_contours_and_centroid(binary_mask, output_path):
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
            centroid = (cX, cY)  # Speichere den Schwerpunkt
    cv2.imwrite(output_path, color_mask)
    return centroid

def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')
    img = img.resize((256, 192))
    img = np.array(img)
    img = img / 255.0
    img = np.expand_dims(img, axis=-1)
    return img

def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)
    predicted_mask = model.predict(image)
    return np.squeeze(predicted_mask)

def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0
    for threshold in np.arange(0.1, 1, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size
            if score > best_score:
                best_score = score
                best_threshold = threshold
    return best_threshold

def create_heatmap(predicted_mask):
    # Normiere die Vorhersagewerte auf den Bereich [0, 1]
    normalized_mask = (predicted_mask - np.min(predicted_mask)) / (np.max(predicted_mask) - np.min(predicted_mask))
    
    # Wandle die normalisierte Maske in eine Heatmap um (z.B. Jet Colormap)
    heatmap = cv2.applyColorMap((normalized_mask * 255).astype(np.uint8), cv2.COLORMAP_JET)
    
    return heatmap

def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)

def start_processing():
    global process_running
    input_dir = input_folder_entry.get()
    output_dir = output_folder_entry.get()

    if not (os.path.isdir(input_dir) and os.path.isdir(output_dir)):
        messagebox.showerror("Fehler", "Bitte überprüfen Sie die angegebenen Pfade.")
        return

    process_running.set()  # Signal, dass der Prozess läuft
    progress_var.set(0)
    processing_thread = threading.Thread(target=run_processing, args=(input_dir, output_dir))
    processing_thread.start()
    root.after(100, check_thread, processing_thread)

def run_processing(input_dir, output_dir):
    model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_unet_trained5.h5'
    model = load_model(model_path, compile=False)
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
                  loss=lambda y_true, y_pred: combined_loss(y_true, y_pred, binary_weight=0.5, dice_weight=0.5),
                  metrics=[])

    results = []

    scale_factor_width = 1296 / 256
    scale_factor_height = 966 / 192

    tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

    total_files = len(tif_files)
    for i, filename in enumerate(tif_files):
        if not process_running.is_set():
            break

        img_path = os.path.join(input_dir, filename)
        try:
            image = load_and_preprocess_image_pillow(img_path)
            predicted_mask = predict_with_model(model, image)
            print("Shape der Vorhersage:", predicted_mask.shape)
            print("Einige Werte der Vorhersage:", predicted_mask.flatten()[:10])  # Geben Sie die ersten 10 Werte aus

            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            heatmap = create_heatmap(predicted_mask)
            heatmap_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_heatmap.tif")
            cv2.imwrite(heatmap_path, heatmap)
            print(f"Heatmap für {filename} wurde gespeichert.")

            best_threshold = find_best_threshold(predicted_mask)
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255
            
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            largest_contour = max(filtered_contours, key=cv2.contourArea)
            centroid = draw_contours_and_centroid(binary_mask, os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif"))
            if centroid is None:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue

            avg_diameter_pixels = calculate_average_diameter(largest_contour, centroid)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width) * 0.994

            area_micrometers = cv2.contourArea(largest_contour) * (0.3745 * scale_factor_width) * (0.3745 * scale_factor_height)

            results.append([filename, avg_diameter_micrometers, area_micrometers])

            # Lade das originale Bild für die Überlagerung
            original_image = Image.open(img_path).convert('L')
            original_image = original_image.resize((256, 192))
            original_image = np.array(original_image)

            # Erstelle die Überlagerung: Skaliere die binäre Maske für die Überlagerung
            overlay = cv2.addWeighted(original_image, 0.9, binary_mask, 0.1, 0)

            # Speichere die Überlagerung im Ausgabeordner
            overlay_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_overlay.tif")
            cv2.imwrite(overlay_path, overlay)
            print(f"Überlagerungsbild für {filename} wurde gespeichert.")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

        progress = (i + 1) / total_files * 100
        progress_var.set(progress)
        root.update_idletasks()

    # Excel-Ausgabe nach Verarbeitung aller Bilder
    save_excel_file(output_dir, results)

    # Öffnen des Ausgabeordners
    open_output_folder(output_dir)

    # Signalisieren, dass der Prozess abgeschlossen ist
    process_running.clear()


def save_excel_file(output_dir, results):
    save_path = filedialog.asksaveasfilename(defaultextension=".xlsx",
                                             filetypes=[("Excel files", "*.xlsx")],
                                             initialdir=output_dir,
                                             title="Speichern Sie die Excel-Datei")
    if not save_path:
        return

    df = pd.DataFrame(results, columns=['Bildname', 'Durchmesser (µm)', 'Flächeninhalt (µm²)'])
    df.to_excel(save_path, index=False)
    print(f"Ergebnisse wurden in {save_path} gespeichert.")

def cancel_process():
    global process_running
    process_running.clear()  # Signal, dass der Prozess abgebrochen wurde
    messagebox.showinfo("Abbruch", "Die Verarbeitung wurde abgebrochen.")

def check_thread(thread):
    if thread.is_alive():
        root.after(100, check_thread, thread)
    else:
        progress_var.set(100)  # Fortschritt auf 100% setzen, wenn abgeschlossen
        root.update_idletasks()
        root.after(500, close_window)  # Fenster nach 500 ms schließen

def close_window():
    root.quit()  # Beendet die Tkinter-Hauptschleife
    root.destroy()  # Bereinigt alle Tkinter-Ressourcen und schließt das Fenster

def open_output_folder(output_dir):
    try:
        if os.name == 'nt':  # Windows
            os.startfile(output_dir)
        elif os.name == 'posix':  # macOS/Linux
            os.system(f'open "{output_dir}"')  # macOS
    except Exception as e:
        print(f"Fehler beim Öffnen des Ausgabeordners: {e}")

def select_folder(title):
    folder_path = filedialog.askdirectory(title=title)
    return folder_path

def main():
    global input_folder_entry, output_folder_entry, progress_var, root

    root = tk.Tk()
    root.title("Sphäroid-Auswertung")

    # Setze das Fenster im Vordergrund
    root.attributes("-topmost", True)

    progress_var = tk.DoubleVar()

    tk.Label(root, text="Eingabeordner:").grid(row=0, column=0, padx=10, pady=5)
    input_folder_entry = tk.Entry(root, width=50)
    input_folder_entry.grid(row=0, column=1, padx=10, pady=5)
    tk.Button(root, text="Durchsuchen...", command=lambda: input_folder_entry.insert(0, select_folder("Wählen Sie den Eingabeordner"))).grid(row=0, column=2, padx=10, pady=5)

    tk.Label(root, text="Ausgabeordner:").grid(row=1, column=0, padx=10, pady=5)
    output_folder_entry = tk.Entry(root, width=50)
    output_folder_entry.grid(row=1, column=1, padx=10, pady=5)
    tk.Button(root, text="Durchsuchen...", command=lambda: output_folder_entry.insert(0, select_folder("Wählen Sie den Ausgabeordner"))).grid(row=1, column=2, padx=10, pady=5)

    tk.Button(root, text="Verarbeitung starten", command=start_processing).grid(row=2, column=1, pady=20)

    progress_bar = ttk.Progressbar(root, orient='horizontal', length=400, mode='determinate', variable=progress_var)
    progress_bar.grid(row=3, column=0, columnspan=3, padx=10, pady=5)
    
    tk.Button(root, text="Abbrechen", command=cancel_process).grid(row=4, column=1, pady=20)

    root.mainloop()


if __name__ == "__main__":
    main()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 787ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06132817 0.00485172 0.00155415 0.00112338 0.00089742 0.00088659
#  0.00119921 0.00146369 0.00141252 0.00160413]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_B8_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_B8_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.0595479  0.00571111 0.00177683 0.00113475 0.0007738  0.00072428
#  0.00097717 0.00110448 0.00114727 0.00134636]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_D7_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_D7_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05731119 0.00615985 0.00194078 0.00132199 0.00097989 0.00084023
#  0.00107521 0.0010421  0.00103406 0.00121278]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05174196 0.00360399 0.0019361  0.00092317 0.00066149 0.00066814
#  0.00089149 0.00089211 0.0009774  0.00094199]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05965152 0.00491049 0.00208471 0.00130146 0.0009933  0.00085304
#  0.0010609  0.001135   0.00115207 0.00133416]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F7_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F7_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05418007 0.00542471 0.00145565 0.00118874 0.00124253 0.00116949
#  0.00140637 0.00132981 0.00137926 0.00147579]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06468242 0.00564953 0.00168552 0.00157422 0.00220079 0.00313877
#  0.00274113 0.00424616 0.00449387 0.00403587]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_C5_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_C5_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.0618834  0.00474201 0.0021604  0.00136561 0.00109886 0.0010075
#  0.00117322 0.00118747 0.0012783  0.00151057]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D5_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D5_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05365584 0.00547302 0.00158959 0.00106945 0.000883   0.00088317
#  0.00117013 0.00124627 0.00129843 0.00140208]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D6_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_D6_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.09720473 0.00602453 0.00151004 0.00150109 0.00181026 0.00174402
#  0.00193722 0.00173    0.00184939 0.00189595]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_E5_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_E5_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.04740192 0.00353095 0.00180902 0.00086694 0.0006096  0.00061806
#  0.00080305 0.00073839 0.00077654 0.00079432]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_F6_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_3.000 ohne Rock_F6_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06006799 0.00426399 0.00209026 0.00108013 0.00080519 0.00076369
#  0.00101016 0.00105898 0.00107078 0.00116208]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06054788 0.00433411 0.00223285 0.00129456 0.00091094 0.00084014
#  0.00104653 0.00103593 0.00105921 0.0011696 ]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C12_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_C12_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.0551425  0.00567757 0.00178168 0.00116706 0.00085475 0.00073303
#  0.00103767 0.00101993 0.00109196 0.00130572]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_D11_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_D11_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05956519 0.00622469 0.00206886 0.00128066 0.00089266 0.00077852
#  0.00109059 0.00108992 0.00108672 0.00110582]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_G11_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 mit Rock_G11_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.07473662 0.00481634 0.00131413 0.00109872 0.00139283 0.00137515
#  0.00181808 0.00179304 0.00241263 0.00215314]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D10_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D10_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06175039 0.00579651 0.00169785 0.00120994 0.00151211 0.00158277
#  0.00170114 0.001502   0.00164715 0.00166841]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D9_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_D9_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.03853033 0.00297592 0.0019506  0.00084872 0.00049513 0.00054944
#  0.00064387 0.00066369 0.00073104 0.00073891]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E10_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E10_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05466543 0.00428582 0.00228607 0.00175285 0.00099231 0.00079585
#  0.00101005 0.00113681 0.00123775 0.00123838]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E9_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 1_4.000 ohne Rock_E9_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.07448699 0.00571585 0.00157587 0.00130718 0.00148718 0.00139215
#  0.00171303 0.00168984 0.00179284 0.00194726]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_B8_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_B8_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05284028 0.00562477 0.00172904 0.0011236  0.00099534 0.00088964
#  0.00111374 0.00115067 0.00117105 0.00131419]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_D7_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_D7_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.19511919 0.00965356 0.00283487 0.00404468 0.00481107 0.00460642
#  0.00478283 0.0041957  0.00442451 0.00405504]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.13163391 0.00626264 0.00154655 0.00167136 0.00203536 0.00185413
#  0.00224572 0.00220404 0.00285444 0.00292317]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.22193728 0.00986437 0.00317236 0.00456375 0.00549591 0.00517409
#  0.00555954 0.0051872  0.00550574 0.00550404]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05247738 0.00388602 0.00219533 0.00098902 0.0007011  0.00065646
#  0.00084245 0.00087507 0.00093188 0.00096336]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_C5_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_C5_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.13777031 0.00664608 0.00156542 0.00179627 0.00223662 0.00217112
#  0.00249279 0.00228096 0.00265345 0.00278426]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D5_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D5_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05329524 0.00489336 0.00138552 0.00129904 0.00133767 0.00117618
#  0.00146179 0.00142296 0.00151719 0.00157226]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D6_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_D6_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.13288544 0.00645967 0.00149471 0.00153923 0.0017599  0.00158539
#  0.00183606 0.00182542 0.00221808 0.00231299]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_E5_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_E5_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05600876 0.00578119 0.00186737 0.00119031 0.0009207  0.00078709
#  0.00094999 0.00112535 0.00125162 0.00138451]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_F6_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_3.000 ohne Rock_F6_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06150198 0.00567185 0.00185117 0.00113011 0.00082317 0.00076151
#  0.00095107 0.00113306 0.00117531 0.00128046]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05976851 0.00489464 0.00196159 0.00123734 0.00087873 0.00085061
#  0.0011579  0.00121203 0.00123688 0.0013599 ]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_D11_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_D11_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06061629 0.0057117  0.00180911 0.00116203 0.0009005  0.00080923
#  0.00095938 0.00112664 0.00120276 0.00131895]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_F11_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_F11_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.04619229 0.00288175 0.00223496 0.00169948 0.00124934 0.00097948
#  0.00090422 0.00073613 0.00072213 0.00075771]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_G11_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 mit Rock_G11_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.157081   0.00701392 0.00160256 0.00178126 0.00234432 0.0022147
#  0.00248846 0.00239416 0.00308719 0.00340882]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_D10_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_D10_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05751979 0.00628262 0.0016655  0.00130379 0.00114124 0.00094703
#  0.00116187 0.00111644 0.00124889 0.00134332]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_E10_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 2_4.000 ohne Rock_E10_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.04937116 0.00572267 0.00181693 0.0012685  0.0011177  0.00093859
#  0.00125396 0.00125582 0.00131406 0.00140039]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 mit Rock_G3_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 mit Rock_G3_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06634283 0.00474415 0.0013595  0.00109447 0.00127138 0.00115744
#  0.00135263 0.00136453 0.00151106 0.0016128 ]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_C2_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_C2_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05242841 0.0056381  0.00153864 0.00126044 0.00109097 0.00093286
#  0.00121629 0.00119708 0.00127385 0.0013928 ]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_E2_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_2.000 ohne Rock_E2_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.12889074 0.00636966 0.0016871  0.00188872 0.00251531 0.00250793
#  0.00299726 0.00303787 0.00378107 0.00407134]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.06022526 0.005579   0.00151836 0.0012921  0.00126607 0.00105621
#  0.00122256 0.00118607 0.00134974 0.0014913 ]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05967224 0.00415326 0.00203336 0.00112173 0.00079403 0.00077586
#  0.00105723 0.00116486 0.00118293 0.00123086]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F7_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F7_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.08116954 0.00940029 0.00338023 0.00283412 0.00204557 0.00201624
#  0.00226839 0.00213759 0.00205441 0.0020423 ]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 3_3.000 mit Rock_F8_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.10472834 0.00378507 0.00217829 0.00501115 0.00477524 0.00296244
#  0.00245293 0.00229247 0.0020981  0.00199482]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_3.000 mit Rock_E7_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05457296 0.00423561 0.00231075 0.0011297  0.00076488 0.00073013
#  0.00092853 0.00096852 0.00097665 0.00098928]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_C11_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.04924693 0.00537273 0.00153594 0.00117659 0.00105073 0.00081591
#  0.00110368 0.00120956 0.00141012 0.00154333]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_F11_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 4_4.000 mit Rock_F11_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.04954561 0.00582311 0.00171109 0.00129415 0.00109166 0.0009141
#  0.00109771 0.00111657 0.00120492 0.00135754]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2,.000 ohne Rock_D2_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2,.000 ohne Rock_D2_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.1367676  0.00552983 0.00251932 0.00425272 0.0040134  0.00322444
#  0.00285164 0.0030706  0.00274185 0.00247905]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 mit Rock_D4_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 mit Rock_D4_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05683465 0.00559626 0.00146256 0.00119056 0.00119646 0.00103599
#  0.00125661 0.00125341 0.00137313 0.00157604]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_C2_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_C2_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.05273374 0.00578231 0.00175062 0.0012335  0.00097872 0.00081195
#  0.00102329 0.00105569 0.00108398 0.00122023]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_E2_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_2.000 ohne Rock_E2_ch00.tif wurde gespeichert.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# Shape der Vorhersage: (192, 256)
# Einige Werte der Vorhersage: [0.17628329 0.0080481  0.00227682 0.00306432 0.00371252 0.00392417
#  0.00432909 0.0037212  0.00420893 0.00426034]
# Heatmap für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Überlagerungsbild für hanging drop mittlere 3 Zellzahlen mit und ohne Rock_Tag 7_3.000 mit Rock_E8_ch00.tif wurde gespeichert.
# Ergebnisse wurden in C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/testordner/test.xlsx gespeichert.
