# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Images alle/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Masken alle/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)
    
# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X vorher: {X.shape}')
print(f'Form von Y vorher: {Y.shape}')

# Modell erstellen
model = Sequential([
    Conv2D(64, 3, activation='relu', padding='same', input_shape=(192, 256, 1)),
    Dropout(0.1),  # Dropout-Schicht hinzugefügt
    Conv2D(64, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(128, 3, activation='relu', padding='same'),
    Dropout(0.2),  # Dropout-Schicht hinzugefügt
    Conv2D(128, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(512, 3, activation='relu', padding='same'),
    Dropout(0.3),  # Dropout-Schicht hinzugefügt
    Conv2D(256, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(128, 3, activation='relu', padding='same'),
    Dropout(0.2),  # Dropout-Schicht hinzugefügt
    Conv2D(128, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(64, 3, activation='relu', padding='same'),
    Dropout(0.1),  # Dropout-Schicht hinzugefügt
    Conv2D(64, 3, activation='relu', padding='same'),
    Conv2D(1, (3, 3), activation='sigmoid', padding='same')
])

# Modellzusammenfassung anzeigen
model.summary()

# Adam-Optimizer mit spezifischer Lernrate erstellen
optimizer = Adam(learning_rate=0.0001)

# Modell kompilieren mit dem Adam-Optimizer
model.compile(optimizer=optimizer, loss='binary_crossentropy')

# EarlyStopping-Callback hinzufügen
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Trainieren des Modells
history = model.fit(X, Y, batch_size=8, epochs=500, validation_split=0.15, callbacks=[early_stopping])

# Pfad zum Speichern des Modells im HDF5-Format
model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_200_trainingsbilder_noch_komplexer_early_stop_and_droput_3_3.h5') 

# Überprüfen der Formen (optional)
print(f'Form von X nachher: {X.shape}')
print(f'Form von Y nachher: {Y.shape}')

def plot_training_history(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_training_history(history)
# Out:
# Form von X vorher: (214, 192, 256, 1)
# Form von Y vorher: (214, 192, 256, 1)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_22 (Conv2D)              │ (None, 192, 256, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_23 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_24 (Conv2D)              │ (None, 96, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 48, 64, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 48, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (None, 48, 64, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_4 (UpSampling2D)  │ (None, 96, 128, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_28 (Conv2D)              │ (None, 96, 128, 128)   │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_5 (UpSampling2D)  │ (None, 192, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_30 (Conv2D)              │ (None, 192, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_31 (Conv2D)              │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_32 (Conv2D)              │ (None, 192, 256, 1)    │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,583,169 (9.85 MB)
#  Trainable params: 2,583,169 (9.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.5894 - val_loss: 0.4861
# Epoch 2/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 166s 7s/step - loss: 0.4054 - val_loss: 0.3850
# Epoch 3/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 166s 7s/step - loss: 0.3877 - val_loss: 0.3449
# Epoch 4/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 166s 7s/step - loss: 0.3740 - val_loss: 0.3571
# Epoch 5/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 164s 7s/step - loss: 0.3679 - val_loss: 0.3748
# Epoch 6/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.3412 - val_loss: 0.3586
# Epoch 7/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 164s 7s/step - loss: 0.3241 - val_loss: 0.3404
# Epoch 8/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.3282 - val_loss: 0.2811
# Epoch 9/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.2702 - val_loss: 0.1977
# Epoch 10/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 166s 7s/step - loss: 0.1974 - val_loss: 0.2731
# Epoch 11/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 166s 7s/step - loss: 0.1882 - val_loss: 0.2636
# Epoch 12/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.1457 - val_loss: 0.2484
# Epoch 13/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 164s 7s/step - loss: 0.1257 - val_loss: 0.3163
# Epoch 14/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 168s 7s/step - loss: 0.1143 - val_loss: 0.2476
# Epoch 15/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.1070 - val_loss: 0.2149
# Epoch 16/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 169s 7s/step - loss: 0.1061 - val_loss: 0.2101
# Epoch 17/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.1037 - val_loss: 0.2772
# Epoch 18/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 203s 7s/step - loss: 0.1056 - val_loss: 0.2402
# Epoch 19/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 166s 7s/step - loss: 0.1083 - val_loss: 0.2064
# Epoch 20/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.0974 - val_loss: 0.1706
# Epoch 21/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 167s 7s/step - loss: 0.0996 - val_loss: 0.1729
# Epoch 22/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.0961 - val_loss: 0.2495
# Epoch 23/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.0914 - val_loss: 0.2083
# Epoch 24/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 166s 7s/step - loss: 0.0851 - val_loss: 0.1507
# Epoch 25/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 164s 7s/step - loss: 0.0968 - val_loss: 0.1612
# Epoch 26/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 164s 7s/step - loss: 0.0782 - val_loss: 0.1957
# Epoch 27/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.0798 - val_loss: 0.1518
# Epoch 28/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 166s 7s/step - loss: 0.0753 - val_loss: 0.2124
# Epoch 29/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 165s 7s/step - loss: 0.0681 - val_loss: 0.1937
# Epoch 30/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 167s 7s/step - loss: 0.0643 - val_loss: 0.2015
# Epoch 31/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 166s 7s/step - loss: 0.0609 - val_loss: 0.1139
# Epoch 32/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 134s 6s/step - loss: 0.0737 - val_loss: 0.2995
# Epoch 33/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0665 - val_loss: 0.2588
# Epoch 34/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0732 - val_loss: 0.2763
# Epoch 35/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - loss: 0.0515 - val_loss: 0.2223
# Epoch 36/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0451 - val_loss: 0.2167
# Epoch 37/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - loss: 0.0475 - val_loss: 0.1219
# Epoch 38/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0542 - val_loss: 0.2630
# Epoch 39/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - loss: 0.0454 - val_loss: 0.1752
# Epoch 40/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0547 - val_loss: 0.1174
# Epoch 41/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - loss: 0.0490 - val_loss: 0.2342
# Epoch 42/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0432 - val_loss: 0.1701
# Epoch 43/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0479 - val_loss: 0.1750
# Epoch 44/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0572 - val_loss: 0.1599
# Epoch 45/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - loss: 0.0429 - val_loss: 0.2056
# Epoch 46/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - loss: 0.0472 - val_loss: 0.0782
# Epoch 47/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0418 - val_loss: 0.1323
# Epoch 48/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0381 - val_loss: 0.2184
# Epoch 49/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0415 - val_loss: 0.1648
# Epoch 50/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0385 - val_loss: 0.2200
# Epoch 51/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0410 - val_loss: 0.2091
# Epoch 52/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - loss: 0.0457 - val_loss: 0.1787
# Epoch 53/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0293 - val_loss: 0.0698
# Epoch 54/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0392 - val_loss: 0.1900
# Epoch 55/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 77s 3s/step - loss: 0.0329 - val_loss: 0.0544
# Epoch 56/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0368 - val_loss: 0.0902
# Epoch 57/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0346 - val_loss: 0.0937
# Epoch 58/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0337 - val_loss: 0.1235
# Epoch 59/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0288 - val_loss: 0.1678
# Epoch 60/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0343 - val_loss: 0.1116
# Epoch 61/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0301 - val_loss: 0.1178
# Epoch 62/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0258 - val_loss: 0.1540
# Epoch 63/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - loss: 0.0255 - val_loss: 0.1216
# Epoch 64/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - loss: 0.0311 - val_loss: 0.1303
# Epoch 65/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0376 - val_loss: 0.1460
# Epoch 66/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0353 - val_loss: 0.0741
# Epoch 67/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0328 - val_loss: 0.1325
# Epoch 68/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0292 - val_loss: 0.0729
# Epoch 69/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0299 - val_loss: 0.1446
# Epoch 70/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0263 - val_loss: 0.0670
# Epoch 71/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0262 - val_loss: 0.0805
# Epoch 72/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0284 - val_loss: 0.1108
# Epoch 73/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0292 - val_loss: 0.1344
# Epoch 74/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0292 - val_loss: 0.0471
# Epoch 75/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0233 - val_loss: 0.0997
# Epoch 76/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0251 - val_loss: 0.0898
# Epoch 77/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0238 - val_loss: 0.0623
# Epoch 78/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0244 - val_loss: 0.0977
# Epoch 79/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0259 - val_loss: 0.1145
# Epoch 80/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0244 - val_loss: 0.0594
# Epoch 81/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0223 - val_loss: 0.0729
# Epoch 82/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0264 - val_loss: 0.0449
# Epoch 83/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0217 - val_loss: 0.0521
# Epoch 84/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0209 - val_loss: 0.1256
# Epoch 85/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0192 - val_loss: 0.0550
# Epoch 86/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0198 - val_loss: 0.0584
# Epoch 87/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0239 - val_loss: 0.0658
# Epoch 88/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - loss: 0.0210 - val_loss: 0.0625
# Epoch 89/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - loss: 0.0199 - val_loss: 0.0643
# Epoch 90/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0170 - val_loss: 0.0650
# Epoch 91/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0215 - val_loss: 0.0804
# Epoch 92/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0257 - val_loss: 0.0490
# Epoch 93/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0256 - val_loss: 0.0503
# Epoch 94/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0205 - val_loss: 0.0563
# Epoch 95/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0188 - val_loss: 0.0786
# Epoch 96/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0174 - val_loss: 0.0470
# Epoch 97/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0204 - val_loss: 0.0404
# Epoch 98/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0174 - val_loss: 0.0627
# Epoch 99/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0171 - val_loss: 0.0576
# Epoch 100/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0186 - val_loss: 0.0933
# Epoch 101/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0183 - val_loss: 0.0340
# Epoch 102/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0199 - val_loss: 0.0488
# Epoch 103/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0174 - val_loss: 0.0573
# Epoch 104/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0238 - val_loss: 0.0675
# Epoch 105/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0204 - val_loss: 0.0477
# Epoch 106/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0152 - val_loss: 0.0430
# Epoch 107/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0160 - val_loss: 0.0296
# Epoch 108/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0175 - val_loss: 0.0587
# Epoch 109/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0145 - val_loss: 0.0606
# Epoch 110/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0143 - val_loss: 0.0316
# Epoch 111/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0219 - val_loss: 0.0311
# Epoch 112/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0203 - val_loss: 0.0330
# Epoch 113/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0166 - val_loss: 0.0517
# Epoch 114/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0154 - val_loss: 0.0279
# Epoch 115/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0160 - val_loss: 0.0374
# Epoch 116/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0160 - val_loss: 0.0442
# Epoch 117/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - loss: 0.0144 - val_loss: 0.0469
# Epoch 118/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0154 - val_loss: 0.0327
# Epoch 119/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0136 - val_loss: 0.0423
# Epoch 120/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0163 - val_loss: 0.0558
# Epoch 121/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0128 - val_loss: 0.0592
# Epoch 122/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0149 - val_loss: 0.0447
# Epoch 123/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0139 - val_loss: 0.0907
# Epoch 124/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0144 - val_loss: 0.0856
# Epoch 125/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0137 - val_loss: 0.0368
# Epoch 126/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0138 - val_loss: 0.0465
# Epoch 127/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0144 - val_loss: 0.0518
# Epoch 128/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0169 - val_loss: 0.0464
# Epoch 129/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0153 - val_loss: 0.0367
# Epoch 130/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0124 - val_loss: 0.0435
# Epoch 131/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0135 - val_loss: 0.0389
# Epoch 132/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0129 - val_loss: 0.0348
# Epoch 133/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0144 - val_loss: 0.0412
# Epoch 134/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0135 - val_loss: 0.0443
# Epoch 135/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0129 - val_loss: 0.0512
# Epoch 136/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0122 - val_loss: 0.0244
# Epoch 137/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0133 - val_loss: 0.0552
# Epoch 138/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0199 - val_loss: 0.0289
# Epoch 139/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0260 - val_loss: 0.0745
# Epoch 140/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0226 - val_loss: 0.0477
# Epoch 141/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0144 - val_loss: 0.0533
# Epoch 142/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0127 - val_loss: 0.0332
# Epoch 143/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0131 - val_loss: 0.0470
# Epoch 144/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0122 - val_loss: 0.0444
# Epoch 145/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0115 - val_loss: 0.0430
# Epoch 146/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0121 - val_loss: 0.0612
# Epoch 147/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0183 - val_loss: 0.0360
# Epoch 148/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0117 - val_loss: 0.0380
# Epoch 149/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0125 - val_loss: 0.0275
# Epoch 150/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0118 - val_loss: 0.0349
# Epoch 151/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0108 - val_loss: 0.0375
# Epoch 152/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0117 - val_loss: 0.0300
# Epoch 153/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0128 - val_loss: 0.0239
# Epoch 154/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0126 - val_loss: 0.0392
# Epoch 155/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0115 - val_loss: 0.0201
# Epoch 156/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0126 - val_loss: 0.0420
# Epoch 157/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0113 - val_loss: 0.0241
# Epoch 158/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0174 - val_loss: 0.0683
# Epoch 159/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0188 - val_loss: 0.0329
# Epoch 160/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0125 - val_loss: 0.0211
# Epoch 161/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0124 - val_loss: 0.0323
# Epoch 162/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0118 - val_loss: 0.0572
# Epoch 163/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0110 - val_loss: 0.0273
# Epoch 164/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0108 - val_loss: 0.0267
# Epoch 165/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0102 - val_loss: 0.0314
# Epoch 166/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0106 - val_loss: 0.0286
# Epoch 167/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0100 - val_loss: 0.0256
# Epoch 168/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0100 - val_loss: 0.0434
# Epoch 169/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0109 - val_loss: 0.0410
# Epoch 170/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0111 - val_loss: 0.0304
# Epoch 171/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0149 - val_loss: 0.0297
# Epoch 172/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0145 - val_loss: 0.0241
# Epoch 173/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0114 - val_loss: 0.0354
# Epoch 174/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0104 - val_loss: 0.0376
# Epoch 175/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0106 - val_loss: 0.0271
# Epoch 176/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0179 - val_loss: 0.0271
# Epoch 177/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0191 - val_loss: 0.0286
# Epoch 178/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0183 - val_loss: 0.0300
# Epoch 179/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0127 - val_loss: 0.1005
# Epoch 180/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0139 - val_loss: 0.0162
# Epoch 181/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0107 - val_loss: 0.0216
# Epoch 182/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0099 - val_loss: 0.0367
# Epoch 183/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0123 - val_loss: 0.0222
# Epoch 184/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0100 - val_loss: 0.0209
# Epoch 185/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0092 - val_loss: 0.0217
# Epoch 186/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0103 - val_loss: 0.0309
# Epoch 187/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0105 - val_loss: 0.0276
# Epoch 188/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0103 - val_loss: 0.0222
# Epoch 189/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0097 - val_loss: 0.0261
# Epoch 190/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0096 - val_loss: 0.0379
# Epoch 191/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0099 - val_loss: 0.0284
# Epoch 192/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0094 - val_loss: 0.0262
# Epoch 193/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0092 - val_loss: 0.0178
# Epoch 194/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0092 - val_loss: 0.0236
# Epoch 195/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0092 - val_loss: 0.0239
# Epoch 196/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0091 - val_loss: 0.0180
# Epoch 197/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0084 - val_loss: 0.0285
# Epoch 198/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0089 - val_loss: 0.0273
# Epoch 199/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0091 - val_loss: 0.0337
# Epoch 200/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0092 - val_loss: 0.0339
# Epoch 201/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0088 - val_loss: 0.0197
# Epoch 202/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0089 - val_loss: 0.0463
# Epoch 203/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0100 - val_loss: 0.0194
# Epoch 204/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0094 - val_loss: 0.0223
# Epoch 205/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0110 - val_loss: 0.0609
# Epoch 206/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0148 - val_loss: 0.0981
# Epoch 207/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0167 - val_loss: 0.0186
# Epoch 208/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0144 - val_loss: 0.0279
# Epoch 209/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0106 - val_loss: 0.0433
# Epoch 210/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0120 - val_loss: 0.0223
# Epoch 211/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0104 - val_loss: 0.0250
# Epoch 212/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0093 - val_loss: 0.0327
# Epoch 213/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0101 - val_loss: 0.0233
# Epoch 214/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0092 - val_loss: 0.0236
# Epoch 215/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0092 - val_loss: 0.0143
# Epoch 216/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0091 - val_loss: 0.0244
# Epoch 217/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0092 - val_loss: 0.0185
# Epoch 218/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0087 - val_loss: 0.0240
# Epoch 219/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0084 - val_loss: 0.0233
# Epoch 220/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0087 - val_loss: 0.0186
# Epoch 221/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0082 - val_loss: 0.0264
# Epoch 222/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0083 - val_loss: 0.0202
# Epoch 223/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0083 - val_loss: 0.0274
# Epoch 224/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0085 - val_loss: 0.0253
# Epoch 225/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0088 - val_loss: 0.0176
# Epoch 226/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0086 - val_loss: 0.0200
# Epoch 227/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0085 - val_loss: 0.0143
# Epoch 228/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0140 - val_loss: 0.0246
# Epoch 229/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0151 - val_loss: 0.0317
# Epoch 230/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0330 - val_loss: 0.0778
# Epoch 231/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0303 - val_loss: 0.0646
# Epoch 232/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0293 - val_loss: 0.0822
# Epoch 233/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0225 - val_loss: 0.0187
# Epoch 234/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0139 - val_loss: 0.0320
# Epoch 235/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0119 - val_loss: 0.0149
# Epoch 236/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0110 - val_loss: 0.0146
# Epoch 237/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0114 - val_loss: 0.0176
# Epoch 238/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0115 - val_loss: 0.0351
# Epoch 239/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0112 - val_loss: 0.0263
# Epoch 240/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0095 - val_loss: 0.0167
# Epoch 241/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0086 - val_loss: 0.0232
# Epoch 242/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0088 - val_loss: 0.0185
# Epoch 243/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0121 - val_loss: 0.0267
# Epoch 244/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0112 - val_loss: 0.0150
# Epoch 245/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0093 - val_loss: 0.0148
# Epoch 246/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0091 - val_loss: 0.0170
# Epoch 247/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0084 - val_loss: 0.0164
# Epoch 248/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0086 - val_loss: 0.0186
# Epoch 249/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0092 - val_loss: 0.0186
# Epoch 250/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0078 - val_loss: 0.0166
# Epoch 251/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0082 - val_loss: 0.0169
# Epoch 252/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0082 - val_loss: 0.0160
# Epoch 253/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 145s 6s/step - loss: 0.0078 - val_loss: 0.0192
# Epoch 254/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 107s 5s/step - loss: 0.0080 - val_loss: 0.0176
# Epoch 255/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 86s 4s/step - loss: 0.0083 - val_loss: 0.0177
# Epoch 256/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0074 - val_loss: 0.0149
# Epoch 257/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0082 - val_loss: 0.0173
# Epoch 258/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0082 - val_loss: 0.0204
# Epoch 259/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0078 - val_loss: 0.0187
# Epoch 260/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0079 - val_loss: 0.0139
# Epoch 261/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0076 - val_loss: 0.0165
# Epoch 262/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0078 - val_loss: 0.0183
# Epoch 263/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0075 - val_loss: 0.0161
# Epoch 264/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0078 - val_loss: 0.0159
# Epoch 265/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0078 - val_loss: 0.0170
# Epoch 266/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0078 - val_loss: 0.0188
# Epoch 267/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0080 - val_loss: 0.0166
# Epoch 268/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0080 - val_loss: 0.0205
# Epoch 269/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0077 - val_loss: 0.0176
# Epoch 270/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0079 - val_loss: 0.0192
# Epoch 271/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0077 - val_loss: 0.0197
# Epoch 272/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0075 - val_loss: 0.0180
# Epoch 273/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0076 - val_loss: 0.0182
# Epoch 274/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0077 - val_loss: 0.0203
# Epoch 275/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - loss: 0.0078 - val_loss: 0.0167
# Epoch 276/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0076 - val_loss: 0.0170
# Epoch 277/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0073 - val_loss: 0.0198
# Epoch 278/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0076 - val_loss: 0.0204
# Epoch 279/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0078 - val_loss: 0.0166
# Epoch 280/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0073 - val_loss: 0.0171
# Epoch 281/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0076 - val_loss: 0.0180
# Epoch 282/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0071 - val_loss: 0.0175
# Epoch 283/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0072 - val_loss: 0.0179
# Epoch 284/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0074 - val_loss: 0.0193
# Epoch 285/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0074 - val_loss: 0.0165
# Epoch 286/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0072 - val_loss: 0.0207
# Epoch 287/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0076 - val_loss: 0.0224
# Epoch 288/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0081 - val_loss: 0.0241
# Epoch 289/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0088 - val_loss: 0.0173
# Epoch 290/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0078 - val_loss: 0.0127
# Epoch 291/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0075 - val_loss: 0.0164
# Epoch 292/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0071 - val_loss: 0.0174
# Epoch 293/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0074 - val_loss: 0.0175
# Epoch 294/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0074 - val_loss: 0.0142
# Epoch 295/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0070 - val_loss: 0.0164
# Epoch 296/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0073 - val_loss: 0.0164
# Epoch 297/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0073 - val_loss: 0.0164
# Epoch 298/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0072 - val_loss: 0.0154
# Epoch 299/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0068 - val_loss: 0.0196
# Epoch 300/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0072 - val_loss: 0.0170
# Epoch 301/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0072 - val_loss: 0.0136
# Epoch 302/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0074 - val_loss: 0.0130
# Epoch 303/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0079 - val_loss: 0.0172
# Epoch 304/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0164 - val_loss: 0.0334
# Epoch 305/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0165 - val_loss: 0.0472
# Epoch 306/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0141 - val_loss: 0.0214
# Epoch 307/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0110 - val_loss: 0.0163
# Epoch 308/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0108 - val_loss: 0.0197
# Epoch 309/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0091 - val_loss: 0.0155
# Epoch 310/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0135 - val_loss: 0.0263
# Epoch 311/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0133 - val_loss: 0.0174
# Epoch 312/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0094 - val_loss: 0.0157
# Epoch 313/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0084 - val_loss: 0.0251
# Epoch 314/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0178 - val_loss: 0.0206
# Epoch 315/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0155 - val_loss: 0.0118
# Epoch 316/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0132 - val_loss: 0.0172
# Epoch 317/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0098 - val_loss: 0.0108
# Epoch 318/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0084 - val_loss: 0.0109
# Epoch 319/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0084 - val_loss: 0.0109
# Epoch 320/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0076 - val_loss: 0.0138
# Epoch 321/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0073 - val_loss: 0.0139
# Epoch 322/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0070 - val_loss: 0.0161
# Epoch 323/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0075 - val_loss: 0.0124
# Epoch 324/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0068 - val_loss: 0.0172
# Epoch 325/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0068 - val_loss: 0.0152
# Epoch 326/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0068 - val_loss: 0.0137
# Epoch 327/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 80s 3s/step - loss: 0.0069 - val_loss: 0.0146
# Epoch 328/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0066 - val_loss: 0.0131
# Epoch 329/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0068 - val_loss: 0.0157
# Epoch 330/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0066 - val_loss: 0.0138
# Epoch 331/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0066 - val_loss: 0.0146
# Epoch 332/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0069 - val_loss: 0.0152
# Epoch 333/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0068 - val_loss: 0.0154
# Epoch 334/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0070 - val_loss: 0.0148
# Epoch 335/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0064 - val_loss: 0.0143
# Epoch 336/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0065 - val_loss: 0.0139
# Epoch 337/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0063 - val_loss: 0.0147
# Epoch 338/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0066 - val_loss: 0.0119
# Epoch 339/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0074 - val_loss: 0.0158
# Epoch 340/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0070 - val_loss: 0.0355
# Epoch 341/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0079 - val_loss: 0.0759
# Epoch 342/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0110 - val_loss: 0.0218
# Epoch 343/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0086 - val_loss: 0.0187
# Epoch 344/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0080 - val_loss: 0.0131
# Epoch 345/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0069 - val_loss: 0.0153
# Epoch 346/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0066 - val_loss: 0.0117
# Epoch 347/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0070 - val_loss: 0.0162
# Epoch 348/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0066 - val_loss: 0.0125
# Epoch 349/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0064 - val_loss: 0.0128
# Epoch 350/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0065 - val_loss: 0.0136
# Epoch 351/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0062 - val_loss: 0.0145
# Epoch 352/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0062 - val_loss: 0.0131
# Epoch 353/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0063 - val_loss: 0.0149
# Epoch 354/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0064 - val_loss: 0.0138
# Epoch 355/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0060 - val_loss: 0.0160
# Epoch 356/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0063 - val_loss: 0.0153
# Epoch 357/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0060 - val_loss: 0.0139
# Epoch 358/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0062 - val_loss: 0.0148
# Epoch 359/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0060 - val_loss: 0.0144
# Epoch 360/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0061 - val_loss: 0.0150
# Epoch 361/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 78s 3s/step - loss: 0.0062 - val_loss: 0.0154
# Epoch 362/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0058 - val_loss: 0.0154
# Epoch 363/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0062 - val_loss: 0.0162
# Epoch 364/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0060 - val_loss: 0.0138
# Epoch 365/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0060 - val_loss: 0.0152
# Epoch 366/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0061 - val_loss: 0.0159
# Epoch 367/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 79s 3s/step - loss: 0.0060 - val_loss: 0.0138
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Form von X nachher: (214, 192, 256, 1)
# Form von Y nachher: (214, 192, 256, 1)

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

def draw_contours_and_centroid(binary_mask, output_path):
    # Finden der Konturen
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Erstellen eines Farbbilds zum Zeichnen
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    
    # Zeichnen der Konturen
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    
    # Berechnung und Zeichnen des Schwerpunkts
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
    
    # Speichern des Bildes mit Konturen und Schwerpunkt
    cv2.imwrite(output_path, color_mask)

# Laden und Vorverarbeiten der Bilder mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')  # Convert to grayscale
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x196)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

# Vorhersage mit dem Modell machen
def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
    predicted_mask = model.predict(image)  # Vorhersage machen
    return np.squeeze(predicted_mask)  # Batch-Dimension entfernen

# Funktion zur Berechnung der mittleren Konturgröße
def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

# Funktion zur Auswahl des besten Schwellenwerts
def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0

    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size  # Anpassen der Bewertungsmetrik nach Bedarf

            if score > best_score:
                best_score = score
                best_threshold = threshold

    return best_threshold

# Funktion zur Berechnung des mittleren Durchmessers
def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)


# Pfade definieren
model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_200_trainingsbilder_noch_komplexer_early_stop_and_droput_3_3.h5'
input_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Sphäroide BA/Alle BA Sphäaeroidbilder sortiert/'
output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher/'
excel_file_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Sphäroide BA/gemessene Durchmesser neu.xlsx'

# Modell laden
model = tf.keras.models.load_model(model_path)

# Daten aus der Excel-Tabelle laden
predicted_diameters = []
df_manual = pd.read_excel(excel_file_path, header=0)  # Daten ab der zweiten Zeile 
manual_diameters = df_manual.iloc[:, 1].tolist()  # Durchmesser sind in der zweiten Spalte

# Debug-Ausgabe: Anzahl der manuellen Durchmesser
print(f"Anzahl der manuellen Durchmesser: {len(df_manual)}")

# Skalierungsfaktoren berechnen
scale_factor_width = 1296 / 256  # Originalbreite / skalierte Breite
scale_factor_height = 966 / 196  # Originalhöhe / skalierte Höhe

# Listen für die berechneten Durchmesser und die manuell gemessenen Durchmesser
manual_diameters = []

# Iteration über alle TIFF-Dateien im Eingabeordner
tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Debug-Ausgabe: Anzahl der TIFF-Dateien
print(f"Anzahl der TIFF-Dateien: {len(tif_files)}")

# Überprüfen, ob die Anzahl der Dateien mit der Anzahl der manuellen Messungen übereinstimmt
if len(tif_files) != len(df_manual):
    print("Die Anzahl der Bilddateien stimmt nicht mit der Anzahl der manuellen Messungen überein.")
else:
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        
        try:
            # Bild laden und vorverarbeiten
            image = load_and_preprocess_image_pillow(img_path)
            # Vorhersage mit dem Modell machen
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            # Besten Schwellenwert für Konturen finden
            best_threshold = find_best_threshold(predicted_mask)

            # Maske mit dem besten Schwellenwert erstellen
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
            
            # Konturen finden
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            # Filtere Konturen nach Schmalheitsverhältnis
            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:  # Anpassen des Schmalheitsverhältnisses nach Bedarf
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            # Die größte Kontur nach dem Flächeninhalt finden
            largest_contour = max(filtered_contours, key=cv2.contourArea)

            # Berechne den Schwerpunkt der Kontur
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

            # Berechne den mittleren Durchmesser
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width) *0.994     #mit faktor für verzerrung

            # Berechnung des Flächeninhalts
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.3745 * scale_factor_width * 0.3745 * scale_factor_height)

            # Ergebnisse hinzufügen
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])  # Manuell gemessener Durchmesser hinzufügen

            # Ausgabepfad für das segmentierte Bild definieren
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            draw_contours_and_centroid(binary_mask, output_path)

            # Maske als TIFF-Datei speichern
            Image.fromarray(binary_mask, mode='L').save(output_path)
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")

            # Ergebnisse ausgeben
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Flächeninhalt: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    # Debug-Ausgabe: Anzahl der erfolgreichen Vorhersagen und manuell gemessenen Durchmesser
    print(f"Anzahl der erfolgreichen Vorhersagen: {len(predicted_diameters)}")
    print(f"Anzahl der zugehörigen manuellen Durchmesser: {len(manual_diameters)}")

    # Ergebnisse in ein DataFrame konvertieren
    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    # Ergebnisse in eine Excel-Datei exportieren
    excel_output_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx'
    df_results.to_excel(excel_output_path, index=False)

    # Berechnung der Metriken zur Bewertung der Modellgenauigkeit
    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)

        print(f"\nMetriken zur Bewertung der Modellgenauigkeit:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")

        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print("Keine ausreichenden Daten zur Berechnung der Metriken vorhanden.")

    # Scatterplot erstellen
    plt.figure(figsize=(10, 6))
    plt.scatter(manual_diameters, predicted_diameters, color='blue', label='Vorhergesagt vs. Manuell')
    plt.plot([min(manual_diameters), max(manual_diameters)], [min(manual_diameters), max(manual_diameters)], color='red', linestyle='--', label='Perfekte Übereinstimmung')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title('Vergleich von manuellen und vorhergesagten Durchmessern')
    plt.legend()
    plt.grid(True)
    plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/scatterplot.png')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Anzahl der manuellen Durchmesser: 357
# Anzahl der TIFF-Dateien: 357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 C6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 C6_ch00.tif, Durchmesser: 156.91 µm, Flächeninhalt: 19213.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 D6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 D6_ch00.tif, Durchmesser: 158.11 µm, Flächeninhalt: 19470.49 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS +P1 E6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS +P1 E6_ch00.tif, Durchmesser: 148.29 µm, Flächeninhalt: 17111.91 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS B4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS B4_ch00.tif, Durchmesser: 161.31 µm, Flächeninhalt: 20266.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS C4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS C4_ch00.tif, Durchmesser: 160.33 µm, Flächeninhalt: 20026.89 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS D4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS D4_ch00.tif, Durchmesser: 152.74 µm, Flächeninhalt: 18159.98 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 B5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 B5_ch00.tif, Durchmesser: 130.48 µm, Flächeninhalt: 13294.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 C5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 C5_ch00.tif, Durchmesser: 166.68 µm, Flächeninhalt: 21643.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 E5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 E5_ch00.tif, Durchmesser: 149.40 µm, Flächeninhalt: 17400.61 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer C3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer C3_ch00.tif, Durchmesser: 157.26 µm, Flächeninhalt: 19276.27 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer D3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer D3_ch00.tif, Durchmesser: 153.30 µm, Flächeninhalt: 18315.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer F3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer F3_ch00.tif, Durchmesser: 154.76 µm, Flächeninhalt: 18616.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 D10_ch00.tif, Durchmesser: 137.62 µm, Flächeninhalt: 14746.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 E10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 E10_ch00.tif, Durchmesser: 131.49 µm, Flächeninhalt: 13458.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 G10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 G10_ch00.tif, Durchmesser: 125.22 µm, Flächeninhalt: 12205.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS C8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS C8_ch00.tif, Durchmesser: 145.63 µm, Flächeninhalt: 16513.52 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS E8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS E8_ch00.tif, Durchmesser: 138.56 µm, Flächeninhalt: 14907.31 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS F8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS F8_ch00.tif, Durchmesser: 149.55 µm, Flächeninhalt: 17442.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 c9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 c9_ch00.tif, Durchmesser: 147.72 µm, Flächeninhalt: 16987.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 D9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 D9_ch00.tif, Durchmesser: 151.94 µm, Flächeninhalt: 17999.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 E9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 E9_ch00.tif, Durchmesser: 142.24 µm, Flächeninhalt: 15769.91 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer B7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer B7_ch00.tif, Durchmesser: 132.21 µm, Flächeninhalt: 13603.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer D7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer D7_ch00.tif, Durchmesser: 153.35 µm, Flächeninhalt: 18315.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer F7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer F7_ch00.tif, Durchmesser: 159.97 µm, Flächeninhalt: 19979.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS D11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS D11_ch00.tif, Durchmesser: 125.27 µm, Flächeninhalt: 12218.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS E11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS E11_ch00.tif, Durchmesser: 151.97 µm, Flächeninhalt: 17969.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS F11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS F11_ch00.tif, Durchmesser: 153.79 µm, Flächeninhalt: 18403.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle C2_ch00.tif, Durchmesser: 162.73 µm, Flächeninhalt: 20579.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle D2_ch00.tif, Durchmesser: 151.67 µm, Flächeninhalt: 17925.52 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle F2_ch00.tif, Durchmesser: 157.06 µm, Flächeninhalt: 19152.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_P1 B11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_P1 B11_ch00.tif, Durchmesser: 170.63 µm, Flächeninhalt: 22637.42 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_P1 C11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_P1 C11_ch00.tif, Durchmesser: 139.40 µm, Flächeninhalt: 15126.02 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_P1 D11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_P1 D11_ch00.tif, Durchmesser: 148.86 µm, Flächeninhalt: 17313.13 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 C6_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 C6_ch00.tif, Durchmesser: 162.77 µm, Flächeninhalt: 20618.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 D6_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 D6_ch00.tif, Durchmesser: 168.92 µm, Flächeninhalt: 22184.25 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 E6_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 E6_ch00.tif, Durchmesser: 157.93 µm, Flächeninhalt: 19390.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS B4_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS B4_ch00.tif, Durchmesser: 166.80 µm, Flächeninhalt: 21645.35 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 177
#     174 center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))
#     176 # Berechne den mittleren Durchmesser
# --> 177 avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
#     178 avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width) *0.994     #mit faktor für verzerrung
#     180 # Berechnung des Flächeninhalts
#
# Cell In[2], line 84, in calculate_average_diameter(contour, center, num_lines)
#      82     x = int(center[0] + i * dx)
#      83     y = int(center[1] + i * dy)
# ---> 84     if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
#      85         intersections.append((x, y))
#      86 if len(intersections) >= 2:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Funktion zum Zeichnen von Konturen und Schwerpunkt
def draw_contours_and_centroid(binary_mask, output_path):
    # Finden der Konturen
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Erstellen eines Farbbilds zum Zeichnen
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    
    # Zeichnen der Konturen
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    
    # Berechnung und Zeichnen des Schwerpunkts
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
    
    # Speichern des Bildes mit Konturen und Schwerpunkt
    cv2.imwrite(output_path, color_mask)

# Laden und Vorverarbeiten der Bilder mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')  # Convert to grayscale
    img = img.resize((256, 196))  # Größe anpassen (Beispiel: 256x196)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

# Vorhersage mit dem Modell machen
def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
    predicted_mask = model.predict(image)  # Vorhersage machen
    return np.squeeze(predicted_mask)  # Batch-Dimension entfernen

# Funktion zur Berechnung der mittleren Konturgröße
def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

# Funktion zur Auswahl des besten Schwellenwerts
def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0

    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size  # Anpassen der Bewertungsmetrik nach Bedarf

            if score > best_score:
                best_score = score
                best_threshold = threshold

    return best_threshold

# Funktion zur Berechnung des mittleren Durchmessers
def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)

# Pfade definieren
model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_200_trainingsbilder_noch_komplexer_early_stop_and_droput_3.h5'
input_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Sphäroide BA/Alle BA Sphäaeroidbilder sortiert/'
output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher test/'
excel_file_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Sphäroide BA/gemessene Durchmesser neu2.xlsx'

# Modell laden
model = tf.keras.models.load_model(model_path)

# Daten aus der Excel-Tabelle laden
predicted_diameters = []
df_manual = pd.read_excel(excel_file_path, header=0)  # Daten ab der zweiten Zeile 
manual_diameters = df_manual.iloc[:, 1].tolist()  # Durchmesser sind in der zweiten Spalte

# Debug-Ausgabe: Anzahl der manuellen Durchmesser
print(f"Anzahl der manuellen Durchmesser: {len(df_manual)}")

# Skalierungsfaktoren berechnen
scale_factor_width = 1296 / 256  # Originalbreite / skalierte Breite
scale_factor_height = 966 / 196  # Originalhöhe / skalierte Höhe

# Listen für die berechneten Durchmesser und die manuell gemessenen Durchmesser
manual_diameters = []

# Iteration über alle TIFF-Dateien im Eingabeordner
tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Debug-Ausgabe: Anzahl der TIFF-Dateien
print(f"Anzahl der TIFF-Dateien: {len(tif_files)}")

# Überprüfen, ob die Anzahl der Dateien mit der Anzahl der manuellen Messungen übereinstimmt
if len(tif_files) != len(df_manual):
    print("Die Anzahl der Bilddateien stimmt nicht mit der Anzahl der manuellen Messungen überein.")
else:
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        
        try:
            # Bild laden und vorverarbeiten
            image = load_and_preprocess_image_pillow(img_path)
            # Vorhersage mit dem Modell machen
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            # Besten Schwellenwert für Konturen finden
            best_threshold = find_best_threshold(predicted_mask)

            # Maske mit dem besten Schwellenwert erstellen
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
            
            # Konturen finden
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            # Filtere Konturen nach Schmalheitsverhältnis
            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:  # Anpassen des Schmalheitsverhältnisses nach Bedarf
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            # Die größte Kontur nach dem Flächeninhalt finden
            largest_contour = max(filtered_contours, key=cv2.contourArea)

            # Berechne den Schwerpunkt der Kontur
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

            # Berechne den mittleren Durchmesser
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width)

            # Berechnung des Flächeninhalts
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.3745 * scale_factor_width * 0.3745 * scale_factor_height)

            # Ergebnisse hinzufügen
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])  # Manuell gemessener Durchmesser hinzufügen

            # Ausgabepfad für das segmentierte Bild definieren
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            
            # Maske als TIFF-Datei speichern und Konturen und Schwerpunkt einzeichnen
            draw_contours_and_centroid(binary_mask, output_path)
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")

            # Ergebnisse ausgeben
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Flächeninhalt: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    # Debug-Ausgabe: Anzahl der erfolgreichen Vorhersagen und manuell gemessenen Durchmesser
    print(f"Anzahl der erfolgreichen Vorhersagen: {len(predicted_diameters)}")
    print(f"Anzahl der zugehörigen manuellen Durchmesser: {len(manual_diameters)}")

    # Ergebnisse in ein DataFrame konvertieren
    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    # Ergebnisse in eine Excel-Datei exportieren
    excel_output_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx'
    df_results.to_excel(excel_output_path, index=False)

    # Berechnung der Metriken zur Bewertung der Modellgenauigkeit
    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)

        print(f"\nMetriken zur Bewertung der Modellgenauigkeit:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")

        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print("Keine ausreichenden Daten zur Berechnung der Metriken vorhanden.")

    # Scatterplot erstellen
    plt.figure(figsize=(10, 6))
    plt.scatter(manual_diameters, predicted_diameters, color='blue', label='Vorhergesagt vs. Manuell')
    plt.plot([min(manual_diameters), max(manual_diameters)], [min(manual_diameters), max(manual_diameters)], color='red', linestyle='--', label='Perfekte Übereinstimmung')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title('Vergleich von manuellen und vorhergesagten Durchmessern')
    plt.legend()
    plt.grid(True)
    plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/scatterplot.png')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Anzahl der manuellen Durchmesser: 357
# Anzahl der TIFF-Dateien: 357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 C6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 C6_ch00.tif, Durchmesser: 159.46 µm, Flächeninhalt: 19580.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 D6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 D6_ch00.tif, Durchmesser: 161.25 µm, Flächeninhalt: 20018.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS +P1 E6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS +P1 E6_ch00.tif, Durchmesser: 151.44 µm, Flächeninhalt: 17661.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS B4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS B4_ch00.tif, Durchmesser: 164.50 µm, Flächeninhalt: 20809.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS C4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS C4_ch00.tif, Durchmesser: 163.39 µm, Flächeninhalt: 20529.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS D4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS D4_ch00.tif, Durchmesser: 154.93 µm, Flächeninhalt: 18494.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 B5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 B5_ch00.tif, Durchmesser: 133.93 µm, Flächeninhalt: 13817.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 C5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 C5_ch00.tif, Durchmesser: 170.45 µm, Flächeninhalt: 22301.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 E5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 E5_ch00.tif, Durchmesser: 154.60 µm, Flächeninhalt: 18396.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer C3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer C3_ch00.tif, Durchmesser: 160.79 µm, Flächeninhalt: 19902.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer D3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer D3_ch00.tif, Durchmesser: 157.40 µm, Flächeninhalt: 19055.81 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer F3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer F3_ch00.tif, Durchmesser: 157.58 µm, Flächeninhalt: 19118.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 D10_ch00.tif, Durchmesser: 140.54 µm, Flächeninhalt: 15152.27 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 E10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 E10_ch00.tif, Durchmesser: 134.56 µm, Flächeninhalt: 13902.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 G10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 G10_ch00.tif, Durchmesser: 127.09 µm, Flächeninhalt: 12433.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS C8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS C8_ch00.tif, Durchmesser: 148.91 µm, Flächeninhalt: 17033.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS E8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS E8_ch00.tif, Durchmesser: 141.07 µm, Flächeninhalt: 15290.49 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS F8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS F8_ch00.tif, Durchmesser: 152.83 µm, Flächeninhalt: 17978.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 c9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 c9_ch00.tif, Durchmesser: 151.28 µm, Flächeninhalt: 17615.82 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 D9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 D9_ch00.tif, Durchmesser: 155.42 µm, Flächeninhalt: 18578.15 µm²
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 133
#     131 image = load_and_preprocess_image_pillow(img_path)
#     132 # Vorhersage mit dem Modell machen
# --> 133 predicted_mask = predict_with_model(model, image)
#     134 if predicted_mask is None:
#     135     print(f"Fehler bei der Vorhersage für {filename}.")
#
# Cell In[3], line 44, in predict_with_model(model, image)
#      42 def predict_with_model(model, image):
#      43     image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
# ---> 44     predicted_mask = model.predict(image)  # Vorhersage machen
#      45     return np.squeeze(predicted_mask)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:504, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     502 callbacks.on_predict_batch_begin(step)
#     503 data = get_data(iterator)
# --> 504 batch_outputs = self.predict_function(data)
#     505 outputs = append_to_outputs(batch_outputs, outputs)
#     506 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
