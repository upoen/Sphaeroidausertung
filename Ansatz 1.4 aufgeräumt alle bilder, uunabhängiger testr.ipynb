# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Images alle/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Masken alle/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 192))  # Größe anpassen (Beispiel: 256x256)
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)
    
# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X vorher: {X.shape}')
print(f'Form von Y vorher: {Y.shape}')

# Modell erstellen
model = Sequential([
    Conv2D(64, 3, activation='relu', padding='same', input_shape=(192, 256, 1)),
    Dropout(0.1),  # Dropout-Schicht hinzugefügt
    Conv2D(64, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(128, 3, activation='relu', padding='same'),
    Dropout(0.2),  # Dropout-Schicht hinzugefügt
    Conv2D(128, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(512, 3, activation='relu', padding='same'),
    Dropout(0.3),  # Dropout-Schicht hinzugefügt
    Conv2D(256, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(128, 3, activation='relu', padding='same'),
    Dropout(0.2),  # Dropout-Schicht hinzugefügt
    Conv2D(128, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(64, 3, activation='relu', padding='same'),
    Dropout(0.1),  # Dropout-Schicht hinzugefügt
    Conv2D(64, 3, activation='relu', padding='same'),
    Conv2D(1, (3, 3), activation='sigmoid', padding='same')
])

# Modellzusammenfassung anzeigen
model.summary()

# Adam-Optimizer mit spezifischer Lernrate erstellen
optimizer = Adam(learning_rate=0.0001)

# Modell kompilieren mit dem Adam-Optimizer
model.compile(optimizer=optimizer, loss='binary_crossentropy')

# EarlyStopping-Callback hinzufügen
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Trainieren des Modells
history = model.fit(X, Y, batch_size=8, epochs=500, validation_split=0.01, callbacks=[early_stopping])

# Pfad zum Speichern des Modells im HDF5-Format
model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_200_trainingsbilder_noch_komplexer_early_stop_and_droput_3_4.h5') 

# Überprüfen der Formen (optional)
print(f'Form von X nachher: {X.shape}')
print(f'Form von Y nachher: {Y.shape}')

def plot_training_history(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_training_history(history)
# Out:
# Form von X vorher: (214, 192, 256, 1)
# Form von Y vorher: (214, 192, 256, 1)
# c:\Users\chris\miniconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 192, 256, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 96, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 96, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 48, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 48, 64, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 48, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 48, 64, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 96, 128, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 96, 128, 128)   │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 96, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 96, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 192, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 192, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 192, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 192, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 192, 256, 1)    │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,583,169 (9.85 MB)
#  Trainable params: 2,583,169 (9.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.5959 - val_loss: 0.3998
# Epoch 2/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.3806 - val_loss: 0.3486
# Epoch 3/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.3582 - val_loss: 0.3314
# Epoch 4/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - loss: 0.3609 - val_loss: 0.3845
# Epoch 5/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.3443 - val_loss: 0.3216
# Epoch 6/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.3143 - val_loss: 0.2745
# Epoch 7/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.3144 - val_loss: 0.2848
# Epoch 8/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.2956 - val_loss: 0.2044
# Epoch 9/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.2173 - val_loss: 0.2799
# Epoch 10/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.1941 - val_loss: 0.2030
# Epoch 11/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.1563 - val_loss: 0.1670
# Epoch 12/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.1420 - val_loss: 0.2418
# Epoch 13/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.1734 - val_loss: 0.1743
# Epoch 14/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.1222 - val_loss: 0.2037
# Epoch 15/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.1237 - val_loss: 0.1574
# Epoch 16/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.1094 - val_loss: 0.1123
# Epoch 17/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.1151 - val_loss: 0.1716
# Epoch 18/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.1106 - val_loss: 0.1551
# Epoch 19/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.1002 - val_loss: 0.1107
# Epoch 20/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0971 - val_loss: 0.1450
# Epoch 21/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0901 - val_loss: 0.1093
# Epoch 22/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0902 - val_loss: 0.1025
# Epoch 23/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0872 - val_loss: 0.1151
# Epoch 24/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0951 - val_loss: 0.1108
# Epoch 25/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0756 - val_loss: 0.1470
# Epoch 26/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0763 - val_loss: 0.1203
# Epoch 27/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0768 - val_loss: 0.1245
# Epoch 28/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0659 - val_loss: 0.0459
# Epoch 29/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0844 - val_loss: 0.1175
# Epoch 30/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0758 - val_loss: 0.0979
# Epoch 31/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - loss: 0.0740 - val_loss: 0.0968
# Epoch 32/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 93s 3s/step - loss: 0.0732 - val_loss: 0.1801
# Epoch 33/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0549 - val_loss: 0.1497
# Epoch 34/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0649 - val_loss: 0.0318
# Epoch 35/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0592 - val_loss: 0.0832
# Epoch 36/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0511 - val_loss: 0.1258
# Epoch 37/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0625 - val_loss: 0.0813
# Epoch 38/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0597 - val_loss: 0.1732
# Epoch 39/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0529 - val_loss: 0.0566
# Epoch 40/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0498 - val_loss: 0.0710
# Epoch 41/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0527 - val_loss: 0.0779
# Epoch 42/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0461 - val_loss: 0.0415
# Epoch 43/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0511 - val_loss: 0.0618
# Epoch 44/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0500 - val_loss: 0.0786
# Epoch 45/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0446 - val_loss: 0.0527
# Epoch 46/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0408 - val_loss: 0.0306
# Epoch 47/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0522 - val_loss: 0.1839
# Epoch 48/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0542 - val_loss: 0.1022
# Epoch 49/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0421 - val_loss: 0.0617
# Epoch 50/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0348 - val_loss: 0.0529
# Epoch 51/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0381 - val_loss: 0.0363
# Epoch 52/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0403 - val_loss: 0.1428
# Epoch 53/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0336 - val_loss: 0.0728
# Epoch 54/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0338 - val_loss: 0.0502
# Epoch 55/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0422 - val_loss: 0.0889
# Epoch 56/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0410 - val_loss: 0.0434
# Epoch 57/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0368 - val_loss: 0.0302
# Epoch 58/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0340 - val_loss: 0.0332
# Epoch 59/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0349 - val_loss: 0.0624
# Epoch 60/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0373 - val_loss: 0.0677
# Epoch 61/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0382 - val_loss: 0.0307
# Epoch 62/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0334 - val_loss: 0.1387
# Epoch 63/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0359 - val_loss: 0.0599
# Epoch 64/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0334 - val_loss: 0.0381
# Epoch 65/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0291 - val_loss: 0.0366
# Epoch 66/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0346 - val_loss: 0.0255
# Epoch 67/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0318 - val_loss: 0.0607
# Epoch 68/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0290 - val_loss: 0.0719
# Epoch 69/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0270 - val_loss: 0.0281
# Epoch 70/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0265 - val_loss: 0.0220
# Epoch 71/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0294 - val_loss: 0.0833
# Epoch 72/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0330 - val_loss: 0.0220
# Epoch 73/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0359 - val_loss: 0.0272
# Epoch 74/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0278 - val_loss: 0.0483
# Epoch 75/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0227 - val_loss: 0.0291
# Epoch 76/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0260 - val_loss: 0.0961
# Epoch 77/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0270 - val_loss: 0.0281
# Epoch 78/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0266 - val_loss: 0.0270
# Epoch 79/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0230 - val_loss: 0.0391
# Epoch 80/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0214 - val_loss: 0.0354
# Epoch 81/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0253 - val_loss: 0.0237
# Epoch 82/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0268 - val_loss: 0.0562
# Epoch 83/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0278 - val_loss: 0.0461
# Epoch 84/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0222 - val_loss: 0.0405
# Epoch 85/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0198 - val_loss: 0.0197
# Epoch 86/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0226 - val_loss: 0.0749
# Epoch 87/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0196 - val_loss: 0.0433
# Epoch 88/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0196 - val_loss: 0.0484
# Epoch 89/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0209 - val_loss: 0.0683
# Epoch 90/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0221 - val_loss: 0.0230
# Epoch 91/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0201 - val_loss: 0.0139
# Epoch 92/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0187 - val_loss: 0.0140
# Epoch 93/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0184 - val_loss: 0.0254
# Epoch 94/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0328 - val_loss: 0.0491
# Epoch 95/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0259 - val_loss: 0.0389
# Epoch 96/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0214 - val_loss: 0.0216
# Epoch 97/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0189 - val_loss: 0.0234
# Epoch 98/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0194 - val_loss: 0.0195
# Epoch 99/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0179 - val_loss: 0.0565
# Epoch 100/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0187 - val_loss: 0.0198
# Epoch 101/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0155 - val_loss: 0.0315
# Epoch 102/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0190 - val_loss: 0.0399
# Epoch 103/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0193 - val_loss: 0.0388
# Epoch 104/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0198 - val_loss: 0.0178
# Epoch 105/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0177 - val_loss: 0.0282
# Epoch 106/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0156 - val_loss: 0.0333
# Epoch 107/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0168 - val_loss: 0.0150
# Epoch 108/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0180 - val_loss: 0.0300
# Epoch 109/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0194 - val_loss: 0.0108
# Epoch 110/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0169 - val_loss: 0.0109
# Epoch 111/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0175 - val_loss: 0.0710
# Epoch 112/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0158 - val_loss: 0.0195
# Epoch 113/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0142 - val_loss: 0.0195
# Epoch 114/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0155 - val_loss: 0.0151
# Epoch 115/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0161 - val_loss: 0.0549
# Epoch 116/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 89s 3s/step - loss: 0.0159 - val_loss: 0.0194
# Epoch 117/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - loss: 0.0149 - val_loss: 0.0379
# Epoch 118/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - loss: 0.0136 - val_loss: 0.0324
# Epoch 119/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - loss: 0.0159 - val_loss: 0.0095
# Epoch 120/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - loss: 0.0394 - val_loss: 0.0431
# Epoch 121/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 105s 4s/step - loss: 0.0212 - val_loss: 0.0149
# Epoch 122/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - loss: 0.0225 - val_loss: 0.0216
# Epoch 123/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - loss: 0.0185 - val_loss: 0.0256
# Epoch 124/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 99s 4s/step - loss: 0.0157 - val_loss: 0.0163
# Epoch 125/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - loss: 0.0153 - val_loss: 0.0115
# Epoch 126/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - loss: 0.0135 - val_loss: 0.0143
# Epoch 127/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - loss: 0.0129 - val_loss: 0.0096
# Epoch 128/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - loss: 0.0138 - val_loss: 0.0104
# Epoch 129/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - loss: 0.0127 - val_loss: 0.0091
# Epoch 130/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - loss: 0.0151 - val_loss: 0.0168
# Epoch 131/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 106s 4s/step - loss: 0.0169 - val_loss: 0.0390
# Epoch 132/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - loss: 0.0147 - val_loss: 0.0107
# Epoch 133/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - loss: 0.0140 - val_loss: 0.0101
# Epoch 134/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - loss: 0.0147 - val_loss: 0.0091
# Epoch 135/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - loss: 0.0610 - val_loss: 0.0946
# Epoch 136/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 94s 4s/step - loss: 0.0406 - val_loss: 0.0194
# Epoch 137/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - loss: 0.0276 - val_loss: 0.0187
# Epoch 138/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 101s 4s/step - loss: 0.0217 - val_loss: 0.0145
# Epoch 139/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - loss: 0.0185 - val_loss: 0.0124
# Epoch 140/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - loss: 0.0152 - val_loss: 0.0102
# Epoch 141/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - loss: 0.0134 - val_loss: 0.0106
# Epoch 142/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 98s 4s/step - loss: 0.0149 - val_loss: 0.0106
# Epoch 143/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - loss: 0.0126 - val_loss: 0.0124
# Epoch 144/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 106s 4s/step - loss: 0.0141 - val_loss: 0.0097
# Epoch 145/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - loss: 0.0128 - val_loss: 0.0107
# Epoch 146/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - loss: 0.0130 - val_loss: 0.0123
# Epoch 147/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - loss: 0.0120 - val_loss: 0.0300
# Epoch 148/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 150s 6s/step - loss: 0.0138 - val_loss: 0.0099
# Epoch 149/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 167s 6s/step - loss: 0.0126 - val_loss: 0.0113
# Epoch 150/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 100s 4s/step - loss: 0.0125 - val_loss: 0.0091
# Epoch 151/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 101s 4s/step - loss: 0.0119 - val_loss: 0.0163
# Epoch 152/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 141s 4s/step - loss: 0.0128 - val_loss: 0.0094
# Epoch 153/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 99s 4s/step - loss: 0.0122 - val_loss: 0.0077
# Epoch 154/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 99s 4s/step - loss: 0.0131 - val_loss: 0.0124
# Epoch 155/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - loss: 0.0117 - val_loss: 0.0094
# Epoch 156/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 104s 4s/step - loss: 0.0109 - val_loss: 0.0087
# Epoch 157/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 104s 4s/step - loss: 0.0118 - val_loss: 0.0093
# Epoch 158/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 103s 4s/step - loss: 0.0146 - val_loss: 0.0101
# Epoch 159/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - loss: 0.0111 - val_loss: 0.0158
# Epoch 160/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - loss: 0.0116 - val_loss: 0.0085
# Epoch 161/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 102s 4s/step - loss: 0.0110 - val_loss: 0.0103
# Epoch 162/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 113s 4s/step - loss: 0.0116 - val_loss: 0.0065
# Epoch 163/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 108s 4s/step - loss: 0.0129 - val_loss: 0.0116
# Epoch 164/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 107s 4s/step - loss: 0.0118 - val_loss: 0.0090
# Epoch 165/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 111s 4s/step - loss: 0.0110 - val_loss: 0.0145
# Epoch 166/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 107s 4s/step - loss: 0.0113 - val_loss: 0.0091
# Epoch 167/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 106s 4s/step - loss: 0.0106 - val_loss: 0.0175
# Epoch 168/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 105s 4s/step - loss: 0.0122 - val_loss: 0.0068
# Epoch 169/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 109s 4s/step - loss: 0.0105 - val_loss: 0.0087
# Epoch 170/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 96s 4s/step - loss: 0.0104 - val_loss: 0.0096
# Epoch 171/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 101s 4s/step - loss: 0.0100 - val_loss: 0.0095
# Epoch 172/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 95s 4s/step - loss: 0.0112 - val_loss: 0.0089
# Epoch 173/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - loss: 0.0122 - val_loss: 0.0066
# Epoch 174/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 99s 4s/step - loss: 0.0141 - val_loss: 0.0602
# Epoch 175/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 100s 4s/step - loss: 0.0177 - val_loss: 0.0156
# Epoch 176/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - loss: 0.0140 - val_loss: 0.0136
# Epoch 177/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 114s 4s/step - loss: 0.0151 - val_loss: 0.0102
# Epoch 178/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 119s 4s/step - loss: 0.0119 - val_loss: 0.0076
# Epoch 179/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - loss: 0.0126 - val_loss: 0.0249
# Epoch 180/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - loss: 0.0124 - val_loss: 0.0089
# Epoch 181/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - loss: 0.0105 - val_loss: 0.0082
# Epoch 182/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - loss: 0.0102 - val_loss: 0.0073
# Epoch 183/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - loss: 0.0101 - val_loss: 0.0080
# Epoch 184/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 116s 4s/step - loss: 0.0097 - val_loss: 0.0105
# Epoch 185/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 117s 4s/step - loss: 0.0106 - val_loss: 0.0132
# Epoch 186/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 97s 4s/step - loss: 0.0100 - val_loss: 0.0144
# Epoch 187/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0104 - val_loss: 0.0193
# Epoch 188/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0118 - val_loss: 0.0088
# Epoch 189/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0110 - val_loss: 0.0147
# Epoch 190/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - loss: 0.0098 - val_loss: 0.0071
# Epoch 191/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0094 - val_loss: 0.0091
# Epoch 192/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0101 - val_loss: 0.0076
# Epoch 193/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0093 - val_loss: 0.0075
# Epoch 194/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0091 - val_loss: 0.0108
# Epoch 195/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0098 - val_loss: 0.0076
# Epoch 196/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0136 - val_loss: 0.0133
# Epoch 197/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0114 - val_loss: 0.4818
# Epoch 198/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0504 - val_loss: 0.0155
# Epoch 199/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - loss: 0.0161 - val_loss: 0.0080
# Epoch 200/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0126 - val_loss: 0.0099
# Epoch 201/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0108 - val_loss: 0.0077
# Epoch 202/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0118 - val_loss: 0.0097
# Epoch 203/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - loss: 0.0099 - val_loss: 0.0086
# Epoch 204/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - loss: 0.0097 - val_loss: 0.0069
# Epoch 205/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - loss: 0.0096 - val_loss: 0.0077
# Epoch 206/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - loss: 0.0090 - val_loss: 0.0081
# Epoch 207/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 91s 3s/step - loss: 0.0093 - val_loss: 0.0080
# Epoch 208/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - loss: 0.0087 - val_loss: 0.0099
# Epoch 209/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - loss: 0.0104 - val_loss: 0.0134
# Epoch 210/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 93s 3s/step - loss: 0.0190 - val_loss: 0.0192
# Epoch 211/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - loss: 0.0190 - val_loss: 0.0523
# Epoch 212/500
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - loss: 0.0256 - val_loss: 0.0157
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Form von X nachher: (214, 192, 256, 1)
# Form von Y nachher: (214, 192, 256, 1)

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

def draw_contours_and_centroid(binary_mask, output_path):
    # Finden der Konturen
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Erstellen eines Farbbilds zum Zeichnen
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    
    # Zeichnen der Konturen
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    
    # Berechnung und Zeichnen des Schwerpunkts
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
    
    # Speichern des Bildes mit Konturen und Schwerpunkt
    cv2.imwrite(output_path, color_mask)

# Laden und Vorverarbeiten der Bilder mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')  # Convert to grayscale
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x196)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

# Vorhersage mit dem Modell machen
def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
    predicted_mask = model.predict(image)  # Vorhersage machen
    return np.squeeze(predicted_mask)  # Batch-Dimension entfernen

# Funktion zur Berechnung der mittleren Konturgröße
def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

# Funktion zur Auswahl des besten Schwellenwerts
def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0

    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size  # Anpassen der Bewertungsmetrik nach Bedarf

            if score > best_score:
                best_score = score
                best_threshold = threshold

    return best_threshold

# Funktion zur Berechnung des mittleren Durchmessers
def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)


# Pfade definieren
model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_200_trainingsbilder_noch_komplexer_early_stop_and_droput_3_4.h5'
input_dir = "C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Bilder jessi"
output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher test/'
excel_file_path = 'C:/Users/chris/Documents/Durchmesser Sphaeroide Jessi.xlsx'

# Modell laden
model = tf.keras.models.load_model(model_path)

# Daten aus der Excel-Tabelle laden
predicted_diameters = []
df_manual = pd.read_excel(excel_file_path, header=0)  # Daten ab der zweiten Zeile 
manual_diameters = df_manual.iloc[:, 1].tolist()  # Durchmesser sind in der zweiten Spalte

# Debug-Ausgabe: Anzahl der manuellen Durchmesser
print(f"Anzahl der manuellen Durchmesser: {len(df_manual)}")

# Skalierungsfaktoren berechnen
scale_factor_width = 1296 / 256  # Originalbreite / skalierte Breite
scale_factor_height = 966 / 196  # Originalhöhe / skalierte Höhe

# Listen für die berechneten Durchmesser und die manuell gemessenen Durchmesser
manual_diameters = []

# Iteration über alle TIFF-Dateien im Eingabeordner
tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Debug-Ausgabe: Anzahl der TIFF-Dateien
print(f"Anzahl der TIFF-Dateien: {len(tif_files)}")

# Überprüfen, ob die Anzahl der Dateien mit der Anzahl der manuellen Messungen übereinstimmt
if len(tif_files) != len(df_manual):
    print("Die Anzahl der Bilddateien stimmt nicht mit der Anzahl der manuellen Messungen überein.")
else:
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        
        try:
            # Bild laden und vorverarbeiten
            image = load_and_preprocess_image_pillow(img_path)
            # Vorhersage mit dem Modell machen
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            # Besten Schwellenwert für Konturen finden
            best_threshold = find_best_threshold(predicted_mask)

            # Maske mit dem besten Schwellenwert erstellen
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
            
            # Konturen finden
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            # Filtere Konturen nach Schmalheitsverhältnis
            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:  # Anpassen des Schmalheitsverhältnisses nach Bedarf
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            # Die größte Kontur nach dem Flächeninhalt finden
            largest_contour = max(filtered_contours, key=cv2.contourArea)

            # Berechne den Schwerpunkt der Kontur
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

            # Berechne den mittleren Durchmesser
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.1874 * scale_factor_width) *0.994     #mit faktor für verzerrung

            # Berechnung des Flächeninhalts
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.1874 * scale_factor_width * 0.1874 * scale_factor_height)

            # Ergebnisse hinzufügen
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])  # Manuell gemessener Durchmesser hinzufügen

            # Ausgabepfad für das segmentierte Bild definieren
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            draw_contours_and_centroid(binary_mask, output_path)

            # Maske als TIFF-Datei speichern
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")

            # Ergebnisse ausgeben
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Flächeninhalt: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    # Debug-Ausgabe: Anzahl der erfolgreichen Vorhersagen und manuell gemessenen Durchmesser
    print(f"Anzahl der erfolgreichen Vorhersagen: {len(predicted_diameters)}")
    print(f"Anzahl der zugehörigen manuellen Durchmesser: {len(manual_diameters)}")

    # Ergebnisse in ein DataFrame konvertieren
    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    # Ergebnisse in eine Excel-Datei exportieren
    excel_output_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx'
    df_results.to_excel(excel_output_path, index=False)

    # Berechnung der Metriken zur Bewertung der Modellgenauigkeit
    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)

        print(f"\nMetriken zur Bewertung der Modellgenauigkeit:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")

        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print("Keine ausreichenden Daten zur Berechnung der Metriken vorhanden.")

    # Scatterplot erstellen
    plt.figure(figsize=(10, 6))
    plt.scatter(manual_diameters, predicted_diameters, color='blue', label='Vorhergesagt vs. Manuell')
    plt.plot([min(manual_diameters), max(manual_diameters)], [min(manual_diameters), max(manual_diameters)], color='red', linestyle='--', label='Perfekte Übereinstimmung')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title('Vergleich von manuellen und vorhergesagten Durchmessern')
    plt.legend()
    plt.grid(True)
    plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/scatterplot.png')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Anzahl der manuellen Durchmesser: 115
# Anzahl der TIFF-Dateien: 115
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step
# Segmentiertes Bild für 001_001_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 001_001_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 64.62 µm, Flächeninhalt: 3256.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# Segmentiertes Bild für 002_002_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 002_002_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 65.74 µm, Flächeninhalt: 3365.22 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Segmentiertes Bild für 003_003_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 003_003_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 63.43 µm, Flächeninhalt: 3143.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# Segmentiertes Bild für 004_004_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 004_004_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B4_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 62.35 µm, Flächeninhalt: 3040.13 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# Segmentiertes Bild für 005_005_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 005_005_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 65.75 µm, Flächeninhalt: 3375.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 557ms/step
# Segmentiertes Bild für 006_006_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 006_006_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 64.21 µm, Flächeninhalt: 3210.12 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# Segmentiertes Bild für 007_007_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 007_007_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 63.45 µm, Flächeninhalt: 3139.58 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Segmentiertes Bild für 008_008_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 008_008_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B5_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 64.65 µm, Flächeninhalt: 3261.82 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Segmentiertes Bild für 009_009_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 009_009_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 66.85 µm, Flächeninhalt: 3477.81 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# Segmentiertes Bild für 010_010_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 010_010_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 67.18 µm, Flächeninhalt: 3515.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Segmentiertes Bild für 011_011_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 011_011_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 65.68 µm, Flächeninhalt: 3370.04 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# Segmentiertes Bild für 012_012_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 012_012_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B6_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 64.34 µm, Flächeninhalt: 3227.21 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# Segmentiertes Bild für 013_013_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 013_013_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 72.87 µm, Flächeninhalt: 4222.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# Segmentiertes Bild für 014_014_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 014_014_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 67.14 µm, Flächeninhalt: 3511.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# Segmentiertes Bild für 015_015_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 015_015_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 65.58 µm, Flächeninhalt: 3362.15 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# Segmentiertes Bild für 016_016_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 016_016_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B7_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 65.38 µm, Flächeninhalt: 3345.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step
# Segmentiertes Bild für 017_017_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 017_017_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 65.12 µm, Flächeninhalt: 3313.52 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# Segmentiertes Bild für 018_018_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 018_018_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 66.93 µm, Flächeninhalt: 3489.21 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Segmentiertes Bild für 019_019_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 019_019_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 64.49 µm, Flächeninhalt: 3243.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Segmentiertes Bild für 020_020_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 020_020_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B8_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 68.55 µm, Flächeninhalt: 3660.51 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Segmentiertes Bild für 021_021_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 021_021_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 63.46 µm, Flächeninhalt: 3135.20 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# Segmentiertes Bild für 022_022_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 022_022_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 65.74 µm, Flächeninhalt: 3371.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step
# Segmentiertes Bild für 023_023_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 023_023_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 70.03 µm, Flächeninhalt: 3873.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# Segmentiertes Bild für 024_024_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 024_024_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_B9_1000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 65.55 µm, Flächeninhalt: 3498.41 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step
# Segmentiertes Bild für 025_025_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 025_025_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 84.70 µm, Flächeninhalt: 5586.50 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# Segmentiertes Bild für 026_026_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 026_026_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 86.72 µm, Flächeninhalt: 5847.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# Segmentiertes Bild für 027_027_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 027_027_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 92.65 µm, Flächeninhalt: 6676.11 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# Segmentiertes Bild für 028_028_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 028_028_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C4_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 94.03 µm, Flächeninhalt: 6879.39 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# Segmentiertes Bild für 029_029_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 029_029_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 83.10 µm, Flächeninhalt: 5370.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# Segmentiertes Bild für 030_030_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 030_030_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 90.02 µm, Flächeninhalt: 6296.25 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# Segmentiertes Bild für 031_031_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240704_ch00.tif wurde gespeichert.
# Bild: 031_031_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240704_ch00.tif, Durchmesser: 97.15 µm, Flächeninhalt: 7336.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step
# Segmentiertes Bild für 032_032_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240705_ch00.tif wurde gespeichert.
# Bild: 032_032_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C5_2000 Zellem_ Sphäroid_20x_240705_ch00.tif, Durchmesser: 101.88 µm, Flächeninhalt: 8066.27 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# Segmentiertes Bild für 033_033_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240702_ch00.tif wurde gespeichert.
# Bild: 033_033_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240702_ch00.tif, Durchmesser: 87.21 µm, Flächeninhalt: 5923.41 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step
# Segmentiertes Bild für 034_034_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240703_ch00.tif wurde gespeichert.
# Bild: 034_034_JES_Späroide_WTCII_Methocell_1000-5000 Zellen_C6_2000 Zellem_ Sphäroid_20x_240703_ch00.tif, Durchmesser: 91.88 µm, Flächeninhalt: 6574.46 µm²
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 133
#     131 image = load_and_preprocess_image_pillow(img_path)
#     132 # Vorhersage mit dem Modell machen
# --> 133 predicted_mask = predict_with_model(model, image)
#     134 if predicted_mask is None:
#     135     print(f"Fehler bei der Vorhersage für {filename}.")
#
# Cell In[7], line 43, in predict_with_model(model, image)
#      41 def predict_with_model(model, image):
#      42     image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
# ---> 43     predicted_mask = model.predict(image)  # Vorhersage machen
#      44     return np.squeeze(predicted_mask)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:504, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     502 callbacks.on_predict_batch_begin(step)
#     503 data = get_data(iterator)
# --> 504 batch_outputs = self.predict_function(data)
#     505 outputs = append_to_outputs(batch_outputs, outputs)
#     506 callbacks.on_predict_batch_end(step, {"outputs": batch_outputs})
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Funktion zum Zeichnen von Konturen und Schwerpunkt
def draw_contours_and_centroid(binary_mask, output_path):
    # Finden der Konturen
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Erstellen eines Farbbilds zum Zeichnen
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    
    # Zeichnen der Konturen
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    
    # Berechnung und Zeichnen des Schwerpunkts
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
    
    # Speichern des Bildes mit Konturen und Schwerpunkt
    cv2.imwrite(output_path, color_mask)

# Laden und Vorverarbeiten der Bilder mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')  # Convert to grayscale
    img = img.resize((256, 196))  # Größe anpassen (Beispiel: 256x196)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

# Vorhersage mit dem Modell machen
def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
    predicted_mask = model.predict(image)  # Vorhersage machen
    return np.squeeze(predicted_mask)  # Batch-Dimension entfernen

# Funktion zur Berechnung der mittleren Konturgröße
def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

# Funktion zur Auswahl des besten Schwellenwerts
def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0

    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size  # Anpassen der Bewertungsmetrik nach Bedarf

            if score > best_score:
                best_score = score
                best_threshold = threshold

    return best_threshold

# Funktion zur Berechnung des mittleren Durchmessers
def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)

# Pfade definieren
model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_200_trainingsbilder_noch_komplexer_early_stop_and_droput_3.h5'
input_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Sphäroide BA/Alle BA Sphäaeroidbilder sortiert/'
output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher test/'
excel_file_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Sphäroide BA/gemessene Durchmesser neu2.xlsx'

# Modell laden
model = tf.keras.models.load_model(model_path)

# Daten aus der Excel-Tabelle laden
predicted_diameters = []
df_manual = pd.read_excel(excel_file_path, header=0)  # Daten ab der zweiten Zeile 
manual_diameters = df_manual.iloc[:, 1].tolist()  # Durchmesser sind in der zweiten Spalte

# Debug-Ausgabe: Anzahl der manuellen Durchmesser
print(f"Anzahl der manuellen Durchmesser: {len(df_manual)}")

# Skalierungsfaktoren berechnen
scale_factor_width = 1296 / 256  # Originalbreite / skalierte Breite
scale_factor_height = 966 / 196  # Originalhöhe / skalierte Höhe

# Listen für die berechneten Durchmesser und die manuell gemessenen Durchmesser
manual_diameters = []

# Iteration über alle TIFF-Dateien im Eingabeordner
tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Debug-Ausgabe: Anzahl der TIFF-Dateien
print(f"Anzahl der TIFF-Dateien: {len(tif_files)}")

# Überprüfen, ob die Anzahl der Dateien mit der Anzahl der manuellen Messungen übereinstimmt
if len(tif_files) != len(df_manual):
    print("Die Anzahl der Bilddateien stimmt nicht mit der Anzahl der manuellen Messungen überein.")
else:
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        
        try:
            # Bild laden und vorverarbeiten
            image = load_and_preprocess_image_pillow(img_path)
            # Vorhersage mit dem Modell machen
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            # Besten Schwellenwert für Konturen finden
            best_threshold = find_best_threshold(predicted_mask)

            # Maske mit dem besten Schwellenwert erstellen
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
            
            # Konturen finden
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            # Filtere Konturen nach Schmalheitsverhältnis
            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:  # Anpassen des Schmalheitsverhältnisses nach Bedarf
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            # Die größte Kontur nach dem Flächeninhalt finden
            largest_contour = max(filtered_contours, key=cv2.contourArea)

            # Berechne den Schwerpunkt der Kontur
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

            # Berechne den mittleren Durchmesser
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width)

            # Berechnung des Flächeninhalts
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.3745 * scale_factor_width * 0.3745 * scale_factor_height)

            # Ergebnisse hinzufügen
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])  # Manuell gemessener Durchmesser hinzufügen

            # Ausgabepfad für das segmentierte Bild definieren
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            
            # Maske als TIFF-Datei speichern und Konturen und Schwerpunkt einzeichnen
            draw_contours_and_centroid(binary_mask, output_path)
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")

            # Ergebnisse ausgeben
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Flächeninhalt: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    # Debug-Ausgabe: Anzahl der erfolgreichen Vorhersagen und manuell gemessenen Durchmesser
    print(f"Anzahl der erfolgreichen Vorhersagen: {len(predicted_diameters)}")
    print(f"Anzahl der zugehörigen manuellen Durchmesser: {len(manual_diameters)}")

    # Ergebnisse in ein DataFrame konvertieren
    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    # Ergebnisse in eine Excel-Datei exportieren
    excel_output_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx'
    df_results.to_excel(excel_output_path, index=False)

    # Berechnung der Metriken zur Bewertung der Modellgenauigkeit
    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)

        print(f"\nMetriken zur Bewertung der Modellgenauigkeit:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")

        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print("Keine ausreichenden Daten zur Berechnung der Metriken vorhanden.")

    # Scatterplot erstellen
    plt.figure(figsize=(10, 6))
    plt.scatter(manual_diameters, predicted_diameters, color='blue', label='Vorhergesagt vs. Manuell')
    plt.plot([min(manual_diameters), max(manual_diameters)], [min(manual_diameters), max(manual_diameters)], color='red', linestyle='--', label='Perfekte Übereinstimmung')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title('Vergleich von manuellen und vorhergesagten Durchmessern')
    plt.legend()
    plt.grid(True)
    plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/scatterplot.png')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Anzahl der manuellen Durchmesser: 357
# Anzahl der TIFF-Dateien: 357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 C6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 C6_ch00.tif, Durchmesser: 159.46 µm, Flächeninhalt: 19580.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 D6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 D6_ch00.tif, Durchmesser: 161.25 µm, Flächeninhalt: 20018.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS +P1 E6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS +P1 E6_ch00.tif, Durchmesser: 151.44 µm, Flächeninhalt: 17661.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS B4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS B4_ch00.tif, Durchmesser: 164.50 µm, Flächeninhalt: 20809.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS C4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS C4_ch00.tif, Durchmesser: 163.39 µm, Flächeninhalt: 20529.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS D4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS D4_ch00.tif, Durchmesser: 154.93 µm, Flächeninhalt: 18494.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 B5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 B5_ch00.tif, Durchmesser: 133.93 µm, Flächeninhalt: 13817.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 C5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 C5_ch00.tif, Durchmesser: 170.45 µm, Flächeninhalt: 22301.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 E5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 E5_ch00.tif, Durchmesser: 154.60 µm, Flächeninhalt: 18396.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer C3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer C3_ch00.tif, Durchmesser: 160.79 µm, Flächeninhalt: 19902.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer D3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer D3_ch00.tif, Durchmesser: 157.40 µm, Flächeninhalt: 19055.81 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer F3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer F3_ch00.tif, Durchmesser: 157.58 µm, Flächeninhalt: 19118.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 D10_ch00.tif, Durchmesser: 140.54 µm, Flächeninhalt: 15152.27 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 E10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 E10_ch00.tif, Durchmesser: 134.56 µm, Flächeninhalt: 13902.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 G10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 G10_ch00.tif, Durchmesser: 127.09 µm, Flächeninhalt: 12433.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS C8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS C8_ch00.tif, Durchmesser: 148.91 µm, Flächeninhalt: 17033.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS E8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS E8_ch00.tif, Durchmesser: 141.07 µm, Flächeninhalt: 15290.49 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS F8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS F8_ch00.tif, Durchmesser: 152.83 µm, Flächeninhalt: 17978.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 c9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 c9_ch00.tif, Durchmesser: 151.28 µm, Flächeninhalt: 17615.82 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 D9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 D9_ch00.tif, Durchmesser: 155.42 µm, Flächeninhalt: 18578.15 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 E9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 E9_ch00.tif, Durchmesser: 145.48 µm, Flächeninhalt: 16291.31 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer B7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer B7_ch00.tif, Durchmesser: 135.66 µm, Flächeninhalt: 14172.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer D7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer D7_ch00.tif, Durchmesser: 156.28 µm, Flächeninhalt: 18840.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer F7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer F7_ch00.tif, Durchmesser: 163.40 µm, Flächeninhalt: 20537.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS D11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS D11_ch00.tif, Durchmesser: 127.70 µm, Flächeninhalt: 12538.24 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS E11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS E11_ch00.tif, Durchmesser: 154.80 µm, Flächeninhalt: 18445.17 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS F11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS F11_ch00.tif, Durchmesser: 156.08 µm, Flächeninhalt: 18719.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle C2_ch00.tif, Durchmesser: 165.35 µm, Flächeninhalt: 21017.21 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle D2_ch00.tif, Durchmesser: 155.09 µm, Flächeninhalt: 18543.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle F2_ch00.tif, Durchmesser: 160.16 µm, Flächeninhalt: 19745.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_P1 B11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_P1 B11_ch00.tif, Durchmesser: 174.79 µm, Flächeninhalt: 23479.02 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_P1 C11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_P1 C11_ch00.tif, Durchmesser: 141.56 µm, Flächeninhalt: 15437.47 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_P1 D11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_P1 D11_ch00.tif, Durchmesser: 152.33 µm, Flächeninhalt: 17845.03 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 C6_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 C6_ch00.tif, Durchmesser: 166.20 µm, Flächeninhalt: 21206.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 D6_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 D6_ch00.tif, Durchmesser: 172.28 µm, Flächeninhalt: 22800.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 E6_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 E6_ch00.tif, Durchmesser: 161.60 µm, Flächeninhalt: 20046.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS B4_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS B4_ch00.tif, Durchmesser: 170.01 µm, Flächeninhalt: 22177.25 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS C4_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS C4_ch00.tif, Durchmesser: 170.82 µm, Flächeninhalt: 22427.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS d4_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS d4_ch00.tif, Durchmesser: 164.19 µm, Flächeninhalt: 20691.77 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 leer C3_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 leer C3_ch00.tif, Durchmesser: 168.62 µm, Flächeninhalt: 21853.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 lerer D3_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 lerer D3_ch00.tif, Durchmesser: 167.89 µm, Flächeninhalt: 21652.35 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 öeer F3_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 öeer F3_ch00.tif, Durchmesser: 161.11 µm, Flächeninhalt: 19956.90 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 D10_ch00.tif, Durchmesser: 147.29 µm, Flächeninhalt: 16698.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 E10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 E10_ch00.tif, Durchmesser: 141.64 µm, Flächeninhalt: 15447.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 F10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 F10_ch00.tif, Durchmesser: 152.85 µm, Flächeninhalt: 17971.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPCS C8_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPCS C8_ch00.tif, Durchmesser: 156.47 µm, Flächeninhalt: 18812.61 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS E8_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS E8_ch00.tif, Durchmesser: 146.15 µm, Flächeninhalt: 16420.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPCS F8_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPCS F8_ch00.tif, Durchmesser: 160.19 µm, Flächeninhalt: 19729.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_AlPcS D11_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_AlPcS D11_ch00.tif, Durchmesser: 133.13 µm, Flächeninhalt: 13598.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_AlPcS E11_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_AlPcS E11_ch00.tif, Durchmesser: 158.57 µm, Flächeninhalt: 19339.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_AlPcS F11_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_AlPcS F11_ch00.tif, Durchmesser: 159.29 µm, Flächeninhalt: 19570.22 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle C2_ch00.tif, Durchmesser: 173.86 µm, Flächeninhalt: 23262.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle D2_ch00.tif, Durchmesser: 159.14 µm, Flächeninhalt: 19510.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle F2_ch00.tif, Durchmesser: 167.63 µm, Flächeninhalt: 21596.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_P1 B10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_P1 B10_ch00.tif, Durchmesser: 177.16 µm, Flächeninhalt: 24098.40 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_P1 C10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_P1 C10_ch00.tif, Durchmesser: 145.58 µm, Flächeninhalt: 16289.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_P1 D10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_P1 D10_ch00.tif, Durchmesser: 153.86 µm, Flächeninhalt: 18196.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 C6_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 C6_ch00.tif, Durchmesser: 187.72 µm, Flächeninhalt: 27095.61 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 D6_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 D6_ch00.tif, Durchmesser: 194.17 µm, Flächeninhalt: 28969.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 E6_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 E6_ch00.tif, Durchmesser: 182.35 µm, Flächeninhalt: 25533.15 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS B4_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS B4_ch00.tif, Durchmesser: 191.34 µm, Flächeninhalt: 28127.93 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPCs C4_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPCs C4_ch00.tif, Durchmesser: 192.54 µm, Flächeninhalt: 28444.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS E4_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS E4_ch00.tif, Durchmesser: 185.69 µm, Flächeninhalt: 26498.97 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 leer C3_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 leer C3_ch00.tif, Durchmesser: 188.06 µm, Flächeninhalt: 27181.35 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 leer D3_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 leer D3_ch00.tif, Durchmesser: 188.20 µm, Flächeninhalt: 27225.09 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 leer F3_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 leer F3_ch00.tif, Durchmesser: 186.54 µm, Flächeninhalt: 26745.68 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 D10_ch00.tif, Durchmesser: 168.07 µm, Flächeninhalt: 21687.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 E10_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 E10_ch00.tif, Durchmesser: 160.72 µm, Flächeninhalt: 19853.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 F10_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 F10_ch00.tif, Durchmesser: 170.81 µm, Flächeninhalt: 22474.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS C8_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS C8_ch00.tif, Durchmesser: 172.46 µm, Flächeninhalt: 22873.63 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS e8_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS e8_ch00.tif, Durchmesser: 166.90 µm, Flächeninhalt: 21386.39 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS F8_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS F8_ch00.tif, Durchmesser: 181.05 µm, Flächeninhalt: 25211.20 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_AlPcS D11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_AlPcS D11_ch00.tif, Durchmesser: 155.95 µm, Flächeninhalt: 18714.63 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_AlPcS E11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_AlPcS E11_ch00.tif, Durchmesser: 182.22 µm, Flächeninhalt: 25515.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_AlPcS F11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_AlPcS F11_ch00.tif, Durchmesser: 180.81 µm, Flächeninhalt: 25093.97 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_Kontrolle C2_ch00.tif, Durchmesser: 198.11 µm, Flächeninhalt: 30136.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_Kontrolle D2_ch00.tif, Durchmesser: 185.18 µm, Flächeninhalt: 26324.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_Kontrolle F2_ch00.tif, Durchmesser: 190.88 µm, Flächeninhalt: 28010.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_P1 B11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_P1 B11_ch00.tif, Durchmesser: 199.68 µm, Flächeninhalt: 30647.47 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_P1 C11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_P1 C11_ch00.tif, Durchmesser: 163.18 µm, Flächeninhalt: 20483.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_P1 D11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_P1 D11_ch00.tif, Durchmesser: 176.13 µm, Flächeninhalt: 23825.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + alpcs + p1 C6_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + alpcs + p1 C6_ch00.tif, Durchmesser: 232.00 µm, Flächeninhalt: 41224.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + alpcs + p1 D6_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + alpcs + p1 D6_ch00.tif, Durchmesser: 244.45 µm, Flächeninhalt: 45859.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + alpcs +p1 E6_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + alpcs +p1 E6_ch00.tif, Durchmesser: 229.54 µm, Flächeninhalt: 40447.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs B4_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs B4_ch00.tif, Durchmesser: 234.32 µm, Flächeninhalt: 42218.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs C4_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs C4_ch00.tif, Durchmesser: 237.81 µm, Flächeninhalt: 43402.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs D4_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs D4_ch00.tif, Durchmesser: 228.67 µm, Flächeninhalt: 40102.77 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 leer C3_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 leer C3_ch00.tif, Durchmesser: 227.93 µm, Flächeninhalt: 39891.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 leer D3_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 leer D3_ch00.tif, Durchmesser: 229.97 µm, Flächeninhalt: 40562.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 leer F3_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 leer F3_ch00.tif, Durchmesser: 227.50 µm, Flächeninhalt: 39728.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 D10_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 D10_ch00.tif, Durchmesser: 214.08 µm, Flächeninhalt: 35224.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 E10_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 E10_ch00.tif, Durchmesser: 203.28 µm, Flächeninhalt: 31660.54 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 F10_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 F10_ch00.tif, Durchmesser: 214.01 µm, Flächeninhalt: 35170.41 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5 + alpcs C8_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5 + alpcs C8_ch00.tif, Durchmesser: 206.60 µm, Flächeninhalt: 32768.09 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5+ alpcs E8_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5+ alpcs E8_ch00.tif, Durchmesser: 205.59 µm, Flächeninhalt: 32484.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5+ alpcs F8_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5+ alpcs F8_ch00.tif, Durchmesser: 223.49 µm, Flächeninhalt: 38360.08 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_alpcs + D11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_alpcs + D11_ch00.tif, Durchmesser: 205.94 µm, Flächeninhalt: 32589.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_alpcs + E11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_alpcs + E11_ch00.tif, Durchmesser: 238.40 µm, Flächeninhalt: 43631.88 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_alpcs + F11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_alpcs + F11_ch00.tif, Durchmesser: 232.02 µm, Flächeninhalt: 41346.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_Kontrolle C2_ch00.tif, Durchmesser: 253.05 µm, Flächeninhalt: 49138.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_Kontrolle D2_ch00.tif, Durchmesser: 239.72 µm, Flächeninhalt: 44106.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_Kontrolle F2_ch00.tif, Durchmesser: 245.52 µm, Flächeninhalt: 46237.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_P1 B11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_P1 B11_ch00.tif, Durchmesser: 246.38 µm, Flächeninhalt: 46555.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_P1 C11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_P1 C11_ch00.tif, Durchmesser: 210.92 µm, Flächeninhalt: 34146.84 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_P1 D11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_P1 D11_ch00.tif, Durchmesser: 221.90 µm, Flächeninhalt: 37772.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 C6_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 C6_ch00.tif, Durchmesser: 246.41 µm, Flächeninhalt: 46604.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 D6_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 D6_ch00.tif, Durchmesser: 258.43 µm, Flächeninhalt: 51274.50 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 E6_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 E6_ch00.tif, Durchmesser: 245.15 µm, Flächeninhalt: 46079.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs B4_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs B4_ch00.tif, Durchmesser: 246.67 µm, Flächeninhalt: 46706.08 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs C4_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs C4_ch00.tif, Durchmesser: 251.81 µm, Flächeninhalt: 48611.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs D4_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs D4_ch00.tif, Durchmesser: 242.18 µm, Flächeninhalt: 45022.88 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer C3_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer C3_ch00.tif, Durchmesser: 239.83 µm, Flächeninhalt: 44156.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer D3_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer D3_ch00.tif, Durchmesser: 242.24 µm, Flächeninhalt: 45014.13 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer F3_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer F3_ch00.tif, Durchmesser: 241.08 µm, Flächeninhalt: 44569.71 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 D10_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 D10_ch00.tif, Durchmesser: 229.44 µm, Flächeninhalt: 40412.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 E10_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 E10_ch00.tif, Durchmesser: 217.78 µm, Flächeninhalt: 36421.43 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 F10_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 F10_ch00.tif, Durchmesser: 229.49 µm, Flächeninhalt: 40394.97 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs C8_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs C8_ch00.tif, Durchmesser: 224.55 µm, Flächeninhalt: 37943.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs E8_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs E8_ch00.tif, Durchmesser: 219.94 µm, Flächeninhalt: 37154.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5+ alpcs F8_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5+ alpcs F8_ch00.tif, Durchmesser: 237.47 µm, Flächeninhalt: 43285.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs d11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs d11_ch00.tif, Durchmesser: 222.29 µm, Flächeninhalt: 37978.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs e11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs e11_ch00.tif, Durchmesser: 255.01 µm, Flächeninhalt: 50021.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs f11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs f11_ch00.tif, Durchmesser: 248.21 µm, Flächeninhalt: 47232.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle C2_ch00.tif, Durchmesser: 269.55 µm, Flächeninhalt: 55778.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle D2_ch00.tif, Durchmesser: 257.00 µm, Flächeninhalt: 50674.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle F2_ch00.tif, Durchmesser: 261.84 µm, Flächeninhalt: 52655.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 b11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 b11_ch00.tif, Durchmesser: 259.75 µm, Flächeninhalt: 51816.91 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 c11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 c11_ch00.tif, Durchmesser: 225.77 µm, Flächeninhalt: 39119.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 d11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 d11_ch00.tif, Durchmesser: 236.89 µm, Flächeninhalt: 43092.98 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 1_ch00.tif, Durchmesser: 256.35 µm, Flächeninhalt: 50411.91 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 2_ch00.tif, Durchmesser: 268.36 µm, Flächeninhalt: 55312.78 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 3_ch00.tif, Durchmesser: 256.31 µm, Flächeninhalt: 50406.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs 1_ch00.tif, Durchmesser: 255.00 µm, Flächeninhalt: 49918.50 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs 2_ch00.tif, Durchmesser: 262.51 µm, Flächeninhalt: 52861.47 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs 3_ch00.tif, Durchmesser: 253.62 µm, Flächeninhalt: 49409.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 leer 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 leer 1_ch00.tif, Durchmesser: 248.32 µm, Flächeninhalt: 47365.71 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 leer 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 leer 2_ch00.tif, Durchmesser: 251.95 µm, Flächeninhalt: 48740.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 leer 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 leer 3_ch00.tif, Durchmesser: 248.75 µm, Flächeninhalt: 47507.43 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs +  1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs +  1_ch00.tif, Durchmesser: 225.47 µm, Flächeninhalt: 39084.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs +  2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs +  2_ch00.tif, Durchmesser: 232.01 µm, Flächeninhalt: 41392.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs + 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs + 3_ch00.tif, Durchmesser: 249.09 µm, Flächeninhalt: 47601.92 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 1_ch00.tif, Durchmesser: 241.98 µm, Flächeninhalt: 44947.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 2_ch00.tif, Durchmesser: 231.45 µm, Flächeninhalt: 41103.59 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 3_ch00.tif, Durchmesser: 242.61 µm, Flächeninhalt: 45178.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_alpcs D11_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_alpcs D11_ch00.tif, Durchmesser: 239.97 µm, Flächeninhalt: 44214.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_alpcs E11_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_alpcs E11_ch00.tif, Durchmesser: 265.74 µm, Flächeninhalt: 54203.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_alpcs F11_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_alpcs F11_ch00.tif, Durchmesser: 261.23 µm, Flächeninhalt: 52298.07 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_kontrolle 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_kontrolle 1_ch00.tif, Durchmesser: 279.38 µm, Flächeninhalt: 59903.95 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_kontrolle 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_kontrolle 2_ch00.tif, Durchmesser: 268.68 µm, Flächeninhalt: 55326.77 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_kontrollle 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_kontrollle 3_ch00.tif, Durchmesser: 275.10 µm, Flächeninhalt: 58049.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_p1 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_p1 1_ch00.tif, Durchmesser: 267.18 µm, Flächeninhalt: 54744.13 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_p1 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_p1 2_ch00.tif, Durchmesser: 236.10 µm, Flächeninhalt: 42734.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_p1 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_p1 3_ch00.tif, Durchmesser: 248.80 µm, Flächeninhalt: 47498.68 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 1_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 1_ch00.tif, Durchmesser: 269.55 µm, Flächeninhalt: 55688.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 2_ch00.tif, Durchmesser: 280.46 µm, Flächeninhalt: 60341.37 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 3_ch00.tif, Durchmesser: 267.43 µm, Flächeninhalt: 54810.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 1_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 1_ch00.tif, Durchmesser: 264.14 µm, Flächeninhalt: 53561.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 2_ch00.tif, Durchmesser: 272.84 µm, Flächeninhalt: 57176.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 3_ch00.tif, Durchmesser: 265.23 µm, Flächeninhalt: 53995.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer 2_ch00.tif, Durchmesser: 263.10 µm, Flächeninhalt: 53116.92 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer 3_ch00.tif, Durchmesser: 261.93 µm, Flächeninhalt: 52606.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer _ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer _ch00.tif, Durchmesser: 258.65 µm, Flächeninhalt: 51391.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 2_ch00.tif, Durchmesser: 248.29 µm, Flächeninhalt: 47316.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 3_ch00.tif, Durchmesser: 256.32 µm, Flächeninhalt: 50350.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 _ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 _ch00.tif, Durchmesser: 258.11 µm, Flächeninhalt: 51106.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 1_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 1_ch00.tif, Durchmesser: 230.23 µm, Flächeninhalt: 40694.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 2_ch00.tif, Durchmesser: 246.89 µm, Flächeninhalt: 46896.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 3_ch00.tif, Durchmesser: 262.29 µm, Flächeninhalt: 52766.98 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_alpcs d11_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_alpcs d11_ch00.tif, Durchmesser: 257.07 µm, Flächeninhalt: 50761.85 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_alpcs e11_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_alpcs e11_ch00.tif, Durchmesser: 276.46 µm, Flächeninhalt: 58673.92 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_alpcs f11_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_alpcs f11_ch00.tif, Durchmesser: 273.85 µm, Flächeninhalt: 57561.12 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_K1_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_K1_ch00.tif, Durchmesser: 291.69 µm, Flächeninhalt: 65261.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_k2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_k2_ch00.tif, Durchmesser: 280.55 µm, Flächeninhalt: 60344.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_K3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_K3_ch00.tif, Durchmesser: 289.82 µm, Flächeninhalt: 64482.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_p1 1_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_p1 1_ch00.tif, Durchmesser: 267.22 µm, Flächeninhalt: 54843.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_p1 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_p1 2_ch00.tif, Durchmesser: 249.94 µm, Flächeninhalt: 47943.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_p1 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_p1 3_ch00.tif, Durchmesser: 260.13 µm, Flächeninhalt: 51909.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 + P1 E5_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 + P1 E5_ch00.tif, Durchmesser: 197.09 µm, Flächeninhalt: 29847.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 +P1 F5_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 +P1 F5_ch00.tif, Durchmesser: 201.45 µm, Flächeninhalt: 31196.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 +P1 G5_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 +P1 G5_ch00.tif, Durchmesser: 182.34 µm, Flächeninhalt: 25573.39 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu E7_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu E7_ch00.tif, Durchmesser: 191.29 µm, Flächeninhalt: 28150.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu F7_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu F7_ch00.tif, Durchmesser: 205.99 µm, Flächeninhalt: 32442.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu G7_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu G7_ch00.tif, Durchmesser: 197.72 µm, Flächeninhalt: 30012.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu E10_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu E10_ch00.tif, Durchmesser: 187.43 µm, Flächeninhalt: 27001.13 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu F10_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu F10_ch00.tif, Durchmesser: 200.64 µm, Flächeninhalt: 30923.92 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu G10_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu G10_ch00.tif, Durchmesser: 177.46 µm, Flächeninhalt: 24182.39 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_5 + AlPcS E8_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_5 + AlPcS E8_ch00.tif, Durchmesser: 184.34 µm, Flächeninhalt: 26094.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcs + P1 B10_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcs + P1 B10_ch00.tif, Durchmesser: 193.11 µm, Flächeninhalt: 28631.84 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcs + P1 C10_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcs + P1 C10_ch00.tif, Durchmesser: 177.94 µm, Flächeninhalt: 24350.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcS + P1 D10_ch00.tif, Durchmesser: 185.67 µm, Flächeninhalt: 26455.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS E11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS E11_ch00.tif, Durchmesser: 197.93 µm, Flächeninhalt: 30101.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS F11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS F11_ch00.tif, Durchmesser: 193.19 µm, Flächeninhalt: 28670.33 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS G11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS G11_ch00.tif, Durchmesser: 191.04 µm, Flächeninhalt: 28031.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle C2_ch00.tif, Durchmesser: 198.67 µm, Flächeninhalt: 30308.03 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle D2_ch00.tif, Durchmesser: 190.92 µm, Flächeninhalt: 27963.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle E2_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle E2_ch00.tif, Durchmesser: 191.13 µm, Flächeninhalt: 28066.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_P1 B11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_P1 B11_ch00.tif, Durchmesser: 180.27 µm, Flächeninhalt: 24976.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_P1 C11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_P1 C11_ch00.tif, Durchmesser: 184.45 µm, Flächeninhalt: 26161.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_P1 D11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_P1 D11_ch00.tif, Durchmesser: 183.91 µm, Flächeninhalt: 25944.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 B6_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 B6_ch00.tif, Durchmesser: 251.59 µm, Flächeninhalt: 48621.98 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 C6_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 C6_ch00.tif, Durchmesser: 244.40 µm, Flächeninhalt: 45827.74 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 D6_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 D6_ch00.tif, Durchmesser: 236.85 µm, Flächeninhalt: 43073.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 B5_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 B5_ch00.tif, Durchmesser: 237.36 µm, Flächeninhalt: 43274.95 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 C5_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 C5_ch00.tif, Durchmesser: 238.76 µm, Flächeninhalt: 43791.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 D5_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 D5_ch00.tif, Durchmesser: 250.32 µm, Flächeninhalt: 48214.31 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs B4_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs B4_ch00.tif, Durchmesser: 237.50 µm, Flächeninhalt: 43350.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs C4_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs C4_ch00.tif, Durchmesser: 228.07 µm, Flächeninhalt: 39980.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs D4_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs D4_ch00.tif, Durchmesser: 243.49 µm, Flächeninhalt: 45470.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 leer C3_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 leer C3_ch00.tif, Durchmesser: 229.99 µm, Flächeninhalt: 40548.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 leer D3_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 leer D3_ch00.tif, Durchmesser: 243.95 µm, Flächeninhalt: 45927.47 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 leer E3_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 leer E3_ch00.tif, Durchmesser: 247.31 µm, Flächeninhalt: 47685.90 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 B10_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 B10_ch00.tif, Durchmesser: 241.09 µm, Flächeninhalt: 44620.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 C10_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 C10_ch00.tif, Durchmesser: 225.53 µm, Flächeninhalt: 39070.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 D10_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 D10_ch00.tif, Durchmesser: 234.19 µm, Flächeninhalt: 42053.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs B8_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs B8_ch00.tif, Durchmesser: 243.89 µm, Flächeninhalt: 45593.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs D8_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs D8_ch00.tif, Durchmesser: 227.30 µm, Flächeninhalt: 39612.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs E8_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs E8_ch00.tif, Durchmesser: 228.12 µm, Flächeninhalt: 39889.31 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_alpcs E11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_alpcs E11_ch00.tif, Durchmesser: 261.78 µm, Flächeninhalt: 52630.51 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_alpcs F11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_alpcs F11_ch00.tif, Durchmesser: 253.22 µm, Flächeninhalt: 49206.38 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_alpcs G11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_alpcs G11_ch00.tif, Durchmesser: 251.20 µm, Flächeninhalt: 48431.27 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_Kontrolle C2_ch00.tif, Durchmesser: 258.19 µm, Flächeninhalt: 51120.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_Kontrolle D2_ch00.tif, Durchmesser: 248.02 µm, Flächeninhalt: 47237.98 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_Kontrolle E2_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_Kontrolle E2_ch00.tif, Durchmesser: 248.63 µm, Flächeninhalt: 47442.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_P1 B11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_P1 B11_ch00.tif, Durchmesser: 228.65 µm, Flächeninhalt: 40157.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_P1 C11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_P1 C11_ch00.tif, Durchmesser: 234.30 µm, Flächeninhalt: 42149.90 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_P1 D11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_P1 D11_ch00.tif, Durchmesser: 233.06 µm, Flächeninhalt: 41693.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 + alpcs + p1 2_ch00.tif, Durchmesser: 259.33 µm, Flächeninhalt: 51605.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 + alpcs + p1 3_ch00.tif, Durchmesser: 257.03 µm, Flächeninhalt: 50718.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer + alpcs 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer + alpcs 1_ch00.tif, Durchmesser: 257.03 µm, Flächeninhalt: 50698.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer + alpcs 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer + alpcs 2_ch00.tif, Durchmesser: 253.92 µm, Flächeninhalt: 49524.82 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer + alpcs 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer + alpcs 3_ch00.tif, Durchmesser: 260.94 µm, Flächeninhalt: 52217.58 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer 1_ch00.tif, Durchmesser: 247.45 µm, Flächeninhalt: 46928.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer 2_ch00.tif, Durchmesser: 262.07 µm, Flächeninhalt: 52968.20 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer 3_ch00.tif, Durchmesser: 270.29 µm, Flächeninhalt: 57230.43 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 p1 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 p1 1_ch00.tif, Durchmesser: 256.58 µm, Flächeninhalt: 50508.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs + p1 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs + p1 1_ch00.tif, Durchmesser: 258.46 µm, Flächeninhalt: 51285.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs + p1 2_ch00.tif, Durchmesser: 246.42 µm, Flächeninhalt: 46562.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs + p1 3_ch00.tif, Durchmesser: 255.21 µm, Flächeninhalt: 49969.24 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs 1_ch00.tif, Durchmesser: 261.87 µm, Flächeninhalt: 52564.02 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs 2_ch00.tif, Durchmesser: 247.77 µm, Flächeninhalt: 47134.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs 3_ch00.tif, Durchmesser: 247.81 µm, Flächeninhalt: 47112.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_alpcs 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_alpcs 1_ch00.tif, Durchmesser: 283.95 µm, Flächeninhalt: 61814.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_alpcs 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_alpcs 2_ch00.tif, Durchmesser: 278.77 µm, Flächeninhalt: 59665.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_alpcs 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_alpcs 3_ch00.tif, Durchmesser: 273.18 µm, Flächeninhalt: 57274.17 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_Kontreolle 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_Kontreolle 1_ch00.tif, Durchmesser: 278.32 µm, Flächeninhalt: 59433.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_Kontrolle 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_Kontrolle 2_ch00.tif, Durchmesser: 268.33 µm, Flächeninhalt: 55332.02 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_Kontrolle 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_Kontrolle 3_ch00.tif, Durchmesser: 271.45 µm, Flächeninhalt: 56576.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_p1 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_p1 1_ch00.tif, Durchmesser: 248.58 µm, Flächeninhalt: 47421.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_p1 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_p1 2_ch00.tif, Durchmesser: 256.72 µm, Flächeninhalt: 50618.37 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_p1 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_p1 3_ch00.tif, Durchmesser: 257.49 µm, Flächeninhalt: 50942.06 µm²
# Anzahl der erfolgreichen Vorhersagen: 357
# Anzahl der zugehörigen manuellen Durchmesser: 357
#
# Metriken zur Bewertung der Modellgenauigkeit:
# MAE (Mean Absolute Error): 2.07 µm
# MSE (Mean Squared Error): 11.75 µm²
# R2 Score (Coefficient of Determination): 0.99
# Ergebnisse und Metriken wurden in C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx gespeichert.
