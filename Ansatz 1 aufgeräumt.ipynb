# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, UpSampling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Pfade zu den Bildern und Masken
image_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Images alle/'
mask_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Trainingsset/Masken alle/'

# Liste der Bild- und Maskenpfade
image_paths = sorted([os.path.join(image_dir, fname) for fname in os.listdir(image_dir)])
mask_paths = sorted([os.path.join(mask_dir, fname) for fname in os.listdir(mask_dir)])

# Laden und Vorverarbeiten der Daten mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path)
    img = img.resize((256, 196))  # Größe anpassen (Beispiel: 256x256)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

def load_and_preprocess_mask_pillow(mask_path):
    mask = Image.open(mask_path)
    mask = mask.resize((256, 196))  # Größe anpassen (Beispiel: 256x256)
    mask = np.array(mask)  # PIL Image zu numpy Array konvertieren
    mask = np.where(mask > 128, 1, 0)  # Binarisierung der Maske
    mask = np.expand_dims(mask, axis=-1)  # Für einen Kanal (Grayscale)
    return mask

# Liste für Bilder und Masken initialisieren
X = []
Y = []

# Bilder und Masken laden und in die Listen einfügen
for img_path, mask_path in zip(image_paths, mask_paths):
    img = load_and_preprocess_image_pillow(img_path)
    mask = load_and_preprocess_mask_pillow(mask_path)
    X.append(img)
    Y.append(mask)
    
# In NumPy Arrays konvertieren
X = np.array(X)
Y = np.array(Y)

# Überprüfen der Formen (optional)
print(f'Form von X vorher: {X.shape}')
print(f'Form von Y vorher: {Y.shape}')

# Modell erstellen
model = Sequential([
    Conv2D(64, 3, activation='relu', padding='same', input_shape=(196, 256, 1)),
    Dropout(0.1),  # Dropout-Schicht hinzugefügt
    Conv2D(64, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(128, 3, activation='relu', padding='same'),
    Dropout(0.2),  # Dropout-Schicht hinzugefügt
    Conv2D(128, 3, activation='relu', padding='same'),
    MaxPooling2D((2, 2), padding='same'),
    Conv2D(512, 3, activation='relu', padding='same'),
    Dropout(0.3),  # Dropout-Schicht hinzugefügt
    Conv2D(256, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(128, 3, activation='relu', padding='same'),
    Dropout(0.2),  # Dropout-Schicht hinzugefügt
    Conv2D(128, 3, activation='relu', padding='same'),
    UpSampling2D((2, 2)),
    Conv2D(64, 3, activation='relu', padding='same'),
    Dropout(0.1),  # Dropout-Schicht hinzugefügt
    Conv2D(64, 3, activation='relu', padding='same'),
    Conv2D(1, (3, 3), activation='sigmoid', padding='same')
])

# Modellzusammenfassung anzeigen
model.summary()

# Adam-Optimizer mit spezifischer Lernrate erstellen
optimizer = Adam(learning_rate=0.0001)

# Modell kompilieren mit dem Adam-Optimizer
model.compile(optimizer=optimizer, loss='binary_crossentropy')

# EarlyStopping-Callback hinzufügen
early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)

# Trainieren des Modells
history = model.fit(X, Y, batch_size=8, epochs=500, validation_split=0.15, callbacks=[early_stopping])

# Pfad zum Speichern des Modells im HDF5-Format
model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_200_trainingsbilder_noch_komplexer_early_stop_and_droput_3_6.h5') 

# Überprüfen der Formen (optional)
print(f'Form von X nachher: {X.shape}')
print(f'Form von Y nachher: {Y.shape}')

def plot_training_history(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

plot_training_history(history)
# Out:
# Form von X vorher: (214, 196, 256, 1)
# Form von Y vorher: (214, 196, 256, 1)
# c:\Users\chris\miniconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 196, 256, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 196, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 196, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 98, 128, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 98, 128, 128)   │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 98, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 98, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 49, 64, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 49, 64, 512)    │       590,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 49, 64, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 49, 64, 256)    │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 98, 128, 256)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 98, 128, 128)   │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 98, 128, 128)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 98, 128, 128)   │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 196, 256, 128)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 196, 256, 64)   │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 196, 256, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 196, 256, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 196, 256, 1)    │           577 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,583,169 (9.85 MB)
#  Trainable params: 2,583,169 (9.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 113s 5s/step - loss: 0.5918 - val_loss: 0.4434
# Epoch 2/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 123s 5s/step - loss: 0.3926 - val_loss: 0.3949
# Epoch 3/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 169s 7s/step - loss: 0.3786 - val_loss: 0.3662
# Epoch 4/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.3572 - val_loss: 0.4097
# Epoch 5/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 173s 8s/step - loss: 0.3730 - val_loss: 0.3253
# Epoch 6/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.3453 - val_loss: 0.3217
# Epoch 7/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.3311 - val_loss: 0.3026
# Epoch 8/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.3030 - val_loss: 0.2523
# Epoch 9/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 170s 7s/step - loss: 0.2591 - val_loss: 0.2600
# Epoch 10/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 170s 7s/step - loss: 0.2034 - val_loss: 0.4792
# Epoch 11/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 173s 8s/step - loss: 0.1439 - val_loss: 0.2026
# Epoch 12/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 173s 8s/step - loss: 0.1389 - val_loss: 0.2829
# Epoch 13/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 173s 7s/step - loss: 0.1193 - val_loss: 0.3035
# Epoch 14/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.1194 - val_loss: 0.3483
# Epoch 15/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 175s 8s/step - loss: 0.1024 - val_loss: 0.1970
# Epoch 16/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 169s 7s/step - loss: 0.1181 - val_loss: 0.3430
# Epoch 17/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 175s 8s/step - loss: 0.1066 - val_loss: 0.2151
# Epoch 18/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 167s 7s/step - loss: 0.1076 - val_loss: 0.2112
# Epoch 19/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 138s 6s/step - loss: 0.0985 - val_loss: 0.3874
# Epoch 20/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 170s 7s/step - loss: 0.0998 - val_loss: 0.2840
# Epoch 21/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 173s 8s/step - loss: 0.0868 - val_loss: 0.3897
# Epoch 22/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 174s 8s/step - loss: 0.1032 - val_loss: 0.2621
# Epoch 23/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 173s 8s/step - loss: 0.0890 - val_loss: 0.2332
# Epoch 24/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 172s 7s/step - loss: 0.0794 - val_loss: 0.3078
# Epoch 25/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 173s 8s/step - loss: 0.0732 - val_loss: 0.1535
# Epoch 26/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.0762 - val_loss: 0.2300
# Epoch 27/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.0768 - val_loss: 0.1702
# Epoch 28/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 172s 7s/step - loss: 0.0735 - val_loss: 0.3059
# Epoch 29/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.0640 - val_loss: 0.2211
# Epoch 30/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.0645 - val_loss: 0.1391
# Epoch 31/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 171s 7s/step - loss: 0.0753 - val_loss: 0.2563
# Epoch 32/500
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 172s 7s/step - loss: 0.0647 - val_loss: 0.3275
# Epoch 33/500
# 10/23 ━━━━━━━━━━━━━━━━━━━━ 1:36 7s/step - loss: 0.0503
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 92
#      89 early_stopping = EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True)
#      91 # Trainieren des Modells
# ---> 92 history = model.fit(X, Y, batch_size=8, epochs=500, validation_split=0.15, callbacks=[early_stopping])
#      94 # Pfad zum Speichern des Modells im HDF5-Format
#      95 model.save('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_200_trainingsbilder_noch_komplexer_early_stop_and_droput_3_6.h5')
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Laden und Vorverarbeiten der Bilder mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')  # Convert to grayscale
    img = img.resize((256, 192))  # Größe anpassen (Beispiel: 256x196)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

# Vorhersage mit dem Modell machen
def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
    predicted_mask = model.predict(image)  # Vorhersage machen
    return np.squeeze(predicted_mask)  # Batch-Dimension entfernen

# Funktion zur Berechnung der mittleren Konturgröße
def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

# Funktion zur Auswahl des besten Schwellenwerts
def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0

    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size  # Anpassen der Bewertungsmetrik nach Bedarf

            if score > best_score:
                best_score = score
                best_threshold = threshold

    return best_threshold

# Funktion zur Berechnung des mittleren Durchmessers
def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)


# Pfade definieren
model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_200_trainingsbilder_noch_komplexer_early_stop_and_droput_3.h5'
input_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Sphäroide BA/Alle BA Sphäaeroidbilder sortiert/'
output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher/'
excel_file_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Sphäroide BA/gemessene Durchmesser neu2.xlsx'

# Modell laden
model = tf.keras.models.load_model(model_path)

# Daten aus der Excel-Tabelle laden
predicted_diameters = []
df_manual = pd.read_excel(excel_file_path, header=0)  # Daten ab der zweiten Zeile 
manual_diameters = df_manual.iloc[:, 1].tolist()  # Durchmesser sind in der zweiten Spalte

# Debug-Ausgabe: Anzahl der manuellen Durchmesser
print(f"Anzahl der manuellen Durchmesser: {len(df_manual)}")

# Skalierungsfaktoren berechnen
scale_factor_width = 1296 / 256  # Originalbreite / skalierte Breite
scale_factor_height = 966 / 196  # Originalhöhe / skalierte Höhe

# Listen für die berechneten Durchmesser und die manuell gemessenen Durchmesser
manual_diameters = []

# Iteration über alle TIFF-Dateien im Eingabeordner
tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Debug-Ausgabe: Anzahl der TIFF-Dateien
print(f"Anzahl der TIFF-Dateien: {len(tif_files)}")

# Überprüfen, ob die Anzahl der Dateien mit der Anzahl der manuellen Messungen übereinstimmt
if len(tif_files) != len(df_manual):
    print("Die Anzahl der Bilddateien stimmt nicht mit der Anzahl der manuellen Messungen überein.")
else:
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        
        try:
            # Bild laden und vorverarbeiten
            image = load_and_preprocess_image_pillow(img_path)
            # Vorhersage mit dem Modell machen
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            # Besten Schwellenwert für Konturen finden
            best_threshold = find_best_threshold(predicted_mask)

            # Maske mit dem besten Schwellenwert erstellen
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
            
            # Konturen finden
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            # Filtere Konturen nach Schmalheitsverhältnis
            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:  # Anpassen des Schmalheitsverhältnisses nach Bedarf
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            # Die größte Kontur nach dem Flächeninhalt finden
            largest_contour = max(filtered_contours, key=cv2.contourArea)

            # Berechne den Schwerpunkt der Kontur
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

            # Berechne den mittleren Durchmesser
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width)

            # Berechnung des Flächeninhalts
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.3745 * scale_factor_width * 0.3745 * scale_factor_height)

            # Ergebnisse hinzufügen
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])  # Manuell gemessener Durchmesser hinzufügen

            # Ausgabepfad für das segmentierte Bild definieren
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            # Maske als TIFF-Datei speichern
            Image.fromarray(binary_mask, mode='L').save(output_path)
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")

            # Ergebnisse ausgeben
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Flächeninhalt: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    # Debug-Ausgabe: Anzahl der erfolgreichen Vorhersagen und manuell gemessenen Durchmesser
    print(f"Anzahl der erfolgreichen Vorhersagen: {len(predicted_diameters)}")
    print(f"Anzahl der zugehörigen manuellen Durchmesser: {len(manual_diameters)}")

    # Ergebnisse in ein DataFrame konvertieren
    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    # Ergebnisse in eine Excel-Datei exportieren
    excel_output_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx'
    df_results.to_excel(excel_output_path, index=False)

    # Berechnung der Metriken zur Bewertung der Modellgenauigkeit
    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)

        print(f"\nMetriken zur Bewertung der Modellgenauigkeit:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")

        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print("Keine ausreichenden Daten zur Berechnung der Metriken vorhanden.")

    # Scatterplot erstellen
    plt.figure(figsize=(10, 6))
    plt.scatter(manual_diameters, predicted_diameters, color='blue', label='Vorhergesagt vs. Manuell')
    plt.plot([min(manual_diameters), max(manual_diameters)], [min(manual_diameters), max(manual_diameters)], color='red', linestyle='--', label='Perfekte Übereinstimmung')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title('Vergleich von manuellen und vorhergesagten Durchmessern')
    plt.legend()
    plt.grid(True)
    plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/scatterplot.png')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Anzahl der manuellen Durchmesser: 357
# Anzahl der TIFF-Dateien: 357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 600ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 C6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 C6_ch00.tif, Durchmesser: 155.90 µm, Flächeninhalt: 18670.88 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 D6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 D6_ch00.tif, Durchmesser: 159.99 µm, Flächeninhalt: 19671.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS +P1 E6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS +P1 E6_ch00.tif, Durchmesser: 149.71 µm, Flächeninhalt: 17258.89 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS B4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS B4_ch00.tif, Durchmesser: 162.14 µm, Flächeninhalt: 20221.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS C4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS C4_ch00.tif, Durchmesser: 161.70 µm, Flächeninhalt: 20114.37 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS D4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS D4_ch00.tif, Durchmesser: 154.10 µm, Flächeninhalt: 18275.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 B5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 B5_ch00.tif, Durchmesser: 131.61 µm, Flächeninhalt: 13350.09 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 C5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 C5_ch00.tif, Durchmesser: 168.21 µm, Flächeninhalt: 21757.33 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 E5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 E5_ch00.tif, Durchmesser: 153.37 µm, Flächeninhalt: 18088.24 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer C3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer C3_ch00.tif, Durchmesser: 158.92 µm, Flächeninhalt: 19458.24 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer D3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer D3_ch00.tif, Durchmesser: 155.37 µm, Flächeninhalt: 18600.90 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer F3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer F3_ch00.tif, Durchmesser: 156.37 µm, Flächeninhalt: 18802.11 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 D10_ch00.tif, Durchmesser: 139.07 µm, Flächeninhalt: 14870.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 E10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 E10_ch00.tif, Durchmesser: 132.18 µm, Flächeninhalt: 13441.08 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 G10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 G10_ch00.tif, Durchmesser: 125.59 µm, Flächeninhalt: 12148.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS C8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS C8_ch00.tif, Durchmesser: 147.10 µm, Flächeninhalt: 16658.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS E8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS E8_ch00.tif, Durchmesser: 139.89 µm, Flächeninhalt: 15019.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS F8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS F8_ch00.tif, Durchmesser: 151.34 µm, Flächeninhalt: 17617.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 c9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 c9_ch00.tif, Durchmesser: 150.68 µm, Flächeninhalt: 17451.35 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 D9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 D9_ch00.tif, Durchmesser: 154.15 µm, Flächeninhalt: 18289.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 E9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 E9_ch00.tif, Durchmesser: 143.71 µm, Flächeninhalt: 15920.38 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer B7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer B7_ch00.tif, Durchmesser: 134.20 µm, Flächeninhalt: 13875.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer D7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer D7_ch00.tif, Durchmesser: 154.64 µm, Flächeninhalt: 18378.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer F7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer F7_ch00.tif, Durchmesser: 161.65 µm, Flächeninhalt: 20081.13 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS D11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS D11_ch00.tif, Durchmesser: 126.89 µm, Flächeninhalt: 12421.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS E11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS E11_ch00.tif, Durchmesser: 153.51 µm, Flächeninhalt: 18114.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS F11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS F11_ch00.tif, Durchmesser: 154.59 µm, Flächeninhalt: 18366.44 µm²
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 112
#     110 image = load_and_preprocess_image_pillow(img_path)
#     111 # Vorhersage mit dem Modell machen
# --> 112 predicted_mask = predict_with_model(model, image)
#     113 if predicted_mask is None:
#     114     print(f"Fehler bei der Vorhersage für {filename}.")
#
# Cell In[1], line 22, in predict_with_model(model, image)
#      20 def predict_with_model(model, image):
#      21     image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
# ---> 22     predicted_mask = model.predict(image)  # Vorhersage machen
#      23     return np.squeeze(predicted_mask)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:442, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     437 @traceback_utils.filter_traceback
#     438 def predict(
#     439     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     440 ):
#     441     # Create an iterator that yields batches of input data.
# --> 442     epoch_iterator = TFEpochIterator(
#     443         x=x,
#     444         batch_size=batch_size,
#     445         steps_per_epoch=steps,
#     446         shuffle=False,
#     447         distribute_strategy=self.distribute_strategy,
#     448         steps_per_execution=self.steps_per_execution,
#     449     )
#     451     # Container that configures and calls callbacks.
#     452     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:625, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     623 super().__init__(*args, **kwargs)
#     624 self._distribute_strategy = distribute_strategy
# --> 625 dataset = self._get_iterator()
#     626 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     627     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     628         dataset
#     629     )
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:634, in TFEpochIterator._get_iterator(self)
#     633 def _get_iterator(self):
# --> 634     return self.data_adapter.get_tf_dataset()
#
# File c:\Users\chris\miniconda3\Lib\site-packages\keras\src\trainers\data_adapters\array_data_adapter.py:140, in ArrayDataAdapter.get_tf_dataset(self)
#     133     return indices
#     135 # We prefetch a single element. Computing large permutations can take
#     136 # quite a while so we don't want to wait for prefetching over an epoch
#     137 # boundary to trigger the next permutation. On the other hand, too many
#     138 # simultaneous shuffles can contend on a hardware level and degrade all
#     139 # performance.
# --> 140 indices_dataset = indices_dataset.map(permutation).prefetch(1)
#     142 def slice_batch_indices(indices):
#     143     """Convert a Tensor of indices into a dataset of batched indices.
#     144
#     145     This step can be accomplished in several ways. The most natural is
#    (...)
#     157         A Dataset of batched indices.
#     158     """
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:1259, in DatasetV2.prefetch(self, buffer_size, name)
#    1231 def prefetch(self, buffer_size, name=None) -> "DatasetV2":
#    1232   """Creates a `Dataset` that prefetches elements from this dataset.
#    1233
#    1234   Most dataset input pipelines should end with a call to `prefetch`. This
#    (...)
#    1257     A new `Dataset` with the transformation applied as described above.
#    1258   """
# -> 1259   return prefetch_op._prefetch(  # pylint: disable=protected-access
#    1260       self, buffer_size, name=name)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\data\ops\prefetch_op.py:28, in _prefetch(input_dataset, buffer_size, name)
#      26 if debug_mode.DEBUG_MODE:
#      27   return input_dataset
# ---> 28 return _PrefetchDataset(input_dataset, buffer_size, name=name)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\data\ops\prefetch_op.py:46, in _PrefetchDataset.__init__(self, input_dataset, buffer_size, slack_period, name)
#      42 # pylint: disable=protected-access
#      43 # We colocate the prefetch dataset with its input as this collocation only
#      44 # happens automatically in graph mode.
#      45 with ops.colocate_with(input_dataset._variant_tensor):
# ---> 46   variant_tensor = gen_dataset_ops.prefetch_dataset(
#      47       input_dataset._variant_tensor,
#      48       buffer_size=self._buffer_size,
#      49       slack_period=slack_period,
#      50       **self._common_args)
#      51 super().__init__(input_dataset, variant_tensor)
#
# File c:\Users\chris\miniconda3\Lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:5990, in prefetch_dataset(input_dataset, buffer_size, output_types, output_shapes, slack_period, legacy_autotune, buffer_size_min, metadata, name)
#    5988 if tld.is_eager:
#    5989   try:
# -> 5990     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    5991       _ctx, "PrefetchDataset", name, input_dataset, buffer_size,
#    5992       "output_types", output_types, "output_shapes", output_shapes,
#    5993       "slack_period", slack_period, "legacy_autotune", legacy_autotune,
#    5994       "buffer_size_min", buffer_size_min, "metadata", metadata)
#    5995     return _result
#    5996   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import os
import numpy as np
import cv2
import pandas as pd
from PIL import Image
import tensorflow as tf
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Funktion zum Zeichnen von Konturen und Schwerpunkt
def draw_contours_and_centroid(binary_mask, output_path):
    # Finden der Konturen
    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # Erstellen eines Farbbilds zum Zeichnen
    color_mask = cv2.cvtColor(binary_mask, cv2.COLOR_GRAY2BGR)
    
    # Zeichnen der Konturen
    cv2.drawContours(color_mask, contours, -1, (0, 255, 0), 2)
    
    # Berechnung und Zeichnen des Schwerpunkts
    for contour in contours:
        M = cv2.moments(contour)
        if M["m00"] != 0:
            cX = int(M["m10"] / M["m00"])
            cY = int(M["m01"] / M["m00"])
            cv2.circle(color_mask, (cX, cY), 5, (0, 0, 255), -1)
    
    # Speichern des Bildes mit Konturen und Schwerpunkt
    cv2.imwrite(output_path, color_mask)

# Laden und Vorverarbeiten der Bilder mit Pillow
def load_and_preprocess_image_pillow(img_path):
    img = Image.open(img_path).convert('L')  # Convert to grayscale
    img = img.resize((256, 196))  # Größe anpassen (Beispiel: 256x196)
    img = np.array(img)  # PIL Image zu numpy Array konvertieren
    img = img / 255.0  # Normalisierung auf den Bereich [0, 1]
    img = np.expand_dims(img, axis=-1)  # Für einen Kanal (Grayscale)
    return img

# Vorhersage mit dem Modell machen
def predict_with_model(model, image):
    image = np.expand_dims(image, axis=0)  # Batch-Dimension hinzufügen
    predicted_mask = model.predict(image)  # Vorhersage machen
    return np.squeeze(predicted_mask)  # Batch-Dimension entfernen

# Funktion zur Berechnung der mittleren Konturgröße
def calculate_average_contour_size(contour):
    perimeter = cv2.arcLength(contour, True)
    if perimeter == 0:
        return 0
    return cv2.contourArea(contour) / perimeter

# Funktion zur Auswahl des besten Schwellenwerts
def find_best_threshold(mask):
    best_threshold = 0
    best_score = 0

    for threshold in np.arange(0.1, 0.5, 0.01):
        binary_mask = (mask > threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
        contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

        if contours:
            largest_contour = max(contours, key=cv2.contourArea)
            avg_size = calculate_average_contour_size(largest_contour)
            score = avg_size  # Anpassen der Bewertungsmetrik nach Bedarf

            if score > best_score:
                best_score = score
                best_threshold = threshold

    return best_threshold

# Funktion zur Berechnung des mittleren Durchmessers
def calculate_average_diameter(contour, center, num_lines=180):
    angles = np.linspace(0, 2 * np.pi, num=num_lines, endpoint=False)
    diameters = []
    for angle in angles:
        dx = np.cos(angle)
        dy = np.sin(angle)
        intersections = []
        for i in range(-1000, 1000):
            x = int(center[0] + i * dx)
            y = int(center[1] + i * dy)
            if cv2.pointPolygonTest(contour, (x, y), False) >= 0:
                intersections.append((x, y))
        if len(intersections) >= 2:
            d = np.linalg.norm(np.array(intersections[0]) - np.array(intersections[-1]))
            diameters.append(d)
    return np.mean(diameters)

# Pfade definieren
model_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Modelle/spheroid_segmentation_200_trainingsbilder_noch_komplexer_early_stop_and_droput_3.h5'
input_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Sphäroide BA/Alle BA Sphäaeroidbilder sortiert/'
output_dir = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Segmentierte_Bilder_mit_dropout_3 beste bisher/'
excel_file_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Sphäroide BA/gemessene Durchmesser neu2.xlsx'

# Modell laden
model = tf.keras.models.load_model(model_path)

# Daten aus der Excel-Tabelle laden
predicted_diameters = []
df_manual = pd.read_excel(excel_file_path, header=0)  # Daten ab der zweiten Zeile 
manual_diameters = df_manual.iloc[:, 1].tolist()  # Durchmesser sind in der zweiten Spalte

# Debug-Ausgabe: Anzahl der manuellen Durchmesser
print(f"Anzahl der manuellen Durchmesser: {len(df_manual)}")

# Skalierungsfaktoren berechnen
scale_factor_width = 1296 / 256  # Originalbreite / skalierte Breite
scale_factor_height = 966 / 196  # Originalhöhe / skalierte Höhe

# Listen für die berechneten Durchmesser und die manuell gemessenen Durchmesser
manual_diameters = []

# Iteration über alle TIFF-Dateien im Eingabeordner
tif_files = [f for f in os.listdir(input_dir) if f.endswith('.tif')]

# Debug-Ausgabe: Anzahl der TIFF-Dateien
print(f"Anzahl der TIFF-Dateien: {len(tif_files)}")

# Überprüfen, ob die Anzahl der Dateien mit der Anzahl der manuellen Messungen übereinstimmt
if len(tif_files) != len(df_manual):
    print("Die Anzahl der Bilddateien stimmt nicht mit der Anzahl der manuellen Messungen überein.")
else:
    for i, filename in enumerate(tif_files):
        img_path = os.path.join(input_dir, filename)
        
        try:
            # Bild laden und vorverarbeiten
            image = load_and_preprocess_image_pillow(img_path)
            # Vorhersage mit dem Modell machen
            predicted_mask = predict_with_model(model, image)
            if predicted_mask is None:
                print(f"Fehler bei der Vorhersage für {filename}.")
                continue

            # Besten Schwellenwert für Konturen finden
            best_threshold = find_best_threshold(predicted_mask)

            # Maske mit dem besten Schwellenwert erstellen
            binary_mask = (predicted_mask > best_threshold).astype(np.uint8) * 255  # Binarisieren und in 8-bit konvertieren
            
            # Konturen finden
            contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)

            if not contours:
                print(f"Keine Konturen im Bild {filename} gefunden.")
                continue

            # Filtere Konturen nach Schmalheitsverhältnis
            filtered_contours = []
            for contour in contours:
                area = cv2.contourArea(contour)
                perimeter = cv2.arcLength(contour, True)
                if perimeter == 0:
                    continue
                circularity = 4 * np.pi * (area / (perimeter * perimeter))
                if circularity > 0.5:  # Anpassen des Schmalheitsverhältnisses nach Bedarf
                    filtered_contours.append(contour)

            if not filtered_contours:
                print(f"Keine geeigneten Konturen im Bild {filename} gefunden.")
                continue

            # Die größte Kontur nach dem Flächeninhalt finden
            largest_contour = max(filtered_contours, key=cv2.contourArea)

            # Berechne den Schwerpunkt der Kontur
            M = cv2.moments(largest_contour)
            if M["m00"] == 0:
                print(f"Schwerpunkt konnte im Bild {filename} nicht berechnet werden.")
                continue
            center = (int(M["m10"] / M["m00"]), int(M["m01"] / M["m00"]))

            # Berechne den mittleren Durchmesser
            avg_diameter_pixels = calculate_average_diameter(largest_contour, center)
            avg_diameter_micrometers = avg_diameter_pixels * (0.3745 * scale_factor_width)

            # Berechnung des Flächeninhalts
            area_pixels = cv2.contourArea(largest_contour)
            area_micrometers = area_pixels * (0.3745 * scale_factor_width * 0.3745 * scale_factor_height)

            # Ergebnisse hinzufügen
            predicted_diameters.append(avg_diameter_micrometers)
            manual_diameters.append(df_manual.iloc[i, 0])  # Manuell gemessener Durchmesser hinzufügen

            # Ausgabepfad für das segmentierte Bild definieren
            output_path = os.path.join(output_dir, f"{os.path.splitext(filename)[0]}_segmentiert.tif")
            
            # Maske als TIFF-Datei speichern und Konturen und Schwerpunkt einzeichnen
            draw_contours_and_centroid(binary_mask, output_path)
            print(f"Segmentiertes Bild für {filename} wurde gespeichert.")

            # Ergebnisse ausgeben
            print(f"Bild: {filename}, Durchmesser: {avg_diameter_micrometers:.2f} µm, Flächeninhalt: {area_micrometers:.2f} µm²")

        except Exception as e:
            print(f"Fehler bei der Verarbeitung von {filename}: {e}")

    # Debug-Ausgabe: Anzahl der erfolgreichen Vorhersagen und manuell gemessenen Durchmesser
    print(f"Anzahl der erfolgreichen Vorhersagen: {len(predicted_diameters)}")
    print(f"Anzahl der zugehörigen manuellen Durchmesser: {len(manual_diameters)}")

    # Ergebnisse in ein DataFrame konvertieren
    df_results = pd.DataFrame({
        'Manuell gemessene Durchmesser (µm)': manual_diameters,
        'Vorhergesagte Durchmesser (µm)': predicted_diameters
    })

    # Ergebnisse in eine Excel-Datei exportieren
    excel_output_path = 'C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx'
    df_results.to_excel(excel_output_path, index=False)

    # Berechnung der Metriken zur Bewertung der Modellgenauigkeit
    if len(predicted_diameters) > 0 and len(manual_diameters) > 0:
        mae = mean_absolute_error(manual_diameters, predicted_diameters)
        mse = mean_squared_error(manual_diameters, predicted_diameters)
        r2 = r2_score(manual_diameters, predicted_diameters)

        print(f"\nMetriken zur Bewertung der Modellgenauigkeit:")
        print(f"MAE (Mean Absolute Error): {mae:.2f} µm")
        print(f"MSE (Mean Squared Error): {mse:.2f} µm²")
        print(f"R2 Score (Coefficient of Determination): {r2:.2f}")

        print(f"Ergebnisse und Metriken wurden in {excel_output_path} gespeichert.")
    else:
        print("Keine ausreichenden Daten zur Berechnung der Metriken vorhanden.")

    # Scatterplot erstellen
    plt.figure(figsize=(10, 6))
    plt.scatter(manual_diameters, predicted_diameters, color='blue', label='Vorhergesagt vs. Manuell')
    plt.plot([min(manual_diameters), max(manual_diameters)], [min(manual_diameters), max(manual_diameters)], color='red', linestyle='--', label='Perfekte Übereinstimmung')
    plt.xlabel('Manuell gemessene Durchmesser (µm)')
    plt.ylabel('Vorhergesagte Durchmesser (µm)')
    plt.title('Vergleich von manuellen und vorhergesagten Durchmessern')
    plt.legend()
    plt.grid(True)
    plt.savefig('C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/scatterplot.png')
    plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Anzahl der manuellen Durchmesser: 357
# Anzahl der TIFF-Dateien: 357
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 C6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 C6_ch00.tif, Durchmesser: 159.60 µm, Flächeninhalt: 19580.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 D6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS + P1 D6_ch00.tif, Durchmesser: 161.26 µm, Flächeninhalt: 20018.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS +P1 E6_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS +P1 E6_ch00.tif, Durchmesser: 151.42 µm, Flächeninhalt: 17661.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS B4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS B4_ch00.tif, Durchmesser: 164.50 µm, Flächeninhalt: 20809.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS C4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS C4_ch00.tif, Durchmesser: 163.42 µm, Flächeninhalt: 20529.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS D4_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + AlPcS D4_ch00.tif, Durchmesser: 155.15 µm, Flächeninhalt: 18494.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 B5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 B5_ch00.tif, Durchmesser: 133.88 µm, Flächeninhalt: 13817.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 C5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 C5_ch00.tif, Durchmesser: 170.28 µm, Flächeninhalt: 22301.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 E5_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% + P1 E5_ch00.tif, Durchmesser: 154.49 µm, Flächeninhalt: 18396.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer C3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer C3_ch00.tif, Durchmesser: 160.83 µm, Flächeninhalt: 19902.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer D3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer D3_ch00.tif, Durchmesser: 157.36 µm, Flächeninhalt: 19055.81 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 689ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer F3_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_2,5% leer F3_ch00.tif, Durchmesser: 157.62 µm, Flächeninhalt: 19118.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 D10_ch00.tif, Durchmesser: 140.40 µm, Flächeninhalt: 15152.27 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 E10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 E10_ch00.tif, Durchmesser: 134.46 µm, Flächeninhalt: 13902.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 G10_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS + P1 G10_ch00.tif, Durchmesser: 127.09 µm, Flächeninhalt: 12433.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS C8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS C8_ch00.tif, Durchmesser: 148.77 µm, Flächeninhalt: 17033.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS E8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS E8_ch00.tif, Durchmesser: 141.04 µm, Flächeninhalt: 15290.49 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 672ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS F8_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + AlPcS F8_ch00.tif, Durchmesser: 152.90 µm, Flächeninhalt: 17978.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 c9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 c9_ch00.tif, Durchmesser: 151.34 µm, Flächeninhalt: 17615.82 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 D9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 D9_ch00.tif, Durchmesser: 155.39 µm, Flächeninhalt: 18578.15 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 E9_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% + P1 E9_ch00.tif, Durchmesser: 145.52 µm, Flächeninhalt: 16291.31 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer B7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer B7_ch00.tif, Durchmesser: 135.69 µm, Flächeninhalt: 14172.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer D7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer D7_ch00.tif, Durchmesser: 156.41 µm, Flächeninhalt: 18840.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_5% leer F7_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_5% leer F7_ch00.tif, Durchmesser: 163.41 µm, Flächeninhalt: 20537.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 694ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS D11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS D11_ch00.tif, Durchmesser: 127.65 µm, Flächeninhalt: 12538.24 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 662ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS E11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS E11_ch00.tif, Durchmesser: 154.85 µm, Flächeninhalt: 18445.17 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_AlPcS F11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_AlPcS F11_ch00.tif, Durchmesser: 156.02 µm, Flächeninhalt: 18719.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle C2_ch00.tif, Durchmesser: 165.39 µm, Flächeninhalt: 21017.21 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle D2_ch00.tif, Durchmesser: 155.23 µm, Flächeninhalt: 18543.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_Kontrolle F2_ch00.tif, Durchmesser: 160.25 µm, Flächeninhalt: 19745.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_P1 B11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_P1 B11_ch00.tif, Durchmesser: 174.80 µm, Flächeninhalt: 23479.02 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_P1 C11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_P1 C11_ch00.tif, Durchmesser: 141.63 µm, Flächeninhalt: 15437.47 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step
# Segmentiertes Bild für 001_CQ Sphaeroide Tag 0 belichtet_P1 D11_ch00.tif wurde gespeichert.
# Bild: 001_CQ Sphaeroide Tag 0 belichtet_P1 D11_ch00.tif, Durchmesser: 152.20 µm, Flächeninhalt: 17845.03 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 C6_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 C6_ch00.tif, Durchmesser: 166.11 µm, Flächeninhalt: 21206.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 694ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 D6_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 D6_ch00.tif, Durchmesser: 172.24 µm, Flächeninhalt: 22800.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 E6_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS + P1 E6_ch00.tif, Durchmesser: 161.55 µm, Flächeninhalt: 20046.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS B4_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS B4_ch00.tif, Durchmesser: 169.89 µm, Flächeninhalt: 22177.25 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS C4_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS C4_ch00.tif, Durchmesser: 170.82 µm, Flächeninhalt: 22427.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS d4_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 + AlPcS d4_ch00.tif, Durchmesser: 164.03 µm, Flächeninhalt: 20691.77 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 leer C3_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 leer C3_ch00.tif, Durchmesser: 168.62 µm, Flächeninhalt: 21853.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 lerer D3_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 lerer D3_ch00.tif, Durchmesser: 167.81 µm, Flächeninhalt: 21652.35 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_2,5 öeer F3_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_2,5 öeer F3_ch00.tif, Durchmesser: 161.06 µm, Flächeninhalt: 19956.90 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 704ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 D10_ch00.tif, Durchmesser: 147.32 µm, Flächeninhalt: 16698.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 E10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 E10_ch00.tif, Durchmesser: 141.69 µm, Flächeninhalt: 15447.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 F10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS + P1 F10_ch00.tif, Durchmesser: 152.81 µm, Flächeninhalt: 17971.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPCS C8_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPCS C8_ch00.tif, Durchmesser: 156.42 µm, Flächeninhalt: 18812.61 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS E8_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPcS E8_ch00.tif, Durchmesser: 146.12 µm, Flächeninhalt: 16420.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 734ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPCS F8_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_5+ AlPCS F8_ch00.tif, Durchmesser: 160.16 µm, Flächeninhalt: 19729.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_AlPcS D11_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_AlPcS D11_ch00.tif, Durchmesser: 132.95 µm, Flächeninhalt: 13598.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_AlPcS E11_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_AlPcS E11_ch00.tif, Durchmesser: 158.58 µm, Flächeninhalt: 19339.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_AlPcS F11_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_AlPcS F11_ch00.tif, Durchmesser: 159.36 µm, Flächeninhalt: 19570.22 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 702ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle C2_ch00.tif, Durchmesser: 173.90 µm, Flächeninhalt: 23262.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle D2_ch00.tif, Durchmesser: 159.14 µm, Flächeninhalt: 19510.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 733ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_Kontrolle F2_ch00.tif, Durchmesser: 167.68 µm, Flächeninhalt: 21596.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_P1 B10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_P1 B10_ch00.tif, Durchmesser: 177.06 µm, Flächeninhalt: 24098.40 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_P1 C10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_P1 C10_ch00.tif, Durchmesser: 145.55 µm, Flächeninhalt: 16289.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# Segmentiertes Bild für 002_CQ Sphaeroide Tag 1 belichtet_P1 D10_ch00.tif wurde gespeichert.
# Bild: 002_CQ Sphaeroide Tag 1 belichtet_P1 D10_ch00.tif, Durchmesser: 153.79 µm, Flächeninhalt: 18196.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 C6_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 C6_ch00.tif, Durchmesser: 187.81 µm, Flächeninhalt: 27095.61 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 702ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 D6_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 D6_ch00.tif, Durchmesser: 194.21 µm, Flächeninhalt: 28969.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 E6_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS + P1 E6_ch00.tif, Durchmesser: 182.35 µm, Flächeninhalt: 25533.15 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS B4_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS B4_ch00.tif, Durchmesser: 191.39 µm, Flächeninhalt: 28127.93 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPCs C4_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPCs C4_ch00.tif, Durchmesser: 192.51 µm, Flächeninhalt: 28444.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS E4_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 + AlPcS E4_ch00.tif, Durchmesser: 185.77 µm, Flächeninhalt: 26498.97 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 719ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 leer C3_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 leer C3_ch00.tif, Durchmesser: 188.16 µm, Flächeninhalt: 27181.35 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 leer D3_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 leer D3_ch00.tif, Durchmesser: 188.24 µm, Flächeninhalt: 27225.09 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 720ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_2,5 leer F3_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_2,5 leer F3_ch00.tif, Durchmesser: 186.49 µm, Flächeninhalt: 26745.68 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 D10_ch00.tif, Durchmesser: 168.03 µm, Flächeninhalt: 21687.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 E10_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 E10_ch00.tif, Durchmesser: 160.72 µm, Flächeninhalt: 19853.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 F10_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS + P1 F10_ch00.tif, Durchmesser: 170.88 µm, Flächeninhalt: 22474.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 733ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS C8_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS C8_ch00.tif, Durchmesser: 172.42 µm, Flächeninhalt: 22873.63 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS e8_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS e8_ch00.tif, Durchmesser: 166.85 µm, Flächeninhalt: 21386.39 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS F8_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_5 + AlPcS F8_ch00.tif, Durchmesser: 181.19 µm, Flächeninhalt: 25211.20 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_AlPcS D11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_AlPcS D11_ch00.tif, Durchmesser: 155.90 µm, Flächeninhalt: 18714.63 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_AlPcS E11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_AlPcS E11_ch00.tif, Durchmesser: 182.22 µm, Flächeninhalt: 25515.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_AlPcS F11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_AlPcS F11_ch00.tif, Durchmesser: 180.77 µm, Flächeninhalt: 25093.97 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_Kontrolle C2_ch00.tif, Durchmesser: 198.08 µm, Flächeninhalt: 30136.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_Kontrolle D2_ch00.tif, Durchmesser: 185.16 µm, Flächeninhalt: 26324.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_Kontrolle F2_ch00.tif, Durchmesser: 190.96 µm, Flächeninhalt: 28010.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_P1 B11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_P1 B11_ch00.tif, Durchmesser: 199.77 µm, Flächeninhalt: 30647.47 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 757ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_P1 C11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_P1 C11_ch00.tif, Durchmesser: 163.26 µm, Flächeninhalt: 20483.56 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step
# Segmentiertes Bild für 003_CQ Sphaeroide belichtet Tag 2_P1 D11_ch00.tif wurde gespeichert.
# Bild: 003_CQ Sphaeroide belichtet Tag 2_P1 D11_ch00.tif, Durchmesser: 176.13 µm, Flächeninhalt: 23825.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 727ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + alpcs + p1 C6_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + alpcs + p1 C6_ch00.tif, Durchmesser: 231.75 µm, Flächeninhalt: 41224.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 735ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + alpcs + p1 D6_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + alpcs + p1 D6_ch00.tif, Durchmesser: 244.48 µm, Flächeninhalt: 45859.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 580ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + alpcs +p1 E6_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + alpcs +p1 E6_ch00.tif, Durchmesser: 229.53 µm, Flächeninhalt: 40447.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs B4_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs B4_ch00.tif, Durchmesser: 234.38 µm, Flächeninhalt: 42218.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 749ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs C4_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs C4_ch00.tif, Durchmesser: 237.80 µm, Flächeninhalt: 43402.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs D4_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 + Alpcs D4_ch00.tif, Durchmesser: 228.49 µm, Flächeninhalt: 40102.77 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 leer C3_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 leer C3_ch00.tif, Durchmesser: 227.92 µm, Flächeninhalt: 39891.06 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 leer D3_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 leer D3_ch00.tif, Durchmesser: 229.89 µm, Flächeninhalt: 40562.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_2,5 leer F3_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_2,5 leer F3_ch00.tif, Durchmesser: 227.51 µm, Flächeninhalt: 39728.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 D10_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 D10_ch00.tif, Durchmesser: 214.18 µm, Flächeninhalt: 35224.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 E10_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 E10_ch00.tif, Durchmesser: 203.12 µm, Flächeninhalt: 31660.54 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 F10_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5 + alpcs + p1 F10_ch00.tif, Durchmesser: 214.02 µm, Flächeninhalt: 35170.41 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 727ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5 + alpcs C8_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5 + alpcs C8_ch00.tif, Durchmesser: 206.55 µm, Flächeninhalt: 32768.09 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5+ alpcs E8_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5+ alpcs E8_ch00.tif, Durchmesser: 205.63 µm, Flächeninhalt: 32484.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_5+ alpcs F8_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_5+ alpcs F8_ch00.tif, Durchmesser: 223.52 µm, Flächeninhalt: 38360.08 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_alpcs + D11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_alpcs + D11_ch00.tif, Durchmesser: 206.04 µm, Flächeninhalt: 32589.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 857ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_alpcs + E11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_alpcs + E11_ch00.tif, Durchmesser: 238.32 µm, Flächeninhalt: 43631.88 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 821ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_alpcs + F11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_alpcs + F11_ch00.tif, Durchmesser: 232.08 µm, Flächeninhalt: 41346.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 540ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_Kontrolle C2_ch00.tif, Durchmesser: 253.00 µm, Flächeninhalt: 49138.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_Kontrolle D2_ch00.tif, Durchmesser: 239.73 µm, Flächeninhalt: 44106.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_Kontrolle F2_ch00.tif, Durchmesser: 245.41 µm, Flächeninhalt: 46237.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_P1 B11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_P1 B11_ch00.tif, Durchmesser: 246.30 µm, Flächeninhalt: 46555.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 750ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_P1 C11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_P1 C11_ch00.tif, Durchmesser: 210.89 µm, Flächeninhalt: 34146.84 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step
# Segmentiertes Bild für 004_Sphaeroide belichtet Tag 5_P1 D11_ch00.tif wurde gespeichert.
# Bild: 004_Sphaeroide belichtet Tag 5_P1 D11_ch00.tif, Durchmesser: 221.80 µm, Flächeninhalt: 37772.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 702ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 C6_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 C6_ch00.tif, Durchmesser: 246.48 µm, Flächeninhalt: 46604.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 D6_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 D6_ch00.tif, Durchmesser: 258.41 µm, Flächeninhalt: 51274.50 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 727ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 E6_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs + p1 E6_ch00.tif, Durchmesser: 245.09 µm, Flächeninhalt: 46079.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs B4_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs B4_ch00.tif, Durchmesser: 246.64 µm, Flächeninhalt: 46706.08 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs C4_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs C4_ch00.tif, Durchmesser: 251.65 µm, Flächeninhalt: 48611.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 721ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs D4_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 + alpcs D4_ch00.tif, Durchmesser: 242.18 µm, Flächeninhalt: 45022.88 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 694ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer C3_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer C3_ch00.tif, Durchmesser: 239.80 µm, Flächeninhalt: 44156.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer D3_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer D3_ch00.tif, Durchmesser: 242.14 µm, Flächeninhalt: 45014.13 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 709ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer F3_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_2,5 leer F3_ch00.tif, Durchmesser: 241.00 µm, Flächeninhalt: 44569.71 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 717ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 D10_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 D10_ch00.tif, Durchmesser: 229.36 µm, Flächeninhalt: 40412.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 E10_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 E10_ch00.tif, Durchmesser: 217.86 µm, Flächeninhalt: 36421.43 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 F10_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs + p1 F10_ch00.tif, Durchmesser: 229.38 µm, Flächeninhalt: 40394.97 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs C8_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs C8_ch00.tif, Durchmesser: 224.39 µm, Flächeninhalt: 37943.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs E8_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5 + alpcs E8_ch00.tif, Durchmesser: 219.89 µm, Flächeninhalt: 37154.55 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5+ alpcs F8_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_5+ alpcs F8_ch00.tif, Durchmesser: 237.53 µm, Flächeninhalt: 43285.44 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 699ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs d11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs d11_ch00.tif, Durchmesser: 222.32 µm, Flächeninhalt: 37978.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs e11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs e11_ch00.tif, Durchmesser: 255.04 µm, Flächeninhalt: 50021.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs f11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_alpcs f11_ch00.tif, Durchmesser: 248.16 µm, Flächeninhalt: 47232.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle C2_ch00.tif, Durchmesser: 269.67 µm, Flächeninhalt: 55778.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle D2_ch00.tif, Durchmesser: 257.05 µm, Flächeninhalt: 50674.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 715ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle F2_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_Kontrolle F2_ch00.tif, Durchmesser: 261.92 µm, Flächeninhalt: 52655.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 b11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 b11_ch00.tif, Durchmesser: 259.79 µm, Flächeninhalt: 51816.91 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 c11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 c11_ch00.tif, Durchmesser: 225.72 µm, Flächeninhalt: 39119.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# Segmentiertes Bild für 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 d11_ch00.tif wurde gespeichert.
# Bild: 005_sphaeroide belichtet Tag 6 1 tag nach belichtung_p1 d11_ch00.tif, Durchmesser: 236.92 µm, Flächeninhalt: 43092.98 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 724ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 1_ch00.tif, Durchmesser: 256.36 µm, Flächeninhalt: 50411.91 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 2_ch00.tif, Durchmesser: 268.44 µm, Flächeninhalt: 55312.78 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs + p1 3_ch00.tif, Durchmesser: 256.23 µm, Flächeninhalt: 50406.66 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs 1_ch00.tif, Durchmesser: 255.10 µm, Flächeninhalt: 49918.50 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs 2_ch00.tif, Durchmesser: 262.48 µm, Flächeninhalt: 52861.47 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 + alpcs 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 + alpcs 3_ch00.tif, Durchmesser: 253.65 µm, Flächeninhalt: 49409.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 leer 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 leer 1_ch00.tif, Durchmesser: 248.43 µm, Flächeninhalt: 47365.71 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 leer 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 leer 2_ch00.tif, Durchmesser: 251.84 µm, Flächeninhalt: 48740.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_2,5 leer 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_2,5 leer 3_ch00.tif, Durchmesser: 248.77 µm, Flächeninhalt: 47507.43 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs +  1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs +  1_ch00.tif, Durchmesser: 225.51 µm, Flächeninhalt: 39084.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs +  2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs +  2_ch00.tif, Durchmesser: 232.09 µm, Flächeninhalt: 41392.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs + 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs + 3_ch00.tif, Durchmesser: 249.03 µm, Flächeninhalt: 47601.92 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 1_ch00.tif, Durchmesser: 241.98 µm, Flächeninhalt: 44947.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 2_ch00.tif, Durchmesser: 231.44 µm, Flächeninhalt: 41103.59 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_5 + alpcs + p1 3_ch00.tif, Durchmesser: 242.54 µm, Flächeninhalt: 45178.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 691ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_alpcs D11_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_alpcs D11_ch00.tif, Durchmesser: 239.99 µm, Flächeninhalt: 44214.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_alpcs E11_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_alpcs E11_ch00.tif, Durchmesser: 265.55 µm, Flächeninhalt: 54203.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_alpcs F11_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_alpcs F11_ch00.tif, Durchmesser: 261.14 µm, Flächeninhalt: 52298.07 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_kontrolle 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_kontrolle 1_ch00.tif, Durchmesser: 279.46 µm, Flächeninhalt: 59903.95 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_kontrolle 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_kontrolle 2_ch00.tif, Durchmesser: 268.58 µm, Flächeninhalt: 55326.77 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_kontrollle 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_kontrollle 3_ch00.tif, Durchmesser: 275.18 µm, Flächeninhalt: 58049.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_p1 1_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_p1 1_ch00.tif, Durchmesser: 267.17 µm, Flächeninhalt: 54744.13 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_p1 2_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_p1 2_ch00.tif, Durchmesser: 235.94 µm, Flächeninhalt: 42734.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Segmentiertes Bild für 006_Sphaeroide belichtet tag 7_p1 3_ch00.tif wurde gespeichert.
# Bild: 006_Sphaeroide belichtet tag 7_p1 3_ch00.tif, Durchmesser: 248.84 µm, Flächeninhalt: 47498.68 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 1_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 1_ch00.tif, Durchmesser: 269.48 µm, Flächeninhalt: 55688.96 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 2_ch00.tif, Durchmesser: 280.46 µm, Flächeninhalt: 60341.37 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs + p1 3_ch00.tif, Durchmesser: 267.30 µm, Flächeninhalt: 54810.62 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 1_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 1_ch00.tif, Durchmesser: 264.07 µm, Flächeninhalt: 53561.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 2_ch00.tif, Durchmesser: 273.00 µm, Flächeninhalt: 57176.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 + alpcs 3_ch00.tif, Durchmesser: 265.28 µm, Flächeninhalt: 53995.26 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer 2_ch00.tif, Durchmesser: 263.15 µm, Flächeninhalt: 53116.92 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer 3_ch00.tif, Durchmesser: 261.81 µm, Flächeninhalt: 52606.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer _ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_2,5 leer _ch00.tif, Durchmesser: 258.67 µm, Flächeninhalt: 51391.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 2_ch00.tif, Durchmesser: 248.30 µm, Flächeninhalt: 47316.72 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 3_ch00.tif, Durchmesser: 256.20 µm, Flächeninhalt: 50350.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 _ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs + p1 _ch00.tif, Durchmesser: 258.10 µm, Flächeninhalt: 51106.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 1_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 1_ch00.tif, Durchmesser: 230.24 µm, Flächeninhalt: 40694.16 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 2_ch00.tif, Durchmesser: 246.98 µm, Flächeninhalt: 46896.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_5 + alpcs 3_ch00.tif, Durchmesser: 262.31 µm, Flächeninhalt: 52766.98 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_alpcs d11_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_alpcs d11_ch00.tif, Durchmesser: 257.09 µm, Flächeninhalt: 50761.85 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_alpcs e11_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_alpcs e11_ch00.tif, Durchmesser: 276.53 µm, Flächeninhalt: 58673.92 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_alpcs f11_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_alpcs f11_ch00.tif, Durchmesser: 273.85 µm, Flächeninhalt: 57561.12 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_K1_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_K1_ch00.tif, Durchmesser: 291.72 µm, Flächeninhalt: 65261.48 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_k2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_k2_ch00.tif, Durchmesser: 280.49 µm, Flächeninhalt: 60344.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_K3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_K3_ch00.tif, Durchmesser: 289.93 µm, Flächeninhalt: 64482.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_p1 1_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_p1 1_ch00.tif, Durchmesser: 267.22 µm, Flächeninhalt: 54843.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_p1 2_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_p1 2_ch00.tif, Durchmesser: 249.86 µm, Flächeninhalt: 47943.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# Segmentiertes Bild für 007_Sphaeroide belichtet Tag 9 CQ_p1 3_ch00.tif wurde gespeichert.
# Bild: 007_Sphaeroide belichtet Tag 9 CQ_p1 3_ch00.tif, Durchmesser: 260.00 µm, Flächeninhalt: 51909.64 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 + P1 E5_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 + P1 E5_ch00.tif, Durchmesser: 197.15 µm, Flächeninhalt: 29847.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 +P1 F5_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 +P1 F5_ch00.tif, Durchmesser: 201.48 µm, Flächeninhalt: 31196.87 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 +P1 G5_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_2,5 +P1 G5_ch00.tif, Durchmesser: 182.37 µm, Flächeninhalt: 25573.39 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu E7_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu E7_ch00.tif, Durchmesser: 191.35 µm, Flächeninhalt: 28150.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu F7_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu F7_ch00.tif, Durchmesser: 205.67 µm, Flächeninhalt: 32442.65 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu G7_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 + P1 neu G7_ch00.tif, Durchmesser: 197.70 µm, Flächeninhalt: 30012.34 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu E10_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu E10_ch00.tif, Durchmesser: 187.47 µm, Flächeninhalt: 27001.13 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu F10_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu F10_ch00.tif, Durchmesser: 200.68 µm, Flächeninhalt: 30923.92 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Segmentiertes Bild für 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu G10_ch00.tif wurde gespeichert.
# Bild: 008_CQ Sphaeroide unbelichtet neu Tag 0_5 leer neu G10_ch00.tif, Durchmesser: 177.45 µm, Flächeninhalt: 24182.39 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 534ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_5 + AlPcS E8_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_5 + AlPcS E8_ch00.tif, Durchmesser: 184.28 µm, Flächeninhalt: 26094.79 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 366ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcs + P1 B10_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcs + P1 B10_ch00.tif, Durchmesser: 193.09 µm, Flächeninhalt: 28631.84 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcs + P1 C10_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcs + P1 C10_ch00.tif, Durchmesser: 177.97 µm, Flächeninhalt: 24350.36 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcS + P1 D10_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_5+ AlPcS + P1 D10_ch00.tif, Durchmesser: 185.57 µm, Flächeninhalt: 26455.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS E11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS E11_ch00.tif, Durchmesser: 197.95 µm, Flächeninhalt: 30101.57 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS F11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS F11_ch00.tif, Durchmesser: 193.18 µm, Flächeninhalt: 28670.33 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS G11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_AlPcS G11_ch00.tif, Durchmesser: 191.05 µm, Flächeninhalt: 28031.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle C2_ch00.tif, Durchmesser: 198.63 µm, Flächeninhalt: 30308.03 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle D2_ch00.tif, Durchmesser: 190.86 µm, Flächeninhalt: 27963.46 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle E2_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_Kontrolle E2_ch00.tif, Durchmesser: 191.21 µm, Flächeninhalt: 28066.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_P1 B11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_P1 B11_ch00.tif, Durchmesser: 180.30 µm, Flächeninhalt: 24976.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_P1 C11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_P1 C11_ch00.tif, Durchmesser: 184.56 µm, Flächeninhalt: 26161.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 500ms/step
# Segmentiertes Bild für 015_CQ Sphaeroide unbelichtet Tag 2_P1 D11_ch00.tif wurde gespeichert.
# Bild: 015_CQ Sphaeroide unbelichtet Tag 2_P1 D11_ch00.tif, Durchmesser: 183.82 µm, Flächeninhalt: 25944.32 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 B6_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 B6_ch00.tif, Durchmesser: 251.53 µm, Flächeninhalt: 48621.98 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 375ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 C6_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 C6_ch00.tif, Durchmesser: 244.42 µm, Flächeninhalt: 45827.74 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 D6_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + alpcs + p1 D6_ch00.tif, Durchmesser: 236.92 µm, Flächeninhalt: 43073.73 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 B5_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 B5_ch00.tif, Durchmesser: 237.38 µm, Flächeninhalt: 43274.95 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 C5_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 C5_ch00.tif, Durchmesser: 238.65 µm, Flächeninhalt: 43791.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 D5_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 + p1 D5_ch00.tif, Durchmesser: 250.38 µm, Flächeninhalt: 48214.31 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs B4_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs B4_ch00.tif, Durchmesser: 237.63 µm, Flächeninhalt: 43350.18 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs C4_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs C4_ch00.tif, Durchmesser: 228.13 µm, Flächeninhalt: 39980.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs D4_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 alpcs D4_ch00.tif, Durchmesser: 243.48 µm, Flächeninhalt: 45470.80 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 leer C3_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 leer C3_ch00.tif, Durchmesser: 229.88 µm, Flächeninhalt: 40548.94 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 leer D3_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 leer D3_ch00.tif, Durchmesser: 243.82 µm, Flächeninhalt: 45927.47 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_2,5 leer E3_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_2,5 leer E3_ch00.tif, Durchmesser: 247.30 µm, Flächeninhalt: 47685.90 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 B10_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 B10_ch00.tif, Durchmesser: 241.08 µm, Flächeninhalt: 44620.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 C10_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 C10_ch00.tif, Durchmesser: 225.56 µm, Flächeninhalt: 39070.45 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 D10_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs + p1 D10_ch00.tif, Durchmesser: 234.11 µm, Flächeninhalt: 42053.67 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs B8_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs B8_ch00.tif, Durchmesser: 243.80 µm, Flächeninhalt: 45593.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs D8_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs D8_ch00.tif, Durchmesser: 227.18 µm, Flächeninhalt: 39612.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_5 + alpcs E8_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_5 + alpcs E8_ch00.tif, Durchmesser: 227.94 µm, Flächeninhalt: 39889.31 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_alpcs E11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_alpcs E11_ch00.tif, Durchmesser: 261.82 µm, Flächeninhalt: 52630.51 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_alpcs F11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_alpcs F11_ch00.tif, Durchmesser: 253.23 µm, Flächeninhalt: 49206.38 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_alpcs G11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_alpcs G11_ch00.tif, Durchmesser: 251.10 µm, Flächeninhalt: 48431.27 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_Kontrolle C2_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_Kontrolle C2_ch00.tif, Durchmesser: 258.17 µm, Flächeninhalt: 51120.53 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_Kontrolle D2_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_Kontrolle D2_ch00.tif, Durchmesser: 248.06 µm, Flächeninhalt: 47237.98 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_Kontrolle E2_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_Kontrolle E2_ch00.tif, Durchmesser: 248.65 µm, Flächeninhalt: 47442.69 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_P1 B11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_P1 B11_ch00.tif, Durchmesser: 228.58 µm, Flächeninhalt: 40157.01 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_P1 C11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_P1 C11_ch00.tif, Durchmesser: 234.25 µm, Flächeninhalt: 42149.90 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# Segmentiertes Bild für 016_Sphaeroide unbelichtet Tag 5_P1 D11_ch00.tif wurde gespeichert.
# Bild: 016_Sphaeroide unbelichtet Tag 5_P1 D11_ch00.tif, Durchmesser: 233.04 µm, Flächeninhalt: 41693.23 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 + alpcs + p1 2_ch00.tif, Durchmesser: 259.32 µm, Flächeninhalt: 51605.19 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 + alpcs + p1 3_ch00.tif, Durchmesser: 257.10 µm, Flächeninhalt: 50718.10 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 440ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer + alpcs 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer + alpcs 1_ch00.tif, Durchmesser: 257.05 µm, Flächeninhalt: 50698.86 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer + alpcs 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer + alpcs 2_ch00.tif, Durchmesser: 254.04 µm, Flächeninhalt: 49524.82 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer + alpcs 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer + alpcs 3_ch00.tif, Durchmesser: 260.93 µm, Flächeninhalt: 52217.58 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer 1_ch00.tif, Durchmesser: 247.30 µm, Flächeninhalt: 46928.29 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer 2_ch00.tif, Durchmesser: 262.16 µm, Flächeninhalt: 52968.20 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 leer 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 leer 3_ch00.tif, Durchmesser: 270.29 µm, Flächeninhalt: 57230.43 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_2,5 p1 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_2,5 p1 1_ch00.tif, Durchmesser: 256.48 µm, Flächeninhalt: 50508.14 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs + p1 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs + p1 1_ch00.tif, Durchmesser: 258.51 µm, Flächeninhalt: 51285.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs + p1 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs + p1 2_ch00.tif, Durchmesser: 246.40 µm, Flächeninhalt: 46562.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs + p1 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs + p1 3_ch00.tif, Durchmesser: 255.15 µm, Flächeninhalt: 49969.24 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs 1_ch00.tif, Durchmesser: 261.80 µm, Flächeninhalt: 52564.02 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs 2_ch00.tif, Durchmesser: 247.84 µm, Flächeninhalt: 47134.75 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_5 + alpcs 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_5 + alpcs 3_ch00.tif, Durchmesser: 247.87 µm, Flächeninhalt: 47112.00 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_alpcs 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_alpcs 1_ch00.tif, Durchmesser: 283.92 µm, Flächeninhalt: 61814.60 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_alpcs 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_alpcs 2_ch00.tif, Durchmesser: 278.83 µm, Flächeninhalt: 59665.99 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_alpcs 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_alpcs 3_ch00.tif, Durchmesser: 273.27 µm, Flächeninhalt: 57274.17 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_Kontreolle 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_Kontreolle 1_ch00.tif, Durchmesser: 278.36 µm, Flächeninhalt: 59433.28 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_Kontrolle 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_Kontrolle 2_ch00.tif, Durchmesser: 268.45 µm, Flächeninhalt: 55332.02 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_Kontrolle 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_Kontrolle 3_ch00.tif, Durchmesser: 271.47 µm, Flächeninhalt: 56576.05 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_p1 1_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_p1 1_ch00.tif, Durchmesser: 248.55 µm, Flächeninhalt: 47421.70 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_p1 2_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_p1 2_ch00.tif, Durchmesser: 256.80 µm, Flächeninhalt: 50618.37 µm²
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# Segmentiertes Bild für 017_Tag 7 unbelichtet_p1 3_ch00.tif wurde gespeichert.
# Bild: 017_Tag 7 unbelichtet_p1 3_ch00.tif, Durchmesser: 257.49 µm, Flächeninhalt: 50942.06 µm²
# Anzahl der erfolgreichen Vorhersagen: 357
# Anzahl der zugehörigen manuellen Durchmesser: 357
#
# Metriken zur Bewertung der Modellgenauigkeit:
# MAE (Mean Absolute Error): 2.07 µm
# MSE (Mean Squared Error): 11.75 µm²
# R2 Score (Coefficient of Determination): 0.99
# Ergebnisse und Metriken wurden in C:/Users/chris/Documents/Master/Sphaeroidauswertung/Ergebnisse/Durchmesser Liste mit dropout 3.xlsx gespeichert.
